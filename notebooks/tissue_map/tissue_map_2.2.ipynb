# %% [markdown]
# # Version 2.2
# - Adds optional patterns for "redundant" terms in the matcher
#     - If final term is "redundant" then regex operator "?" added to final term
#
#
# ## Issues
# - Creates may falso positives from having 'cell' as an optional term

# %%
from owlready2 import *
import pandas as pd
import re
import spacy
import xml.sax
import csv
import importlib
import tissue_eval
from spacy.matcher import Matcher
from spacy.tokenizer import Tokenizer
# Out:
# * Owlready2 * Warning: optimized Cython parser module 'owlready2_optimized' is not available, defaulting to slower Python implementation
#
# Warning: SQLite3 version 3.40.0 and 3.41.2 have huge performance regressions; please install version 3.41.1 or 3.42!

# %%
# Load the BTO ontology
onto_path.append('../../data/ontologies/')
onto = get_ontology('http://purl.obolibrary.org/obo/bto.owl').load()

# classes dictionary: {class_name: class_label} 
#   - class_label is None if no label is found
# class_synonyms dictionary: {class_name: [synonym1, synonym2, ...]}
#   - synonym list is empty if no synonym is found
classes = {c.name: c.label.first() for c in onto.classes()}
class_synonyms = {c.name: c.hasExactSynonym + c.hasRelatedSynonym for c in onto.classes()}

# added possible missing synonyms
class_synonyms['BTO_0000440'] = class_synonyms['BTO_0000440'] + ['stool']

# create a reverse mapping of classes and synonyms to BTO IDs
classes_reverse = {c.label.first().lower(): c.name for c in onto.classes() if c.label != []}
class_synonyms_reverse = {s.lower(): c for c, syn in class_synonyms.items() for s in syn}
labels_reverse = {**classes_reverse, **class_synonyms_reverse}

assert len(classes) == len(class_synonyms)
print('Number of classes:', len(classes))

# flatten the synonyms and class labels into a single set
class_labels = {c for c in classes.values() if c is not None}
class_synonyms_flattend = {s for syn in class_synonyms.values() for s in syn}
bto_values = class_labels.union(class_synonyms_flattend)
# Out:
# Number of classes: 6569

# %%
# creates a spacy matcher to match patterns of BRENDA terms and synonyms
#  - patterns are created by tokenizing the BRENDA terms and synonyms
#  - matcher looks at only direct matches

redundant_end_terms = ['tissue', 'tissues', 'cell', 'cells']

nlp = spacy.load('en_core_web_sm')
matcher = Matcher(nlp.vocab)
tokenizer = Tokenizer(nlp.vocab)

patterns = []

for bto_value in bto_values:
    pattern = [{'LOWER': token.lower_} for token in tokenizer(bto_value)]

    # make any redundant terms optional
    if pattern[-1]['LOWER'] in redundant_end_terms:
        pattern[-1]['OP'] = '?'


    patterns.append(pattern)
    

matcher.add('bto', patterns, greedy='LONGEST')

# %%
class BioSamplesMatcherHandler(xml.sax.ContentHandler):
    def __init__(self, sample_dict) -> None:
        super().__init__()
        self.sample_dict = sample_dict
        self.attribute_dict = {}
        self.biosample_id = ''
        self.content_dict = {}
        self.is_title = False
        self.is_paragraph = False
        self.attribute_name = ''

    def startElement(self, name, attrs):
        if name == 'BioSample':
            self.biosample_id = attrs['accession']
        elif name == 'Title':
            self.is_title = True
        elif name == 'Paragraph':
            self.is_paragraph = True
        elif name == 'Attribute':
            try:
                self.attribute_name = attrs['harmonized_name']
            except KeyError:
                self.attribute_name = attrs['attribute_name']

    def characters(self, content):
        if self.is_title:
            self.content_dict['title'] = content
            self.is_title = False
        elif self.is_paragraph:
            self.content_dict['paragraph'] = content
            self.is_paragraph = False
        elif self.attribute_name != '':
            self.attribute_dict[self.attribute_name] = content
            self.attribute_name = ''
        

    def endElement(self, name):
        if name == 'BioSample':
            self.content_dict['attributes'] = self.attribute_dict
            self.sample_dict[self.biosample_id] = self.content_dict
            self.attribute_dict = {}
            self.content_dict = {}
    
    def endDocument(self):
        print('Finished parsing BioSamples XML file')

# %%
sample_dict = {}
biosamples_path = '../../data/biosamples/biosample_random_samples.xml'

parser = xml.sax.make_parser()
handler = BioSamplesMatcherHandler(sample_dict)
parser.setContentHandler(handler)

parser.parse(biosamples_path)
print('Number of samples:', len(sample_dict))
# Out:
# Finished parsing BioSamples XML file
# Number of samples: 10000

# %%
# adds a regex pattern to the default tokenizer to split on underscores
nlp = spacy.load('en_core_web_lg')
tokenizer = nlp.tokenizer

infixes = nlp.Defaults.infixes + [r'[_~]']
infix_re = spacy.util.compile_infix_regex(infixes)
tokenizer.infix_finditer = infix_re.finditer

# %%
matches_dict = {}

# finds all returned matches from the matcher
# - matcher looks at the title, paragraph, and attributes
# - returns a dictionary of matches for each sample

for biosample_id, content_dict in sample_dict.items():
    cur_matches = {}
    title = content_dict['title']
    attributes = content_dict['attributes'] # dictionary of attributes

    title_tokens = tokenizer(title)
    attributes_tokens = {key: tokenizer(value) for key, value in attributes.items()}

    title_matches = matcher(title_tokens, as_spans=True)
    attribute_matches = {}
    for key, value in attributes_tokens.items():
        attribute_match = matcher(value, as_spans=True)
        if len(attribute_match) > 0:
            attribute_matches[key] = matcher(value, as_spans=True)


    if len(title_matches) > 0:
        cur_matches['title'] = title_matches
    if len(attribute_matches) > 0:
        cur_matches['attributes'] = attribute_matches

    if 'paragraph' in content_dict:
        paragraph = content_dict['paragraph']
        paragraph_tokens = tokenizer(paragraph)
        paragraph_matches = matcher(paragraph_tokens, as_spans=True)
        
        if len(paragraph_matches) > 0:
            cur_matches['paragraph'] = paragraph_matches

    
    matches_dict[biosample_id] = cur_matches

# %%
import pprint
pprint.pprint(matches_dict)
# Out:
# {'SAMD00000683': {},
#  'SAMD00006380': {},
#  'SAMD00014374': {'attributes': {'sample comment': [Root]}},
#  'SAMD00021033': {'attributes': {'project_name': [medium]}, 'paragraph': [GSC]},
#  'SAMD00021226': {'title': [Smooth muscle]},
#  'SAMD00036614': {},
#  'SAMD00049287': {'attributes': {'estimated_size': [M]}, 'paragraph': [GSC]},
#  'SAMD00050272': {'attributes': {'elev': [m],
#                                  'env_medium': [soil],
#                                  'project_name': [soil]},
#                   'paragraph': [GSC],
#                   'title': [soil]},
#  'SAMD00056207': {'attributes': {'depth': [m]}, 'paragraph': [GSC]},
#  'SAMD00060149': {'attributes': {'env_local_scale': [oral cavity]},
#                   'paragraph': [GSC]},
#  'SAMD00060847': {'paragraph': [GSC]},
#  'SAMD00061605': {'paragraph': [GSC]},
#  'SAMD00078983': {'attributes': {'cell_line': [N2A]}, 'paragraph': [N2A]},
#  'SAMD00079210': {'attributes': {'env_local_scale': [Satellite]},
#                   'paragraph': [GSC],
#                   'title': [satellite]},
#  'SAMD00091260': {'title': [ES]},
#  'SAMD00098583': {'attributes': {'env_broad_scale': [plant],
#                                  'sample_name': [M-1]},
#                   'paragraph': [GSC]},
#  'SAMD00100214': {'attributes': {'env_medium': [plant],
#                                  'project_name': [root, fungi]},
#                   'paragraph': [GSC]},
#  'SAMD00107974': {'attributes': {'project_name': [gut]}, 'paragraph': [GSC]},
#  'SAMD00115040': {'attributes': {'env_medium': [feces], 'project_name': [gut]},
#                   'paragraph': [GSC],
#                   'title': [feces]},
#  'SAMD00118585': {'attributes': {'propagation': [vegetative],
#                                  'tissue': [mature]},
#                   'paragraph': [GSC]},
#  'SAMD00119977': {'attributes': {'cell_line': [H1299], 'sample_name': [H1299]},
#                   'title': [H1299]},
#  'SAMD00121723': {'attributes': {'cell_line': [H1975], 'sample_name': [H1975]},
#                   'title': [H1975]},
#  'SAMD00122745': {},
#  'SAMD00129084': {'paragraph': [GSC]},
#  'SAMD00130755': {'attributes': {'env_medium': [root]}, 'paragraph': [GSC]},
#  'SAMD00133768': {'attributes': {'strain': [Hos],
#                                  'tissue': [pancreatic islet]}},
#  'SAMD00133797': {'attributes': {'env_broad_scale': [plant],
#                                  'sample_name': [granular]},
#                   'paragraph': [GSC]},
#  'SAMD00134506': {'attributes': {'env_medium': [stool]},
#                   'paragraph': [GSC],
#                   'title': [gut]},
#  'SAMD00142065': {'attributes': {'cell_type': [B cell]},
#                   'paragraph': [B, lymphoblast],
#                   'title': [Blood]},
#  'SAMD00154357': {'attributes': {'env_medium': [feces], 'project_name': [gut]},
#                   'paragraph': [GSC],
#                   'title': [pregnant]},
#  'SAMD00154869': {'attributes': {'cell_type': [ES cell],
#                                  'tissue': [blastocyst]}},
#  'SAMD00157588': {'attributes': {'elev': [m],
#                                  'project_name': [soil],
#                                  'sample_name': [Soil]},
#                   'paragraph': [GSC]},
#  'SAMD00158380': {'attributes': {'project_name': [gut],
#                                  'ref_biomaterial': [gut]},
#                   'paragraph': [GSC]},
#  'SAMD00158574': {'attributes': {'project_name': [gut],
#                                  'ref_biomaterial': [gut]},
#                   'paragraph': [GSC]},
#  'SAMD00165112': {'attributes': {'project_name': [Delta]}, 'paragraph': [GSC]},
#  'SAMD00171651': {'paragraph': [GSC]},
#  'SAMD00176343': {'attributes': {'disease_stage': [infected],
#                                  'env_medium': [blood],
#                                  'project_name': [B, infected],
#                                  'samp_mat_process': [blood],
#                                  'sample_name': [B]},
#                   'paragraph': [GSC],
#                   'title': [blood]},
#  'SAMD00192567': {'paragraph': [GSC]},
#  'SAMD00192749': {},
#  'SAMD00195195': {'attributes': {'dev_stage': [larva], 'tissue': [gut]}},
#  'SAMD00199674': {},
#  'SAMD00203185': {'paragraph': [GSC]},
#  'SAMD00209188': {'attributes': {'project_name': [Gut]}, 'paragraph': [GSC]},
#  'SAMD00219821': {'attributes': {'cell_line': [T]}},
#  'SAMD00223822': {'attributes': {'env_medium': [Feces]}, 'paragraph': [GSC]},
#  'SAMD00226417': {'attributes': {'elev': [m], 'env_medium': [soil]},
#                   'paragraph': [GSC]},
#  'SAMD00231066': {'attributes': {'depth': [m], 'sample_name': [m]},
#                   'paragraph': [GSC],
#                   'title': [m]},
#  'SAMD00235438': {'paragraph': [GSC]},
#  'SAMD00239440': {'attributes': {'cell_line': [A2058],
#                                  'sample_name': [A2058, Cnt]},
#                   'title': [A2058, Cnt]},
#  'SAMD00239942': {'paragraph': [stem]},
#  'SAMD00243312': {'attributes': {'env_medium': [feces], 'project_name': [gut]},
#                   'paragraph': [GSC]},
#  'SAMD00244426': {'attributes': {'env_broad_scale': [gut],
#                                  'env_local_scale': [gut],
#                                  'occupation': [Nurse],
#                                  'project_name': [infected]},
#                   'paragraph': [GSC],
#                   'title': [infected]},
#  'SAMD00247029': {'paragraph': [GSC]},
#  'SAMD00250814': {'paragraph': [GSC]},
#  'SAMD00255893': {},
#  'SAMD00258792': {'attributes': {'env_broad_scale': [animal],
#                                  'env_local_scale': [feces],
#                                  'project_name': [feces]},
#                   'paragraph': [GSC],
#                   'title': [gut]},
#  'SAMD00268369': {'paragraph': [GSC]},
#  'SAMD00269220': {'paragraph': [GSC]},
#  'SAMD00275592': {'paragraph': [GSC]},
#  'SAMD00285598': {'attributes': {'env_medium': [feces],
#                                  'project_name': [colorectal cancer,
#                                                   gut,
#                                                   secretion]},
#                   'paragraph': [GSC],
#                   'title': [gut, feces]},
#  'SAMD00289717': {'paragraph': [GSC]},
#  'SAMD00290206': {'paragraph': [GSC]},
#  'SAMD00290484': {'paragraph': [GSC]},
#  'SAMD00318011': {'attributes': {'env_local_scale': [honey],
#                                  'env_medium': [honey],
#                                  'project_name': [honey],
#                                  'samp_mat_process': [whole body]},
#                   'paragraph': [GSC]},
#  'SAMD00321647': {},
#  'SAMD00324423': {},
#  'SAMD00326789': {'paragraph': [GSC]},
#  'SAMD00333936': {'paragraph': [GSC]},
#  'SAMD00334798': {'attributes': {'env_medium': [feces], 'project_name': [Gut]},
#                   'paragraph': [GSC],
#                   'title': [gut]},
#  'SAMD00335229': {'title': [asm]},
#  'SAMD00347441': {'title': [asm]},
#  'SAMD00348350': {'title': [asm]},
#  'SAMD00349721': {'title': [asm]},
#  'SAMD00353948': {'title': [asm]},
#  'SAMD00355846': {'title': [asm]},
#  'SAMD00358349': {'title': [asm]},
#  'SAMD00358973': {'title': [asm]},
#  'SAMD00361343': {'title': [asm]},
#  'SAMD00361752': {'title': [asm]},
#  'SAMD00362489': {'title': [asm]},
#  'SAMD00363370': {'title': [asm]},
#  'SAMD00379836': {'title': [asm]},
#  'SAMD00386246': {'title': [asm]},
#  'SAMD00392262': {},
#  'SAMD00392533': {'attributes': {'tissue': [whole body]}},
#  'SAMD00400369': {'paragraph': [GSC]},
#  'SAMD00409303': {'attributes': {'env_medium': [feces], 'project_name': [gut]},
#                   'paragraph': [GSC],
#                   'title': [gut, feces]},
#  'SAMD00410182': {'attributes': {'env_medium': [feces], 'project_name': [gut]},
#                   'paragraph': [GSC],
#                   'title': [gut, feces]},
#  'SAMD00417280': {'paragraph': [GSC]},
#  'SAMD00418393': {'paragraph': [GSC]},
#  'SAMD00422182': {'paragraph': [GSC]},
#  'SAMD00422312': {'paragraph': [GSC]},
#  'SAMD00436052': {'paragraph': [m]},
#  'SAMD00439565': {'attributes': {'sample_name': [Root], 'tissue': [Root]},
#                   'title': [Root]},
#  'SAMD00440745': {'attributes': {'env_medium': [soil]},
#                   'paragraph': [GSC],
#                   'title': [root]},
#  'SAMD00445797': {'attributes': {'geo_loc_name': [Ishikawa]},
#                   'paragraph': [GSC]},
#  'SAMD00446207': {'paragraph': [GSC]},
#  'SAMD00449314': {},
#  'SAMD00452549': {'attributes': {'sample_name': [SR]},
#                   'paragraph': [GSC],
#                   'title': [SR]},
#  'SAMD00470677': {'attributes': {'metagenome_source': [gut],
#                                  'source_material_id': [gut]},
#                   'paragraph': [GSC],
#                   'title': [gut]},
#  'SAMD00474532': {'attributes': {'metagenome_source': [gut],
#                                  'source_material_id': [gut]},
#                   'paragraph': [GSC],
#                   'title': [gut]},
#  'SAMD00480906': {'attributes': {'metagenome_source': [gut],
#                                  'source_material_id': [gut]},
#                   'paragraph': [GSC],
#                   'title': [gut]},
#  'SAMD00481281': {'attributes': {'metagenome_source': [gut],
#                                  'source_material_id': [gut]},
#                   'paragraph': [GSC],
#                   'title': [gut]},
#  'SAMD00482197': {'attributes': {'metagenome_source': [gut],
#                                  'source_material_id': [gut]},
#                   'paragraph': [GSC],
#                   'title': [gut]},
#  'SAMD00485407': {'attributes': {'metagenome_source': [gut],
#                                  'source_material_id': [gut]},
#                   'paragraph': [GSC],
#                   'title': [gut]},
#  'SAMD00487933': {'attributes': {'metagenome_source': [gut],
#                                  'source_material_id': [gut]},
#                   'paragraph': [GSC],
#                   'title': [gut]},
#  'SAMD00491831': {},
#  'SAMD00495969': {'attributes': {'serotype': [H7]}, 'paragraph': [GSC]},
#  'SAMD00498219': {'attributes': {'isolation_source': [sputum]}},
#  'SAMD00500253': {'attributes': {'isolation_source': [urine]}},
#  'SAMD00505775': {'attributes': {'sample_name': [B], 'tissue': [Leaf]},
#                   'title': [B]},
#  'SAMD00506627': {'attributes': {'dev_stage': [Adult], 'tissue': [muscle]}},
#  'SAMD00520696': {'attributes': {'depth': [m],
#                                  'geo_loc_name': [Seta],
#                                  'tissue': [muscle]}},
#  'SAMD00529505': {'attributes': {'feed': [M], 'tissue': [Kidney]},
#                   'paragraph': [Kidney],
#                   'title': [Kidney]},
#  'SAMD00532289': {},
#  'SAMD00536809': {'attributes': {'isolation_source': [soil],
#                                  'sample_type': [cell culture]}},
#  'SAMD00537191': {'attributes': {'isolation_source': [soil],
#                                  'sample_type': [cell culture]}},
#  'SAMD00537705': {'attributes': {'sample_type': [cell culture]}},
#  'SAMD00537819': {'attributes': {'isolation_source': [Tuber],
#                                  'sample_type': [cell culture]}},
#  'SAMD00539715': {'attributes': {'isolation_source': [soil],
#                                  'sample_type': [cell culture]}},
#  'SAMD00540977': {'attributes': {'isolation_source': [oil],
#                                  'sample_type': [cell culture]}},
#  'SAMD00542553': {'attributes': {'isolation_source': [soil],
#                                  'sample_type': [cell culture]}},
#  'SAMD00549931': {},
#  'SAMD00563702': {'paragraph': [GSC]},
#  'SAMD00564173': {'paragraph': [GSC]},
#  'SAMD00565464': {'attributes': {'env_medium': [soil]},
#                   'paragraph': [GSC],
#                   'title': [soil]},
#  'SAMD00593873': {},
#  'SAMEA10037587': {},
#  'SAMEA10038694': {},
#  'SAMEA10041202': {},
#  'SAMEA10045181': {},
#  'SAMEA10045658': {},
#  'SAMEA10048278': {},
#  'SAMEA10050026': {},
#  'SAMEA10050791': {},
#  'SAMEA10087941': {},
#  'SAMEA10089965': {},
#  'SAMEA10093458': {},
#  'SAMEA10104672': {},
#  'SAMEA10107178': {},
#  'SAMEA10107687': {},
#  'SAMEA10111151': {},
#  'SAMEA10112748': {},
#  'SAMEA10112801': {},
#  'SAMEA10123733': {},
#  'SAMEA10124027': {},
#  'SAMEA10126423': {},
#  'SAMEA10132668': {},
#  'SAMEA10133613': {},
#  'SAMEA10136337': {},
#  'SAMEA10144230': {},
#  'SAMEA10145454': {},
#  'SAMEA10146260': {},
#  'SAMEA10146274': {},
#  'SAMEA10150663': {},
#  'SAMEA10158188': {},
#  'SAMEA10164433': {},
#  'SAMEA10168143': {},
#  'SAMEA10169385': {},
#  'SAMEA10170624': {},
#  'SAMEA10178158': {},
#  'SAMEA10179491': {},
#  'SAMEA10179894': {},
#  'SAMEA10181163': {},
#  'SAMEA10183560': {},
#  'SAMEA10184226': {},
#  'SAMEA10184294': {'attributes': {'INSDC center alias': [HSC],
#                                   'INSDC center name': [HSC],
#                                   'collecting institution': [HSC]}},
#  'SAMEA10185453': {},
#  'SAMEA10196828': {},
#  'SAMEA10196867': {},
#  'SAMEA10198171': {'attributes': {'INSDC center alias': [HSC],
#                                   'INSDC center name': [HSC],
#                                   'collecting institution': [HSC]}},
#  'SAMEA10198540': {},
#  'SAMEA10201648': {'attributes': {'broker name': [Plant],
#                                   'life_stage': [adult],
#                                   'tissue': [SOMATIC, ANIMAL]}},
#  'SAMEA10206676': {},
#  'SAMEA10207979': {},
#  'SAMEA10219570': {},
#  'SAMEA10233996': {},
#  'SAMEA10235300': {},
#  'SAMEA10235730': {},
#  'SAMEA10240129': {},
#  'SAMEA10244880': {},
#  'SAMEA10245996': {},
#  'SAMEA10246828': {},
#  'SAMEA10247249': {},
#  'SAMEA10250033': {},
#  'SAMEA10252446': {'attributes': {'INSDC center alias': [HSC],
#                                   'INSDC center name': [HSC],
#                                   'collecting institution': [HSC]}},
#  'SAMEA10260621': {'paragraph': [M, B]},
#  'SAMEA10263283': {},
#  'SAMEA10275290': {},
#  'SAMEA10276660': {},
#  'SAMEA10278948': {},
#  'SAMEA10286239': {},
#  'SAMEA10286741': {},
#  'SAMEA10293434': {},
#  'SAMEA10296069': {},
#  'SAMEA10304256': {},
#  'SAMEA10304618': {},
#  'SAMEA10305825': {},
#  'SAMEA10313618': {'attributes': {'empo_2': [Animal],
#                                   'empo_3': [Animal, gut],
#                                   'env_medium': [feces],
#                                   'env_package': [gut],
#                                   'host_body_habitat': [feces],
#                                   'host_body_product': [feces],
#                                   'host_life_stage': [adult],
#                                   'host_tissue_sampled': [feces],
#                                   'sample_type': [stool]}},
#  'SAMEA1032131': {},
#  'SAMEA10336021': {},
#  'SAMEA10345050': {},
#  'SAMEA10352489': {},
#  'SAMEA10355855': {},
#  'SAMEA10357914': {},
#  'SAMEA10358780': {},
#  'SAMEA10360693': {},
#  'SAMEA10361463': {},
#  'SAMEA10361870': {},
#  'SAMEA10373766': {},
#  'SAMEA10376134': {},
#  'SAMEA10379035': {},
#  'SAMEA10380729': {},
#  'SAMEA10383647': {},
#  'SAMEA103886841': {'attributes': {'dev_stage': [adult], 'tissue': [pons]},
#                     'paragraph': [pons, adult]},
#  'SAMEA103893905': {'attributes': {'Submitter Id': [T],
#                                    'disease': [pancreatic ductal adenocarcinoma],
#                                    'sample_name': [T],
#                                    'xenograft': [pancreatic cancer]},
#                     'title': [T]},
#  'SAMEA103899634': {'attributes': {'common name': [fungus],
#                                    'env_medium': [Leaf]},
#                     'paragraph': [Leaf]},
#  'SAMEA103899666': {'attributes': {'common name': [fungus],
#                                    'env_medium': [Leaf]},
#                     'paragraph': [Leaf]},
#  'SAMEA103899725': {},
#  'SAMEA103917609': {'attributes': {'ArrayExpress-SPECIES': [Plasmodium]}},
#  'SAMEA103921040': {'attributes': {'body_habitat': [skin],
#                                    'body_product': [sebum],
#                                    'env_local_scale': [animal],
#                                    'env_medium': [sebum],
#                                    'life_stage': [adult],
#                                    'sample_type': [skin],
#                                    'tissue': [skin]},
#                     'paragraph': [trunk]},
#  'SAMEA103923374': {'attributes': {'INSDC center alias': [Stem],
#                                    'INSDC center name': [Stem],
#                                    'Submitter Id': [H10],
#                                    'cell_type': [blood cell],
#                                    'dev_stage': [adult],
#                                    'sample_name': [H10],
#                                    'single cell well quality': [OK],
#                                    'strain': [Fin],
#                                    'tissue': [kidney]},
#                     'paragraph': [kidney, serum, Kidney, spike],
#                     'title': [H10]},
#  'SAMEA103925718': {'attributes': {'ArrayExpress-SPECIES': [Plasmodium]}},
#  'SAMEA103927633': {'attributes': {'cell_type': [T cell, CD4],
#                                    'infection': [Plasmodium]},
#                     'paragraph': [RBC,
#                                   T,
#                                   CD4,
#                                   APC,
#                                   APC,
#                                   A20,
#                                   Dendritic,
#                                   APC,
#                                   T,
#                                   Dendritic,
#                                   dendritic,
#                                   Inflammatory,
#                                   Plasmodium,
#                                   infected,
#                                   blood,
#                                   blood,
#                                   tail,
#                                   spike]},
#  'SAMEA10392773': {},
#  'SAMEA103931655': {},
#  'SAMEA103934949': {},
#  'SAMEA103940321': {},
#  'SAMEA103943268': {'attributes': {'ArrayExpress-SPECIES': [Plasmodium]}},
#  'SAMEA103943433': {'attributes': {'ArrayExpress-SPECIES': [Plasmodium]}},
#  'SAMEA103944095': {'attributes': {'ArrayExpress-SPECIES': [Plasmodium]}},
#  'SAMEA103949199': {'paragraph': [Blood], 'title': [Blood]},
#  'SAMEA103951150': {},
#  'SAMEA103960493': {},
#  'SAMEA103960533': {'title': [P19]},
#  'SAMEA103960683': {},
#  'SAMEA103963944': {},
#  'SAMEA103980121': {'title': [Chondrosarcoma]},
#  'SAMEA103980205': {'title': [B]},
#  'SAMEA103984813': {},
#  'SAMEA103988719': {'attributes': {'dev_stage': [adult],
#                                    'tissue': [tracheal epithelium]},
#                     'paragraph': [tracheal epithelium]},
#  'SAMEA103989404': {'attributes': {'dev_stage': [adult],
#                                    'tissue': [adrenal cortex]},
#                     'paragraph': [adrenal cortex]},
#  'SAMEA103989850': {'attributes': {'dev_stage': [adult], 'tissue': [thymus]},
#                     'paragraph': [thymus]},
#  'SAMEA103991365': {'attributes': {'dev_stage': [adult], 'tissue': [jejunum]},
#                     'paragraph': [jejunum]},
#  'SAMEA103993929': {'attributes': {'sample_name': [b]}},
#  'SAMEA103995837': {},
#  'SAMEA103997583': {'attributes': {'tissue': [blood]}},
#  'SAMEA104009137': {'attributes': {'genotype': [somatic], 'tissue': [blood]}},
#  'SAMEA104010179': {'attributes': {'tissue': [Bronchial Epithelium]}},
#  'SAMEA104014988': {},
#  'SAMEA104017475': {},
#  'SAMEA104019308': {'attributes': {'ArrayExpress-SPECIES': [Plasmodium]}},
#  'SAMEA104026421': {'attributes': {'strain': [NA]}},
#  'SAMEA104027358': {'attributes': {'INSDC center alias': [SERUM],
#                                    'INSDC center name': [SERUM]}},
#  'SAMEA104035637': {'attributes': {'isolation_source': [blood]}},
#  'SAMEA104057154': {'attributes': {'ArrayExpress-SPECIES': [Plasmodium]}},
#  'SAMEA104062044': {},
#  'SAMEA104063701': {},
#  'SAMEA10406407': {},
#  'SAMEA104064851': {},
#  'SAMEA104076804': {},
#  'SAMEA104081356': {},
#  'SAMEA104081449': {},
#  'SAMEA104088204': {},
#  'SAMEA104092061': {'attributes': {'tissue': [embryo]}},
#  'SAMEA104099125': {},
#  'SAMEA104100940': {},
#  'SAMEA10410254': {},
#  'SAMEA104103877': {},
#  'SAMEA104104289': {},
#  'SAMEA104104525': {},
#  'SAMEA104120348': {'attributes': {'phenotype': [Brain]}},
#  'SAMEA104124504': {'attributes': {'INSDC center alias': [Plant],
#                                    'INSDC center name': [Plant],
#                                    'genotype': [Shoot, phloem, companion],
#                                    'tissue': [phloem companion, shoot]},
#                     'paragraph': [shoot, shoot, phloem, companion]},
#  'SAMEA104132512': {},
#  'SAMEA104137914': {},
#  'SAMEA104140143': {'attributes': {'env_local_scale': [soil],
#                                    'env_medium': [Soil],
#                                    'soil environmental package': [soil]}},
#  'SAMEA104140940': {'attributes': {'age': [adult],
#                                    'collected_by': [Iris],
#                                    'common name': [feces]}},
#  'SAMEA104141281': {},
#  'SAMEA104144045': {},
#  'SAMEA104146908': {},
#  'SAMEA104148537': {},
#  'SAMEA104148645': {},
#  'SAMEA104150936': {'attributes': {'common name': [M]}, 'paragraph': [plasma]},
#  'SAMEA104159584': {},
#  'SAMEA104160281': {},
#  'SAMEA104160576': {},
#  'SAMEA10416604': {},
#  'SAMEA104181591': {'attributes': {'env_local_scale': [plant],
#                                    'env_medium': [soil],
#                                    'env_package': [soil],
#                                    'sample_type': [soil]}},
#  'SAMEA104189786': {'attributes': {'Submitter Id': [C8],
#                                    'cell_type': [fibroblast],
#                                    'sample_name': [C8],
#                                    'tissue': [dermis]},
#                     'paragraph': [growth medium,
#                                   all,
#                                   skin,
#                                   skin,
#                                   fibroblast,
#                                   Fibroblast,
#                                   Basal,
#                                   Medium,
#                                   Fibroblast,
#                                   serum,
#                                   Spike,
#                                   head],
#                     'title': [C8]},
#  'SAMEA104190649': {'attributes': {'common name': [feces]}},
#  'SAMEA104203658': {'attributes': {'cell_line': [fibroblast],
#                                    'cell_type': [fibroblast],
#                                    'tissue': [dermis]},
#                     'paragraph': [all, Serum, B]},
#  'SAMEA104204959': {'attributes': {'Submitter Id': [2008],
#                                    'cell_line': [fibroblast],
#                                    'cell_type': [fibroblast],
#                                    'sample_name': [2008],
#                                    'tissue': [dermis]},
#                     'paragraph': [all, Serum, B],
#                     'title': [2008]},
#  'SAMEA104205968': {'attributes': {'Submitter Id': [R1],
#                                    'isolate': [R1],
#                                    'sample_name': [R1],
#                                    'strain': [R1]}},
#  'SAMEA104206525': {'attributes': {'body_habitat': [feces],
#                                    'body_product': [feces],
#                                    'bowel_movement_quality': [stool],
#                                    'dominant_hand': [am],
#                                    'env_medium': [feces],
#                                    'env_package': [gut],
#                                    'fed_as_infant': [breast, milk],
#                                    'sample_type': [Stool],
#                                    'tissue': [feces]},
#                     'paragraph': [Gut, Stool],
#                     'title': [Gut]},
#  'SAMEA104210617': {'attributes': {'Submitter Id': [S1],
#                                    'sample_name': [S1],
#                                    'soil environmental package': [soil]}},
#  'SAMEA104219321': {},
#  'SAMEA104220999': {'paragraph': [faeces], 'title': [f5]},
#  'SAMEA104225526': {'attributes': {'ArrayExpress-SPECIES': [pallidum, pallidum],
#                                    'common name': [pallidum, pallidum],
#                                    'sub_species': [pallidum]}},
#  'SAMEA104229780': {'attributes': {'env_local_scale': [mouth],
#                                    'env_medium': [saliva],
#                                    'host disease status': [Burkitt lymphoma],
#                                    'host_body_product': [saliva]},
#                     'paragraph': [Saliva]},
#  'SAMEA104231295': {'attributes': {'Submitter Id': [B],
#                                    'env_local_scale': [soil],
#                                    'env_medium': [soil],
#                                    'sample_name': [B],
#                                    'soil environmental package': [soil]},
#                     'paragraph': [soil],
#                     'title': [B]},
#  'SAMEA10424331': {},
#  'SAMEA104244444': {},
#  'SAMEA104245643': {'attributes': {'dev_stage': [scale], 'tissue': [seedling]}},
#  'SAMEA104246459': {'attributes': {'sample_name': [b]}},
#  'SAMEA104252190': {},
#  'SAMEA104255718': {'attributes': {'tissue': [whole blood]}},
#  'SAMEA104257705': {'attributes': {'dev_stage': [adult],
#                                    'tissue': [animal, ovary]}},
#  'SAMEA104263357': {'attributes': {'clinical history': [carcinoma],
#                                    'dev_stage': [adult],
#                                    'tissue': [mammary gland]}},
#  'SAMEA104264163': {'attributes': {'sample_name': [b]}},
#  'SAMEA104266464': {'attributes': {'cell_type': [peripheral blood mononuclear cell]}},
#  'SAMEA104270077': {'attributes': {'disease': [lung cancer],
#                                    'phenotype': [lung],
#                                    'tissue': [lung]}},
#  'SAMEA104270468': {'attributes': {'cell_type': [epithelial cell],
#                                    'tissue': [bronchus]}},
#  'SAMEA104270499': {'attributes': {'cell_line': [NHBE cell],
#                                    'cell_type': [epithelial cell],
#                                    'tissue': [bronchus]}},
#  'SAMEA104270891': {'attributes': {'sample_name': [muscle],
#                                    'tissue': [muscle]}},
#  'SAMEA104275450': {},
#  'SAMEA104278753': {},
#  'SAMEA104288468': {'attributes': {'Submitter Id': [m],
#                                    'plant-associated environmental package': [plant],
#                                    'sample_name': [m]},
#                     'title': [m]},
#  'SAMEA104292376': {},
#  'SAMEA104297496': {},
#  'SAMEA104298116': {},
#  'SAMEA104301738': {},
#  'SAMEA104303000': {'attributes': {'Submitter Id': [na],
#                                    'env_medium': [Colon],
#                                    'sample_name': [na]}},
#  'SAMEA104306271': {'attributes': {'body_habitat': [feces],
#                                    'body_product': [feces],
#                                    'env_local_scale': [animalia],
#                                    'env_medium': [feces],
#                                    'sample_type': [stool],
#                                    'tissue': [feces]},
#                     'title': [gut]},
#  'SAMEA104307973': {'paragraph': [T]},
#  'SAMEA104322278': {'attributes': {'cell_type': [memory T cell,
#                                                  CD4,
#                                                  alpha,
#                                                  beta],
#                                    'tissue': [spleen]},
#                     'paragraph': [melanoma,
#                                   melanoma,
#                                   melanoma,
#                                   lymph,
#                                   spleen,
#                                   skin,
#                                   lymph,
#                                   spleen,
#                                   skin,
#                                   B,
#                                   Lymph,
#                                   all,
#                                   skin,
#                                   Spike]},
#  'SAMEA10432325': {'attributes': {'INSDC center alias': [HSC],
#                                   'INSDC center name': [HSC],
#                                   'collecting institution': [HSC]}},
#  'SAMEA104323318': {'attributes': {'cell_type': [T cell, CD4, alpha, beta],
#                                    'individual': [skin],
#                                    'tissue': [skin]},
#                     'paragraph': [Peripheral blood mononuclear cell,
#                                   CD4,
#                                   T,
#                                   skin,
#                                   skin,
#                                   reticular,
#                                   dermis,
#                                   fat,
#                                   skin,
#                                   skin,
#                                   skin,
#                                   colon,
#                                   bowel,
#                                   mucosa,
#                                   epithelial,
#                                   mononuclear,
#                                   g,
#                                   blood,
#                                   skin,
#                                   serum,
#                                   medium,
#                                   L,
#                                   serum,
#                                   Spike]},
#  'SAMEA10433473': {},
#  'SAMEA104341813': {},
#  'SAMEA104352403': {},
#  'SAMEA104356212': {'attributes': {'env_medium': [feces],
#                                    'human gut environmental package': [gut]}},
#  'SAMEA104372159': {},
#  'SAMEA104372533': {},
#  'SAMEA104375623': {'title': [P12]},
#  'SAMEA104376599': {},
#  'SAMEA104382892': {'attributes': {'tissue': [liver]}},
#  'SAMEA104384578': {},
#  'SAMEA104385104': {'attributes': {'cell_line': [293T]}},
#  'SAMEA104395440': {'attributes': {'INSDC center alias': [HEART, LUNG],
#                                    'INSDC center name': [HEART, LUNG]}},
#  'SAMEA104397282': {'title': [M10]},
#  'SAMEA104398512': {'attributes': {'INSDC center alias': [HEART, LUNG],
#                                    'INSDC center name': [HEART, LUNG]}},
#  'SAMEA104401214': {},
#  'SAMEA104402235': {'attributes': {'collection_date': [2008]}},
#  'SAMEA104406069': {},
#  'SAMEA104406591': {},
#  'SAMEA104407445': {},
#  'SAMEA104426229': {},
#  'SAMEA104426821': {},
#  'SAMEA104434767': {},
#  'SAMEA104440944': {},
#  'SAMEA104449880': {},
#  'SAMEA104456546': {},
#  'SAMEA104459099': {},
#  'SAMEA104459600': {'attributes': {'cell or tissue type': [frontal cortex]},
#                     'paragraph': [frontal cortex]},
#  'SAMEA104461098': {},
#  'SAMEA10446277': {},
#  'SAMEA10448600': {},
#  'SAMEA104493871': {'attributes': {'cell_type': [pluripotent stem cell]}},
#  'SAMEA104494573': {'attributes': {'sample_name': [B]}},
#  'SAMEA104495988': {'attributes': {'cell_line': [ES],
#                                    'cell_type': [embryonic stem cell],
#                                    'sample_name': [E14]}},
#  'SAMEA104497231': {},
#  'SAMEA104587420': {},
#  'SAMEA104587614': {},
#  'SAMEA104588610': {'attributes': {'env_medium': [Soil],
#                                    'geographic location (longitude)': [E14]},
#                     'paragraph': [plant],
#                     'title': [soil]},
#  'SAMEA104589900': {'paragraph': [AML]},
#  'SAMEA10459075': {},
#  'SAMEA104595668': {},
#  'SAMEA104598588': {},
#  'SAMEA104599530': {'attributes': {'Submitter Id': [R1], 'sample_name': [R1]}},
#  'SAMEA104610364': {'attributes': {'subject id': [Th2]}},
#  'SAMEA10461644': {},
#  'SAMEA104618068': {'attributes': {'external sample id': [C2],
#                                    'tissue': [airway epithelial]}},
#  'SAMEA104625844': {'title': [Colorectal Cancer]},
#  'SAMEA104626313': {'attributes': {'tissue': [epidermis]}},
#  'SAMEA104630696': {'attributes': {'biological material altitude': [m],
#                                    'biological material preprocessing': [seed,
#                                                                          plant],
#                                    'description': [T, leaf, cap],
#                                    'plant anatomical entity': [leaf],
#                                    'plant structure development stage': [seedling]}},
#  'SAMEA104631899': {},
#  'SAMEA104635674': {'attributes': {'biological material altitude': [m],
#                                    'biological material preprocessing': [seed,
#                                                                          plant],
#                                    'description': [T, leaf, cap],
#                                    'plant anatomical entity': [leaf],
#                                    'plant structure development stage': [seedling]}},
#  'SAMEA104636702': {'attributes': {'biological material altitude': [m],
#                                    'biological material preprocessing': [seed,
#                                                                          plant],
#                                    'description': [T, leaf, cap],
#                                    'plant anatomical entity': [leaf],
#                                    'plant structure development stage': [seedling]}},
#  'SAMEA104637583': {'attributes': {'biological material altitude': [m],
#                                    'biological material preprocessing': [seed,
#                                                                          plant],
#                                    'description': [T, leaf, cap],
#                                    'plant anatomical entity': [leaf],
#                                    'plant structure development stage': [seedling]}},
#  'SAMEA104640411': {'paragraph': [m, m, m, m, m]},
#  'SAMEA104656051': {'attributes': {'meso_shoot_id': [b]}},
#  'SAMEA104656436': {'attributes': {'env_medium': [soil],
#                                    'project_name': [soil],
#                                    'soil environmental package': [soil]},
#                     'title': [soil]},
#  'SAMEA104663083': {},
#  'SAMEA104671014': {'attributes': {'isolation source host associated': [Blood]}},
#  'SAMEA104675633': {},
#  'SAMEA104677237': {},
#  'SAMEA104681231': {},
#  'SAMEA104682433': {},
#  'SAMEA104684630': {},
#  'SAMEA10468845': {},
#  'SAMEA104699069': {'attributes': {'ArrayExpress-SPECIES': [Plasmodium]}},
#  'SAMEA104699895': {},
#  'SAMEA104704509': {},
#  'SAMEA104704832': {},
#  'SAMEA104706935': {},
#  'SAMEA104707368': {'attributes': {'env_medium': [soil],
#                                    'soil environmental package': [soil]}},
#  'SAMEA104711545': {'attributes': {'ArrayExpress-SPECIES': [Plasmodium]}},
#  'SAMEA104726821': {'attributes': {'cell gating': [NK],
#                                    'dev_stage': [adult],
#                                    'tissue': [decidua]},
#                     'paragraph': [red blood cell,
#                                   red blood cell,
#                                   immune cell,
#                                   decidual,
#                                   Decidual,
#                                   medium,
#                                   medium,
#                                   Decidual,
#                                   medium,
#                                   medium,
#                                   sieve,
#                                   sieve,
#                                   placenta,
#                                   medium,
#                                   sieve,
#                                   Decidual,
#                                   blood,
#                                   all,
#                                   decidua,
#                                   B,
#                                   decidua,
#                                   b,
#                                   g,
#                                   storage]},
#  'SAMEA10539140': {},
#  'SAMEA10539414': {},
#  'SAMEA10541936': {},
#  'SAMEA10542236': {},
#  'SAMEA10542990': {},
#  'SAMEA10556076': {},
#  'SAMEA10566117': {},
#  'SAMEA10567907': {},
#  'SAMEA10568793': {},
#  'SAMEA10571151': {},
#  'SAMEA10572405': {},
#  'SAMEA10573287': {'attributes': {'INSDC center alias': [HSC],
#                                   'INSDC center name': [HSC],
#                                   'collecting institution': [HSC]}},
#  'SAMEA10585299': {},
#  'SAMEA1063701': {},
#  'SAMEA10648179': {},
#  'SAMEA10648337': {},
#  'SAMEA10656598': {},
#  'SAMEA10659173': {},
#  'SAMEA10659240': {},
#  'SAMEA10661098': {},
#  'SAMEA10662129': {},
#  'SAMEA10667950': {},
#  'SAMEA10668274': {},
#  'SAMEA10673733': {},
#  'SAMEA10676781': {},
#  'SAMEA10677773': {},
#  'SAMEA1067946': {},
#  'SAMEA10681215': {},
#  'SAMEA10685301': {},
#  'SAMEA10685972': {},
#  'SAMEA10689035': {},
#  'SAMEA10689290': {},
#  'SAMEA1069177': {'title': [Stool]},
#  'SAMEA10695597': {},
#  'SAMEA10697828': {'attributes': {'collecting institution': [Am]}},
#  'SAMEA10699129': {},
#  'SAMEA10701070': {},
#  'SAMEA10701793': {},
#  'SAMEA10703843': {},
#  'SAMEA10706183': {},
#  'SAMEA10707055': {},
#  'SAMEA10707254': {},
#  'SAMEA10707898': {},
#  'SAMEA10708823': {},
#  'SAMEA10713963': {},
#  'SAMEA10716587': {},
#  'SAMEA10717085': {},
#  'SAMEA10717458': {},
#  'SAMEA10724273': {},
#  'SAMEA10727029': {},
#  'SAMEA10727560': {},
#  'SAMEA10740302': {'paragraph': [saliva]},
#  'SAMEA10744588': {},
#  'SAMEA10766918': {},
#  'SAMEA10767627': {},
#  'SAMEA1077001': {},
#  'SAMEA10777000': {},
#  'SAMEA10780951': {},
#  'SAMEA10781661': {},
#  'SAMEA10784884': {},
#  'SAMEA10785405': {'attributes': {'INSDC center alias': [HSC],
#                                   'INSDC center name': [HSC],
#                                   'collecting institution': [HSC]}},
#  'SAMEA10788489': {},
#  'SAMEA10790378': {},
#  'SAMEA10792403': {'attributes': {'cell_type': [pericyte],
#                                   'tissue': [vasculature, brain]},
#                    'paragraph': [basal,
#                                  l,
#                                  basal,
#                                  basal,
#                                  hCMEC,
#                                  D3,
#                                  coculture,
#                                  basal]},
#  'SAMEA10793065': {'attributes': {'empo_2': [Animal],
#                                   'empo_3': [Animal, secretion],
#                                   'env_medium': [saliva],
#                                   'host_body_habitat': [saliva],
#                                   'host_body_product': [saliva],
#                                   'host_height_units': [m],
#                                   'host_tissue_sampled': [saliva],
#                                   'sample_type': [saliva]}},
#  'SAMEA10794171': {'title': [gut]},
#  'SAMEA10795062': {},
#  'SAMEA10797299': {},
#  'SAMEA10801058': {'attributes': {'dev_stage': [adult], 'tissue': [kidney]},
#                    'paragraph': [kidney]},
#  'SAMEA10801310': {'attributes': {'Submitter Id': [AML], 'sample_name': [AML]},
#                    'paragraph': [AML],
#                    'title': [AML]},
#  'SAMEA10805127': {},
#  'SAMEA10807423': {},
#  'SAMEA10814684': {'attributes': {'collecting institution': [m]}},
#  'SAMEA10818944': {'attributes': {'collecting institution': [NA]}},
#  'SAMEA10819145': {},
#  'SAMEA10819741': {},
#  'SAMEA10822999': {},
#  'SAMEA10823788': {},
#  'SAMEA10827141': {},
#  'SAMEA10828185': {},
#  'SAMEA10833496': {},
#  'SAMEA1085481': {'paragraph': [all]},
#  'SAMEA10898468': {},
#  'SAMEA10932285': {},
#  'SAMEA10935145': {},
#  'SAMEA10935712': {},
#  'SAMEA10945777': {},
#  'SAMEA10949898': {},
#  'SAMEA10962019': {},
#  'SAMEA10963348': {},
#  'SAMEA10966698': {},
#  'SAMEA10969224': {},
#  'SAMEA10972508': {},
#  'SAMEA10972928': {},
#  'SAMEA10983206': {'attributes': {'broker name': [Plant],
#                                   'habitat': [Mouth],
#                                   'life_stage': [gametophyte],
#                                   'tissue': [SHOOT]}},
#  'SAMEA10988247': {},
#  'SAMEA10993611': {},
#  'SAMEA10993896': {},
#  'SAMEA10996311': {},
#  'SAMEA10997755': {},
#  'SAMEA10999320': {},
#  'SAMEA10999926': {},
#  'SAMEA11000291': {},
#  'SAMEA110008833': {},
#  'SAMEA11001190': {},
#  'SAMEA110013350': {'attributes': {'broker name': [Plant],
#                                    'life_stage': [vegetative]}},
#  'SAMEA110015088': {'attributes': {'INSDC center alias': [Serum],
#                                    'INSDC center name': [serum],
#                                    'collecting institution': [Fungi, Serum]}},
#  'SAMEA110016965': {'attributes': {'INSDC center alias': [Serum],
#                                    'INSDC center name': [serum],
#                                    'collecting institution': [Fungi, Serum]}},
#  'SAMEA110018235': {'attributes': {'INSDC center alias': [Serum],
#                                    'INSDC center name': [serum],
#                                    'collecting institution': [Fungi, Serum]}},
#  'SAMEA11001910': {},
#  'SAMEA110021788': {},
#  'SAMEA110022816': {},
#  'SAMEA110024755': {'attributes': {'subject id': [l]}},
#  'SAMEA110034472': {'attributes': {'INSDC center alias': [Serum],
#                                    'INSDC center name': [serum],
#                                    'collecting institution': [Fungi, Serum]}},
#  'SAMEA11003902': {},
#  'SAMEA110039183': {'attributes': {'INSDC center alias': [Serum],
#                                    'INSDC center name': [serum],
#                                    'collecting institution': [Fungi, Serum]}},
#  'SAMEA110039678': {'attributes': {'INSDC center alias': [Serum],
#                                    'INSDC center name': [serum],
#                                    'collecting institution': [Fungi, Serum]}},
#  'SAMEA110042014': {},
#  'SAMEA110043299': {},
#  'SAMEA110052605': {},
#  'SAMEA110063544': {'attributes': {'INSDC center alias': [Serum],
#                                    'INSDC center name': [serum],
#                                    'collecting institution': [Fungi, Serum]}},
#  'SAMEA110066597': {'attributes': {'INSDC center alias': [Serum],
#                                    'INSDC center name': [serum],
#                                    'collecting institution': [Fungi, Serum]}},
#  'SAMEA110075927': {'attributes': {'INSDC center alias': [Serum],
#                                    'INSDC center name': [serum],
#                                    'collecting institution': [Fungi, Serum]}},
#  'SAMEA110081852': {'attributes': {'INSDC center alias': [Serum],
#                                    'INSDC center name': [serum],
#                                    'collecting institution': [Fungi, Serum]}},
#  'SAMEA110082009': {'attributes': {'INSDC center alias': [Serum],
#                                    'INSDC center name': [serum],
#                                    'collecting institution': [Fungi, Serum]}},
#  'SAMEA110082134': {'attributes': {'INSDC center alias': [Serum],
#                                    'INSDC center name': [serum],
#                                    'collecting institution': [Fungi, Serum]}},
#  'SAMEA110086314': {'attributes': {'INSDC center alias': [Serum],
#                                    'INSDC center name': [serum],
#                                    'collecting institution': [Fungi, Serum]}},
#  'SAMEA110092180': {'attributes': {'INSDC center alias': [Serum],
#                                    'INSDC center name': [serum],
#                                    'collecting institution': [Fungi, Serum]}},
#  'SAMEA110093178': {'attributes': {'INSDC center alias': [Serum],
#                                    'INSDC center name': [serum],
#                                    'collecting institution': [Fungi, Serum]}},
#  'SAMEA110099397': {'attributes': {'INSDC center alias': [Serum],
#                                    'INSDC center name': [serum],
#                                    'collecting institution': [Fungi, Serum]}},
#  'SAMEA110102563': {},
#  'SAMEA110114686': {},
#  'SAMEA110123067': {},
#  'SAMEA110131943': {},
#  'SAMEA110132813': {'paragraph': [leaf]},
#  'SAMEA110133226': {'attributes': {'empo_2': [Animal],
#                                    'empo_3': [Animal, gut],
#                                    'env_local_scale': [animal],
#                                    'env_medium': [intestine],
#                                    'host_body_product': [gut],
#                                    'host_life_stage': [adult],
#                                    'host_tissue_sampled': [cecum],
#                                    'host_weight_units': [g],
#                                    'sample_type': [cecum]}},
#  'SAMEA110140039': {},
#  'SAMEA110144365': {},
#  'SAMEA110153856': {'attributes': {'INSDC center alias': [Serum],
#                                    'INSDC center name': [serum],
#                                    'collecting institution': [Fungi, Serum]}},
#  'SAMEA110160602': {'attributes': {'INSDC center alias': [Serum],
#                                    'INSDC center name': [serum],
#                                    'collecting institution': [Fungi, Serum]}},
#  'SAMEA110165062': {'attributes': {'INSDC center alias': [Serum],
#                                    'INSDC center name': [serum],
#                                    'collecting institution': [Fungi, Serum]}},
#  'SAMEA110165705': {'attributes': {'INSDC center alias': [Serum],
#                                    'INSDC center name': [serum],
#                                    'collecting institution': [Fungi, Serum]}},
#  'SAMEA110167738': {'attributes': {'INSDC center alias': [Serum],
#                                    'INSDC center name': [serum],
#                                    'collecting institution': [Fungi, Serum]}},
#  'SAMEA110168508': {'attributes': {'INSDC center alias': [Serum],
#                                    'INSDC center name': [serum],
#                                    'collecting institution': [Fungi, Serum]}},
#  'SAMEA110178717': {'attributes': {'cell_type': [hematopoietic stem cell],
#                                    'dev_stage': [adult],
#                                    'tissue': [bone marrow]},
#                     'paragraph': [Bone marrow,
#                                   bone marrow,
#                                   Hematopoietic Progenitor,
#                                   Hematopoietic stem,
#                                   femur,
#                                   tibia,
#                                   hip,
#                                   hematopoietic,
#                                   Stem,
#                                   medium,
#                                   APC,
#                                   APC,
#                                   APC,
#                                   Stem,
#                                   All,
#                                   All,
#                                   Animal]},
#  'SAMEA110180117': {},
#  'SAMEA110184509': {},
#  'SAMEA110184823': {},
#  'SAMEA110197029': {},
#  'SAMEA110198299': {},
#  'SAMEA110199827': {},
#  'SAMEA110208485': {'attributes': {'INSDC center alias': [Serum],
#                                    'INSDC center name': [serum],
#                                    'collecting institution': [Fungi, Serum]}},
#  'SAMEA110213417': {'attributes': {'INSDC center alias': [Serum],
#                                    'INSDC center name': [serum],
#                                    'collecting institution': [Fungi, Serum]}},
#  'SAMEA110216881': {'attributes': {'INSDC center alias': [Serum],
#                                    'INSDC center name': [serum],
#                                    'collecting institution': [Fungi, Serum]}},
#  'SAMEA110216990': {'attributes': {'INSDC center alias': [Serum],
#                                    'INSDC center name': [serum],
#                                    'collecting institution': [Fungi, Serum]}},
#  'SAMEA110225458': {'attributes': {'INSDC center alias': [Serum],
#                                    'INSDC center name': [serum],
#                                    'collecting institution': [Fungi, Serum]}},
#  'SAMEA110225739': {'attributes': {'INSDC center alias': [Serum],
#                                    'INSDC center name': [serum],
#                                    'collecting institution': [Fungi, Serum]}},
#  'SAMEA110225947': {'attributes': {'INSDC center alias': [Serum],
# ...
#                                  'samp_mat_process': [dried]}},
#  'SAMN33562027': {'attributes': {'isolation_source': [soil]}, 'title': [soil]},
#  'SAMN33576137': {'paragraph': [K1]},
#  'SAMN33576678': {},
#  'SAMN33577153': {'attributes': {'env_medium': [saliva]}, 'paragraph': [GSC]},
#  'SAMN33578227': {},
#  'SAMN33593800': {'attributes': {'source_name': [leaf, rosette],
#                                  'tissue': [leaf, rosette]}},
#  'SAMN33597381': {},
#  'SAMN33599314': {},
#  'SAMN33602573': {},
#  'SAMN33608577': {},
#  'SAMN33609838': {},
#  'SAMN33613535': {},
#  'SAMN33616506': {},
#  'SAMN33618124': {},
#  'SAMN33619174': {},
#  'SAMN33621639': {'attributes': {'host': [plant]},
#                   'paragraph': [GSC],
#                   'title': [plant]},
#  'SAMN33625383': {'attributes': {'histological_type': [Buffy Coat],
#                                  'tissue': [Buffy Coat]},
#                   'title': [Buffy Coat]},
#  'SAMN33626401': {'attributes': {'histological_type': [Buffy Coat],
#                                  'tissue': [Buffy Coat]},
#                   'title': [Buffy Coat]},
#  'SAMN33627530': {'attributes': {'histological_type': [Buffy Coat],
#                                  'tissue': [Buffy Coat]},
#                   'title': [Buffy Coat]},
#  'SAMN33628431': {'attributes': {'histological_type': [Buffy Coat],
#                                  'tissue': [Buffy Coat]},
#                   'title': [Buffy Coat]},
#  'SAMN33629206': {},
#  'SAMN33631410': {'attributes': {'histological_type': [Buffy Coat],
#                                  'tissue': [Buffy Coat]},
#                   'title': [Buffy Coat]},
#  'SAMN33635313': {'attributes': {'histological_type': [Buffy Coat],
#                                  'tissue': [Buffy Coat]},
#                   'title': [Buffy Coat]},
#  'SAMN33636653': {'attributes': {'histological_type': [Buffy Coat],
#                                  'tissue': [Buffy Coat]},
#                   'title': [Buffy Coat]},
#  'SAMN33639448': {'attributes': {'histological_type': [Buffy Coat],
#                                  'tissue': [Buffy Coat]},
#                   'title': [Buffy Coat]},
#  'SAMN33641051': {'attributes': {'histological_type': [Buffy Coat],
#                                  'tissue': [Buffy Coat]},
#                   'title': [Buffy Coat]},
#  'SAMN33642500': {'attributes': {'histological_type': [Buffy Coat],
#                                  'tissue': [Buffy Coat]},
#                   'title': [Buffy Coat]},
#  'SAMN33646765': {'attributes': {'histological_type': [Buffy Coat],
#                                  'tissue': [Buffy Coat]},
#                   'title': [Buffy Coat]},
#  'SAMN33650937': {'attributes': {'histological_type': [Buffy Coat],
#                                  'tissue': [Buffy Coat]},
#                   'title': [Buffy Coat]},
#  'SAMN33651397': {'attributes': {'histological_type': [Buffy Coat],
#                                  'tissue': [Buffy Coat]},
#                   'title': [Buffy Coat]},
#  'SAMN33655055': {'attributes': {'histological_type': [Buffy Coat],
#                                  'tissue': [Buffy Coat]},
#                   'title': [Buffy Coat]},
#  'SAMN33655831': {},
#  'SAMN33656810': {'attributes': {'histological_type': [Buffy Coat],
#                                  'tissue': [Buffy Coat]},
#                   'title': [Buffy Coat]},
#  'SAMN33657298': {'attributes': {'histological_type': [Buffy Coat],
#                                  'tissue': [Buffy Coat]},
#                   'title': [Buffy Coat]},
#  'SAMN33693645': {},
#  'SAMN33702743': {'attributes': {'biospecimen_repository': [NCI],
#                                  'submitter_handle': [NCI],
#                                  'tissue': [Blood]},
#                   'title': [Blood]},
#  'SAMN33703152': {'attributes': {'biospecimen_repository': [NCI],
#                                  'study_disease': [Breast Cancer],
#                                  'submitter_handle': [NCI],
#                                  'tissue': [Blood]},
#                   'title': [Blood]},
#  'SAMN33703428': {'attributes': {'biospecimen_repository': [NCI],
#                                  'submitter_handle': [NCI],
#                                  'tissue': [Blood]},
#                   'title': [Blood]},
#  'SAMN33707108': {'attributes': {'isolation_source': [liver]}},
#  'SAMN33712753': {},
#  'SAMN33727507': {'attributes': {'age': [Embryo],
#                                  'external': [G],
#                                  'seq_batch': [G],
#                                  'tissue': [embryo]},
#                   'title': [animal]},
#  'SAMN33733290': {},
#  'SAMN33735866': {'attributes': {'biospecimen_repository_sample_id': [T],
#                                  'study_name': [Breast Cancer, Somatic],
#                                  'submitted_sample_id': [T],
#                                  'tissue': [breast]},
#                   'title': [Breast Cancer, breast, Somatic]},
#  'SAMN33739387': {'attributes': {'tissue': [gut]},
#                   'paragraph': [null],
#                   'title': [null]},
#  'SAMN33744529': {'attributes': {'tissue': [Breast]}},
#  'SAMN33745855': {'attributes': {'source_type': [animal]}},
#  'SAMN33746241': {},
#  'SAMN33752062': {'attributes': {'biospecimen_repository': [NCI],
#                                  'submitter_handle': [NCI],
#                                  'tissue': [Blood]},
#                   'title': [Blood]},
#  'SAMN33754975': {'attributes': {'source_name': [Adult, LEC]},
#                   'title': [Adult]},
#  'SAMN33770571': {'attributes': {'env_medium': [secretion],
#                                  'geo_loc_name': [es],
#                                  'host_tissue_sampled': [oropharynx]},
#                   'paragraph': [GSC]},
#  'SAMN33780239': {'attributes': {'env_medium': [soil]}, 'paragraph': [GSC]},
#  'SAMN33783537': {},
#  'SAMN33816580': {'attributes': {'GOLD Ecosystem Classification': [Leaf],
#                                  'isolation_source': [leaf]},
#                   'paragraph': [Leaf, plant],
#                   'title': [Leaf, plant]},
#  'SAMN33817039': {'attributes': {'ww_sample_site': [plant],
#                                  'ww_surv_target_1_conc_unit': [L]}},
#  'SAMN33831406': {'attributes': {'isolation_source': [feces]}},
#  'SAMN33833941': {'attributes': {'dev_stage': [seedling]}, 'title': [Plant]},
#  'SAMN33837561': {'attributes': {'cell_type': [erythroid],
#                                  'tissue': [Hematopoietic stem, progenitor]}},
#  'SAMN33863207': {'attributes': {'source_name': [infected, T],
#                                  'tissue': [lymph node]}},
#  'SAMN33866122': {'paragraph': [GSC]},
#  'SAMN33870192': {'attributes': {'tissue': [Left Ventricle]},
#                   'title': [animal]},
#  'SAMN33874244': {},
#  'SAMN33875330': {},
#  'SAMN33876383': {},
#  'SAMN33890334': {},
#  'SAMN33905008': {'attributes': {'tissue': [peripheral blood]},
#                   'title': [peripheral blood]},
#  'SAMN33906495': {'attributes': {'sample_type': [Cell culture]}},
#  'SAMN33913845': {'attributes': {'dev_stage': [Seedling], 'tissue': [leaf]},
#                   'paragraph': [F9],
#                   'title': [Plant]},
#  'SAMN33921889': {'attributes': {'isolation_source': [root]},
#                   'paragraph': [root],
#                   'title': [root]},
#  'SAMN33928951': {'attributes': {'biospecimen_repository_sample_id': [G],
#                                  'study_name': [Heart, Heart],
#                                  'submitted_sample_id': [G],
#                                  'submitted_subject_id': [G]},
#                   'title': [Heart, Heart]},
#  'SAMN33930210': {'attributes': {'study_name': [Heart, Heart]},
#                   'title': [Heart, Heart]},
#  'SAMN33937725': {},
#  'SAMN33943000': {'attributes': {'depth': [m],
#                                  'elev': [m],
#                                  'isolate': [soil, column]},
#                   'paragraph': [GSC],
#                   'title': [soil]},
#  'SAMN33950800': {'attributes': {'cell_line': [hiPSC, C10],
#                                  'cell_type': [hiPSC],
#                                  'source_name': [hiPSC, C10]},
#                   'title': [S2, hiPSC]},
#  'SAMN33954936': {'attributes': {'dev_stage': [tadpole],
#                                  'sex': [NA],
#                                  'tissue': [tail]},
#                   'title': [animal]},
#  'SAMN33957506': {'paragraph': [GSC]},
#  'SAMN33958413': {'attributes': {'sample_type': [larva, pupa]}},
#  'SAMN33963212': {},
#  'SAMN33976930': {'attributes': {'geo_loc_name': [Rd],
#                                  'isolation_source': [Soil]},
#                   'title': [soil]},
#  'SAMN33977072': {'attributes': {'geo_loc_name': [NA, NA],
#                                  'isolation_source': [Soil]},
#                   'title': [soil]},
#  'SAMN33979900': {},
#  'SAMN33992001': {},
#  'SAMN33992296': {},
#  'SAMN33994007': {},
#  'SAMN33994905': {},
#  'SAMN33999888': {},
#  'SAMN34000554': {},
#  'SAMN34047596': {},
#  'SAMN34057844': {'attributes': {'ww_sample_site': [plant],
#                                  'ww_surv_target_1_conc_unit': [L]}},
#  'SAMN34058260': {'attributes': {'ww_sample_site': [plant],
#                                  'ww_surv_target_1_conc_unit': [L]}},
#  'SAMN34060886': {'attributes': {'ww_sample_site': [plant],
#                                  'ww_surv_target_1_conc_unit': [L]}},
#  'SAMN34091537': {'paragraph': [granular]},
#  'SAMN34104218': {'paragraph': [GSC], 'title': [soil]},
#  'SAMN34127867': {'attributes': {'tissue': [gill]}, 'title': [animal]},
#  'SAMN34137290': {'attributes': {'source_name': [lung],
#                                  'tissue': [lung],
#                                  'treatment': [MCT]},
#                   'title': [MCT, M]},
#  'SAMN34139744': {},
#  'SAMN34148048': {'attributes': {'cultivar': [NA],
#                                  'env_local_scale': [T1],
#                                  'env_medium': [NA],
#                                  'geo_loc_name': [NA],
#                                  'isol_growth_condt': [NA],
#                                  'isolate': [NA],
#                                  'strain': [NA]},
#                   'paragraph': [GSC]},
#  'SAMN34150467': {'attributes': {'tissue': [Blood]}, 'title': [Blood]},
#  'SAMN34151320': {'attributes': {'tissue': [Blood]}, 'title': [Blood]},
#  'SAMN34155192': {'title': [Plant]},
#  'SAMN34167261': {},
#  'SAMN34196739': {},
#  'SAMN34218393': {'attributes': {'env_medium': [medium]}, 'paragraph': [GSC]},
#  'SAMN34218830': {'attributes': {'host_anatomical_part': [nasopharynx]}},
#  'SAMN34219469': {},
#  'SAMN34226897': {},
#  'SAMN34235804': {},
#  'SAMN34237328': {},
#  'SAMN34240077': {},
#  'SAMN34243527': {'attributes': {'biospecimen_repository_sample_id': [M],
#                                  'submitted_sample_id': [M]}},
#  'SAMN34243751': {'attributes': {'biospecimen_repository_sample_id': [M],
#                                  'submitted_sample_id': [M]}},
#  'SAMN34274175': {},
#  'SAMN34282102': {},
#  'SAMN34283003': {'attributes': {'source_name': [Brain]}, 'title': [M]},
#  'SAMN34284471': {'attributes': {'source_name': [Brain]}, 'title': [M]},
#  'SAMN34286777': {'attributes': {'cultivar': [NA],
#                                  'ecotype': [NA],
#                                  'isolate': [NA],
#                                  'strain': [NA],
#                                  'tissue': [Whole Blood]},
#                   'title': [animal]},
#  'SAMN34291660': {'attributes': {'study_name': [Tooth], 'tissue': [Saliva]},
#                   'title': [Saliva, Tooth]},
#  'SAMN34294841': {'attributes': {'source_name': [Brain]}, 'title': [M]},
#  'SAMN34298446': {'attributes': {'source_name': [Brain]}, 'title': [M]},
#  'SAMN34333167': {'attributes': {'source_name': [Brain]}, 'title': [M]},
#  'SAMN34339750': {'paragraph': [HEK293, T]},
#  'SAMN34353220': {'attributes': {'env_broad_scale': [Gland],
#                                  'env_local_scale': [NA],
#                                  'host_body_habitat': [Gland],
#                                  'host_body_product': [Gland],
#                                  'isolation_source': [Gland]},
#                   'paragraph': [GSC],
#                   'title': [gland]},
#  'SAMN34360975': {},
#  'SAMN34371493': {'attributes': {'ww_sample_site': [plant],
#                                  'ww_surv_target_1_conc_unit': [L]}},
#  'SAMN34389001': {'attributes': {'tissue': [peripheral blood]},
#                   'title': [peripheral blood]},
#  'SAMN34410301': {},
#  'SAMN34422951': {'attributes': {'source_name': [brain], 'tissue': [brain]}},
#  'SAMN34425190': {'attributes': {'source_name': [brain], 'tissue': [brain]},
#                   'title': [A7]},
#  'SAMN34432633': {'attributes': {'source_name': [brain], 'tissue': [brain]}},
#  'SAMN34432986': {'attributes': {'source_name': [brain], 'tissue': [brain]}},
#  'SAMN34439888': {'attributes': {'tissue': [Leaf]}, 'title': [Plant]},
#  'SAMN34442989': {},
#  'SAMN34473407': {'paragraph': [GSC], 'title': [gut]},
#  'SAMN34485599': {'attributes': {'source_name': [brain], 'tissue': [brain]}},
#  'SAMN34489613': {'attributes': {'source_name': [brain], 'tissue': [brain]}},
#  'SAMN34494266': {'attributes': {'source_name': [brain], 'tissue': [brain]}},
#  'SAMN34501844': {'attributes': {'source_name': [brain], 'tissue': [brain]}},
#  'SAMN34505467': {'attributes': {'source_name': [brain], 'tissue': [brain]}},
#  'SAMN34536893': {},
#  'SAMN34538029': {'attributes': {'source_name': [brain], 'tissue': [brain]},
#                   'title': [M1]},
#  'SAMN34560116': {'attributes': {'biospecimen_repository': [NCI],
#                                  'biospecimen_repository_sample_id': [Lung],
#                                  'histological_type': [Blood],
#                                  'study_name': [Lung Cancer],
#                                  'submitted_sample_id': [Lung],
#                                  'submitted_subject_id': [Lung],
#                                  'submitter_handle': [NCI],
#                                  'tissue': [Peripheral blood]},
#                   'title': [Peripheral blood, Lung Cancer]},
#  'SAMN34560610': {'attributes': {'biospecimen_repository': [NCI],
#                                  'biospecimen_repository_sample_id': [Lung],
#                                  'histological_type': [Blood],
#                                  'study_disease': [Lung],
#                                  'study_name': [Lung Cancer],
#                                  'submitted_sample_id': [Lung],
#                                  'submitted_subject_id': [Lung],
#                                  'submitter_handle': [NCI],
#                                  'tissue': [Peripheral blood]},
#                   'title': [Peripheral blood, Lung Cancer]},
#  'SAMN34564137': {'attributes': {'biospecimen_repository': [NCI],
#                                  'biospecimen_repository_sample_id': [Lung],
#                                  'histological_type': [Blood],
#                                  'study_name': [Lung Cancer],
#                                  'submitted_sample_id': [Lung],
#                                  'submitted_subject_id': [Lung],
#                                  'submitter_handle': [NCI],
#                                  'tissue': [Peripheral blood]},
#                   'title': [Peripheral blood, Lung Cancer]},
#  'SAMN34567493': {'attributes': {'host': [NA], 'isolation_source': [soil]},
#                   'title': [soil]},
#  'SAMN34573124': {},
#  'SAMN34573311': {'paragraph': [GSC], 'title': [soil]},
#  'SAMN34577227': {},
#  'SAMN34577430': {'attributes': {'env_local_scale': [soil],
#                                  'env_medium': [soil]},
#                   'paragraph': [GSC]},
#  'SAMN34577529': {'attributes': {'env_local_scale': [soil],
#                                  'env_medium': [soil]},
#                   'paragraph': [GSC]},
#  'SAMN34584030': {},
#  'SAMN34721029': {},
#  'SAMN34721207': {},
#  'SAMN34896041': {},
#  'SAMN34993370': {'attributes': {'host_tissue_sampled': [Head],
#                                  'source_type': [animal]}}}

# %%
# take the whole attribute stuff to check results


with open('../../data/biosamples/results/biosample_tissue_locations_2.2.csv', 'w') as f:
    writer = csv.writer(f)
    writer.writerow(['biosample_accession_id', 'biosample_url', 'title_match', 'paragraph_match', 'attribute_matches'])
    for biosample_id, matches in matches_dict.items():
        title_match = ''
        paragraph_match = ''
        attribute_matches = ''

        for match_type, match in matches.items():
            if match_type == 'title':
                for token in match:
                    title_match += token.text + ' '
            elif match_type == 'paragraph':
                for token in match:
                    paragraph_match += token.text + ' '
            elif match_type == 'attributes':
                for attribute, match in match.items():
                    attribute_matches += f'{attribute},'
                    for token in match:
                        attribute_matches += token.text + ' '
        
        biosample_url = f'https://www.ncbi.nlm.nih.gov/biosample/{biosample_id}'
        writer.writerow([biosample_id, biosample_url, title_match, paragraph_match, attribute_matches])


print('Finished writing results to CSV file')
# Out:
# Finished writing results to CSV file
