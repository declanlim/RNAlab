# %%
from owlready2 import *
import pandas as pd
import xml.sax
from rapidfuzz import process
# from rapidfuzz import fuzz
import rapidfuzz

# %% [markdown]
# ----
# # Loading data...
#
# - loads the BRENDA ontology OWL file
#     - loads the properties, classes and synonyms from BRENDA
#     - classes information split into names and labels
#     - properties split into annotation/object and also names and labels
# - loads the body_site_terms from a csv of manually collated terms

# %%
# load the BTO ontology
onto_path.append("/data/ontology")
onto = get_ontology("http://purl.obolibrary.org/obo/bto.owl").load()
# print(onto.base_iri)

# %%
# load class information and properties from the ontology
class_names = [c.name for c in onto.classes()]
# account for missing class labels in the ontology
class_labels = [c.label[0] if len(c.label) > 0 else '' for c in onto.classes()]
class_synonyms = {c.name: c.hasExactSynonym + c.hasRelatedSynonym for c in onto.classes()}

num_synonyms = 0

for class_label in onto.classes():
    num_synonyms += len(class_label.hasRelatedSynonym) + len(class_label.hasExactSynonym)

print("Num synonyms: ", num_synonyms)
# properties_names contains all properties, including object and annotation properties
# names list contains ontology
object_properties_names = [o.name for o in onto.object_properties()]
object_properties_labels = [o.label[0] if len(o.label) > 0 else o.name for o in onto.object_properties()]

annotation_properties_names = [a.name for a in onto.annotation_properties()]
annotation_properties_labels = [a.label[0] if len(a.label) > 0 else a.name for a in onto.annotation_properties()]

properties_names = [p.name for p in onto.properties()]
properties_labels = [p.label[0] if len(p.label) > 0 else p.name for p in onto.properties()]

print("Number of classes: ", len(class_names))
print(class_synonyms)
# Out:
# Num synonyms:  6210
# Number of classes:  6569
# {'BTO_0000000': [], 'BTO_0000001': [], 'BTO_0000002': [], 'BTO_0000003': [], 'BTO_0000004': [], 'BTO_0000005': [], 'BTO_0000006': [], 'BTO_0000007': ['293 cell', 'A-293 cell', 'A293 cell', 'HEK cell', 'HEK293 cell', 'human embryonal kidney cell', 'human embryonic kidney cell'], 'BTO_0000008': [], 'BTO_0000009': [], 'BTO_0000010': [], 'BTO_0000011': ['NIH3T3-L1 cell'], 'BTO_0000012': [], 'BTO_0000013': [], 'BTO_0000014': [], 'BTO_0000015': [], 'BTO_0000016': ['A172 cell'], 'BTO_0000017': ['A431 cell'], 'BTO_0000018': ['A549 cell', 'NCI-A549 cell'], 'BTO_0000019': [], 'BTO_0000020': ['abdominal cavity'], 'BTO_0000021': [], 'BTO_0000022': ['visceral ganglion'], 'BTO_0000023': ['breast muscle', 'pectoralis muscle'], 'BTO_0000024': ['fourth stomach'], 'BTO_0000025': [], 'BTO_0000026': [], 'BTO_0000027': [], 'BTO_0000028': ['exocrine pancreas cell', 'pancreatic acinus'], 'BTO_0000029': ['long adductor muscle', 'musculus adductor longus'], 'BTO_0000030': ['adductor muscle'], 'BTO_0000031': [], 'BTO_0000032': ['adenocarcinoma cell, colon', 'colon adenocarcinoma cell'], 'BTO_0000033': ['SW403 cell'], 'BTO_0000034': [], 'BTO_0000035': ['adenocarcinoma cell, colorectal'], 'BTO_0000036': ['adenocarcinoma cell of the stomach', 'gastric carcinoma cell'], 'BTO_0000037': ['CCRCC cell', "Grawitz's tumor cell", 'adenocarcinoma cell of kidney', 'clear cell carcinoma cell', 'clear cell renal cell carcinoma cell', 'clear-cell renal cell carcinoma cell', 'hypernephroid carcinoma cell', 'hypernephroma cell', 'kidney adenocarcinoma cell', 'renal adenocarcinoma cell'], 'BTO_0000038': ['SW480 cell'], 'BTO_0000039': [], 'BTO_0000040': ['anterior hypophysis', 'anterior lobe of pituitary', 'anterior pituitary', 'anterior pituitary gland'], 'BTO_0000041': ['metepencephalon'], 'BTO_0000042': ['Tier', 'animalia', 'metazoa'], 'BTO_0000043': ['cortex cerebellaris'], 'BTO_0000044': ['lacrimal gland'], 'BTO_0000045': ['adrenal gland cortex', 'cortex glandulae suprarenalis', 'cortex of adrenal gland', 'cortex of suprarenal gland', 'suprarenal cortex'], 'BTO_0000046': ['Y1 cell'], 'BTO_0000047': ['adrenal', 'adrenal capsule', 'atrabiliary capsule', 'epinephros', 'glandula suprarenalis', 'paranephros', 'suprarenal capsule', 'suprarenal gland'], 'BTO_0000048': ['glomerulosa'], 'BTO_0000049': ['medulla of adrenal gland', 'medulla of glandula suprarenalis', 'medulla of suprarenal gland', 'suprarenal medulla'], 'BTO_0000050': [], 'BTO_0000051': [], 'BTO_0000052': ['stomatal complex'], 'BTO_0000053': [], 'BTO_0000054': [], 'BTO_0000055': ['pars recta tubuli renalis'], 'BTO_0000056': ['zona reticularis'], 'BTO_0000057': ['aleurone'], 'BTO_0000058': ['alimentary tract', 'digestive canal', 'digestive system', 'digestive tract', 'digestive tube'], 'BTO_0000059': ['kidney epithelium'], 'BTO_0000060': ['air sac', 'alveoli'], 'BTO_0000061': [], 'BTO_0000062': ['Leishman-Donovan body', 'aflagellate form', 'leishmanial form', 'micromastigote', 'spheromastigote'], 'BTO_0000063': [], 'BTO_0000064': ['Chorioamnion'], 'BTO_0000065': [], 'BTO_0000066': ['amniotic cell'], 'BTO_0000067': ['renal cell line'], 'BTO_0000068': ['acqua amnii', 'liquor amnii'], 'BTO_0000069': [], 'BTO_0000070': ['fungus cell line'], 'BTO_0000071': [], 'BTO_0000072': ['pistil'], 'BTO_0000073': [], 'BTO_0000074': ['feeler'], 'BTO_0000075': [], 'BTO_0000076': [], 'BTO_0000077': [], 'BTO_0000078': ['Hortega cell', 'microglial cell', 'microgliocyte'], 'BTO_0000079': [], 'BTO_0000080': [], 'BTO_0000081': ['Geschlechtsorgan', 'animal reproductive system', 'genital system', 'genitalia', 'organa genitalia', 'reproductive tissue', 'reproductive tract'], 'BTO_0000082': ['male genital organ', 'male genital system', 'male genitalia', 'systema genitale masculinum'], 'BTO_0000083': ['female genital system', 'female genitalia', 'gynaecological tissue', 'systema genitale femininum'], 'BTO_0000084': ['appendix'], 'BTO_0000085': [], 'BTO_0000086': [], 'BTO_0000087': ['arterial smooth muscle cell'], 'BTO_0000088': ['CV system', ...

# %%
# load the list of annotated body_site terms
body_site_terms = pd.read_csv("data/BioAnnotate_rh-body_site.csv", header=None)
body_site_terms = body_site_terms[0].tolist()
body_site_terms = set(body_site_terms)
body_site_string = " ".join(body_site_terms)
# print("sample_tissue_type" in body_site_terms)
# print(body_site_string)

# %% [markdown]
# ----
# # Parsing the Biosamples files
# - BioSamplesDictHandler looks at all the attributes for each biosample
#     - uses a fuzzy search to find the attribute that has the highest similarity to the attribute names in the body_site_terms
# - BioSamplesPackageHandler looks for 'useful' packages and finds the appropriate information

# %%
# load a single biosamples XML file. File 699 used due to smaller size
# SAX parser used to avoid memory issues - CAN IN THEORY LOAD ALL BIOSAMPLES IN ONE FILE
biosamples_path = "data/biosamples/biosample_set.699.xml"
# biosamples_path = "data/biosamples/biosample_small.xml"

class BioSamplesDictHandler(xml.sax.ContentHandler):
    def __init__(self):
        super().__init__()
        # self.is_tissue_attribute = False
        self.attribute_name = ""
        self.num_samples = 0
        # self.num_attributes = 0
        # self.tissue_sample_count = 0
        self.attribute_dict = {}
        self.sample_dict = {}
        self.biosample_id = ""

    def startElement(self, tag_name, tag_attrs):
        if tag_name == "BioSample":
            self.num_samples += 1
            self.biosample_id = tag_attrs["id"]

        elif tag_name == "Attribute":
            self.attribute_name = tag_attrs["attribute_name"]
            # self.num_attributes += 1
  
            
    def characters(self, content):
        if self.attribute_name != "":
            self.attribute_dict[self.attribute_name] = content
            self.attribute_name = ""


    def endElement(self, name):
        if name == "Attributes":
            if self.attribute_dict != {}:
                for key in self.attribute_dict.keys():
                    result = process.extractOne(key, body_site_terms, scorer=rapidfuzz.fuzz.ratio)
                    if result[1] > 87:
                        self.sample_dict[self.biosample_id] = (key, self.attribute_dict[key])
                        break
                    else:
                        self.sample_dict[self.biosample_id] = None
            self.attribute_dict = {}

    def endDocument(self):
        print("num_samples: ", self.num_samples)
        print(self.sample_dict)
        # print(len(self.sample_dict))
        print(len([x for x in self.sample_dict.values() if x is not None]))
        # print the key value pairs in the sample dict that don't have None as the value in a list
        print([x for x in self.sample_dict.items() if x[1] is not None])

parser = xml.sax.make_parser()
handler = BioSamplesDictHandler()
parser.setContentHandler(handler)
parser.parse(biosamples_path)


# using a direct lookup from body_site_terms, 45m 22.9s
# num_samples: 32526809
# num_tissue_samples: 6492612

# 17718
# 40839

# token sort ratio
# 3121
# Out:
# num_samples:  17718
# {'32338113': None, '32338114': None, '32338115': None, '32338116': None, '32338117': None, '32338118': None, '32338119': None, '32338120': None, '32338121': None, '32338122': None, '32338123': None, '32338229': None, '32338230': None, '32338231': None, '32338232': None, '32338233': None, '32338234': None, '32338235': None, '32338236': None, '32338237': None, '32338238': None, '32338239': None, '32338240': None, '32338241': None, '32338242': None, '32338243': None, '32338244': None, '32338245': None, '32338246': None, '32338247': None, '32338248': None, '32338249': None, '32338250': None, '32338251': None, '32338252': None, '32338253': None, '32338254': None, '32338255': None, '32338256': None, '32338257': None, '32338258': None, '32338259': None, '32338260': None, '32338261': None, '32338262': None, '32338263': None, '32338264': None, '32338265': None, '32338266': None, '32338267': None, '32338268': None, '32338269': None, '32338270': None, '32338271': None, '32338272': None, '32338273': None, '32338274': None, '32338275': None, '32338276': None, '32338282': ('tissue', 'Tillering node'), '32338283': ('tissue', 'Tillering node'), '32338284': ('tissue', 'Tillering node'), '32338285': ('tissue', 'Tillering node'), '32338286': ('tissue', 'Tillering node'), '32338287': ('tissue', 'Tillering node'), '32338288': ('tissue', 'Tillering node'), '32338289': ('tissue', 'Tillering node'), '32338290': ('tissue', 'Tillering node'), '32338291': ('tissue', 'Tillering node'), '32338292': ('tissue', 'Tillering node'), '32338293': ('tissue', 'Tillering node'), '32338294': ('tissue', 'Tillering node'), '32338295': ('tissue', 'Tillering node'), '32338296': ('tissue', 'Tillering node'), '32338297': ('tissue', 'Tillering node'), '32338298': ('tissue', 'Tillering node'), '32338299': ('tissue', 'Tillering node'), '32338333': None, '32338334': None, '32338335': None, '32338336': None, '32338337': None, '32338338': None, '32338339': None, '32338340': None, '32338341': None, '32338359': None, '32338360': None, '32338361': None, '32338362': None, '32338363': None, '32338364': None, '32338365': None, '32338366': None, '32338367': None, '32338368': None, '32338369': None, '32338370': None, '32338371': None, '32338372': None, '32338373': None, '32338374': None, '32338375': None, '32338376': None, '32338377': None, '32338378': None, '32338379': None, '32338380': None, '32338381': None, '32338382': None, '32338383': None, '32338384': None, '32338385': None, '32338386': None, '32338387': None, '32338388': None, '32338389': None, '32338390': None, '32338391': None, '32338392': None, '32338393': None, '32338394': None, '32338395': None, '32338396': None, '32338397': None, '32338398': None, '32338399': None, '32338400': None, '32338401': None, '32338402': None, '32338403': None, '32338404': None, '32338405': None, '32338406': None, '32338407': None, '32338408': None, '32338409': None, '32338410': None, '32338411': None, '32338412': None, '32338413': None, '32338414': None, '32338415': None, '32338416': None, '32338417': None, '32338418': None, '32338419': None, '32338420': None, '32338421': None, '32338422': None, '32338423': None, '32338428': None, '32338429': None, '32338430': None, '32338431': None, '32338432': None, '32338433': None, '32338434': None, '32338435': None, '32338436': None, '32338437': None, '32338438': None, '32338439': None, '32338440': None, '32338441': None, '32338442': None, '32338443': None, '32338444': None, '32338445': None, '32338446': None, '32338447': None, '32338448': None, '32338449': None, '32338450': None, '32338451': None, '32338452': None, '32338453': None, '32338454': None, '32338455': None, '32338456': None, '32338457': None, '32338458': None, '32338459': None, '32338460': None, '32338461': None, '32338462': None, '32338463': None, '32338464': None, '32338465': None, '32338466': None, '32338467': None, '32338468': None, '32338469': None, '32338470': None, '32338471': None, '32338472': None, '32338473': None, '32338474': None, '32 ...
# 2996
# [('32338282', ('tissue', 'Tillering node')), ('32338283', ('tissue', 'Tillering node')), ('32338284', ('tissue', 'Tillering node')), ('32338285', ('tissue', 'Tillering node')), ('32338286', ('tissue', 'Tillering node')), ('32338287', ('tissue', 'Tillering node')), ('32338288', ('tissue', 'Tillering node')), ('32338289', ('tissue', 'Tillering node')), ('32338290', ('tissue', 'Tillering node')), ('32338291', ('tissue', 'Tillering node')), ('32338292', ('tissue', 'Tillering node')), ('32338293', ('tissue', 'Tillering node')), ('32338294', ('tissue', 'Tillering node')), ('32338295', ('tissue', 'Tillering node')), ('32338296', ('tissue', 'Tillering node')), ('32338297', ('tissue', 'Tillering node')), ('32338298', ('tissue', 'Tillering node')), ('32338299', ('tissue', 'Tillering node')), ('32338602', ('tissue', 'stomach')), ('32338603', ('tissue', 'stomach')), ('32338604', ('tissue', 'stomach')), ('32338605', ('tissue', 'stomach')), ('32338606', ('tissue', 'stomach')), ('32338607', ('tissue', 'stomach')), ('32338608', ('tissue', 'stomach')), ('32338609', ('tissue', 'stomach')), ('32338610', ('tissue', 'stomach')), ('32338611', ('tissue', 'stomach')), ('32338612', ('tissue', 'stomach')), ('32338613', ('tissue', 'stomach')), ('32338614', ('tissue', 'stomach')), ('32338615', ('tissue', 'stomach')), ('32338825', ('tissue', 'Canine Mammary Tumor Cell')), ('32338826', ('tissue', 'Canine Mammary Tumor Cell')), ('32338827', ('tissue', 'Canine Mammary Tumor Cell')), ('32338828', ('tissue', 'Canine Mammary Tumor Cell')), ('32338829', ('tissue', 'Canine Mammary Tumor Cell')), ('32338830', ('tissue', 'Canine Mammary Tumor Cell')), ('32338831', ('tissue', 'Canine Mammary Tumor Cell')), ('32338832', ('tissue', 'Canine Mammary Tumor Cell')), ('32338833', ('tissue', 'Canine Mammary Tumor Cell')), ('32338834', ('tissue', 'Canine Mammary Tumor Cell')), ('32338835', ('tissue', 'Canine Mammary Tumor Cell')), ('32338836', ('tissue', 'Canine Mammary Tumor Cell')), ('32338863', ('tissue', 'muscle')), ('32339020', ('tissue', 'leaf 2-11')), ('32339021', ('tissue', 'leaf 2-11')), ('32339022', ('tissue', 'leaf 2-11')), ('32339023', ('tissue', 'leaf 2-28')), ('32339024', ('tissue', 'leaf 2-28')), ('32339025', ('tissue', 'leaf 2-28')), ('32339026', ('tissue', 'leaf 2-7')), ('32339027', ('tissue', 'leaf 2-7')), ('32339028', ('tissue', 'leaf 2-7')), ('32339029', ('tissue', 'leaf 4-13')), ('32339030', ('tissue', 'leaf 4-13')), ('32339031', ('tissue', 'leaf 4-13')), ('32339032', ('tissue', 'leaf 4-5')), ('32339033', ('tissue', 'leaf 4-5')), ('32339034', ('tissue', 'leaf 4-5')), ('32339035', ('tissue', 'leaf 4-7')), ('32339036', ('tissue', 'leaf 4-7')), ('32339037', ('tissue', 'leaf 4-7')), ('32339038', ('tissue', 'leaf 4-9')), ('32339039', ('tissue', 'leaf 4-9')), ('32339040', ('tissue', 'leaf 4-9')), ('32339046', ('tissue', 'Leaves-CK1')), ('32339047', ('tissue', 'Leaves-CK2')), ('32339048', ('tissue', 'Leaves-CK3')), ('32339049', ('tissue', 'Leaves-drought1')), ('32339050', ('tissue', 'Leaves-drought2')), ('32339051', ('tissue', 'Leaves-drought3')), ('32339052', ('tissue', 'LeavesCK1')), ('32339053', ('tissue', 'LeavesCK2')), ('32339054', ('tissue', 'LeavesCK3')), ('32339055', ('tissue', 'Leavesdrought1')), ('32339056', ('tissue', 'Leavesdrought2')), ('32339057', ('tissue', 'Leavesdrought3')), ('32339221', ('tissue', 'foot')), ('32339278', ('tissue', 'Gill')), ('32339279', ('tissue', 'Gill')), ('32339280', ('tissue', 'Gill')), ('32339281', ('tissue', 'Gill')), ('32339282', ('tissue', 'Gill')), ('32339283', ('tissue', 'Gill')), ('32339284', ('tissue', 'Gill')), ('32339285', ('tissue', 'Gill')), ('32339286', ('tissue', 'Gill')), ('32339289', ('tissue', 'Brain')), ('32339290', ('tissue', 'Brain')), ('32339291', ('tissue', 'Brain')), ('32339292', ('tissue', 'Brain')), ('32339293', ('tissue', 'Brain')), ('32339294', ('tissue', 'Brain')), ('32339295', ('tissue', 'Brain')), ('32339296', ('tissue', 'Brain')), ('32339297', ('tissue', 'Brain')), ('32339298', ('tissue', 'Br ...

# %%
templates_path = "data/biosamples/templates_xml/"
biosamples_packages_xml_path = "data/biosamples/biosample_packages.xml"
packages_list = []

class TemplateNamesHander(xml.sax.ContentHandler):
    def __init__(self, templates_list) -> None:
        super().__init__()
        # self.templates = []
        self.is_name = False

    def startElement(self, name, attrs):
        if name == "Name":
            self.is_name = True

    def characters(self, content):
        if self.is_name:
            packages_list.append(content)
            self.is_name = False    
    
parser = xml.sax.make_parser()
parser.setContentHandler(TemplateNamesHander(templates_list=packages_list))
parser.parse(biosamples_packages_xml_path)


'''
- Reads the xml file for each package and extracts the mandatory attributes
- Mandatory attributes for a single package will be stored in a set
    - attributes where at least one in a group is required will be stored in a list

- All data will be stored in a dictionary where the key is the package name and the value is a list of mandatory attributes
'''
class MandatoryAttributeHandler(xml.sax.ContentHandler):
    def __init__(self, attributes_list) -> None:
        super().__init__()
        self.attributes_list = attributes_list
        self.is_mandatory_attribute = False
        self.group_name = None
        self.is_harmonized_name = False
        self.mandatory_groups = {}

    def startElement(self, name, attrs):
        if name == "Attribute":
            use = attrs["use"]
            if use == "optional":
                pass
            elif use == "mandatory":
                self.is_mandatory_attribute = True
            elif use == "either_one_mandatory":
                self.group_name = attrs["group_name"]
                self.is_mandatory_attribute = True
        elif name == "HarmonizedName":
            self.is_harmonized_name = True

    def characters(self, content):
        if self.is_mandatory_attribute and self.is_harmonized_name:
            if self.group_name is None:
                self.attributes_list.append(content)
            else:
                # group name is not None therefore the attribute is part of a group 
                # attribute name added to dictionary with group name as key
                if self.group_name in self.mandatory_groups:
                    self.mandatory_groups[self.group_name].append(content)
                else:
                    self.mandatory_groups[self.group_name] = [content]
                self.group_name = None
            
            self.is_mandatory_attribute = False
            self.is_harmonized_name = False

    def endDocument(self):
        for group in self.mandatory_groups.items():
            self.attributes_list.append(group)
        attribute_list = self.attributes_list


attributes_dict = {}
for package in packages_list:
    with open("data/biosamples/templates_xml/" + package + ".xml") as f:
        attribute_list = []
        parser = xml.sax.make_parser()
        parser.setContentHandler(MandatoryAttributeHandler(attribute_list))
        parser.parse(f)
        attributes_dict[package] = attribute_list

# %%
biosamples_path = "data/biosamples/biosample_random_samples.xml"
possible_tissue = {"cell_line", "cell_subtype", "cell_type", "host_tissue_sampled", "sample_type", "tissue", "host_anatomical_part", "isolation_source", "source_name", "source_type", "strain", "subclone", "subgroup"}
# possible_tissue = {"tissue"}
import pprint

class BioSamplesPackageHandler(xml.sax.ContentHandler):
    def __init__(self, useful_packages, attributes_dict):
        super().__init__()
        self.useful_packages = useful_packages
        self.attributes_dict = attributes_dict
        self.is_package = False
        self.package_name = ""
        self.target_attributes = set()
        self.num_samples = 0
        self.biosample_id = ""
        self.attribute_name = ""
        self.sample_dict = {}

    def startElement(self, name, attrs):
        if name == "BioSample":
            self.biosample_id = attrs["id"]
            self.num_samples += 1
        elif name == "Package":
            self.is_package = True
        elif name == "Attribute" and "harmonized_name" in attrs:
                self.attribute_name = attrs["harmonized_name"]

    def characters(self, content):
        if self.is_package:
            self.package_name = content
            if self.package_name in self.useful_packages:
                self.target_attributes = possible_tissue.intersection(set(a for a in self.attributes_dict[self.package_name] if type(a) == str))
                if len(self.target_attributes) > 1:
                    print("more than one matching package ", self.biosample_id)
            self.is_package = False

        if self.attribute_name != "":
            if self.attribute_name in self.target_attributes:
                self.sample_dict[self.biosample_id] = (self.attribute_name, content)
            self.attribute_name = ""

    def endDocument(self):
        print("num_samples: ", self.num_samples)
        # print(self.sample_dict)
        pprint.pprint(self.sample_dict)
        print(len(self.sample_dict))

# %%
useful_packages = set()
with open("data/biosamples/useful_packages.txt", "r") as f:
    for package in f.readlines():
        useful_packages.add(package.strip())


parser = xml.sax.make_parser()
handler = BioSamplesPackageHandler(useful_packages, attributes_dict)
parser.setContentHandler(handler)
parser.parse(biosamples_path)
# Out:
# more than one matching package  30414169
# num_samples:  10000
# {'10037706': ('tissue', 'Whole blood'),
#  '10039586': ('isolation_source', 'missing'),
#  '10058440': ('isolation_source', 'food'),
#  '10070699': ('tissue', 'cormel'),
#  '10072908': ('tissue', 'Proximal jejunum'),
#  '10080731': ('isolation_source', 'Hospital patients'),
#  '10088371': ('tissue', 'Sputum'),
#  '10092280': ('isolation_source', 'missing'),
#  '10097534': ('isolation_source', 'human'),
#  '10104985': ('isolation_source', 'Water column'),
#  '10119081': ('tissue', 'tumor'),
#  '10128932': ('tissue', 'blood'),
#  '10142456': ('tissue', 'lung cancer'),
#  '10148089': ('tissue', 'SKIN FIBROBLASTS'),
#  '10148996': ('tissue', 'leaf'),
#  '10162994': ('tissue', 'cortex'),
#  '10163223': ('isolation_source', 'Drainage from GT site'),
#  '10178733': ('isolation_source', 'upper respiratory tract'),
#  '10179895': ('isolation_source', 'upper respiratory tract'),
#  '10182641': ('isolation_source', 'missing'),
#  '10218328': ('isolation_source', 'not applicable'),
#  '10221719': ('isolation_source', 'stool'),
#  '10222917': ('sample_type', 'metagenomic assembly'),
#  '10223709': ('sample_type', 'metagenomic assembly'),
#  '10239220': ('tissue', 'whole body'),
#  '10250336': ('tissue', 'fin clip'),
#  '10251068': ('tissue', '7 day-old whole mount seedling'),
#  '10251091': ('tissue', '7 day-old whole mount seedling'),
#  '10253602': ('isolation_source', 'clinical'),
#  '10257240': ('tissue', 'Liver'),
#  '10261766': ('isolation_source', 'animal-cattle-dairy cow'),
#  '10268665': ('tissue', 'Liver'),
#  '10273713': ('tissue', 'liver'),
#  '10280703': ('tissue', 'Liver'),
#  '10288577': ('tissue', 'Liver'),
#  '10288578': ('tissue', 'Liver'),
#  '10294455': ('tissue', 'spleen'),
#  '10294851': ('tissue', 'spleen'),
#  '10295030': ('tissue', 'spleen'),
#  '10305610': ('tissue', 'Liver'),
#  '10305865': ('tissue', 'Brain'),
#  '10306396': ('tissue', 'heart'),
#  '10306753': ('tissue', 'heart'),
#  '10306770': ('tissue', 'heart'),
#  '10320007': ('tissue', 'upper leaf'),
#  '10321799': ('tissue', 'Saliva'),
#  '10322698': ('tissue', 'Saliva'),
#  '10326188': ('tissue', 'Blood'),
#  '10369272': ('tissue', 'Peripheral Blood'),
#  '10369720': ('tissue', 'Peripheral Blood'),
#  '10372718': ('tissue', 'Peripheral Blood'),
#  '10373080': ('tissue', 'Bone marrow'),
#  '10382627': ('tissue', 'Peripheral blood'),
#  '10394479': ('tissue', 'nectar'),
#  '10400161': ('tissue', 'inner cell mass'),
#  '10405537': ('tissue', 'Lung'),
#  '10417374': ('sample_type', 'metagenomic assembly'),
#  '10425650': ('tissue', 'leaf'),
#  '10432154': ('isolation_source', 'missing'),
#  '10432940': ('isolation_source', 'human'),
#  '10436663': ('tissue', 'skin'),
#  '10438262': ('tissue', 'lung'),
#  '10444757': ('tissue', 'Blood'),
#  '10444952': ('tissue', 'Blood'),
#  '10445243': ('tissue', 'Buffy coat'),
#  '10457598': ('isolation_source', 'clinical isolate'),
#  '10457703': ('isolation_source', 'clinical isolate'),
#  '10458708': ('isolation_source', 'urine'),
#  '10464209': ('isolation_source', 'hindgut'),
#  '10484209': ('tissue', 'Leaf'),
#  '10488290': ('tissue', 'mammary tumor'),
#  '10501305': ('tissue', 'Placenta'),
#  '10505554': ('isolation_source', 'missing'),
#  '10506826': ('tissue', 'leaf'),
#  '10507055': ('tissue', 'leaf'),
#  '10507251': ('tissue', 'leaf'),
#  '10507440': ('tissue', 'leaf'),
#  '10508228': ('tissue', 'leaf'),
#  '10512103': ('tissue', 'vascular leaf'),
#  '10521872': ('isolation_source', 'human'),
#  '10523477': ('isolation_source', 'lake'),
#  '10525541': ('isolation_source', "['Marine sediment metagenome', '']"),
#  '10527736': ('isolation_source', 'child nostril 86'),
#  '10536141': ('tissue', 'pancreas'),
#  '10579885': ('isolation_source', 'missing'),
#  '10588243': ('isolation_source', 'wood branche'),
#  '10588517': ('isolation_source', 'wood branche'),
#  '10592240': ('tissue', 'leaf'),
#  '10610574': ('sample_type', 'metagenomic assembly'),
#  '10613022': ('tissue', 'Cell line'),
#  '10633369': ('tissue', 'blood'),
#  '10637578': ('tissue', 'Fat4 organoid 2'),
#  '10641765': ('tissue', 'seedlings'),
#  '10644384': ('tissue', 'liver (tumor tissue)'),
#  '10661715': ('isolation_source', 'missing'),
#  '10662759': ('tissue', 'Blood'),
#  '10670995': ('tissue', 'gallbladder'),
#  '10682815': ('tissue', 'lymph node'),
#  '10683969': ('tissue', 'leaf'),
#  '10685947': ('isolation_source', 'missing'),
#  '10689717': ('isolation_source', 'missing'),
#  '10697921': ('isolation_source', 'ocean plankton'),
#  '10713055': ('tissue', 'leaf'),
#  '10757690': ('tissue', 'Whole Blood'),
#  '10758991': ('tissue', 'Whole Blood'),
#  '10759776': ('tissue', 'Whole Blood'),
#  '10774428': ('tissue', 'whole insects'),
#  '10779052': ('tissue', 'Kidney'),
#  '10795181': ('tissue', 'bone marrow'),
#  '10828741': ('sample_type', 'Cell culture'),
#  '10844035': ('tissue', 'Cecal contents'),
#  '10853018': ('tissue', 'prostate cancer'),
#  '10862478': ('tissue', 'whole malpighian tubules'),
#  '10870425': ('tissue', 'Single acute myeloid leukemia intitiating cell'),
#  '10882751': ('tissue', 'Root'),
#  '10887371': ('strain', 'Ec-173'),
#  '10908559': ('tissue', 'Leaf'),
#  '10919884': ('isolation_source', 'missing'),
#  '10921654': ('isolation_source', 'missing'),
#  '10926408': ('isolation_source', 'missing'),
#  '10948556': ('tissue', 'blood'),
#  '10949696': ('tissue', 'Brain'),
#  '10951240': ('tissue', 'Brain'),
#  '10955039': ('tissue', 'adrenal cortex'),
#  '10961432': ('sample_type', 'whole organism'),
#  '10965976': ('sample_type', 'Culture'),
#  '10974888': ('tissue', 'Kidney'),
#  '10990790': ('tissue', 'Blood'),
#  '10997814': ('isolation_source', 'missing'),
#  '11019705': ('tissue', 'ear'),
#  '11026848': ('isolation_source', 'not collected'),
#  '11029462': ('isolation_source',
#               'Biofilm cultures acclimated in artificial seawater with 300 mg '
#               'nitrate-N/L at 23 C, methanol 0.3%'),
#  '11039701': ('isolation_source',
#               'DCD application vegetable soil (Day 21,replicate1)'),
#  '11040044': ('isolation_source', 'Breast milk'),
#  '11041277': ('isolation_source', 'Antarctic soil'),
#  '11048273': ('isolation_source', 'Zea mays'),
#  '11053121': ('isolation_source', 'Bacteria_NPK4'),
#  '11094841': ('tissue', 'whole tadpole'),
#  '11110163': ('tissue', 'body'),
#  '11116540': ('isolation_source', 'sterile site'),
#  '11125023': ('sample_type', 'cell culture'),
#  '11126947': ('strain', '105-L71-A'),
#  '11129563': ('tissue', 'tumor-1'),
#  '11132612': ('tissue', 'whole embryo'),
#  '11150893': ('tissue', 'Brain (middle temporal gyrus)'),
#  '11167516': ('tissue', 'leaf'),
#  '11169373': ('tissue', 'Peripheral Blood'),
#  '11169777': ('tissue', 'Peripheral Blood'),
#  '11170356': ('tissue', 'Peripheral Blood'),
#  '11172493': ('tissue', 'Peripheral Blood'),
#  '11175411': ('tissue', 'cells'),
#  '11179265': ('sample_type', 'cell culture'),
#  '11183865': ('sample_type', 'skin'),
#  '11184252': ('sample_type', 'wall'),
#  '11229513': ('tissue', 'frozen leaf tissue'),
#  '11239006': ('tissue', 'Saliva'),
#  '11242336': ('tissue', 'leaf'),
#  '11244396': ('tissue', 'Kidney'),
#  '11245190': ('tissue', 'Liver'),
#  '11247823': ('tissue', 'leaf'),
#  '11252572': ('tissue', 'other'),
#  '11258622': ('isolation_source', 'pig'),
#  '11263222': ('tissue', 'floral bud'),
#  '11263894': ('tissue', 'Young leaves'),
#  '11264388': ('tissue', 'Young leaves'),
#  '11266299': ('tissue', 'Dorsal root ganglion'),
#  '11285932': ('tissue', 'Primary Blood Derived Cancer - Bone Marrow'),
#  '11292258': ('tissue', 'chest muscle'),
#  '11316702': ('tissue', 'gametophyte'),
#  '11338954': ('isolation_source',
#               'pulmonary sample from from cystic fibrosis patient'),
#  '11343118': ('tissue', 'Kidney'),
#  '11362216': ('tissue', 'Blood'),
#  '11371873': ('tissue', 'Blood'),
#  '11374781': ('tissue', 'Sinoatrial'),
#  '11387980': ('tissue', 'Cochlear implant_control mucosa'),
#  '11401644': ('tissue', 'breast muscle'),
#  '11417993': ('tissue', 'hESCs'),
#  '11462128': ('tissue', 'Ewing sarcoma'),
#  '11475845': ('tissue', 'Whole body'),
#  '11476167': ('sample_type', 'Conidia'),
#  '11477096': ('isolation_source', 'chicken carcass'),
#  '11483577': ('sample_type', 'Frozen Cells'),
#  '11488869': ('tissue', 'leaf'),
#  '11494564': ('tissue', 'not applicable'),
#  '11510403': ('strain', 'WCS417 pqqC::Tn'),
#  '11512334': ('strain', '110'),
#  '11523853': ('isolation_source', 'stool'),
#  '11524200': ('isolation_source', 'sort3AwellK9'),
#  '11527368': ('sample_type', 'Tissue sample'),
#  '11534623': ('tissue', 'ear biopsy'),
#  '11541243': ('tissue', 'Peripheral blood'),
#  '11565131': ('tissue', 'Subcutaneous tumor tissue'),
#  '11566634': ('tissue', 'Spleen'),
#  '11584724': ('tissue', 'blood'),
#  '11590929': ('tissue', 'WholeBlood'),
#  '11612205': ('tissue', 'muscle'),
#  '11613477': ('tissue', 'the whole root system'),
#  '11615590': ('tissue', 'not applicable'),
#  '11620121': ('tissue', 'Bone marrow'),
#  '11642703': ('tissue', 'skin'),
#  '11646060': ('tissue', 'skin'),
#  '11649648': ('tissue', 'skin'),
#  '11658413': ('sample_type', 'cell culture'),
#  '11811966': ('tissue', 'muscle'),
#  '11828034': ('tissue', 'Heart - Left Ventricle'),
#  '11829926': ('tissue', 'Pituitary'),
#  '11830009': ('tissue', 'Skin - Not Sun Exposed (Suprapubic)'),
#  '11846001': ('tissue', 'Liver'),
#  '11849559': ('strain', 'BIOML-A131'),
#  '11849964': ('strain', 'C57BL/6J'),
#  '11854326': ('sample_type', 'pure culture'),
#  '11854585': ('tissue', 'Lung_7'),
#  '11877735': ('tissue', 'Pallial tentacle'),
#  '11890841': ('tissue', 'tea leaves'),
#  '11920491': ('tissue', 'MOUTH'),
#  '11922630': ('tissue', 'MOUTH'),
#  '11923710': ('tissue', 'MOUTH'),
#  '11924653': ('tissue', 'MOUTH'),
#  '11925777': ('tissue', 'MOUTH'),
#  '11946579': ('strain', 'BIOML-A169'),
#  '11952044': ('sample_type', 'Culture'),
#  '11954521': ('sample_type', 'Stool Swab'),
#  '11962847': ('tissue', 'stem'),
#  '11972290': ('tissue', 'Blood'),
#  '12006381': ('isolation_source', 'missing'),
#  '12013299': ('isolation_source', 'human gut'),
#  '12030368': ('isolation_source', 'human gut'),
#  '12057863': ('sample_type', 'not applicable'),
#  '12071539': ('sample_type', 'mixed cultures'),
#  '12078180': ('sample_type', 'Nasal'),
#  '12080461': ('tissue', 'whole body'),
#  '12082351': ('tissue', 'whole body'),
#  '12085308': ('tissue', 'heart'),
#  '12095047': ('tissue', 'gynoecium'),
#  '12101784': ('sample_type', 'whole organism'),
#  '12107914': ('isolation_source', 'missing'),
#  '12138196': ('isolation_source', 'CR9A'),
#  '12142523': ('isolation_source', 'missing'),
#  '12164036': ('isolation_source', 'faecal'),
#  '12164524': ('isolation_source', 'faecal'),
#  '12211534': ('isolation_source', 'subgingival plaque'),
#  '12212205': ('isolation_source', 'sputum'),
#  '12221062': ('isolation_source', 'missing'),
#  '12234444': ('strain', 'MyJU297'),
#  '12236624': ('isolation_source', 'CB-WINGS'),
#  '12237776': ('isolation_source', 'missing'),
#  '12248454': ('tissue', 'liver'),
#  '12250740': ('isolation_source', 'lung'),
#  '12251043': ('isolation_source', 'lung'),
#  '12259529': ('isolation_source', 'feces'),
#  '12276807': ('isolation_source', 'Clinic'),
#  '12283759': ('tissue', 'liver samples'),
#  '12305912': ('tissue', 'full body'),
#  '12319583': ('tissue', 'buccal mucosa'),
#  '12322213': ('tissue', 'leaf'),
#  '12322511': ('tissue', 'leaf'),
#  '12340610': ('tissue', 'leaf'),
#  '12361031': ('tissue', 'one thorax'),
#  '12361176': ('tissue', 'Bone marrow'),
#  '12389796': ('tissue', 'Leaf'),
#  '12394093': ('tissue', 'dentine'),
#  '12398496': ('tissue', 'lymph node'),
#  '12399592': ('tissue', 'leaf'),
#  '12400142': ('tissue', 'Pancreas'),
#  '12401827': ('isolation_source', 'comminuted beef'),
#  '12411271': ('tissue', 'Blood'),
#  '12415794': ('isolation_source', 'missing'),
#  '12475958': ('isolation_source', 'animal-cattle-heifer'),
#  '12484288': ('isolation_source', 'cattle rumen'),
#  '12484440': ('isolation_source', 'cattle rumen'),
#  '12486924': ('isolation_source', 'cattle rumen'),
#  '12487705': ('isolation_source', 'cattle rumen'),
#  '12488792': ('isolation_source', 'cattle rumen'),
#  '12496142': ('tissue', 'root'),
#  '12502969': ('tissue', 'breast'),
#  '12507855': ('strain', 'SESURV_p0_395'),
#  '12508019': ('strain', 'SESURV_p1_0581'),
#  '12509170': ('isolation_source', 'missing'),
#  '12511169': ('isolation_source', 'Microcosm_sample377'),
#  '12519395': ('isolation_source', 'human gut'),
#  '12541047': ('isolation_source', 'feces'),
#  '12546739': ('isolation_source', 'human'),
#  '12551182': ('isolation_source', 'sputum'),
#  '12551394': ('isolation_source', 'sputum'),
#  '12565850': ('isolation_source', 'sputum'),
#  '12573836': ('isolation_source', 'human'),
#  '12578678': ('isolation_source', 'rotten substrate'),
#  '12581495': ('tissue', 'leaf'),
#  '12583493': ('tissue', 'Blood'),
#  '12585648': ('isolation_source', 'feces'),
#  '12589366': ('isolation_source', 'missing'),
#  '12594614': ('isolation_source', 'soil'),
#  '12595544': ('tissue', 'gastric cancer'),
#  '12598709': ('sample_type', 'metagenomic assembly'),
#  '12619494': ('tissue', 'not applicable'),
#  '12624308': ('sample_type', 'cell culture'),
#  '12641608': ('tissue', 'skin'),
#  '12648571': ('isolation_source', 'human'),
#  '12650778': ('isolation_source', 'Arch_A120d_incubation_15_16'),
#  '12658015': ('tissue', 'Leaf'),
#  '12664677': ('tissue', 'Blood'),
#  '12684612': ('isolation_source', 'missing'),
#  '12696886': ('tissue', 'Legs'),
#  '12696954': ('tissue', 'blood'),
#  '12700458': ('tissue', 'basal (= proximal) halves of fully expanded leaves'),
#  '12700555': ('tissue', 'WBC'),
#  '12710038': ('sample_type', 'gut microbiome'),
#  '12711117': ('sample_type', 'saliva'),
#  '12745570': ('isolation_source', 'resp'),
#  '12745606': ('isolation_source', 'blood'),
#  '12746623': ('isolation_source', 'environment'),
#  '12751698': ('isolation_source', 'HF Mouse feces 6'),
#  '12751701': ('isolation_source', 'HS Mouse feces 6'),
#  '12755934': ('isolation_source', 'Rimov reservoir'),
#  '12769348': ('isolation_source', 'gut'),
#  '12769366': ('isolation_source', 'gut'),
#  '12771554': ('isolation_source', 'missing'),
#  '12773534': ('isolation_source', 'surface waters_0.2um'),
#  '12774251': ('sample_type', 'Whole organism'),
#  '12799286': ('isolation_source', 'environmental swab'),
#  '12812247': ('isolation_source', 'missing'),
#  '12815297': ('isolation_source', 'missing'),
#  '12817674': ('isolation_source', 'Semi-arid orchards in the loess plateau'),
#  '12829597': ('tissue', 'not collected'),
#  '12840178': ('tissue', 'Intestine'),
#  '12843670': ('tissue', 'embryonic kidney'),
#  '12847829': ('tissue', 'not collected'),
#  '12867246': ('tissue', 'Blood'),
#  '12875514': ('tissue', 'Leaves'),
#  '12875930': ('tissue', 'Whole organism'),
#  '12877909': ('tissue', 'Liver'),
#  '12878413': ('sample_type', 'not collected'),
#  '12881385': ('isolation_source', 'missing'),
#  '12897947': ('tissue', 'Leaf'),
#  '12904251': ('tissue', 'blood'),
#  '12911150': ('isolation_source', 'missing'),
#  '12911850': ('isolation_source', 'xylem shavings'),
#  '12912828': ('tissue', 'Primary dermal lymphatic endothelial cells'),
#  '12914874': ('tissue', 'Blood'),
#  '12987302': ('tissue', 'Adjacent normal'),
#  '12988544': ('tissue', 'Adjacent normal'),
#  '12988684': ('tissue', 'Tumor'),
#  '13003190': ('isolation_source', 'missing'),
#  '13004499': ('isolation_source', 'food'),
#  '13008173': ('isolation_source', 'Grassland_soil'),
#  '13008405': ('strain', 'FAM19160'),
#  '13021508': ('tissue', 'leaf'),
#  '13028119': ('isolation_source', 'Not applicable'),
#  '13028847': ('tissue', 'whole organism'),
#  '13033211': ('tissue', 'blood'),
#  '13033903': ('tissue', 'not applicable'),
#  '13035003': ('tissue', 'not applicable'),
#  '13041115': ('tissue', 'Whole organism'),
#  '13041581': ('tissue', 'neural cells'),
#  '13048230': ('tissue',
#               'DNA from 2-5 true leaf stage. Phenotypes from fully mature '
#               'plants.'),
#  '13048414': ('tissue', 'nasal ChAT-eGFP+ FSChi/SSChi epithelial cells'),
#  '13049952': ('tissue', 'peripheral blood'),
#  '13058558': ('tissue', 'not applicable'),
#  '13067630': ('tissue', 'MCF-7 cell line'),
#  '13070759': ('tissue', 'placenta/decidua'),
#  '13078383': ('tissue', 'liver'),
#  '13084914': ('tissue', 'mixed embryo and skin'),
#  '13087565': ('isolation_source', 'missing'),
#  '13088838': ('tissue', 'whole body'),
#  '13100934': ('tissue', 'unknown'),
#  '13101942': ('tissue', 'unknown'),
#  '13144567': ('tissue', 'BLOOD'),
#  '13144977': ('tissue', 'BLOOD'),
#  '13147465': ('tissue', 'BLOOD'),
#  '13147508': ('tissue', 'BLOOD'),
#  '13148357': ('tissue', 'BLOOD'),
#  '13165964': ('tissue', 'Root'),
#  '13169709': ('isolation_source', 'sputum'),
#  '13173830': ('isolation_source', 'human'),
#  '13175880': ('isolation_source', 'human oral'),
#  '13182864': ('isolation_source', 'soil78'),
#  '13195468': ('isolation_source', 'Pulmonary'),
#  '13196570': ('isolation_source', 'Fermented pineapple'),
#  '13240872': ('sample_type', 'stool'),
#  '13290057': ('sample_type', 'Soil53'),
#  '13323077': ('strain', 'missing'),
#  '13334965': ('isolation_source', 'patient'),
#  '13340304': ('isolation_source', 'animal-swine-market swine'),
#  '13344095': ('tissue', 'gills'),
#  '13354599': ('isolation_source', 'Auditory canal'),
#  '13356454': ('tissue', 'Pleura'),
#  '13356540': ('tissue', 'Lung'),
#  '13358410': ('tissue', 'Liver'),
#  '13359440': ('tissue', 'Pleura'),
#  '13364556': ('tissue', 'Lung'),
#  '13375836': ('tissue', 'Lung'),
#  '13379099': ('tissue', 'brain'),
#  '13388076': ('tissue', 'Pooled'),
#  '13396520': ('tissue', 'Inner Oral Cavity'),
#  '13400910': ('tissue', 'Brain'),
#  '13405012': ('tissue', 'leaf'),
#  '13452612': ('tissue', 'Stool'),
#  '13463155': ('tissue', 'Blood'),
#  '13467792': ('tissue', 'Plasma'),
#  '13471821': ('isolation_source', 'eye swab'),
#  '13472170': ('isolation_source', 'throat swab'),
#  '13500127': ('isolation_source', 'Fecal matter'),
#  '13500550': ('tissue', 'adult thoracic muscle tissue'),
#  '13503754': ('tissue', 'metastasis lesion'),
#  '13503919': ('sample_type', 'strain culture'),
#  '13518912': ('tissue', 'Leaf'),
#  '13530596': ('tissue', 'spleen'),
#  '13530992': ('tissue', 'spleen'),
#  '13532721': ('tissue', 'Stool'),
#  '13551901': ('tissue', 'whole legs'),
#  '13552797': ('sample_type', 'Single Pathogen Reads from Metagenomic Sample'),
#  '13577992': ('isolation_source', 'human'),
#  '13608391': ('tissue', 'anterior end of body'),
#  '13615526': ('tissue', 'whole brain'),
#  '13625047': ('tissue', 'Primary human adult islet'),
#  '13626487': ('tissue', 'Blood'),
#  '13627938': ('tissue', 'Blood'),
#  '13629956': ('tissue', 'Blood'),
#  '13630003': ('tissue', 'Blood'),
#  '13632608': ('sample_type', 'metagenomic assembly'),
#  '13633042': ('sample_type', 'metagenomic DNA3'),
#  '13633053': ('sample_type', 'metagenomic DNA14'),
#  '13638970': ('isolation_source', 'stool'),
#  '13649740': ('isolation_source', 'feces'),
#  '13662535': ('isolation_source', 'missing'),
#  '13663658': ('isolation_source', 'missing'),
#  '13675508': ('isolation_source', 'oil production water84'),
#  '13676719': ('isolation_source', 'Cecum'),
#  '13684428': ('isolation_source', 'Pelagic sediment'),
#  '13684673': ('isolation_source', 'missing'),
#  '13699479': ('tissue', 'DNA from 2-5 true leaf stage.'),
#  '13707912': ('tissue', 'Foot'),
#  '13717329': ('tissue', 'Brain'),
#  '13722596': ('tissue', 'Peripheral Blood'),
#  '13723605': ('tissue', 'Peripheral Blood'),
#  '13723840': ('tissue', 'Peripheral Blood'),
#  '13725944': ('tissue', 'Peripheral Blood'),
#  '13727602': ('tissue', 'Peripheral Blood'),
#  '13731137': ('tissue', 'Peripheral Blood'),
#  '13765183': ('tissue', 'Blood'),
#  '13765418': ('tissue', 'Blood'),
#  '13765426': ('tissue', 'Blood'),
#  '13768881': ('tissue', 'Blood'),
#  '13772778': ('tissue', 'Blood'),
#  '13776749': ('tissue', 'Blood'),
#  '13779185': ('tissue', 'Blood'),
#  '13779346': ('tissue', 'Blood'),
#  '13781264': ('tissue', 'cochlea'),
#  '13816732': ('tissue', 'caudal fin'),
#  '13819665': ('tissue', 'Peripheral blood'),
#  '13820171': ('tissue', 'Peripheral blood'),
#  '13831794': ('tissue', 'missing'),
#  '13836411': ('tissue', 'dorsal hippocampus'),
#  '13841686': ('tissue', 'germinated conidia'),
#  '13843306': ('tissue', 'not available'),
#  '13844439': ('tissue', 'not available'),
#  '13855440': ('tissue', 'colon'),
#  '13859149': ('tissue', 'colon'),
#  '13890806': ('tissue', 'whole organism'),
#  '13900623': ('tissue', 'colorectal'),
#  '13904921': ('tissue', 'brain'),
#  '13906135': ('isolation_source', 'environmental'),
#  '13906421': ('isolation_source', 'environmental'),
#  '13908744': ('isolation_source', 'male C57BL/6J feces'),
#  '13909747': ('tissue', 'tube foot stem'),
#  '13911986': ('tissue', 'faecal sample'),
#  '13916059': ('tissue', 'leaf'),
#  '13926044': ('tissue', 'Leaf'),
#  '13926400': ('tissue', 'hypothalamus'),
#  '13928035': ('tissue', 'liver'),
#  '13942377': ('tissue', 'Embryonic brain'),
#  '13959796': ('tissue', 'Blood'),
#  '13976155': ('isolation_source', 'missing'),
#  '13977288': ('isolation_source',
#               'A mix of two samples: one from near bottom of the lake, and one '
#               'from the surface, both collected at the deepest part of the '
#               'lake.'),
#  '13978667': ('sample_type', 'Whole organism'),
#  '13996995': ('isolation_source', 'pork chop'),
#  '14009944': ('tissue', 'whole tissue'),
#  '14012183': ('tissue', 'Peripheral Blood'),
#  '14014685': ('tissue', 'Peripheral Blood'),
#  '14019819': ('tissue', 'Peripheral Blood'),
#  '14023830': ('tissue', 'Peripheral Blood'),
#  '14025741': ('tissue', 'Peripheral Blood'),
#  '14029691': ('tissue', 'Peripheral Blood'),
#  '14031847': ('tissue', 'Peripheral Blood'),
#  '14035018': ('tissue', 'Peripheral Blood'),
#  '14041536': ('tissue', 'Peripheral Blood'),
#  '14042319': ('tissue', 'Peripheral Blood'),
#  '14044710': ('tissue', 'Peripheral Blood'),
#  '14047593': ('tissue', 'Peripheral Blood'),
#  '14071607': ('tissue', 'Leaf'),
#  '14080582': ('isolation_source', 'chlorinated drinking water, site 4'),
#  '14092771': ('isolation_source', 'anus'),
#  '14095299': ('isolation_source', 'stool'),
#  '14102550': ('isolation_source', 'stool'),
#  '14113671': ('isolation_source', 'Missing'),
#  '14115465': ('tissue', 'leaf'),
#  '14116460': ('tissue', 'Subcutaneous adipose tissue 9'),
#  '14120208': ('tissue', 'carcass'),
#  '14121374': ('isolation_source', 'human'),
#  '14124545': ('tissue', 'whole body'),
#  '14143356': ('tissue', 'hippocampus'),
#  '14150066': ('tissue', 'leaf'),
#  '14150763': ('isolation_source', 'sterile site'),
#  '14151385': ('isolation_source',
#               'Soil core from HaP96 plot (Hainich forest), 80-100 cm'),
#  '14154558': ('isolation_source', 'groin'),
#  '14209868': ('isolation_source', 'sputum'),
#  '14213979': ('tissue', 'Thorax/Abdomen'),
#  '14235018': ('isolation_source', 'blood'),
#  '14239450': ('isolation_source', 'Endotracheal aspirate'),
#  '14256660': ('tissue', 'Leaf'),
#  '14287647': ('tissue', 'Not available'),
#  '14289919': ('tissue', 'Not available'),
#  '14308705': ('tissue', 'five whole worms'),
#  '14309629': ('tissue', 'flower'),
#  '14319469': ('tissue', 'Brain'),
#  '14320558': ('tissue', 'Brain'),
#  '14321610': ('tissue', 'Brain'),
#  '14321672': ('tissue', 'Brain'),
#  '14324483': ('tissue', 'Whole fly'),
#  '14325416': ('tissue', 'brain'),
#  '14325680': ('tissue', 'brain'),
#  '14325708': ('tissue', 'brain'),
#  '14326858': ('tissue', 'brain'),
#  '14328561': ('tissue', 'Blood'),
#  '14334279': ('tissue', 'brain'),
#  '14336393': ('tissue', 'brain'),
#  '14340877': ('tissue', 'brain'),
#  '14364888': ('sample_type', 'pure culture'),
#  '14369509': ('tissue', 'not applicable'),
#  '14370324': ('tissue', 'not applicable'),
#  '14387373': ('tissue', 'liver'),
#  '14389711': ('tissue', 'Abo'),
#  '14392067': ('tissue', 'Implanted MC38 tumor'),
#  '14392661': ('tissue', 'saliva'),
#  '14396023': ('tissue', 'blood'),
#  '14405790': ('tissue', 'Blood'),
#  '14420455': ('tissue', 'Whole body'),
#  '14423715': ('tissue', 'thymus'),
#  '14431079': ('isolation_source', 'Penguin feces'),
#  '14432031': ('isolation_source', 'stool'),
#  '14436502': ('isolation_source', 'patient clinical specimen'),
#  '14444423': ('tissue', 'coral holobiont (skeleton, tissue, symbiont)'),
#  '14465110': ('tissue', 'kidney'),
#  '14470573': ('tissue', 'Young leaves'),
#  '14471369': ('tissue', 'Lung'),
#  '14472484': ('tissue', 'Blood'),
#  '14475509': ('tissue', 'distal lung'),
#  '14475747': ('tissue', 'distal lung'),
#  '14479874': ('tissue', 'brain'),
#  '14488656': ('tissue', 'liver'),
#  '14496811': ('tissue', 'paraventricular nucleus of hypothalamus'),
#  '14503594': ('isolation_source', 'missing'),
#  '14510621': ('isolation_source', 'Mushroom Spring'),
#  '14511125': ('isolation_source', 'untreated salt marsh sediment'),
#  '14512414': ('isolation_source', 'missing'),
#  '14513317': ('isolation_source', 'missing'),
#  '14519818': ('isolation_source', 'soil'),
#  '14521720': ('tissue', 'tail'),
#  '14528593': ('tissue', 'muscle'),
#  '14540480': ('tissue', 'Intestinal organoid'),
#  '14541177': ('sample_type', 'metagenomic assembly'),
#  '14543971': ('sample_type', 'Monoculture'),
#  '14559910': ('isolation_source', 'missing'),
#  '14564101': ('sample_type', 'metagenomic assembly'),
#  '14565024': ('sample_type', 'soil'),
#  '14582101': ('sample_type', 'cell culture'),
#  '14593156': ('isolation_source',
#               '10 sea water samples from phytoplankton spring bloom collected '
#               'during Heincke cruise HE327'),
#  '14596656': ('sample_type', 'pure culture'),
#  '14598083': ('isolation_source', 'missing'),
#  '14607874': ('tissue', 'Gill'),
#  '14611864': ('tissue', 'Tumor developed in mammary gland 2/3'),
#  '14615848': ('tissue', 'hemolymph'),
#  '14647068': ('tissue', 'leaves'),
#  '14652538': ('tissue', 'CC'),
#  '14652899': ('tissue', 'placneta'),
#  '14653776': ('tissue', 'feces'),
#  '14654453': ('tissue', 'blood'),
#  '14660574': ('tissue', 'NULL'),
#  '14667481': ('tissue', 'Basal part'),
#  '14669278': ('sample_type', 'not applicable'),
#  '14672888': ('tissue', 'Leaf'),
#  '14682432': ('tissue', 'Blood'),
#  '14686624': ('tissue', 'blood'),
#  '14686659': ('tissue', 'blood'),
#  '14690659': ('tissue', 'heart'),
#  '14749566': ('tissue', 'OB'),
#  '14749968': ('tissue', 'blood'),
#  '14753415': ('tissue', 'Blood'),
#  '14760235': ('tissue', 'not applicable'),
#  '14760512': ('tissue', 'not applicable'),
#  '14761166': ('tissue', 'not applicable'),
#  '14761557': ('tissue', 'not applicable'),
#  '14762253': ('tissue', 'not applicable'),
#  '14779728': ('tissue', 'Peripheral Blood'),
#  '14782997': ('tissue', 'skeletal muscle'),
#  '14785623': ('tissue', 'leaf'),
#  '14795801': ('tissue', 'NULL'),
#  '14797096': ('tissue', 'NULL'),
#  '14805604': ('tissue', 'NULL'),
#  '14807558': ('tissue', 'NULL'),
#  '14809896': ('tissue', 'NULL'),
#  '14813242': ('tissue', 'NULL'),
#  '14816247': ('tissue', 'leaves'),
#  '14831115': ('tissue', 'colon'),
#  '14837519': ('tissue', 'Corpus Striatum'),
#  '14838129': ('tissue', 'Seed'),
#  '14840423': ('tissue', 'Two centimetres of germinating seedling roots'),
#  '14850793': ('tissue', 'Whole tick digest (up to 150mg)'),
#  '14851393': ('tissue', 'gill'),
#  '14853732': ('tissue', 'gonad'),
#  '14856834': ('sample_type', 'Dried Blood Spot'),
#  '14885855': ('tissue', 'blood'),
#  '14887894': ('tissue', 'blood'),
#  '14921716': ('tissue', 'Blood'),
#  '14931657': ('tissue', 'Kidney'),
#  '14933166': ('sample_type', 'Pure cell culture'),
#  '14967301': ('isolation_source', 'missing'),
#  '14973448': ('sample_type', 'Culture'),
#  '14980702': ('tissue', 'Ear Biopsy'),
#  '14991135': ('tissue', 'Ear Biopsy'),
#  '14995723': ('tissue', 'muscle'),
#  '14996947': ('isolation_source', 'food'),
#  '14998741': ('isolation_source', 'Ocean water'),
#  '14998810': ('isolation_source', 'Ocean water'),
#  '15007006': ('tissue', 'Dried tissue106283'),
#  '15009967': ('tissue', 'Leaves'),
#  '15011357': ('tissue', 'fin'),
#  '15016641': ('isolation_source', 'unknown'),
#  '15032721': ('tissue', 'tadpole'),
#  '15035839': ('tissue', 'bone marrow'),
#  '15054343': ('tissue', 'Skin fruit tissue'),
#  '15066219': ('tissue', 'liver'),
#  '15073964': ('tissue', 'Resected tumors'),
#  '15083487': ('tissue', 'White muscle'),
#  '15084299': ('tissue', 'Blood'),
#  '15092397': ('tissue', 'Olfactory bulb'),
#  '15097800': ('tissue', 'leaves and young fruits'),
#  '15098055': ('tissue', 'Blood'),
#  '15106692': ('tissue', 'NULL'),
#  '15117335': ('tissue', 'NULL'),
#  '15119963': ('tissue', 'NULL'),
#  '15125927': ('tissue', 'NULL'),
#  '15127351': ('tissue', 'NULL'),
#  '15127550': ('tissue', 'NULL'),
#  '15127834': ('tissue', 'NULL'),
#  '15129646': ('tissue', 'NULL'),
#  '15131699': ('tissue', 'NULL'),
#  '15132104': ('tissue', 'NULL'),
#  '15132940': ('tissue', 'NULL'),
#  '15153080': ('tissue', 'leaf'),
#  '15153303': ('tissue', 'leaf'),
#  '15153702': ('tissue', 'leaf'),
#  '15158342': ('tissue', 'FECAL'),
#  '15165437': ('tissue', 'Blood'),
#  '15190852': ('tissue', 'whole organism'),
#  '15206442': ('tissue', 'testa'),
#  '15218101': ('tissue', 'not applicable'),
#  '15219086': ('isolation_source', 'swab'),
#  '15223231': ('sample_type', 'whole organism'),
#  '15225515': ('isolation_source', 'human'),
#  '15228673': ('isolation_source', 'not applicable'),
#  '15231022': ('isolation_source', 'Sputum sample'),
#  '15248397': ('tissue', 'lung metastasis'),
#  '15250051': ('isolation_source', 'missing'),
#  '15252559': ('isolation_source', 'lake water'),
#  '15257801': ('isolation_source', 'lake water'),
#  '15259258': ('isolation_source', 'lake water'),
#  '15259308': ('isolation_source', 'lake water'),
#  '15264765': ('isolation_source', 'lake water'),
#  '15295889': ('isolation_source', 'Cooper 12'),
#  '15297107': ('tissue', 'blood'),
#  '15307324': ('tissue', 'blood'),
#  '15310709': ('sample_type', 'cell culture'),
#  '15315139': ('strain', 'Hildenborough'),
#  '15315675': ('isolation_source', 'patient isolate'),
#  '15318405': ('tissue', 'feces'),
#  '15320189': ('tissue', 'WBC'),
#  '15325308': ('isolation_source', 'oropharyngeal swab'),
#  '15327976': ('tissue', 'leaf'),
#  '15339181': ('tissue', 'oral buccal mucosa cells'),
#  '15345168': ('tissue', 'Whole root'),
#  '15362171': ('isolation_source', 'buccal swab'),
#  '15391158': ('isolation_source', 'not collected'),
#  '15393694': ('isolation_source', 'missing'),
#  '15393925': ('isolation_source', 'water'),
#  '15399957': ('isolation_source', 'human'),
#  '15402431': ('sample_type', 'missing'),
#  '15403007': ('tissue', 'blood'),
#  '15413369': ('tissue', 'leaf'),
#  '15414592': ('tissue', 'Blood'),
#  '15420235': ('tissue', 'Ileal Crypts'),
#  '15464968': ('tissue', 'white blood cells'),
#  '15465816': ('tissue', 'Spinal Cord Lumbar'),
#  '15472001': ('tissue', 'stool'),
#  '15474713': ('tissue', 'Blood'),
#  '15475895': ('tissue', 'Blood'),
#  '15478435': ('tissue', 'Blood'),
#  '15481053': ('tissue', 'Liver'),
#  '15484816': ('tissue', 'whole larvae'),
#  '15488236': ('tissue', 'Leaf'),
#  '15493233': ('sample_type', 'Pure culture'),
#  '15500907': ('tissue', 'tumor biopsy'),
#  '15507816': ('tissue', 'Leaf'),
#  '15516894': ('tissue', 'whole body'),
#  '15526900': ('tissue', 'CHEEK SWAB'),
#  '15533164': ('sample_type', 'whole organism'),
#  '15533564': ('sample_type', 'Vehicle_Control'),
#  '15562811': ('isolation_source', 'blood'),
#  '15565567': ('isolation_source', 'missing'),
#  '15568299': ('isolation_source', 'sputum'),
#  '15573230': ('tissue', 'Axillary'),
#  '15580409': ('tissue', 'not collected'),
#  '15581490': ('isolation_source', 'comminuted chicken'),
#  '15594498': ('tissue', 'Blood'),
#  '15594768': ('sample_type', 'whole organism'),
#  '15596452': ('tissue', 'fruits'),
#  '15597879': ('tissue', 'Lung tissue, AT2 cells'),
#  '15600363': ('tissue', 'liver'),
#  '15603316': ('tissue', 'Lung tissue, AT2 cells'),
#  '15638740': ('isolation_source', 'missing'),
#  '15639116': ('isolation_source', 'Outdoor air'),
#  '15640964': ('isolation_source', 'Pus'),
#  '15642886': ('tissue', 'fece'),
#  '15663733': ('sample_type', 'fungi'),
#  '15669859': ('isolation_source', 'nasopharyngeal swab'),
#  '15670089': ('isolation_source', 'nasopharyngeal swab'),
#  '15676263': ('strain', 'NBRC 110633'),
#  '15681412': ('strain', 'not applicable'),
#  '15681416': ('strain', 'not applicable'),
#  '15685160': ('tissue', 'seed'),
#  '15687984': ('isolation_source',
#               'activated sludge from Hong Kong Shatin wastewater treatment '
#               'plant'),
#  '15708661': ('isolation_source', 'Human, Faeces'),
#  '15722379': ('sample_type', 'cell culture'),
#  '15730133': ('tissue', 'pelvic fin'),
#  '15732525': ('isolation_source', 'plaque assay'),
#  '15736419': ('isolation_source', 'human listeriosis'),
#  '15737827': ('tissue', 'Whole Blood'),
#  '15747470': ('tissue', 'Flesh'),
#  '15749053': ('sample_type', 'Dried Blood Spot'),
#  '15774195': ('tissue', 'gastrocnemius'),
#  '15776150': ('isolation_source', 'raw intact chicken'),
#  '15797717': ('isolation_source', 'missing'),
#  '15810621': ('tissue', 'blood'),
#  '15817834': ('tissue', 'Bone Marrow'),
#  '15817948': ('tissue', 'Bone Marrow'),
#  '15832203': ('tissue', 'liver'),
#  '15832209': ('tissue', 'liver'),
#  '15858788': ('isolation_source', 'missing'),
#  '15863422': ('tissue', 'muscle/heart/liver'),
#  '15869217': ('tissue', 'ear'),
#  '15871841': ('sample_type', 'metagenomic assembly'),
#  '15890431': ('tissue', 'Leaf'),
#  '15894065': ('isolation_source', 'missing'),
#  '15897522': ('tissue', 'blood'),
#  '15906285': ('tissue', 'Tail end'),
#  '15916719': ('isolation_source', 'missing'),
#  '15934826': ('isolation_source', 'human'),
#  '15938884': ('tissue', 'needles'),
#  '15947028': ('isolation_source', 'chicken carcass'),
#  '15950849': ('isolation_source', 'seawater'),
#  '15970300': ('isolation_source', 'Myrmecodia beccarii'),
#  '16048130': ('isolation_source', 'missing'),
#  '16062699': ('tissue', 'dental plaque'),
#  '16063930': ('tissue', 'blood'),
#  '16066410': ('strain', 'KCTC 32513'),
#  '16074131': ('strain', 'C57BL/6'),
#  '16074446': ('isolation_source', 'freshwater surface (50 cm depth)'),
#  '16088468': ('sample_type', 'culture'),
#  '16094683': ('tissue', 'not applicable'),
#  '16100852': ('tissue', 'Arm vein'),
#  '16102686': ('tissue', 'Arm vein'),
#  '16114399': ('tissue', 'blood'),
#  '16124146': ('tissue', 'leaf'),
#  '16137342': ('tissue', 'thymus'),
#  '16139391': ('tissue', 'thymus'),
#  '16141829': ('tissue', 'NULL'),
#  '16152338': ('tissue', 'NULL'),
#  '16155106': ('tissue', 'NULL'),
#  '16158783': ('tissue', 'NULL'),
#  '16164736': ('tissue', 'thymus'),
#  '16165027': ('tissue', 'thymus'),
#  '16165759': ('tissue', 'thymus'),
#  '16168185': ('tissue', 'thymus'),
#  '16171406': ('tissue', 'thymus'),
#  '16171677': ('tissue', 'thymus'),
#  '16172154': ('tissue', 'thymus'),
#  '16187603': ('tissue', 'leaves'),
#  '16216560': ('tissue', 'Whole Blood'),
#  '16236517': ('isolation_source', 'missing'),
#  '16246062': ('sample_type', 'isolated colony culture'),
#  '16277324': ('sample_type', 'Plasma_ext_blank'),
#  '16279830': ('sample_type', 'isolated colony culture'),
#  '16319905': ('isolation_source', 'missing'),
#  '16323337': ('isolation_source', 'missing'),
#  '16325008': ('isolation_source', 'missing'),
#  '16344046': ('sample_type', 'metagenomic assembly'),
#  '16346838': ('sample_type', 'metagenomic assembly'),
#  '16353157': ('sample_type', 'stool'),
#  '16367541': ('tissue', 'Liver'),
#  '16374871': ('tissue',
#               'Section of primary root containing a lateral root at Stage 1 - '
#               'when two cells express DR5'),
#  '16378269': ('tissue', 'HEK293T cell line'),
#  '16380352': ('tissue', 'Whole blood'),
#  '16395295': ('tissue', 'leaf'),
#  '16400976': ('tissue', 'fecal'),
#  '16408458': ('tissue', 'Pasta'),
#  '16422150': ('isolation_source', 'bovine barrier'),
#  '16425573': ('isolation_source', 'activated sludge from AalW_18-Q3-R10-53'),
#  '16432154': ('isolation_source', 'human'),
#  '16433516': ('sample_type', 'soil'),
#  '16439599': ('isolation_source', 'Partial nitritation anammox bioreactor'),
#  '16443209': ('isolation_source', 'A367'),
#  '16451854': ('isolation_source', 'pig'),
#  '16453731': ('isolation_source', 'Nasopharyngeal/oropharyngeal swab'),
#  '16480344': ('isolation_source', 'stool'),
#  '16522885': ('tissue', 'medulla (brain)'),
#  '16544143': ('tissue', 'Kidney glomerulus'),
#  '16548300': ('isolation_source', 'missing'),
#  '16557526': ('isolation_source', 'decomposing wood'),
#  '16557996': ('sample_type', 'whole organism'),
#  '16563717': ('isolation_source', 'missing'),
#  '16566819': ('tissue', 'blood'),
#  '16569426': ('tissue', 'blood'),
#  '16579954': ('tissue', 'Whole olfactory mucosa'),
#  '16583267': ('tissue', 'leaves'),
#  '16588063': ('tissue', 'Nasopharyngeal'),
#  '16599057': ('tissue', 'Blood'),
#  '16600276': ('tissue', 'Blood'),
#  '16600914': ('tissue', 'Blood'),
#  '16601082': ('tissue', 'Blood'),
#  '16615262': ('isolation_source', 'missing'),
#  '16622896': ('isolation_source', 'feces'),
#  '16628439': ('tissue', 'Young needle'),
#  '16661077': ('tissue', 'Brain'),
#  '16682751': ('tissue', 'Buccal'),
#  '16688975': ('tissue', 'bone_marrow'),
#  '16690972': ('tissue', 'fin clip'),
#  '16696884': ('tissue', 'WHOLE ORGANISM'),
#  '16727252': ('tissue', 'Bone marrow'),
#  '16749455': ('tissue', 'bone marrow'),
#  '16750004': ('tissue', 'whole egg'),
#  '16750600': ('tissue', 'Colon'),
#  '16751733': ('tissue', 'medial frontal gyrus'),
#  '16752374': ('tissue', 'bone marrow'),
#  '16752953': ('tissue', 'not applicable'),
#  '16777781': ('tissue', 'saliva'),
#  '16778729': ('tissue', 'saliva'),
#  '16781666': ('tissue', 'Kidney'),
#  '16787425': ('tissue', 'leaf'),
#  '16790624': ('isolation_source', 'missing'),
#  '16790835': ('tissue', 'Kidney'),
#  '16792275': ('tissue', 'Kidney'),
#  '16802083': ('tissue', 'leaves'),
#  '16822479': ('isolation_source', 'Wound/Abscess'),
#  '16823870': ('tissue', 'muscle, liver, or shed skin'),
#  '16827604': ('tissue', 'whole organism'),
#  '16831485': ('isolation_source', 'missing'),
#  '16846108': ('isolation_source', 'Wood Untreated-control-replicate=1'),
#  '16847209': ('isolation_source', 'human'),
#  '16857576': ('isolation_source', 'missing'),
#  '16860769': ('tissue', 'esophagus'),
#  '16863317': ('tissue', 'fecal'),
#  '16872898': ('tissue', 'Trachea'),
#  '16886515': ('tissue', 'blood'),
#  '16918832': ('tissue', 'Serum'),
#  '16921197': ('tissue', 'Serum'),
#  '16922339': ('tissue', 'Serum'),
#  '16922585': ('tissue', 'Serum'),
#  '16927969': ('tissue', 'fin clips'),
#  '16940496': ('tissue', 'leaf'),
#  '16948673': ('tissue', 'Blood'),
#  '16957135': ('tissue', 'tumour'),
#  '16957934': ('tissue', 'tumour'),
#  '16958284': ('tissue', 'tumour'),
#  '16958865': ('tissue', 'tumour'),
#  '16965054': ('tissue', 'Leaf'),
#  '16968774': ('tissue', 'mature leaf'),
#  '16973051': ('isolation_source', 'missing'),
#  '16975329': ('isolation_source', 'missing'),
#  '16976097': ('tissue', 'Pooled coral larvae'),
#  '16989774': ('isolation_source', 'Nasopharyngeal/oropharyngeal swab'),
#  '17001819': ('isolation_source', 'surgery'),
#  '17013732': ('sample_type', 'missing'),
#  '17015168': ('tissue', 'colon'),
#  '17018844': ('isolation_source', 'missing'),
#  '17020084': ('isolation_source', 'sputum'),
#  '17050155': ('isolation_source', 'soil sample 1'),
#  '17050291': ('sample_type', 'whole organism'),
#  '17057260': ('tissue', 'Leaf blade'),
#  '17067538': ('tissue', 'WHOLE ORGANISM'),
#  '17076110': ('tissue', 'Plasmodium falciparum: asexual blood stage'),
#  '17076167': ('tissue', 'leaf'),
#  '17083998': ('isolation_source', 'missing'),
#  '17086746': ('tissue', 'inflorescence tissue consisting of stage 3 flowers'),
#  '17103685': ('tissue', 'young leaf'),
#  '17110377': ('tissue', 'Whole Blood'),
#  '17118160': ('tissue', 'liver'),
#  '17136507': ('tissue', 'cervical tissues'),
#  '17147442': ('tissue', 'primary mouse motor cortex'),
#  '17147488': ('tissue', 'primary mouse motor cortex'),
#  '17153013': ('tissue', 'brain'),
#  '17158053': ('tissue', 'WHOLE ORGANISM'),
#  '17160023': ('tissue', 'leaves'),
#  '17170907': ('isolation_source', 'not applicable'),
#  '17180621': ('sample_type', 'chyme'),
#  '17209146': ('tissue', 'Leaf'),
#  '17216730': ('sample_type', 'cell culture'),
#  '17223440': ('tissue', 'body'),
#  '17226176': ('tissue', 'Leaf'),
#  '17229085': ('tissue', 'brain'),
#  '17243345': ('isolation_source', 'freshwater sediment'),
#  '17249044': ('tissue', 'body'),
#  '17254054': ('isolation_source', 'none'),
#  '17283331': ('isolation_source', 'T1.D5.3.A/B (Sorting gate 2)'),
#  '17285211': ('isolation_source', 'missing'),
#  '17285393': ('isolation_source', 'patient isolate'),
#  '17300442': ('isolation_source', 'human'),
#  '17313041': ('tissue', 'caudal fin'),
#  '17368733': ('tissue', 'culured immature embryos'),
#  '17382970': ('tissue', 'BLOOD'),
#  '17386458': ('tissue', 'lung'),
#  '17386643': ('sample_type', 'cell culture from single octad cell'),
#  '17506954': ('sample_type', 'DNA-Seq'),
#  '17574413': ('tissue', 'Ovary'),
#  '17574489': ('tissue', 'Pleural fluid'),
#  '17598619': ('tissue', 'Bone marrow'),
#  '17598841': ('tissue', 'Bone marrow'),
#  '17601364': ('isolation_source', 'single-cell amplified by MDA; feces'),
#  '17604646': ('isolation_source', 'seawater'),
#  '17610940': ('tissue', 'Leaf'),
#  '17611165': ('isolation_source', 'pathogen.cl'),
#  '17613801': ('tissue', 'fin clip'),
#  '17613856': ('tissue', 'fin clip'),
#  '17614601': ('tissue', 'leaf'),
#  '17614699': ('tissue', 'leaf'),
#  '17614935': ('tissue', 'leaf'),
#  '17618440': ('isolation_source', 'blood'),
#  '17705445': ('isolation_source', 'seawater'),
#  '17728449': ('tissue', 'blood'),
#  '17791394': ('tissue', 'Tumor'),
#  '17840774': ('isolation_source', 'skin'),
#  '17843809': ('isolation_source', 'missing'),
#  '17846691': ('isolation_source', 'laboratory'),
#  '17852627': ('isolation_source', 'not applicable'),
#  '17854688': ('isolation_source', 'Nasopharynx: Swab'),
#  '17862546': ('isolation_source', 'missing'),
#  '17864483': ('isolation_source', 'Moss crust soil'),
#  '17886165': ('isolation_source', 'soil'),
#  '17887236': ('tissue', 'feces'),
#  '17901280': ('tissue', 'Thymus'),
#  '17902238': ('tissue', 'Thymus'),
#  '17902798': ('tissue', 'Thymus'),
#  '17902914': ('tissue', 'Thymus'),
#  '17920660': ('tissue', 'kidney'),
#  '17930278': ('tissue', '1'),
#  '17931853': ('tissue', '1'),
#  '17936622': ('tissue', 'Stem'),
#  '17939836': ('tissue', 'peripheral blood'),
#  '17942098': ('tissue', 'peripheral blood'),
#  '17980872': ('tissue', 'spleen'),
#  '18026275': ('tissue', 'seedling'),
#  '18031171': ('tissue', 'peripheral blood'),
#  '18031952': ('tissue', 'peripheral blood'),
#  '18032664': ('tissue', 'peripheral blood'),
#  '18033450': ('tissue', 'peripheral blood'),
#  '18035019': ('tissue', 'the whole plantlets'),
#  '18036311': ('tissue', 'blood'),
#  '18037012': ('tissue', 'bone marrow'),
#  '18053183': ('isolation_source', 'chicken carcass'),
#  '18055391': ('isolation_source', 'reactor sample from MC replicate 1'),
#  '18058762': ('isolation_source', 'Superficial water'),
#  '18059520': ('tissue', 'leaf'),
#  '18061166': ('isolation_source', 'Escherichia coli K-12 DH5a'),
#  '18076178': ('tissue', 'CD4+ T cells'),
#  '18077435': ('tissue', 'glioma'),
#  '18082875': ('isolation_source', 'Great toe Swab'),
#  '18092138': ('tissue', 'meiotic terminal tassel'),
#  '18121572': ('isolation_source', 'human'),
#  '18138945': ('tissue', 'shoot'),
#  '18146225': ('sample_type', 'simulated sputum'),
#  '1816110': ('isolation_source', 'pistachio'),
#  '18192351': ('tissue', 'Fecal'),
#  '18196735': ('tissue', 'blood'),
#  '18208245': ('sample_type', 'Pure mutant culture 12'),
#  '18208365': ('isolation_source', 'missing'),
#  '18246113': ('tissue', 'leaf'),
#  '18247786': ('strain', 'DSM 15595'),
#  '18254923': ('isolation_source', 'Dairy farm'),
#  '18268095': ('tissue', 'leg'),
#  '18269778': ('tissue', 'heart'),
#  '18292611': ('sample_type', 'not collected'),
#  '18310152': ('tissue', 'blood'),
#  '18312161': ('isolation_source', 'nasal'),
#  '18312570': ('isolation_source', 'nasal'),
#  '18317841': ('tissue', 'liver'),
#  '18321772': ('isolation_source', 'food'),
#  '18324634': ('isolation_source', 'rectal swab'),
#  '18332902': ('tissue', 'Fresh Pine Needle'),
#  '18336117': ('tissue', 'Young adult whole animals'),
#  '18345918': ('tissue', 'Whole Blood'),
#  '18353741': ('isolation_source', 'marine hydrothermal sediment'),
#  '18381031': ('tissue', 'Flower bud'),
#  '18420217': ('tissue', 'blood'),
#  '18436501': ('sample_type', 'pure culture'),
#  '18471873': ('tissue', 'Whole-blood'),
#  '18473505': ('tissue', 'secondary follicle stage oocyte'),
#  '18473584': ('isolation_source', 'cyanobacterial mat on coral surface'),
#  '18476514': ('isolation_source', 'nectar sample19'),
#  '18515661': ('isolation_source', 'Kingdergarten'),
#  '18522511': ('tissue', 'Peripheral blood'),
#  '18529593': ('isolation_source', 'nasal swab'),
#  '18530844': ('isolation_source', 'wheat straw residue'),
#  '18532414': ('isolation_source', 'soil'),
#  '18533059': ('isolation_source', 'mouse gut'),
#  '18533189': ('isolation_source', 'leaf endosphere'),
#  '18534328': ('isolation_source', 'Spoiled Fermented Olive Fruit'),
#  '18572608': ('isolation_source', 'blood culture'),
#  '18580773': ('isolation_source', 'aqueous humor'),
#  '18581042': ('isolation_source', 'urine'),
#  '18587583': ('tissue', 'thorax'),
#  '18587942': ('tissue', 'thorax'),
#  '18616554': ('isolation_source', 'environmental swab sponge'),
#  '18617133': ('isolation_source', 'nasophyrangeal swab'),
#  '18618978': ('isolation_source', 'missing'),
#  '18640922': ('isolation_source', 'saline spring sediment'),
#  '18645394': ('isolation_source', 'Oropharyngeal swab'),
#  '18649125': ('isolation_source', 'Catheter'),
#  '18678088': ('isolation_source', 'ITS_AHTR'),
#  '18711996': ('tissue', 'fecal swab'),
#  '18713059': ('tissue', 'not applicable'),
#  '18716431': ('isolation_source', 'missing'),
#  '18763332': ('isolation_source', 'Unknown'),
#  '18794754': ('isolation_source', 'urine'),
#  '18797445': ('sample_type', 'Whole organism'),
#  '18819825': ('tissue', 'Not applicable'),
#  '18820424': ('isolation_source', 'stool'),
#  '18824495': ('isolation_source', 'agricultural soil'),
#  '18825684': ('isolation_source', 'wheat'),
#  '18825736': ('isolation_source', 'caecum_chymus'),
#  '18854710': ('tissue', 'Leaf'),
#  '18854763': ('tissue', 'Leaf'),
#  '18869034': ('tissue', 'Rectum'),
#  '18877129': ('tissue', 'Hematopoietic'),
#  '18883604': ('tissue', 'intestine'),
#  '18887055': ('tissue', 'whole fly'),
#  '18893612': ('tissue', 'whole fly'),
#  '18895217': ('tissue', 'Blood'),
#  '18928553': ('tissue', 'brain'),
#  '18938157': ('tissue', 'Multiple entire females'),
#  '18943119': ('isolation_source', 'nasal'),
#  '18945360': ('isolation_source', 'cropland'),
#  '18956925': ('isolation_source', 'nasal'),
#  '18958146': ('isolation_source', 'nasal'),
#  '18968431': ('isolation_source', 'nasal'),
#  '18968940': ('isolation_source', 'nasal'),
#  '18972740': ('isolation_source', 'nasal'),
#  '18977683': ('isolation_source', 'nasal'),
#  '18979591': ('isolation_source', 'nasal'),
#  '18985197': ('isolation_source', 'nasal'),
#  '18985512': ('isolation_source', 'nasal'),
#  '18991966': ('isolation_source', 'nasal'),
#  '18993223': ('isolation_source', 'nasal'),
#  '18993922': ('isolation_source', 'nasal'),
#  '19012134': ('isolation_source', 'clinical'),
#  '19018543': ('tissue', 'retroperitoneal adipose'),
#  '19021999': ('tissue', 'whole organism'),
#  '19023430': ('sample_type', 'pure culture'),
#  '19029529': ('isolation_source', 'nasal'),
#  '19033090': ('isolation_source', 'feces'),
#  '19037683': ('isolation_source', 'clinical'),
#  '19037816': ('isolation_source', 'clinical'),
#  '19066792': ('tissue', 'cryopreserved ejaculate'),
#  '19070493': ('tissue', 'CRH-expressing neuron'),
#  '19076790': ('isolation_source', 'clinical'),
#  '19076933': ('isolation_source', 'clinical'),
#  '19092134': ('tissue', 'Leaf'),
#  '19113424': ('isolation_source', 'missing'),
#  '19115587': ('tissue', 'fin'),
#  '19121156': ('tissue', 'liver'),
#  '19126083': ('tissue', 'liver'),
#  '19131400': ('sample_type', 'bacterial isolate'),
#  '19157558': ('isolation_source', 'clinical'),
#  '19188283': ('tissue', 'whole body'),
#  '19220394': ('isolation_source', 'clinical'),
#  '19222629': ('tissue', 'Gizzard'),
#  '19223871': ('tissue', 'Colorectal cancer'),
#  '19273802': ('tissue', 'embryo'),
#  '19274871': ('tissue', 'embryo'),
#  '19276466': ('tissue', 'muscle'),
#  '19279946': ('tissue', 'whole berries'),
#  '19298620': ('isolation_source', 'Aspo HRL'),
#  '19301138': ('tissue', 'needle/buds'),
#  '19302520': ('sample_type', 'missing'),
#  '19303025': ('tissue', 'not collected'),
#  '19308360': ('tissue', 'needle/buds'),
#  '19312523': ('tissue', 'gill'),
#  '19332219': ('tissue', 'cerebrospinal fluid'),
#  '19332469': ('tissue', 'cerebrospinal fluid'),
#  '19348607': ('sample_type', 'metagenomic assembly'),
#  '19352194': ('isolation_source', 'patient isolate'),
#  '19353683': ('isolation_source', 'ice cream sherbet'),
#  '19366931': ('isolation_source', 'clinical'),
#  '19373960': ('isolation_source', 'nostil'),
#  '19411866': ('isolation_source', 'patient isolate'),
#  '19413865': ('sample_type', 'bacterial isolate'),
#  '19413931': ('sample_type',
#               'Human primary astrocytes (Lonza, #CC-2565) and 2-week '
# ...
#  '6631217': ('tissue', 'Blood or Saliva'),
#  '6641534': ('tissue', 'CD8+ clone 13 LCMV-specific T cell'),
#  '6652790': ('tissue', 'frontal cortex'),
#  '6659742': ('strain', 'missing'),
#  '6669487': ('sample_type', 'Mixed population from laboratory evolution'),
#  '6679207': ('tissue', 'Leaf'),
#  '6700180': ('isolation_source', 'CSF'),
#  '6822081': ('tissue', 'embryonic kidney'),
#  '6824782': ('tissue', 'embryonic kidney'),
#  '6827577': ('tissue', 'whole bone marrow'),
#  '6828778': ('tissue', 'whole seedling'),
#  '6834045': ('tissue', 'blood'),
#  '6837293': ('tissue', 'Blood'),
#  '6854581': ('tissue', 'whole insect body'),
#  '6890227': ('isolation_source', 'case'),
#  '6890331': ('isolation_source', 'case'),
#  '6894100': ('isolation_source', 'missing'),
#  '6897400': ('isolation_source', 'blood'),
#  '6906118': ('isolation_source', 'Throat'),
#  '6919932': ('isolation_source', 'biofilm on Plastic carrier'),
#  '6921584': ('sample_type', 'cell culture'),
#  '6925497': ('sample_type', 'saliva'),
#  '6946632': ('sample_type', '33'),
#  '6947168': ('sample_type', 'whole organism'),
#  '7037939': ('sample_type', 'fresh_sample'),
#  '7163909': ('isolation_source', 'Product-Swab-Non meat'),
#  '7178512': ('sample_type', 'Pure culture'),
#  '7223240': ('tissue', 'harderian'),
#  '7231280': ('tissue', 'peripheral blood plasma'),
#  '7234278': ('tissue', 'peripheral blood'),
#  '7238825': ('tissue', 'saliva'),
#  '7241881': ('tissue', 'blood'),
#  '7260283': ('tissue', 'right_retina'),
#  '7261121': ('tissue', 'whole organism'),
#  '7292100': ('tissue', 'Leaf'),
#  '7292253': ('tissue', 'Leaf'),
#  '7292286': ('tissue', 'Leaf'),
#  '7298248': ('tissue', 'Liver'),
#  '7313064': ('tissue', 'leaf'),
#  '7323021': ('tissue', 'Blood'),
#  '7323061': ('tissue', 'Blood'),
#  '7327185': ('tissue', 'Leaf sheath'),
#  '7337952': ('isolation_source', 'fish'),
#  '7344744': ('isolation_source',
#              'Fermentation day 1, Gena variety, erosa 4, replication 2'),
#  '7376141': ('isolation_source', 'mangrove sediment'),
#  '7416038': ('tissue', 'Liver'),
#  '7416310': ('tissue', 'Ear'),
#  '7417329': ('tissue', 'fore-limb'),
#  '7430067': ('isolation_source', 'urine'),
#  '7444391': ('sample_type', 'whole organism'),
#  '7449420': ('tissue', 'pCRC'),
#  '7455099': ('tissue', 'Lung'),
#  '7457235': ('tissue', 'Nucleus of the solitary tract'),
#  '7458198': ('tissue', 'whole blood'),
#  '7463944': ('tissue', 'Peripheral Blood'),
#  '7464220': ('tissue', 'Peripheral Blood'),
#  '7469409': ('tissue', 'Peripheral Blood'),
#  '7471647': ('tissue', 'BUCCAL'),
#  '7475831': ('tissue', 'BUCCAL'),
#  '7481434': ('tissue', 'BUCCAL'),
#  '7491685': ('tissue', 'Brain'),
#  '7497554': ('tissue', 'UBERON:feces'),
#  '7512257': ('tissue', 'blood'),
#  '7512904': ('tissue', 'new born cordblood'),
#  '7517229': ('tissue', 'Haemolymphatic fluid'),
#  '7521361': ('tissue', 'leaf'),
#  '7536898': ('tissue', 'whole-animal'),
#  '7552458': ('tissue', 'tumor'),
#  '7559929': ('tissue', 'young leaves'),
#  '7563737': ('tissue', 'Middle part of third leaf'),
#  '7603447': ('tissue', 'blood'),
#  '7605197': ('tissue', 'Fin Clip'),
#  '7619540': ('sample_type', 'metagenomic assembly'),
#  '7644150': ('tissue', 'blood'),
#  '7658857': ('isolation_source', 'clinical sample'),
#  '7659636': ('isolation_source', 'clinical sample'),
#  '7666441': ('isolation_source', 'blood'),
#  '7676677': ('sample_type', 'whole organism'),
#  '7761298': ('sample_type', 'cDNA'),
#  '7762901': ('sample_type', 'mixed culture'),
#  '7771402': ('sample_type', 'skin'),
#  '7772068': ('sample_type', 'skin'),
#  '7774790': ('tissue', 'not applicable'),
#  '7776359': ('tissue', 'Liver'),
#  '7786527': ('tissue', 'whole maggot'),
#  '7795052': ('tissue', 'digestive plus excretory system'),
#  '7795243': ('tissue', 'gonad'),
#  '7796846': ('tissue', 'Knee'),
#  '7798828': ('tissue', 'Hip'),
#  '7799358': ('tissue', 'Wrist'),
#  '7800188': ('tissue', 'Knee'),
#  '7801921': ('tissue', 'Knee'),
#  '7802120': ('tissue', 'Knee'),
#  '7821204': ('strain', 'CEC03095'),
#  '7836351': ('tissue', 'leaf'),
#  '7850672': ('tissue', 'Blood'),
#  '7852246': ('tissue', 'Unknown'),
#  '7852628': ('tissue', 'Blood'),
#  '7852742': ('tissue', 'Unknown'),
#  '7855560': ('tissue', 'Buffy Coat'),
#  '7857493': ('tissue', 'Mouthwash/Saliva'),
#  '7860247': ('tissue', 'Unknown'),
#  '7863704': ('tissue', 'Buffy Coat'),
#  '7865166': ('tissue', 'Blood'),
#  '7867198': ('tissue', 'Unknown'),
#  '7884816': ('tissue', 'Unknown'),
#  '7892467': ('tissue', 'Unknown'),
#  '7894217': ('tissue', 'Unknown'),
#  '7894269': ('tissue', 'Unknown'),
#  '7899609': ('tissue', 'Buffy Coat'),
#  '7900060': ('tissue', 'Buffy Coat'),
#  '7905608': ('tissue', 'Unknown'),
#  '7906440': ('tissue', 'Mouthwash/Saliva'),
#  '7907502': ('tissue', 'Mouthwash/Saliva'),
#  '7908524': ('tissue', 'Unknown'),
#  '7909406': ('tissue', 'Blood'),
#  '7915223': ('tissue', 'Blood'),
#  '7924098': ('tissue', 'Unknown'),
#  '7925463': ('tissue', 'Unknown'),
#  '7928990': ('tissue', 'Mouthwash/Saliva'),
#  '7933881': ('tissue', 'Unknown'),
#  '7941637': ('tissue', 'Unknown'),
#  '7942510': ('tissue', 'Blood'),
#  '7943995': ('tissue', 'tail tip'),
#  '7950407': ('tissue', 'Blood'),
#  '7951984': ('tissue', 'Blood'),
#  '7953322': ('tissue', 'Blood'),
#  '7953613': ('tissue', 'Blood'),
#  '7959639': ('tissue', 'Primary Blood Derived Cancer - Peripheral Blood'),
#  '7969867': ('tissue', 'fin clip'),
#  '7982403': ('tissue', 'Vehicle treated frontal cortex'),
#  '7990427': ('tissue', 'Blood'),
#  '7994944': ('tissue', 'Blood'),
#  '7999960': ('tissue', 'Gastrointestinal tract'),
#  '8009027': ('tissue', 'Blood'),
#  '8026101': ('tissue', 'Heart'),
#  '8045391': ('tissue', 'MEPs'),
#  '8061188': ('tissue', 'Saliva'),
#  '8061846': ('tissue', 'Saliva'),
#  '8064067': ('tissue', 'Saliva'),
#  '8070147': ('tissue', 'Saliva'),
#  '8078060': ('tissue', 'Saliva'),
#  '8083553': ('tissue', 'Saliva'),
#  '8084981': ('tissue', 'Saliva'),
#  '8092534': ('tissue', 'Saliva'),
#  '8116103': ('isolation_source', 'blood'),
#  '8130445': ('tissue', 'muscle'),
#  '8136427': ('tissue', 'benign nodule'),
#  '8139222': ('sample_type', 'Skin Swab'),
#  '8161771': ('isolation_source', 'NA'),
#  '8162863': ('tissue', 'appendix'),
#  '8173949': ('tissue', 'fruit'),
#  '8178051': ('strain', 'USDA-ARS-USMARC-76337'),
#  '8193367': ('strain', 'RUC.THI1'),
#  '8213167': ('tissue', 'albumen gland'),
#  '8214634': ('isolation_source', 'Missing'),
#  '8217169': ('isolation_source', 'soil'),
#  '8220029': ('isolation_source', 'missing'),
#  '8222782': ('isolation_source', 'gut digesta'),
#  '8224923': ('isolation_source', 'nasopharynx'),
#  '8225489': ('isolation_source', 'plastic waste recycling plant'),
#  '8234626': ('isolation_source', 'sputum'),
#  '8241793': ('tissue', 'blood'),
#  '8253813': ('tissue', 'Skin'),
#  '8254674': ('tissue', 'Skin'),
#  '8258957': ('tissue', 'Skin'),
#  '8261030': ('tissue', 'Kidney'),
#  '8261093': ('tissue', 'Kidney'),
#  '8262626': ('tissue', 'Kidney'),
#  '8263338': ('tissue', 'Skin'),
#  '8263971': ('tissue', 'Urine'),
#  '8264337': ('tissue', 'Kidney'),
#  '8264912': ('tissue', 'Kidney'),
#  '8267505': ('tissue', 'Skin'),
#  '8268097': ('tissue', 'Kidney'),
#  '8270948': ('tissue', 'Skin'),
#  '8279777': ('tissue', 'liver'),
#  '8289337': ('isolation_source', 'animal-swine-market swine'),
#  '8298857': ('isolation_source', 'wild boar sausage'),
#  '8331617': ('isolation_source', 'insect body'),
#  '8335178': ('isolation_source', 'intestines'),
#  '8346884': ('isolation_source',
#              'WT mouse chow diet before antibiotic treatment - cage 1 sample '
#              '3'),
#  '8361555': ('tissue', 'Leaves'),
#  '8382095': ('tissue', 'not applicable'),
#  '8388446': ('tissue', 'leaf'),
#  '8390660': ('tissue', 'Brain'),
#  '8390785': ('isolation_source', 'urine'),
#  '8391395': ('tissue', 'fin'),
#  '8397302': ('tissue', 'leaf'),
#  '8398983': ('tissue', 'ovary'),
#  '8433810': ('tissue', 'blood'),
#  '8436863': ('tissue', 'whole blood'),
#  '8444723': ('tissue', 'UBERON:feces'),
#  '8450143': ('tissue', 'leaf'),
#  '8459109': ('tissue', 'blood'),
#  '8459327': ('tissue', 'blood'),
#  '8461404': ('tissue', 'head/thorax'),
#  '8469228': ('tissue', 'Fetal pancreas'),
#  '8472236': ('tissue', 'Pancreas'),
#  '8482209': ('tissue', 'Leg'),
#  '8483264': ('tissue', 'Rectum'),
#  '8484435': ('tissue', 'Rectum'),
#  '8486225': ('tissue', 'Buccal mucosa'),
#  '8486726': ('tissue', 'Buccal mucosa'),
#  '8491951': ('tissue', 'Rectum'),
#  '8498986': ('tissue', 'leg'),
#  '8517352': ('sample_type', 'single cell'),
#  '8517446': ('isolation_source', 'blood'),
#  '8535115': ('tissue', 'Cortex'),
#  '8538369': ('tissue', 'Blood'),
#  '8538521': ('tissue', 'Blood'),
#  '8538582': ('tissue', 'Blood'),
#  '8543678': ('tissue', 'spleen'),
#  '8548835': ('tissue', 'spleen'),
#  '8556750': ('tissue', 'feces'),
#  '8557409': ('tissue', 'feces'),
#  '8562459': ('isolation_source', 'normally sterile site'),
#  '8563959': ('isolation_source', 'milk'),
#  '8575644': ('sample_type', 'bacterial culture'),
#  '8583560': ('isolation_source', 'urethra'),
#  '8583562': ('isolation_source', 'urethra'),
#  '8619395': ('sample_type', 'Montipora digitata1'),
#  '8629154': ('isolation_source', 'Not applicable'),
#  '8635886': ('tissue', 'Liver'),
#  '8638554': ('isolation_source', 'cattle fecal samples'),
#  '8647683': ('isolation_source', 'nasopharyngeal'),
#  '8648282': ('isolation_source', 'bulk soil'),
#  '8660769': ('isolation_source', 'missing'),
#  '8662582': ('isolation_source', 'milk'),
#  '8715335': ('tissue', 'Leaf'),
#  '8717009': ('tissue', 'liver tissue'),
#  '8726462': ('tissue', 'endometrium biopsy'),
#  '8732148': ('isolation_source', 'Not applicable'),
#  '8768147': ('tissue', 'blood'),
#  '8769618': ('strain', 'Q2-87'),
#  '8770341': ('tissue', 'leaves'),
#  '8770961': ('tissue', 'leaves'),
#  '8776722': ('strain', 'PP-F2F-G38'),
#  '8796728': ('strain', 'C57BL/6N'),
#  '8796862': ('isolation_source', 'human'),
#  '8803616': ('tissue', 'pool of 300 leafs from individual plants'),
#  '8803755': ('tissue', 'pool of 300 leafs from individual plants'),
#  '8806492': ('tissue', 'leaf'),
#  '8808083': ('tissue', 'Blood'),
#  '8812064': ('tissue', 'leaf'),
#  '8819511': ('isolation_source', 'plasma'),
#  '8819761': ('tissue', 'leaf'),
#  '8822160': ('isolation_source', 'human'),
#  '8822496': ('isolation_source', 'human'),
#  '8862895': ('isolation_source', 'Not applicable'),
#  '8892479': ('isolation_source', 'Not applicable'),
#  '8904521': ('tissue', 'young leaves'),
#  '8909279': ('tissue', 'Blood'),
#  '8911082': ('isolation_source', 'blood'),
#  '8919160': ('tissue', 'leaf'),
#  '8932936': ('tissue', 'Planulae'),
#  '8936564': ('isolation_source', 'feces blood'),
#  '8940535': ('tissue', 'rectum'),
#  '8951290': ('tissue', 'coral (host + endosymbionts)'),
#  '8988253': ('tissue', 'tree phloem'),
#  '9006701': ('tissue', 'Whole blood'),
#  '9017479': ('tissue', 'embryonic kidney'),
#  '9019784': ('tissue', 'Saliva'),
#  '9021426': ('tissue', 'Saliva'),
#  '9021770': ('tissue', 'Saliva'),
#  '9022277': ('tissue', 'Saliva'),
#  '9025718': ('tissue', 'Saliva'),
#  '9026280': ('tissue', 'Saliva'),
#  '9026982': ('tissue', 'Saliva'),
#  '9027146': ('tissue', 'Saliva'),
#  '9031246': ('tissue', 'Saliva'),
#  '9033950': ('tissue', 'Saliva'),
#  '9038390': ('tissue', 'Saliva'),
#  '9038526': ('tissue', 'Saliva'),
#  '9039582': ('tissue', 'Leaf'),
#  '9042258': ('tissue', 'not applicable'),
#  '9047506': ('tissue', 'Inner Oral Cavity'),
#  '9056003': ('tissue', 'Peripheral Blood'),
#  '9056942': ('tissue', 'Inner Oral Cavity'),
#  '9081307': ('strain', '1766'),
#  '9081877': ('sample_type', 'environment'),
#  '9090470': ('isolation_source', 'Not applicable'),
#  '9094002': ('isolation_source', 'Decomposing leaf litter'),
#  '9199099': ('isolation_source', 'paddy soil'),
#  '9201503': ('isolation_source', 'saline lake water'),
#  '9203647': ('isolation_source', 'human'),
#  '9217426': ('tissue', 'cells'),
#  '9233209': ('sample_type', 'bacterial culture'),
#  '9245058': ('tissue', 'stem'),
#  '9247051': ('tissue', 'Blood'),
#  '9248850': ('tissue', 'Blood'),
#  '9250591': ('tissue', 'Blood'),
#  '9251472': ('tissue', 'Lymphoblastoid Cell Line'),
#  '9268629': ('tissue', 'Thorax muscle'),
#  '9271758': ('tissue', 'bone marrow'),
#  '9283062': ('isolation_source', 'Cattle faeces'),
#  '9290616': ('tissue', 'Leaf'),
#  '9299461': ('tissue', 'renal cortex'),
#  '9317452': ('tissue', 'kidney'),
#  '9322629': ('tissue', 'liver'),
#  '9322859': ('tissue', 'blood'),
#  '9332032': ('tissue', 'leaf'),
#  '9333407': ('tissue', 'leaf'),
#  '9336073': ('tissue', 'leaf'),
#  '9356314': ('tissue', 'Blood'),
#  '9356613': ('tissue', 'Pancreas'),
#  '9370895': ('tissue', 'Leaf'),
#  '9372520': ('isolation_source', 'Comminuted Turkey'),
#  '9372596': ('isolation_source', 'raw intact chicken'),
#  '9375494': ('tissue', 'Tail'),
#  '9376060': ('tissue', 'Liver'),
#  '9380095': ('tissue', 'Bladder urothelium'),
#  '9380554': ('isolation_source', 'human'),
#  '9387072': ('tissue', 'Leaf'),
#  '9387370': ('isolation_source', 'human'),
#  '9396722': ('isolation_source', 'Dust'),
#  '9403907': ('isolation_source', 'human'),
#  '9425122': ('tissue', 'stem'),
#  '9429020': ('tissue', 'aerial part'),
#  '9435089': ('isolation_source', 'human'),
#  '9437361': ('isolation_source', 'arable land soil'),
#  '9440204': ('tissue', 'liver'),
#  '9440293': ('tissue', 'liver'),
#  '9442529': ('tissue', 'Arm/Hand Venipuncture'),
#  '9453437': ('tissue', 'seedling'),
#  '9453713': ('tissue', 'pancreatic cyst fluid'),
#  '9455903': ('tissue', 'primary Th17 lymphocytes'),
#  '9462858': ('isolation_source', 'human'),
#  '9469089': ('isolation_source', 'human'),
#  '9476385': ('isolation_source', 'human'),
#  '9484431': ('isolation_source', 'human'),
#  '9487403': ('tissue', 'midgut'),
#  '9489678': ('isolation_source', 'water'),
#  '9501973': ('tissue', 'blood'),
#  '9503550': ('isolation_source', 'human'),
#  '9508652': ('isolation_source', 'Auckland Westhaven Marine, NZ'),
#  '9517886': ('isolation_source', 'not applicable'),
#  '9520498': ('isolation_source', 'microcosm soil'),
#  '9565597': ('isolation_source', 'host'),
#  '9568786': ('isolation_source', 'feces'),
#  '9602333': ('isolation_source', 'fecal sample'),
#  '9605376': ('isolation_source', 'coral reef'),
#  '9621776': ('tissue', 'leaf'),
#  '9664860': ('tissue', 'ES-derived progenitors'),
#  '9664995': ('isolation_source', 'pathogen.cl'),
#  '9696158': ('isolation_source', 'feces'),
#  '9722743': ('tissue', 'feces'),
#  '9735075': ('tissue', 'liver'),
#  '9738666': ('tissue', 'Whole flies'),
#  '9738760': ('tissue', 'Whole flies'),
#  '9743687': ('tissue', 'adipose fin'),
#  '9746675': ('tissue', 'bone marrow'),
#  '9748158': ('tissue', 'fruit peel'),
#  '9756065': ('isolation_source', 'Mycobacterial Culture'),
#  '9760175': ('tissue', 'FRUIT12'),
#  '9760206': ('isolation_source', 'stool'),
#  '9762615': ('tissue', 'muscle'),
#  '9763015': ('tissue', 'UBERON:mouth'),
#  '9767135': ('sample_type', 'cell culture'),
#  '9770347': ('tissue', 'Liver'),
#  '9787662': ('isolation_source', 'missing'),
#  '9788843': ('isolation_source', 'cecum'),
#  '9793954': ('tissue', 'embryonic kidney'),
#  '9794988': ('tissue', 'embryonic kidney'),
#  '9795936': ('tissue', 'embryonic kidney'),
#  '9796185': ('tissue', 'embryonic kidney'),
#  '9796886': ('tissue', 'embryonic kidney'),
#  '9806717': ('tissue', 'embryonic kidney'),
#  '9816013': ('tissue', 'Blood'),
#  '9826181': ('tissue', 'Blood'),
#  '9827805': ('tissue', 'Blood'),
#  '9828157': ('tissue', 'Blood'),
#  '9838056': ('tissue', 'Primary breast tumor tissue'),
#  '9843408': ('tissue', 'cortical brain tissue'),
#  '9848206': ('isolation_source', 'missing'),
#  '9849647': ('isolation_source', 'sterile site'),
#  '9866405': ('isolation_source', 'comminuted beef'),
#  '9905518': ('isolation_source', 'Total RNA isolated from mouse carcasses'),
#  '9907152': ('isolation_source', 'stool'),
#  '9908163': ('tissue', 'connective tissue'),
#  '9911763': ('tissue', 'not applicable'),
#  '9912693': ('tissue', 'UBERON:lung'),
#  '9915174': ('tissue', 'blood'),
#  '9915398': ('tissue', 'ear tissue'),
#  '9920608': ('tissue', 'Leaf'),
#  '9923493': ('tissue', 'Leaf'),
#  '9928369': ('tissue', 'full body'),
#  '9936823': ('isolation_source', 'raw intact chicken'),
#  '9939344': ('isolation_source', 'not collected'),
#  '9947185': ('tissue', 'Semen'),
#  '9949659': ('tissue', 'tumor'),
#  '9953324': ('tissue', 'blood'),
#  '9983854': ('tissue', 'Normal stomach muscle'),
#  '9989470': ('strain', 'LPA8'),
#  '9994973': ('tissue', 'leaf')}
# 3777

# %% [markdown]
# ## Gettting search results from NCBI
#
# - https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=biosamples&term=blood
