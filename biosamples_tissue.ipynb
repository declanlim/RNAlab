# %%
from owlready2 import *
import pandas as pd
import xml.sax
import xml.etree.ElementTree as ET
from rapidfuzz import process
import rapidfuzz
import pprint
import time
import csv

# %% [markdown]
# ----
# # Loading data...
#
# - loads the BRENDA ontology OWL file
#     - loads the properties, classes and synonyms from BRENDA
#     - classes information split into names and labels
#     - properties split into annotation/object and also names and labels
# - loads the body_site_terms from a csv of manually collated terms

# %%
# load the BTO ontology
onto_path.append("/data/ontology")
onto = get_ontology("http://purl.obolibrary.org/obo/bto.owl").load()
# print(onto.base_iri)

# %%
# load class information and properties from the ontology
class_names = [c.name for c in onto.classes()]
# account for missing class labels in the ontology
class_labels = [c.label[0] if len(c.label) > 0 else '' for c in onto.classes()]
class_synonyms = {c.name: c.hasExactSynonym + c.hasRelatedSynonym for c in onto.classes()}

num_synonyms = 0

for class_label in onto.classes():
    num_synonyms += len(class_label.hasRelatedSynonym) + len(class_label.hasExactSynonym)

print("Num synonyms: ", num_synonyms)
# properties_names contains all properties, including object and annotation properties
# names list contains ontology
object_properties_names = [o.name for o in onto.object_properties()]
object_properties_labels = [o.label[0] if len(o.label) > 0 else o.name for o in onto.object_properties()]

annotation_properties_names = [a.name for a in onto.annotation_properties()]
annotation_properties_labels = [a.label[0] if len(a.label) > 0 else a.name for a in onto.annotation_properties()]

properties_names = [p.name for p in onto.properties()]
properties_labels = [p.label[0] if len(p.label) > 0 else p.name for p in onto.properties()]

print("Number of classes: ", len(class_names))
# print(class_synonyms)
# Out:
# Num synonyms:  6210
# Number of classes:  6569

# %%
# load the list of annotated body_site terms
body_site_terms = pd.read_csv("data/BioAnnotate_rh-body_site.csv", header=None)
# body_site_terms = body_site_terms[0].tolist()
body_site_terms = set(body_site_terms[0])

# %%
# print(onto.search(label="*bone*marrow*"))

for label in onto.search(label="*idio*"):
    print(label.name, label.label)

print(onto.search_one(label="*idio*").label)
# Out:
# BTO_0000114 ['basidiocarp']
# BTO_0000281 ['conidiophore']
# BTO_0001180 ['idioblast']
# BTO_0002166 ['basidiospore']
# ['basidiocarp']

# %% [markdown]
# ----
# # Parsing the Biosamples files
# - BioSamplesDictHandler looks at all the attributes for each biosample
#     - uses a fuzzy search to find the attribute that has the highest similarity to the attribute names in the body_site_terms
# - BioSamplesPackageHandler looks for 'useful' packages and finds the appropriate information
# - BioSamplesAttributeHandler looks through all attributes of all samples and checks if the attribute is within the possible_tissue set
#     - takes only the latest attribute in biosample
# - BioSamplesAttributeListHandler stores all matching attributes in a list of tuples

# %%
# load a single biosamples XML file. File 699 used due to smaller size
# SAX parser used to avoid memory issues - CAN IN THEORY LOAD ALL BIOSAMPLES IN ONE FILE
biosamples_path = "data/biosamples/biosample_random_samples.xml"
# biosamples_path = "data/biosamples/biosample_small.xml"

class BioSamplesDictHandler(xml.sax.ContentHandler):
    def __init__(self):
        super().__init__()
        self.attribute_name = ""
        self.num_samples = 0
        self.attribute_dict = {}
        self.sample_dict = {}
        self.biosample_id = ""

    def startElement(self, name, attrs):
        if name == "BioSample":
            self.num_samples += 1
            self.biosample_id = attrs["id"]

        elif name == "Attribute":
            self.attribute_name = attrs["attribute_name"]  
            
    def characters(self, content):
        if self.attribute_name != "":
            self.attribute_dict[self.attribute_name] = content
            self.attribute_name = ""


    def endElement(self, name):
        if name == "Attributes":
            if self.attribute_dict != {}:
                for key in self.attribute_dict.keys():
                    result = process.extractOne(key, body_site_terms, scorer=rapidfuzz.fuzz.ratio)
                    if result[1] > 87:
                        self.sample_dict[self.biosample_id] = (key, self.attribute_dict[key])
                        break
                    else:
                        self.sample_dict[self.biosample_id] = None
            self.attribute_dict = {}

    def endDocument(self):
        print("Number of possible tissue locations found: ", len([x for x in self.sample_dict.values() if x is not None]))
        print("Number of samples with at least one attribute: ", len(self.sample_dict))      
        # print the key value pairs in the sample dict that don't have None as the value in a list
        pprint.pprint([x for x in self.sample_dict.items() if x[1] is not None])

# %%
t1 = time.time()
parser = xml.sax.make_parser()
handler = BioSamplesDictHandler()
parser.setContentHandler(handler)
parser.parse(biosamples_path)
t2 = time.time()
print("Time taken: ", t2  -t1)

# using a direct lookup from body_site_terms, 45m 22.9s
# num_samples: 32526809
# num_tissue_samples: 6492612

# 17718
# 40839

# token sort ratio
# 3121
# Out:
# Number of possible tissue locations found:  3618
# Number of samples with at least one attribute:  9918
# [('24429',
#   ('histological type',
#    'Biopsy obtained in grossly disease unaffected region')),
#  ('24727', ('histological type', 'healthy')),
#  ('47520', ('body site', 'Primary Tumor')),
#  ('52257', ('histological type', 'Serous Cystadenocarcinoma')),
#  ('53145', ('histological type', 'Serous Cystadenocarcinoma')),
#  ('53717', ('histological type', 'Serous Cystadenocarcinoma')),
#  ('54997', ('histological type', 'Untreated primary (De Nova) GBM')),
#  ('56953', ('body site', 'Blood Derived Normal')),
#  ('61491', ('body site', 'Primary Tumor')),
#  ('92151', ('body site', 'Primary Tumor')),
#  ('93344', ('body site', 'Primary Tumor')),
#  ('116303', ('body site', 'Blood')),
#  ('123336', ('histological type', 'Serous Cystadenocarcinoma')),
#  ('154619', ('tissue-type', 'spleen')),
#  ('158248', ('organ', 'testis')),
#  ('158377', ('organ', 'breast')),
#  ('161214', ('organ', 'marrow')),
#  ('174739', ('tissue-type', 'Pooled samples from 6 adult Xenopus testis')),
#  ('176111', ('tissue-type', 'Flavedo, albedo, some red scale')),
#  ('176234', ('tissue-type', 'skin')),
#  ('182671', ('tissue-type', 'Blood')),
#  ('207804', ('body site', 'Blood')),
#  ('209188', ('body site', 'Blood')),
#  ('218984', ('body site', 'Blood')),
#  ('250374', ('histological type', 'NA')),
#  ('259166', ('histological type', 'NA')),
#  ('259774', ('body site', 'Blood')),
#  ('272252', ('body site', 'blood')),
#  ('282424', ('body site', 'blood')),
#  ('285590', ('body site', 'BLOOD')),
#  ('299261', ('body site', 'blood')),
#  ('299409', ('body site', 'blood')),
#  ('300388', ('body site', 'blood')),
#  ('302005', ('body site', 'blood')),
#  ('302869', ('body site', 'Blood')),
#  ('314075', ('body site', 'Blood')),
#  ('320480', ('body site', 'Blood')),
#  ('330926', ('body site', 'Blood')),
#  ('358984', ('body site', 'Blood')),
#  ('376017', ('body site', 'Blood')),
#  ('378418', ('body site', 'Blood')),
#  ('383282', ('body site', 'BLOOD')),
#  ('398656', ('body site', 'Blood')),
#  ('425799', ('body site', 'Blood')),
#  ('426758', ('body site', 'Blood')),
#  ('426891', ('body site', 'Blood')),
#  ('428706', ('body site', 'Blood')),
#  ('452333', ('body site', 'Blood')),
#  ('461095', ('body site', 'Blood')),
#  ('463605', ('body site', 'Blood')),
#  ('468809', ('body site', 'Peripheral Blood')),
#  ('472080', ('body site', 'Peripheral Blood')),
#  ('479608', ('body site', 'Blood')),
#  ('489008', ('body site', 'Saliva or Blood')),
#  ('517051', ('body site', 'Blood')),
#  ('518279', ('body site', 'Blood')),
#  ('519059', ('body site', 'Blood')),
#  ('519521', ('body site', 'Blood')),
#  ('519689', ('body site', 'Blood')),
#  ('520440', ('body site', 'Blood')),
#  ('524175', ('body site', 'Blood')),
#  ('528239', ('body site', 'Blood')),
#  ('528273', ('body site', 'Blood')),
#  ('529484', ('body site', 'Blood')),
#  ('530324', ('body site', 'Blood')),
#  ('531605', ('body site', 'Blood')),
#  ('531794', ('body site', 'Blood')),
#  ('533664', ('body site', 'Blood')),
#  ('560642', ('body site', 'Peripheral Blood')),
#  ('560780', ('body site', 'Peripheral Blood')),
#  ('578669', ('body site', 'Blood')),
#  ('604885', ('body site', 'BLOOD')),
#  ('605938', ('body site', 'BLOOD')),
#  ('608849', ('body site', 'blood')),
#  ('612064', ('body site', 'blood')),
#  ('622379', ('tissue-type', 'gonads; digestive gland; peripheral tissue')),
#  ('631173', ('cell line', 'K562')),
#  ('672804', ('body site', 'STOMACH')),
#  ('675393', ('body site', 'Cell Line')),
#  ('677582', ('body site', 'Blood')),
#  ('679140', ('histological type', 'Serous Cystadenocarcinoma')),
#  ('694064', ('body site', 'Blood')),
#  ('695796', ('body site', 'Blood')),
#  ('698011', ('body site', 'Blood')),
#  ('700466', ('body site', 'Whole_Blood')),
#  ('703128', ('body site', 'Whole_Blood')),
#  ('703213', ('body site', 'Whole_Blood')),
#  ('704535', ('body site', 'Peripheral Whole Blood')),
#  ('704832', ('body site', 'Peripheral Whole Blood')),
#  ('707939', ('body site', 'Blood')),
#  ('760136', ('body site', 'Blood')),
#  ('761804',
#   ('cell description',
#    'B-lymphocyte, lymphoblastoid, International HapMap Project - CEPH/Utah - '
#    'European Caucasion, Epstein-Barr Virus')),
#  ('762142', ('body site', 'cell line')),
#  ('772423', ('body site', 'Blood')),
#  ('773642', ('cell type', 'Schwann cells')),
#  ('775093', ('body site', 'Blood')),
#  ('775310', ('body site', 'Blood')),
#  ('775524', ('body site', 'Blood')),
#  ('784669', ('body site', 'Blood')),
#  ('804677', ('cell_line', 'GM16776')),
#  ('805259', ('cell_line', 'ND28953')),
#  ('806148', ('cell_line', 'GM22123')),
#  ('807139', ('cell_line', 'GM01750')),
#  ('813449', ('body site', 'Blood')),
#  ('829097', ('tissue', 'Oldest 4 to 6 leaves')),
#  ('831042', ('body site', 'blood')),
#  ('832160', ('body site', 'blood')),
#  ('835988', ('body site', 'Blood')),
#  ('844633', ('body site', 'Serum')),
#  ('848966', ('body site', 'Blood')),
#  ('854240', ('body site', 'Blood')),
#  ('855695', ('body_habitat', 'UBERON:oral cavity')),
#  ('865526', ('body site', 'blood')),
#  ('865590', ('body site', 'blood')),
#  ('866983', ('body site', 'serum')),
#  ('881219', ('body site', 'cell line')),
#  ('884550', ('body site', 'blood')),
#  ('887077', ('body site', 'blood')),
#  ('887218', ('body site', 'BLOOD')),
#  ('887768', ('body site', 'blood')),
#  ('909081', ('body site', 'Blood')),
#  ('910382', ('body site', 'Blood')),
#  ('911242', ('body site', 'Blood')),
#  ('916604', ('body site', 'Blood')),
#  ('922416', ('body site', 'Blood')),
#  ('934081', ('body site', 'Blood')),
#  ('941721', ('body site', 'Primary Solid Tumor')),
#  ('945679', ('body site', 'blood')),
#  ('949659', ('body site', 'blood')),
#  ('968654', ('body site', 'blood')),
#  ('969447', ('body site', 'blood')),
#  ('969699', ('body site', 'blood')),
#  ('979049', ('body site', 'blood')),
#  ('981119', ('body site', 'cell line')),
#  ('984126', ('body site', 'serum')),
#  ('984728', ('body site', 'blood')),
#  ('992886', ('body site', 'Skin - Sun Exposed (Lower leg)')),
#  ('1001155', ('cell', 'K562')),
#  ('1010871', ('histological type', 'Serous Cystadenocarcinoma')),
#  ('1011237', ('histological type', 'Serous Cystadenocarcinoma')),
#  ('1016302', ('body site', 'Blood Derived Normal')),
#  ('1017232', ('histological type', 'Serous Cystadenocarcinoma')),
#  ('1019055', ('histological type', 'Serous Cystadenocarcinoma')),
#  ('1019835', ('body site', 'Primary Tumor')),
#  ('1020939', ('histological type', 'Serous Cystadenocarcinoma')),
#  ('1024172', ('body site', 'Blood Derived Normal')),
#  ('1026551', ('body site', 'Primary Tumor')),
#  ('1029614', ('body site', 'Blood Derived Normal')),
#  ('1031861', ('body site', 'Primary Tumor')),
#  ('1035394', ('body site', 'Primary Tumor')),
#  ('1035593', ('histological type', 'Untreated primary (De Nova) GBM')),
#  ('1036321', ('histological type', 'Untreated primary (De Nova) GBM')),
#  ('1059948', ('body site', 'Peripheral blood')),
#  ('1060375', ('body site', 'Peripheral blood')),
#  ('1085711',
#   ('tissue source',
#    'Inoculated tomato roots, 2 days after inoculation with 10000 P. parasitica '
#    'zoospores')),
#  ('1092921', ('body site', 'Blood')),
#  ('1104677', ('body site', 'Saliva')),
#  ('1123101', ('body site', 'Blood')),
#  ('1123138', ('body site', 'Blood')),
#  ('1127487', ('body site', 'BLOOD')),
#  ('1133932', ('body site', 'Blood')),
#  ('1134344', ('body site', 'Blood')),
#  ('1135797', ('body site', 'blood')),
#  ('1157998', ('body site', 'blood')),
#  ('1183519', ('body site', 'blood')),
#  ('1223953', ('body site', 'blood')),
#  ('1666231', ('body site', 'Blood')),
#  ('1667516', ('body site', 'Blood')),
#  ('1677325', ('body site', 'Blood')),
#  ('1678158', ('body site', 'Blood')),
#  ('1728246', ('body site', 'Blood')),
#  ('1733436', ('body site', 'Blood')),
#  ('1734234', ('body site', 'Blood')),
#  ('1735228', ('body site', 'Blood')),
#  ('1780402', ('body site', 'N/A')),
#  ('1815053', ('body site', 'whole blood')),
#  ('1820583', ('body site', 'Primary Solid Tumor')),
#  ('1833685', ('body site', 'blood')),
#  ('1834737', ('body site', 'blood')),
#  ('1842422', ('body site', 'BLOOD')),
#  ('1845154', ('body site', 'Blood')),
#  ('1847662', ('body site', 'Blood')),
#  ('1848612', ('body site', 'Blood')),
#  ('1864579', ('body site', 'BLOOD')),
#  ('1873727', ('body site', 'blood')),
#  ('1903343', ('body site', 'Blood')),
#  ('1903639', ('body site', 'Blood')),
#  ('1906630', ('tissue', 'breast tumor')),
#  ('1913949', ('body site', 'Whole Blood')),
#  ('1925881', ('body site', 'blood')),
#  ('1934953', ('body site', 'Blood')),
#  ('1978304', ('tissue type', 'seedling')),
#  ('1979567', ('body site', 'Blood')),
#  ('1988869', ('body site', 'Blood')),
#  ('2010857', ('body site', 'Blood')),
#  ('2014880', ('body site', 'Blood')),
#  ('2016366', ('body site', 'Blood')),
#  ('2017151', ('body site', 'Blood')),
#  ('2018405', ('body site', 'Blood')),
#  ('2021401', ('body site', 'Blood')),
#  ('2023613', ('body site', 'Blood')),
#  ('2028240', ('tissue', 'liver')),
#  ('2036960', ('body site', 'Blood')),
#  ('2037866', ('body site', 'Blood')),
#  ('2125716', ('histological type', 'NA')),
#  ('2136093', ('histological type', 'NA')),
#  ('2136288', ('histological type', 'NA')),
#  ('2136867', ('histological type', 'NA')),
#  ('2148164', ('body site', 'Blood')),
#  ('2149514', ('body site', 'Blood')),
#  ('2154036', ('body site', 'blood')),
#  ('2159929', ('body site', 'Blood')),
#  ('2164326', ('body site', 'blood')),
#  ('2170116', ('body site', 'cell line')),
#  ('2171996', ('body site', 'blood')),
#  ('2172204', ('body site', 'cell line')),
#  ('2173920', ('body site', 'blood')),
#  ('2178656', ('body_site', 'PBMCs')),
#  ('2211699', ('collection site', 'feces')),
#  ('2221472', ('body site', 'blood')),
#  ('2223803', ('body site', 'Blood')),
#  ('2256048', ('body site', 'BLOOD')),
#  ('2256973', ('cell type', 'BMDC')),
#  ('2265149', ('body site', 'Liver')),
#  ('2266438', ('body site', 'Blood')),
#  ('2268649', ('body site', 'Blood')),
#  ('2271410', ('body site', 'Blood')),
#  ('2271963', ('body site', 'Blood')),
#  ('2276390', ('body site', 'Blood')),
#  ('2276754', ('body site', 'Blood')),
#  ('2278320', ('body site', 'Blood')),
#  ('2282069', ('body site', 'Blood')),
#  ('2282655', ('body site', 'Blood')),
#  ('2286190', ('body site', 'Blood')),
#  ('2292257', ('body site', 'Blood')),
#  ('2299297', ('body site', 'Breast epithelium')),
#  ('2307207', ('body site', 'Blood')),
#  ('2308360', ('body site', 'Blood')),
#  ('2312142', ('body site', 'Blood')),
#  ('2312369', ('body site', 'Blood')),
#  ('2329377', ('body site', 'Buffy Coat')),
#  ('2330081', ('body site', 'Unknown')),
#  ('2347460', ('cell line', '3T3-L1')),
#  ('2354806', ('body site', 'blood')),
#  ('2355212', ('body site', 'blood')),
#  ('2366798', ('fungi_head', 'no')),
#  ('2376894',
#   ('tissue',
#    'single cell circulating in mouse blood enriched for tumor cells')),
#  ('2377110', ('body_site', 'plasma')),
#  ('2381366', ('cell_type', 'whole blood')),
#  ('2396744', ('body site', 'Peripheral blood')),
#  ('2408377', ('body site', 'Peripheral Blood')),
#  ('2411395', ('histological type', 'PBMC')),
#  ('2411875', ('histological type', 'PBMC')),
#  ('2429100', ('cell line', 'S2')),
#  ('2439874',
#   ('cell type', 'Human Umbilical Cord Blood CD34+ Hematopoietic Stem Cells')),
#  ('2446356', ('body site', 'Blood')),
#  ('2447029', ('body site', 'Blood')),
#  ('2450509', ('body site', 'Blood')),
#  ('2452554', ('body site', 'Blood')),
#  ('2460115', ('body site', 'Blood')),
#  ('2468131', ('body site', 'blood')),
#  ('2474110', ('body site', 'Blood')),
#  ('2476709', ('body site', 'Blood')),
#  ('2480689', ('body site', 'Blood')),
#  ('2485825', ('tissue', 'aerial shoots')),
#  ('2489651', ('body site', 'Saliva')),
#  ('2492787', ('body site', 'Saliva')),
#  ('2493735', ('body site', 'Saliva')),
#  ('2500739', ('body site', 'Saliva')),
#  ('2504380', ('body site', 'Saliva')),
#  ('2505106', ('body site', 'Saliva')),
#  ('2508270', ('body site', 'Saliva')),
#  ('2515258', ('body site', 'Saliva')),
#  ('2520595', ('body site', 'Saliva')),
#  ('2522594', ('body site', 'Saliva')),
#  ('2522692', ('body site', 'Saliva')),
#  ('2523445', ('body site', 'Saliva')),
#  ('2526296', ('body site', 'Saliva')),
#  ('2527481', ('body site', 'Saliva')),
#  ('2530821', ('body site', 'Saliva')),
#  ('2535564', ('body site', 'Saliva')),
#  ('2535721', ('body site', 'Saliva')),
#  ('2539976', ('body site', 'Saliva')),
#  ('2543510', ('body site', 'Saliva')),
#  ('2545304', ('body site', 'Saliva')),
#  ('2551924', ('body site', 'Saliva')),
#  ('2557265', ('body site', 'Saliva')),
#  ('2558790', ('body site', 'Saliva')),
#  ('2560776', ('body site', 'Saliva')),
#  ('2566853', ('tissue_type', 'Peripheral Retina_3')),
#  ('2569421', ('Biopsy_grade', '1R/1A')),
#  ('2573698', ('body site', 'blood - buffy coat')),
#  ('2574434', ('body site', 'blood - buffy coat')),
#  ('2583970', ('body site', 'Cerebellum; Frontal cortex')),
#  ('2606593', ('body site', 'Blood')),
#  ('2620022', ('body site', 'Blood')),
#  ('2621333', ('body site', 'Blood')),
#  ('2625996', ('body site', 'Femoral Arterial Sheath')),
#  ('2626724', ('body site', 'Femoral Arterial Sheath')),
#  ('2631714', ('body site', 'Blood')),
#  ('2632405', ('body site', 'Blood')),
#  ('2634631', ('body site', 'Blood')),
#  ('2634767', ('body site', 'Blood')),
#  ('2635389', ('body site', 'Blood')),
#  ('2636636', ('body site', 'Blood')),
#  ('2637066', ('body site', 'Blood')),
#  ('2638950', ('body site', 'Blood')),
#  ('2647342', ('body site', 'Blood')),
#  ('2647908', ('body site', 'BLOOD')),
#  ('2648756', ('body site', 'BLOOD')),
#  ('2648800', ('body site', 'BLOOD')),
#  ('2652663', ('body site', 'Blood')),
#  ('2657017', ('body site', 'WHOLE BLOOD')),
#  ('2675490', ('cell type', 'embryonic stem cells')),
#  ('2676855', ('body site', 'blood')),
#  ('2678379', ('cell line', 'GM06170')),
#  ('2683459', ('body site', 'Blood')),
#  ('2683759', ('body site', 'Blood')),
#  ('2683796', ('body site', 'Saliva')),
#  ('2687766', ('cell line', 'Swiss 3T3')),
#  ('2694955', ('body site', 'Neonatal Saliva')),
#  ('2695066', ('body site', 'Maternal Blood')),
#  ('2715067', ('body site', 'BLOOD')),
#  ('2749025', ('body_habitat', 'UBERON:feces')),
#  ('2754949', ('body site', 'Blood')),
#  ('2762958', ('cell line', 'primary cell culture of spleenocytes')),
#  ('2768740', ('tissue', 'heart/liver/muscle')),
#  ('2777608', ('env_material', 'sediment')),
#  ('2789232', ('body site', 'Brain - Cerebellum')),
#  ('2792299', ('body site', 'Brain - Cortex')),
#  ('2792650', ('body site', 'Heart - Left Ventricle')),
#  ('2808608', ('env_material', 'air')),
#  ('2810925', ('histological type', 'blood')),
#  ('2814529', ('histological type', 'blood')),
#  ('2815181', ('histological type', 'blood')),
#  ('2825841', ('histological type', 'blood')),
#  ('2827834', ('histological type', 'blood')),
#  ('2829693', ('histological type', 'blood')),
#  ('2843191', ('tissue', 'not collected')),
#  ('2850765', ('tissue', 'testis')),
#  ('2851944', ('env_material', 'raw water metagenome')),
#  ('2852589', ('env_material', 'fecal contents')),
#  ('2855565', ('body site', 'Blood')),
#  ('2856544', ('body site', 'Blood')),
#  ('2859835', ('body site', 'Blood')),
#  ('2860277', ('body site', 'Blood')),
#  ('2875134', ('body site', 'blood')),
#  ('2877239', ('body site', 'blood')),
#  ('2877737', ('body site', 'blood')),
#  ('2882633', ('body site', 'blood')),
#  ('2883774', ('body site', 'blood')),
#  ('2887874', ('body site', 'Blood')),
#  ('2889757', ('body site', 'Blood')),
#  ('2896343', ('body site', 'Peripheral blood')),
#  ('2896843', ('body site', 'Blood')),
#  ('2897406', ('body habitat', 'UBERON:stomach')),
#  ('2899688', ('tissue', 'Right Inferior Colliculus on Trizol')),
#  ('2899750', ('env_material', 'Soil')),
#  ('2900496', ('tissue', 'whole embryos')),
#  ('2904547', ('tissue', 'kidney')),
#  ('2907685', ('cell type', 'multipotent progenitor')),
#  ('2917574', ('body site', 'BLOOD')),
#  ('2928308', ('env_material', 'feces')),
#  ('2933504', ('body site', 'Saliva')),
#  ('2946696', ('tissue', 'Leaf')),
#  ('2956244', ('body site', 'Blood')),
#  ('2959647', ('body site', 'Blood')),
#  ('2961030', ('body site', 'Blood')),
#  ('2978307', ('body site', 'Blood')),
#  ('2989212', ('tissue', 'Skin')),
#  ('2992202', ('body site', 'Saliva')),
#  ('2992724', ('body site', 'Saliva')),
#  ('2996273', ('body site', 'Whole Blood')),
#  ('3008286', ('cell type', 'v6.5 mouse embryonic stem cells')),
#  ('3020844', ('tissue', 'piece of toes')),
#  ('3025460', ('env_material', 'Ss')),
#  ('3031873', ('env_material', 'not applicable')),
#  ('3033648', ('body site', 'blood')),
#  ('3033682', ('body site', 'blood')),
#  ('3040714', ('body site', 'blood')),
#  ('3041211', ('body site', 'cell')),
#  ('3043252', ('body site', 'blood')),
#  ('3052392', ('body site', 'Blood')),
#  ('3054494', ('body site', 'Blood')),
#  ('3057911', ('body site', 'Blood')),
#  ('3058498', ('body site', 'Blood')),
#  ('3059307', ('body site', 'Blood')),
#  ('3061164', ('body site', 'Blood')),
#  ('3064489', ('body site', 'Blood')),
#  ('3064500', ('body site', 'Blood')),
#  ('3073467', ('tissue', 'fin clips')),
#  ('3073625', ('cell type', 'haematopoietic stem cell')),
#  ('3075143', ('tissue', 'a bud and a leaf')),
#  ('3079509', ('tissue', 'Hippocampus')),
#  ('3080864', ('body site', 'PBMC')),
#  ('3085473', ('cell line', 'G1ME')),
#  ('3090370', ('tissue_type', 'leaf')),
#  ('3093807', ('body habitat', 'UBERON:feces')),
#  ('3094068', ('body habitat', 'UBERON:feces')),
#  ('3099491', ('bio material', 'Faeces')),
#  ('3100383', ('env_material', 'not collected')),
#  ('3103296', ('tissue', 'cheek_cells')),
#  ('3104763',
#   ('cell type',
#    'an immortalized but non-transformed ovarian epithelial cell line')),
#  ('3105976', ('tissue', 'Whole organism')),
#  ('3115667', ('body site', 'blood')),
#  ('3120771', ('cell type', 'Alveolar macrophages')),
#  ('3124275', ('body site', 'Blood or Buccal')),
#  ('3128008', ('body site', 'Blood')),
#  ('3128035', ('body site', 'Blood')),
#  ('3130482', ('body site', 'Blood')),
#  ('3130618', ('body site', 'Blood or Buccal')),
#  ('3131086', ('body site', 'Blood')),
#  ('3133295', ('body site', 'Blood')),
#  ('3136241', ('body site', 'Blood')),
#  ('3139003', ('body site', 'Blood')),
#  ('3158439', ('body_habitat', 'UBERON:feces')),
#  ('3162955', ('body habitat', 'UBERON:feces')),
#  ('3196559', ('env_material', 'microbial mat/biofilm')),
#  ('3198379', ('tissue', 'right upper lobe PSB')),
#  ('3201273', ('cell line', 'MCF-10A-H1047R')),
#  ('3216830', ('tissue', 'seedling')),
#  ('3219249', ('tissue', 'colon')),
#  ('3220256', ('tissue', '4 pairs of antennae')),
#  ('3223188', ('tissue', 'blood or bone marrow')),
#  ('3247476', ('body site', 'Saliva')),
#  ('3252382', ('tissue', 'Blood')),
#  ('3256908', ('cell type', 'human embryonic stem cells')),
#  ('3260267', ('tissue', 'leaf')),
#  ('3260499', ('tissue', 'leaf')),
#  ('3262581', ('tissue', 'young leaf')),
#  ('3263233', ('body site', 'Blood')),
#  ('3267815', ('tissue', 'Liver')),
#  ('3269936', ('env_material', 'fecal')),
#  ('3276754', ('env_material', 'saline water')),
#  ('3287069', ('tissue', 'cell line')),
#  ('3290052', ('env_material', 'soil')),
#  ('3324088', ('cell type', 'iPSC derived motor neuron')),
#  ('3326721', ('tissue', 'leaf')),
#  ('3330171', ('cell type', 'sperm')),
#  ('3333588', ('cell type', 'Enodthelial cells')),
#  ('3343355', ('cell_type', 'CELL MIXTURE - tissue sample')),
#  ('3344689', ('env_material', 'water')),
#  ('3355849', ('body site', 'Blood')),
#  ('3363755', ('body site', 'Blood')),
#  ('3370223', ('body site', 'peripheral blood')),
#  ('3371014', ('body site', 'peripheral blood')),
#  ('3376029', ('env_material', 'oropharynx')),
#  ('3381267', ('env_material', 'soil')),
#  ('3381269', ('tissue', 'not applicable')),
#  ('3406698', ('tissue', 'Seedling')),
#  ('3409983', ('body site', 'SALIVA')),
#  ('3413115', ('body site', 'BLOOD')),
#  ('3413551', ('body site', 'BLOOD')),
#  ('3418025', ('env_material', 'Not applicable')),
#  ('3424538', ('body site', 'BLOOD')),
#  ('3424811', ('body site', 'BLOOD')),
#  ('3425435', ('body site', 'BLOOD')),
#  ('3426694', ('body site', 'BLOOD')),
#  ('3432178', ('body site', 'blood')),
#  ('3433125', ('body site', 'Liver')),
#  ('3438287', ('body site', 'Peripheral Blood')),
#  ('3450948', ('tissue', 'liver')),
#  ('3451285', ('env_material', 'Ectomycorrhizal roots')),
#  ('3471251', ('cell line', 'CCD-919Sk')),
#  ('3490477', ('tissue', 'embryo')),
#  ('3498499', ('body site', 'Saliva')),
#  ('3499282', ('body site', 'Saliva')),
#  ('3503287', ('body site', 'Saliva')),
#  ('3507889', ('body site', 'Blood')),
#  ('3510669', ('body site', 'NULL')),
#  ('3518317', ('body site', 'NULL')),
#  ('3523007', ('body site', 'NULL')),
#  ('3524273', ('body site', 'NULL')),
#  ('3525709', ('body site', 'NULL')),
#  ('3527569', ('body site', 'NULL')),
#  ('3529132', ('body site', 'NULL')),
#  ('3538668', ('body site', 'NULL')),
#  ('3540472', ('body site', 'NULL')),
#  ('3559024', ('body site', 'NULL')),
#  ('3564113', ('body site', 'NULL')),
#  ('3604646', ('body site', 'blood')),
#  ('3605549', ('body site', 'blood')),
#  ('3606298', ('body site', 'buccal')),
#  ('3611129', ('env_material', 'Human gut')),
#  ('3617945', ('body site', 'blood')),
#  ('3621905', ('body site', 'blood')),
#  ('3622195', ('body site', 'blood')),
#  ('3624150', ('body site', 'blood')),
#  ('3624392', ('body site', 'blood')),
#  ('3628211', ('body site', 'blood')),
#  ('3642173', ('body site', 'blood')),
#  ('3654194', ('body site', 'Peripheral blood')),
#  ('3660222', ('body site', 'Blood')),
#  ('3663251', ('body site', 'Blood')),
#  ('3670799', ('body site', 'Blood')),
#  ('3670825', ('body site', 'Blood')),
#  ('3671428', ('body site', 'Blood')),
#  ('3675248', ('body site', 'Blood')),
#  ('3679727', ('body site', 'Blood')),
#  ('3683539', ('body site', 'Blood')),
#  ('3691756', ('body site', 'Blood')),
#  ('3758587', ('env_material', 'Gut_DB13')),
#  ('3770822', ('env_material', 'Faeces')),
#  ('3776368', ('body site', 'pleural cavity')),
#  ('3782480', ('env_material', 'fecal')),
#  ('3782509', ('tissue', 'berry')),
#  ('3783064', ('tissue', 'normal lung')),
#  ('3786774', ('body site', 'WHOLE BLOOD')),
#  ('3786986', ('env_material', 'NA')),
#  ('3788115', ('cell line', 'HEK 293 T-REx cell')),
#  ('3796556', ('body site', 'Peripheral Blood')),
#  ('3800577', ('tissue', 'blood')),
#  ('3817126', ('env_material', 'Feces')),
#  ('3821794', ('body site', 'cellline_for_SNP_EXOME')),
#  ('3829704', ('body site', 'cellline_for_SNP_EXOME')),
#  ('3831668', ('body site', 'blood_for_SNP_EXOME')),
#  ('3832100', ('body site', 'blood_for_Array_SNP')),
#  ('3835781', ('tissue', 'fish fin')),
#  ('3840687', ('tissue', 'Whole-body')),
#  ('3850814', ('tissue', 'ovary chromatin')),
#  ('3868065', ('tissue', 'saliva')),
#  ('3869551', ('tissue', 'saliva')),
#  ('3874107', ('tissue', 'saliva')),
#  ('3876478', ('tissue', 'saliva')),
#  ('3876679',
#   ('cell type', 'MLL-AF9 c-kit+ leukemic spleen cells Dnmt3b-knockin')),
#  ('3877854', ('body site', 'Whole Blood')),
#  ('3892362', ('tissue', 'Feces')),
#  ('3892665', ('cell type', 'non-B cells from spleen')),
#  ('3894041', ('tissue', 'wing biopsy')),
#  ('3894711', ('body site', 'Blood')),
#  ('3895248', ('body site', 'Blood')),
#  ('3898062', ('body site', 'BLOOD')),
#  ('3900954', ('body site', 'BLOOD')),
#  ('3901034', ('body site', 'BLOOD')),
#  ('3912962', ('body site', 'Blood')),
#  ('3915259', ('body site', 'blood')),
#  ('3919089', ('histological type', 'blood')),
#  ('3919302', ('histological type', 'blood')),
#  ('3920638', ('histological type', 'blood')),
#  ('3935517', ('body site', 'Blood')),
#  ('3936355', ('body site', 'Blood')),
#  ('3937448', ('body site', 'Blood')),
#  ('3939810', ('env_material', 'feces')),
#  ('3943901', ('cell type', 'mouse embryonic fibroblast')),
#  ('3944397', ('tissue', 'brain')),
#  ('3953135', ('body site', 'Peripheral blood')),
#  ('3960177', ('env_material', 'oil contaminated soil')),
#  ('3960465', ('body site', 'blood')),
#  ('3963132', ('body site', 'Lymph node')),
#  ('3977890', ('body site', 'peripheral blood')),
#  ('3978382', ('body site', 'peripheral blood')),
#  ('3979862', ('cell line', 'H1')),
#  ('3984322', ('body site', 'BLOOD')),
#  ('3987635', ('body site', 'BLOOD')),
#  ('4015105', ('tissue', 'ovarian')),
#  ('4016471', ('body site', 'Blood')),
#  ('4017801', ('tissue', 'whole blood')),
#  ('4025705', ('tissue', 'lung')),
#  ('4025796', ('cell line', 'Gliobmastoma cell line')),
#  ('4026157', ('cell type', 'Human induced pluripotent stem cells')),
#  ('4034007', ('body site', 'Whole Blood')),
#  ('4039610', ('tissue', 'liver')),
#  ('4040752', ('tissue', 'leaf')),
#  ('4055058', ('body site', 'blood')),
#  ('4063127', ('body site', 'blood')),
#  ('4063378', ('body site', 'blood')),
#  ('4065080', ('body site', 'blood')),
#  ('4065422', ('body site', 'blood')),
#  ('4068845', ('body site', 'blood')),
#  ('4069315', ('body site', 'blood')),
#  ('4072465', ('body site', 'Peripheral_Blood')),
#  ('4073116', ('body site', 'Peripheral_Blood')),
#  ('4078557', ('histological type', 'blood')),
#  ('4084799', ('histological type', 'blood')),
#  ('4087325', ('tissue', 'liver')),
#  ('4091500', ('tissue', 'Lung Lessions')),
#  ('4095866', ('tissue', 'muscle')),
#  ('4111681', ('body site', 'Blood')),
#  ('4123951', ('tissue', 'ovary')),
#  ('4125683', ('cell line', 'MCF7')),
#  ('4139760', ('body site', 'Blood')),
#  ('4141779', ('body site', 'Blood')),
#  ('4143845', ('body site', 'Blood')),
#  ('4146025', ('tissue', 'Whole blood')),
#  ('4156907', ('tissue', 'whole mosquito')),
#  ('4176366', ('body site', 'Oragene Saliva')),
#  ('4180458', ('body site', 'Buccal')),
#  ('4183192', ('body site', 'Buccal')),
#  ('4184894', ('env_material', '69.38 N 20.29 E')),
#  ('4188769', ('env_material', 'sterile water')),
#  ('4190935', ('env_material', 'sterile water')),
#  ('4191201', ('body habitat', 'UBERON:feces')),
#  ('4194192', ('cell type', 'Bone marrow-derived dendritic cells')),
#  ('4197782', ('body site', 'Blood')),
#  ('4212270', ('histological type', 'Ampullary adenocarcinoma')),
#  ('4212751', ('body habitat', 'UBERON:feces')),
#  ('4221139', ('tissue', 'Spleen')),
#  ('4228958', ('tissue', 'missing')),
#  ('4228990', ('tissue', 'missing')),
#  ('4244281', ('tissue', 'A375 tumor')),
#  ('4248406', ('body site', 'Blood')),
#  ('4253520', ('body site', 'Blood')),
#  ('4256876', ('body site', 'Frozen blood')),
#  ('4258756', ('body site', 'Frozen blood')),
#  ('4265584', ('body site', 'blood')),
#  ('4265771', ('body site', 'blood')),
#  ('4272077', ('env_material', 'beach sand')),
#  ('4279323', ('host_tissue_sampled', 'pleopods and gills')),
#  ('4280722', ('cell type', 'lymphoblastoid cell line (LCL)')),
#  ('4281323', ('body site', 'blood')),
#  ('4283909', ('tissue', 'body')),
#  ('4285346', ('tissue', 'ventral lips')),
#  ('4306061', ('tissue', 'peripheral venous blood')),
#  ('4313467', ('cell type', 'ex vivo single Tcell')),
#  ('4328089', ('tissue', 'brain')),
#  ('4333625', ('body site', 'NULL')),
#  ('4334134', ('body site', 'NULL')),
#  ('4335652', ('tissue', 'tibialis anterior (skeletal muscle)')),
#  ('4336569', ('tissue', 'developing xylem')),
#  ('4341209', ('body site', 'Blood')),
#  ('4342695', ('body site', 'Blood')),
#  ('4349627', ('tissue', 'young leaves')),
#  ('4352969', ('body habitat', 'UBERON:feces')),
#  ('4354084', ('body site', 'RLat')),
#  ('4354513', ('body site', 'LHip')),
#  ('4364667', ('cell type', 'Mouse embryonic fibroblasts')),
#  ('4367488', ('body site', 'Saliva')),
#  ('4368975', ('body site', 'Saliva')),
#  ('4382339', ('env_material', 'feces')),
#  ('4384927', ('body habitat', 'UBERON:skin')),
#  ('4388119', ('env_material', 'feces')),
#  ('4392647', ('tissue', 'outflow tract')),
#  ('4395648', ('tissue', 'Calcified tricuspid aortic valve (TAV)')),
#  ('4396492', ('env_material', 'eDNA')),
#  ('4403036', ('body site', 'Inner Oral Cavity')),
#  ('4431894', ('env_material', 'Soil')),
#  ('4433864', ('histological type', 'blood')),
#  ('4447958', ('tissue', 'brain')),
#  ('4462533', ('body site', 'blood')),
#  ('4465307', ('body site', 'blood')),
#  ('4470052', ('body site', 'Blood')),
#  ('4470366', ('body site', 'Blood')),
#  ('4472717', ('body site', 'Blood')),
#  ('4491760', ('body site', 'Blood')),
#  ('4499396', ('body site', 'saliva')),
#  ('4501619', ('tissue', 'Liver')),
#  ('4502739', ('tissue', 'lung')),
#  ('4502743', ('tissue', 'lung')),
#  ('4507969', ('tissue', 'pancreatic islets')),
#  ('4510580', ('cell type', 'Acute myeloid leukemia')),
#  ('4536487', ('host_tissue_sampled', 'missing')),
#  ('4539034', ('tissue', 'Skin')),
#  ('4541615', ('body site', 'Blood')),
#  ('4541758', ('body site', 'Blood')),
#  ('4544847', ('tissue', 'Breast')),
#  ('4547713', ('body site', "Left Brodmann's Area 21 (Temporal Cortex)")),
#  ('4554796', ('cell type', 'CD4-positive, alpha-beta T cell')),
#  ('4555095', ('cell line', 'ESC-iNkx2.2')),
#  ('4558037', ('cell line', 'RKO-p53_WT')),
#  ('4567503', ('env_material', 'water')),
#  ('4567912', ('env_material', 'underground water(ENVO:00005792)')),
#  ('4570960',
#   ('env_material',
#    'ITS7F-ITS4R_CG_D_3Soil from soil-wood interface of stakes')),
#  ('4573480', ('tissue', 'blood')),
#  ('4573504', ('tissue', 'blood')),
#  ('4594579', ('tissue', 'lung')),
#  ('4594695', ('tissue', 'Liver')),
#  ('4597665', ('body site', 'Nerve - Tibial')),
#  ('4611202', ('env_material', 'feces')),
#  ('4614584', ('body site', 'BLOOD')),
#  ('4618376', ('body site', 'BLOOD')),
#  ('4619998', ('cell type', 'P19Cl6 during cardiomyocytes differentiation')),
#  ('4632152', ('tissue', 'Carcass')),
#  ('4633022', ('env_material', 'activated sludge(ENVO:00002046)')),
#  ('4645874', ('cell type', 'multipotent stem cell')),
#  ('4656643', ('cell line', 'CGR8')),
#  ('4670056', ('cell type', 'CD138 plasma cell')),
#  ('4692328', ('cell type', 'hematopoietic stem cell')),
#  ('4713996', ('cell type', 'hepatocyte')),
#  ('4758825', ('cell type', 'keratinocyte')),
#  ('4770242', ('cell type', 'embryonic stem cell')),
#  ('4789210', ('cell line', 'NCI-H295')),
#  ('4794349', ('cell type', 'mononuclear')),
#  ('4813066', ('cell type', 'hepatocyte')),
#  ('4814722', ('cell type', 'hepatocyte')),
#  ('4844390', ('cell type', 'fibroblast')),
#  ('4850268', ('tissue', 'Leaf')),
#  ('4860172', ('cell type', 'hepatic stellate cell')),
#  ('4872016', ('env_material', 'sterile water')),
#  ('4872366', ('env_material', 'feces')),
#  ('4881623', ('body site', 'Blood')),
#  ('4882621', ('body site', 'Blood')),
#  ('4888763', ('cell line', 'SNU-81')),
#  ('4904112', ('env_material', 'surface agricultural soil')),
#  ('4910626', ('tissue', 'leaf')),
#  ('4910750', ('tissue', 'leaf')),
#  ('4914360', ('env_material', 'Human gut')),
#  ('4920690', ('cell type', 'NeuN-negative cell')),
#  ('4925398', ('body habitat', 'UBERON:feces')),
#  ('4931959', ('tissue', 'fin')),
#  ('4944193', ('body site', 'whole blood')),
#  ('4960251', ('cell line', 'S2R+')),
#  ('4964137', ('tissue', 'Peripheral Blood Stem Cells [PBSCs]')),
#  ('4969173', ('body site', 'BLOOD')),
#  ('4969407', ('body site', 'BLOOD')),
#  ('4973521', ('body site', 'BLOOD')),
#  ('4975086', ('body site', 'BLOOD')),
#  ('4976660', ('body site', 'BUCCAL')),
#  ('4976691', ('body site', 'BLOOD')),
#  ('4988164', ('body site', 'whole blood')),
#  ('4989165', ('body site', 'whole blood')),
#  ('5039814', ('cell line', 'HeLa')),
#  ('5176969', ('body site', 'Peripheral Blood')),
#  ('5177799', ('body site', 'Right_Colon')),
#  ('5178239', ('body site', 'Right_Colon')),
#  ('5183416', ('cell type', 'epithelial cell')),
#  ('5204197', ('env_material', 'Activated sludge')),
#  ('5204761', ('tissue type', 'root')),
#  ('5217776', ('body site', 'whole blood')),
#  ('5220238', ('env_material', 'NA')),
#  ('5248337', ('cell type', 'CD4+ T-cells')),
#  ('5259514', ('tissue', 'bone marrow')),
#  ('5260325', ('tissue', 'colon')),
#  ('5263991', ('body habitat', 'UBERON:gill')),
#  ('5274144', ('cell type', 'embryonic cells')),
#  ('5280520', ('env_material', 'surface layer')),
#  ('5280899', ('env_material', 'surface layer')),
#  ('5292496', ('cell line', 'Kc167')),
#  ('5298988', ('body site', 'blood')),
#  ('5315633', ('histological type', 'blood')),
#  ('5320721', ('histological type', 'blood')),
#  ('5326868', ('env_material', 'lung non-malignant tissue')),
#  ('5344324', ('body site', 'blood')),
#  ('5345938', ('env_material', 'maternalPlacenta')),
#  ('5352320', ('cell type', 'monocyte')),
#  ('5352322', ('cell type', 'monocyte')),
#  ('5359788', ('tissue', 'pancreas')),
#  ('5360847', ('body site', 'blood')),
#  ('5376742', ('body habitat', 'UBERON:feces')),
#  ('5378024', ('body habitat', 'UBERON:feces')),
#  ('5390137', ('cell type', 'IPSC-derived mesodermal progenitor')),
#  ('5412744', ('env_material', 'soil')),
#  ('5416593', ('tissue', 'liver')),
#  ('5422609', ('tissue', 'Periphery')),
#  ('5426870', ('env_material', 'Biofilm')),
#  ('5437019', ('tissue', 'Sponge tissue')),
#  ('5456558', ('body site', 'Peripheral Blood')),
#  ('5457935', ('body site', 'Peripheral Blood')),
#  ('5472549', ('body site', 'Blood')),
#  ('5475309', ('body site', 'Blood')),
#  ('5478218', ('body site', 'Blood')),
#  ('5479766', ('body site', 'Blood')),
#  ('5486261', ('body site', 'Blood')),
#  ('5486284', ('body site', 'Whole Genome Amplified')),
#  ('5487832', ('body site', 'Blood')),
#  ('5491269', ('body site', 'Blood')),
#  ('5494638', ('body site', 'Blood')),
#  ('5503208', ('body site', 'Blood')),
#  ('5503511', ('body site', 'Blood')),
#  ('5504329', ('host_tissue_sampled', 'missing')),
#  ('5507339', ('body habitat', 'UBERON:feces')),
#  ('5526045', ('env_material', 'missing')),
#  ('5561834', ('tissue', 'stem cells')),
#  ('5562045', ('tissue', 'hES DA commercial')),
#  ('5563837', ('tissue', 'ventral midbrain')),
#  ('5572554', ('tissue', 'head and thorax')),
#  ('5573882', ('env_material', 'soil')),
#  ('5594050', ('env_material', 'fresh water')),
#  ('5595442', ('env_material', 'soil')),
#  ('5599163',
#   ('body site', "Left Brodmann's Area 22 (Superior temporal cortex)")),
#  ('5602008', ('env_material', 'soil')),
#  ('5604491', ('body site', 'Blood')),
#  ('5605813', ('body site', 'Bone Marrow')),
#  ('5607235', ('cell type', 'immortalized human astrocytes')),
#  ('5612103', ('body site', 'BLOOD')),
#  ('5613233', ('body site', 'BLOOD')),
#  ('5711469', ('tissue', 'Mouse Embryonic Fibroblasts')),
#  ('5715053', ('tissue', 'Dissociated whole cerebral organoid')),
#  ('5738079', ('body site', 'Blood')),
#  ('5742746', ('body site', 'Blood')),
#  ('5744634', ('body site', 'Blood')),
#  ('5745058', ('body site', 'Blood')),
#  ('5745142', ('body site', 'Blood')),
#  ('5749141', ('body site', 'Blood')),
#  ('5760827', ('body site', 'Subcutaneous fat')),
#  ('5768833', ('body site', 'umbilical_cord')),
#  ('5773426', ('tissue', 'adipose')),
#  ('5787659', ('tissue', 'developing ventral midbrain cells')),
#  ('5800881', ('body site', 'saliva')),
#  ('5808102', ('body site', 'Blood')),
#  ('5809851', ('body site', 'Blood')),
#  ('5811586', ('body site', 'Blood')),
#  ('5813159', ('body site', 'Blood')),
#  ('5819093', ('tissue', 'muscle')),
#  ('5847157', ('cell type', 'mast cell')),
#  ('5848909', ('cell type', 'alpha cell')),
#  ('5856157', ('env_material', 'water')),
#  ('5856739', ('env_material', 'Feces')),
#  ('5859811', ('tissue', 'Liver')),
#  ('5861535', ('body site', 'breast')),
#  ('5862639', ('env_material', 'marine sediment')),
#  ('5865511', ('body site', 'Blood')),
#  ('5879383', ('env_material', 'not applicable')),
#  ('5884222', ('body site', 'Saliva')),
#  ('5888438', ('body site', 'Saliva')),
#  ('5889933', ('body site', 'Saliva')),
#  ('5894443', ('env_material', 'Plankton')),
#  ('5894775', ('cell line', 'Brg1fl/fl (BRG1 conditional)')),
#  ('5896458', ('body site', 'Buccal')),
#  ('5896477', ('body site', 'Buccal')),
#  ('5897382', ('cell line', 'K562')),
#  ('5898545', ('host_tissue_sampled', 'Blood')),
#  ('5904340', ('body site', 'Blood')),
#  ('5905356', ('env_material', 'Digesta')),
#  ('5910491', ('body site', 'Whole Blood')),
#  ('5914019', ('cell line', 'HUES2')),
#  ('5917336', ('body site', 'Blood')),
#  ('5920023', ('body site', 'Blood')),
#  ('5941986', ('cell type', 'Myeloid dendritic cells')),
#  ('5945641', ('env_material', 'Middle meatus')),
#  ('5964793', ('tissue', 'heart')),
#  ('5970468', ('env_material', 'sea water')),
#  ('5974342', ('env_material', 'fresh water')),
#  ('5974667', ('env_material', 'biofilm')),
#  ('5981201', ('tissue', 'lymphoma')),
#  ('5991403', ('env_material', 'bronchoalveolar lavage fluid')),
#  ('5991942', ('tissue', 'whole animal')),
#  ('6014270', ('cell type', 'Embryonic pancreatic cell')),
#  ('6017404', ('env_material', 'stool')),
#  ('6026718', ('env_material', 'Filter 0.2uM')),
#  ('6034491', ('cell type', 'TRA-1-60(+) cells on day 15')),
#  ('6044558', ('tissue', 'thyroid gland')),
#  ('6055325', ('tissue', 'islets')),
#  ('6061700', ('tissue', 'liver')),
#  ('6067350', ('cell type', 'cell line derived from mouse embryo fibroblasts')),
#  ('6069801', ('body site', 'Peripheral Blood')),
#  ('6070689', ('body site', 'Peripheral Blood')),
#  ('6071541', ('body site', 'Peripheral Blood')),
#  ('6077690', ('body site', 'Blood')),
#  ('6077960', ('body site', 'Blood')),
#  ('6078497', ('body site', 'Blood')),
#  ('6082465', ('body site', 'Blood')),
#  ('6083255', ('body site', 'Blood')),
#  ('6100409', ('env_material', 'feces')),
#  ('6100679', ('tissue', 'Spleen')),
#  ('6104773', ('body site', 'Saliva')),
#  ('6110426', ('env_material', 'ENVO:00002003')),
#  ('6116735', ('body habitat', 'UBERON:feces')),
#  ('6133933', ('body site', 'Blood')),
#  ('6140217', ('tissue', 'thorax and abdomen')),
#  ('6146666', ('body site', 'Blood')),
#  ('6150054', ('body site', 'Blood')),
#  ('6151632', ('body site', 'Blood')),
#  ('6155161', ('body site', 'Blood')),
#  ('6163912', ('tissue', 'aerial shoot')),
#  ('6164415', ('env_material', 'ENVO:00002003')),
#  ('6176081', ('tissue', 'olfactory epithelium')),
#  ('6178096', ('env_material', 'sand')),
#  ('6178180', ('env_material', 'sand')),
#  ('6183051', ('tissue', 'ear')),
#  ('6184191', ('cell type', 'monocyte-derived dendritic cells')),
#  ('6190117', ('cell type', 'OT-I CD8+ T cells')),
#  ('6199190', ('tissue', 'saliva')),
#  ('6206210', ('cell type', 'blood serum')),
#  ('6212172', ('tissue_type', 'flat leaf')),
#  ('6226056', ('tissue', 'coral host (with limited contamination)')),
#  ('6226231', ('tissue', 'coral host (with limited contamination)')),
#  ('6230039', ('tissue', 'Ileal biopsy')),
#  ('6235018', ('env_material', 'soil')),
#  ('6244097', ('env_material', 'marine sediment')),
#  ('6245122', ('tissue', 'Not applicable')),
#  ('6253953', ('body site', 'Blood')),
#  ('6254236', ('body site', 'Blood')),
#  ('6275410', ('body site', 'Cortex')),
#  ('6275967', ('tissue', 'liver')),
#  ('6312942', ('tissue', 'dorsolateral prefrontal cortex')),
#  ('6322810', ('body site', 'N/A')),
#  ('6328998', ('tissue', 'Leaf')),
#  ('6329532', ('host_tissue_sampled', 'Gastric Biopsy')),
#  ('6329596', ('host_tissue_sampled', 'Gastric Biopsy')),
#  ('6333583', ('env_material', 'feces')),
#  ('6344250', ('tissue', 'lung')),
#  ('6345866', ('tissue', 'Venom gland')),
#  ('6349468', ('cell type', 'cancer cells (CCs)')),
#  ('6360389', ('cell type', 'effector memory CD4-positive, alpha-beta T cell')),
#  ('6365867', ('body_habitat', 'UBERON:feces')),
#  ('6373865', ('body site', 'peripheral blood')),
#  ('6377636', ('body site', 'peripheral blood')),
#  ('6378066', ('body site', 'peripheral blood')),
#  ('6380268', ('body site', 'peripheral blood')),
#  ('6385286', ('body site', 'peripheral blood')),
#  ('6386163', ('body site', 'peripheral blood')),
#  ('6393126', ('tissue', 'not collected')),
#  ('6401348', ('body site', 'not available')),
#  ('6410900', ('body site', 'not available')),
#  ('6410905', ('body site', 'not available')),
#  ('6413666', ('body site', 'not available')),
#  ('6414086', ('body site', 'not available')),
#  ('6422016', ('body site', 'not available')),
#  ('6423382', ('body site', 'not available')),
#  ('6429055', ('body site', 'not available')),
#  ('6435813', ('tissue', 'whole insect')),
#  ('6442839', ('tissue', 'dentate gyrus')),
#  ('6443088', ('tissue', 'dentate gyrus')),
#  ('6464544', ('tissue', 'body of pancreas')),
#  ('6483071', ('tissue', 'dentate gyrus')),
#  ('6484211', ('tissue', 'dentate gyrus')),
#  ('6484289', ('tissue', 'dentate gyrus')),
#  ('6490502', ('body site', 'blood')),
#  ('6491721', ('body site', 'blood')),
#  ('6494479', ('body site', 'blood')),
#  ('6494981', ('body site', 'blood')),
#  ('6497360', ('body site', 'blood')),
#  ('6499405', ('body site', 'blood')),
#  ('6500082', ('body site', 'blood')),
#  ('6505093', ('body site', 'blood')),
#  ('6506241', ('body site', 'blood')),
#  ('6518367', ('body site', 'blood')),
#  ('6533823', ('body site', 'blood')),
#  ('6534011', ('body site', 'blood')),
#  ('6544007', ('body site', 'blood')),
#  ('6551633', ('env_material', 'biofilm')),
#  ('6569257', ('body site', 'Peripheral_Blood')),
#  ('6570046', ('body site', 'Peripheral_Blood')),
#  ('6571572', ('body site', 'Peripheral_Blood')),
#  ('6574797', ('body site', 'Peripheral_Blood')),
#  ('6576502', ('body site', 'Peripheral_Blood')),
#  ('6577827', ('body site', 'Peripheral_Blood')),
#  ('6578723', ('tissue', 'cerebellum')),
#  ('6582159', ('body site', 'Blood')),
#  ('6589111', ('body site', 'Blood')),
#  ('6592511', ('body site', 'Blood')),
#  ('6595082', ('body site', 'Blood')),
#  ('6600896', ('body habitat', 'UBERON:feces')),
#  ('6603546', ('tissue', 'spleen')),
#  ('6631217', ('body site', 'Blood or Saliva')),
#  ('6641534', ('tissue', 'CD8+ clone 13 LCMV-specific T cell')),
#  ('6644281', ('env_material', 'air')),
#  ('6652790', ('tissue', 'frontal cortex')),
#  ('6659742', ('env_material', 'groundwater')),
#  ('6679207', ('tissue', 'Leaf')),
#  ('6694947', ('cell type', 'RNA-Tempus')),
#  ('6700180', ('host_tissue_sampled', 'missing')),
#  ('6712886', ('cell line', 'NIH3T3')),
#  ('6716077', ('body site', 'Peripheral Blood')),
#  ('6724739', ('body site', 'Buffy Coat')),
#  ('6726539', ('body site', 'Buffy Coat')),
#  ('6726848', ('body site', 'Buffy Coat')),
#  ('6734451', ('histological type', 'blood')),
#  ('6741119', ('histological type', 'blood')),
#  ('6742480', ('histological type', 'blood')),
#  ('6742635', ('histological type', 'blood')),
#  ('6744202', ('histological type', 'blood')),
#  ('6754025', ('histological type', 'blood')),
#  ('6767820', ('body site', 'Peripheral Blood')),
#  ('6771324', ('cell line', 'GM12878')),
#  ('6772928', ('body site', 'Buffy Coat')),
#  ('6774179', ('body site', 'Buffy Coat')),
#  ('6774229', ('body site', 'Buffy Coat')),
#  ('6774254', ('body site', 'Blood')),
#  ('6775115', ('body site', 'Buffy Coat')),
#  ('6778425', ('body site', 'Buffy Coat')),
#  ('6779112', ('body site', 'Blood')),
#  ('6780032', ('body site', 'Buffy Coat')),
#  ('6783032', ('body site', 'Blood')),
#  ('6783457', ('body site', 'Blood')),
#  ('6784763', ('body site', 'Blood')),
#  ('6795998', ('body site', 'Blood')),
#  ('6798415', ('body site', 'Blood')),
#  ('6804484', ('body site', 'Blood')),
#  ('6807522', ('env_material', 'feces')),
#  ('6817924', ('cell line', 'mpkCCD (clone 11)')),
#  ('6822081', ('tissue', 'embryonic kidney')),
#  ('6824782', ('tissue', 'embryonic kidney')),
#  ('6827577', ('tissue', 'whole bone marrow')),
#  ('6828778', ('tissue', 'whole seedling')),
#  ('6834045', ('tissue', 'blood')),
#  ('6837293', ('body site', 'Blood')),
#  ('6854581', ('tissue', 'whole insect body')),
#  ('6859712', ('env_material', 'skin')),
#  ('6891263', ('cell source', 'D218')),
#  ('6901614', ('body site', 'blood')),
#  ('6902463', ('body site', 'blood')),
#  ('6904169', ('body site', 'saliva')),
#  ('6906118', ('histological type', 'Throat swabs')),
#  ('6915185', ('tissue', 'Whole blood')),
#  ('6925497', ('body habitat', 'UBERON:oral cavity')),
#  ('6929629', ('tissue', 'brain')),
#  ('6937295', ('body site', 'Peripheral blood')),
#  ('6941889', ('body site', 'blood')),
#  ('6942340', ('body site', 'cell')),
#  ('6943924', ('body site', 'blood')),
#  ('6944214', ('body site', 'blood')),
#  ('6945860', ('body site', 'blood')),
#  ('6965041', ('tissue', 'inlet cells')),
#  ('6965737', ('tissue', 'inlet cells')),
#  ('6983700', ('cell type', 'lymphoblastoid cell')),
#  ('7018959', ('cell type', 'peripheral blood mononuclear cell')),
#  ('7034755', ('cell type', 'CD138-purified plasma cells')),
#  ('7058975', ('cell type', 'mononuclear cell')),
#  ('7070361', ('cell line', 'SW620')),
#  ('7085119', ('cell line', 'KY821')),
#  ('7096031', ('cell type', 'embryonic stem cell')),
#  ('7114264', ('env_material', 'manure slurry')),
#  ('7121562', ('cell type', 'peripheral blood mononuclear cell')),
#  ('7122958', ('cell type', 'macrophage')),
#  ('7152776', ('env_material', 'Coastal Sea Water')),
#  ('7164792', ('tissue', 'lung')),
#  ('7178983', ('env_material', 'feces')),
#  ('7186125', ('cell line', '416B')),
#  ('7197587', ('body site', 'blood')),
#  ('7207549', ('cell type', 'Trunk ventral cells')),
#  ('7221368', ('cell type', 'sympatho-adrenal anlage')),
#  ('7223240', ('tissue', 'harderian')),
#  ('7231280', ('body site', 'peripheral blood plasma')),
#  ('7234278', ('body site', 'peripheral blood')),
#  ('7238825', ('body site', 'saliva')),
#  ('7241881', ('body site', 'blood')),
#  ('7245766', ('cell type', 'olfactory projection neuron')),
#  ('7247280', ('env_material', 'not applicable')),
#  ('7260283', ('tissue', 'right_retina')),
#  ('7263611', ('env_material', 'organic material feature')),
#  ('7264393', ('env_material', 'organic material feature')),
#  ('7267750', ('cell type', 'Monocyte-derived sorted cell')),
#  ('7271133', ('cell line', 'CMT167 (CMT)')),
#  ('7290557', ('cell type', 'CD8+T cells')),
#  ('7292100', ('tissue', 'Leaf')),
#  ('7292253', ('tissue', 'Leaf')),
#  ('7292286', ('tissue', 'Leaf')),
#  ('7298248', ('tissue', 'Liver')),
#  ('7313064', ('tissue', 'leaf')),
#  ('7323021', ('body site', 'Blood')),
#  ('7323061', ('body site', 'Blood')),
#  ('7342042', ('tissue', 'Hippocampus')),
#  ('7347022', ('cell type', 'large airway epithelial cells')),
#  ('7357882', ('cell line', 'HeLa')),
#  ('7365612', ('tissue', 'somatosensory cortex')),
#  ('7372846', ('cell type', 'Colonic epithelial cells')),
#  ('7386260', ('body site', 'Blood')),
#  ('7388198', ('body site', 'Blood')),
#  ('7392697', ('body site', 'Blood')),
#  ('7397557', ('body site', 'Blood')),
#  ('7399382', ('body site', 'Blood')),
#  ('7400298', ('body site', 'Blood')),
#  ('7400674', ('body site', 'Blood')),
#  ('7401000', ('body site', 'Blood')),
#  ('7401611', ('body site', 'Blood')),
#  ('7404335', ('body site', 'Blood')),
#  ('7404762', ('body site', 'Blood')),
#  ('7414730', ('body site', 'Brain')),
#  ('7416038', ('tissue', 'Liver')),
#  ('7416310', ('env_material', 'NA')),
#  ('7417329', ('tissue', 'fore-limb')),
#  ('7423754', ('cell line', 'GM02171')),
#  ('7431267', ('organ', 'ovary')),
#  ('7439482', ('env_material', 'sterile water')),
#  ('7444993',
#   ('body site', 'Recurrent Blood Derived Cancer - Peripheral Blood')),
#  ('7449420', ('tissue', 'pCRC')),
#  ('7455099', ('cell type', 'Innate lymphoid cell')),
#  ('7457235', ('tissue', 'Nucleus of the solitary tract')),
#  ('7458198', ('body site', 'whole blood')),
#  ('7463944', ('body site', 'Peripheral Blood')),
#  ('7464220', ('body site', 'Peripheral Blood')),
#  ('7469409', ('body site', 'Peripheral Blood')),
#  ('7471647', ('body site', 'BUCCAL')),
#  ('7475831', ('body site', 'BUCCAL')),
#  ('7481434', ('body site', 'BUCCAL')),
#  ('7491685', ('body site', 'Brain')),
#  ('7492032', ('collection_site', 'mucosa')),
#  ('7497554', ('body habitat', 'UBERON:feces')),
#  ('7512257', ('body site', 'blood')),
#  ('7512904', ('tissue', 'new born cordblood')),
#  ('7521361', ('tissue', 'leaf')),
#  ('7534548', ('cell type', 'neuronal progenitors')),
#  ('7536898', ('tissue', 'whole-animal')),
#  ('7539076', ('env_material', 'reagents and plastic consumables')),
#  ('7552458', ('tissue', 'tumor')),
#  ('7557404', ('env_material', 'brackish water')),
#  ('7559929', ('tissue', 'young leaves')),
#  ('7574566', ('tumor site', 'Lymph node')),
#  ('7578803', ('tumor site', 'Primary (oral cavity)')),
#  ('7583401',
#   ('cell type', 'isolated, FACS sorted single hippocampal microglia')),
#  ('7603447', ('tissue', 'blood')),
#  ('7605197', ('tissue', 'Fin Clip')),
#  ('7610705', ('cell type', 'Blastocyst')),
#  ('7629909',
#   ('cell type', 'Fetus derived cell line from female human embryonic kidney')),
#  ('7630937', ('tissue', 'brain')),
#  ('7634511', ('tissue', 'foreskin')),
#  ('7634701', ('env_material', 'water')),
#  ('7637471', ('tissue_type', 'whole embryo')),
#  ('7644150', ('tissue', 'blood')),
#  ('7679966', ('tissue', 'Heart')),
#  ('7694441', ('cell line', 'H1')),
#  ('7705677', ('body site', 'Brain')),
#  ('7708206', ('body site', 'Brain')),
#  ('7711863', ('histological type', 'DLBCL')),
#  ('7713019', ('histological type', 'DLBCL')),
#  ('7722522', ('cell type', 'Embryonic kidney cells')),
#  ('7739910', ('body site', 'Blood')),
#  ('7740260', ('body site', 'Blood')),
#  ('7744176', ('body site', 'Peripheral Blood')),
#  ('7750370', ('brain region', 'FWM')),
#  ('7752375', ('body site', 'blood')),
#  ('7752490', ('body site', 'blood')),
#  ('7755832', ('body site', 'blood')),
#  ('7771402', ('body habitat', 'UBERON:skin')),
#  ('7772068', ('body habitat', 'UBERON:skin')),
#  ('7774790', ('tissue', 'not applicable')),
#  ('7776359', ('tissue', 'Liver')),
#  ('7776718', ('env_material', 'water')),
# ...
#  ('27863346', ('tissue', 'Rumen fluid')),
#  ('27914802', ('tissue', 'whole seedlings')),
#  ('27968807', ('tissue type', 'whole embryos at N')),
#  ('27998303', ('body site', 'BLOOD')),
#  ('27998644', ('body site', 'BLOOD')),
#  ('28001399', ('body site', 'BLOOD')),
#  ('28017157', ('tissue', 'primary bronchial epithelial cells')),
#  ('28025032', ('tissue', 'leaf')),
#  ('28033481', ('anatomical_part', 'Anterior Nares')),
#  ('28041556', ('tissue', 'Tumor')),
#  ('28062766', ('tissue', 'Retina')),
#  ('28101412', ('tissue', 'liver')),
#  ('28110688', ('env_material', 'feces')),
#  ('28126193', ('anatomical_part', 'Anterior Nares')),
#  ('28131743', ('tissue', 'Right Lung')),
#  ('28183987', ('tissue', 'Metastases')),
#  ('28184286', ('tissue', 'Tumor')),
#  ('28387880', ('env_material', 'feces')),
#  ('28388132', ('env_material', 'feces')),
#  ('28503777', ('tissue', 'leaf')),
#  ('28508291', ('body site', 'arm vein')),
#  ('28508479', ('body site', 'BLOOD')),
#  ('28525070', ('anatomical_part', 'Anterior Nares')),
#  ('28527972', ('cell line', 'E14')),
#  ('28538748', ('tissue', 'Cardiac')),
#  ('28560002', ('cancer', 'I do not have this condition')),
#  ('28577937', ('tissue', 'HY')),
#  ('28638710', ('body site', 'Lung')),
#  ('28638989', ('body site', 'Prostate')),
#  ('28653061', ('tissue type', 'Muscle')),
#  ('28803542', ('cell line', 'B16F10_B2MKO')),
#  ('28899684', ('tissue', 'Leaf')),
#  ('28919239', ('anatomical_part', 'Anterior Nares')),
#  ('28936431', ('env_material', 'feces')),
#  ('28950345', ('tissue', 'Peripheral blood')),
#  ('28957297', ('tissue', 'PDX lung metastasis')),
#  ('28978961', ('tissue', 'head')),
#  ('28987941', ('cell line', 'HAP1')),
#  ('28988157', ('cell line', 'HAP1')),
#  ('29003694', ('env_material', 'sebum')),
#  ('29041115', ('tissue', 'lymphocyte')),
#  ('29046337', ('tissue', 'liver')),
#  ('29100828', ('body site', 'oral cavity')),
#  ('29107767', ('body site', 'Blood')),
#  ('29110502', ('body site', 'Blood')),
#  ('29113989', ('body site', 'Blood')),
#  ('29114024', ('body site', 'Blood')),
#  ('29117118', ('body site', 'Blood')),
#  ('29117599', ('body site', 'Blood')),
#  ('29119346', ('body site', 'peripheral blood')),
#  ('29127566', ('tissue', 'leaf')),
#  ('29139475', ('body site', 'Blood')),
#  ('29139605', ('body site', 'Blood')),
#  ('29139977', ('body site', 'Blood')),
#  ('29142414', ('body site', 'Blood')),
#  ('29144283', ('body site', 'Blood')),
#  ('29205249', ('tissue', 'muscle')),
#  ('29225248', ('tissue', 'blood')),
#  ('29226992', ('tissue', 'blood')),
#  ('29333632', ('cell type', 'C57BL6/6J x CAST/EiJ F1 hybrid mESC')),
#  ('29358073', ('tissue', 'Leaf')),
#  ('29382841', ('cell type', 'Lymphoblastoid')),
#  ('29391633', ('body site', 'Blood')),
#  ('29404442', ('tissue', 'breast cancer')),
#  ('29424673', ('tissue', 'whole body')),
#  ('29441515', ('tissue', 'longissimus dorsi muscle')),
#  ('29480729', ('tissue', 'faeces')),
#  ('29532212', ('env_material', 'control31')),
#  ('29550744', ('body site', 'Blood')),
#  ('29589846', ('body site', 'rectum')),
#  ('29638384', ('body site', 'LUNG')),
#  ('29641772', ('anatomical_part', 'Anterior Nares')),
#  ('29767207', ('cell_type', 'CD4 T cell')),
#  ('29767487', ('tissue', 'Mammary gland')),
#  ('29780392', ('cell_type', 'epithelial cell of stomach')),
#  ('29796181', ('tissue', 'Liver')),
#  ('29797255', ('tissue', 'Peripheral blood')),
#  ('29854936', ('tissue', 'Whole worm')),
#  ('29854949', ('tissue', 'Whole worm')),
#  ('29857026', ('tissue', 'breast')),
#  ('29883274', ('tissue', 'hemocyte')),
#  ('29890838', ('tissue', 'kidney; embryo')),
#  ('29929597', ('tissue', 'leaf')),
#  ('29929608', ('tissue', 'leaf')),
#  ('29939098', ('cell type', 'yeast')),
#  ('29943524', ('anatomical_material', 'Not Provided')),
#  ('29980473', ('tissue', 'basilar papillae')),
#  ('29999992', ('tissue', 'Cambium')),
#  ('30000046', ('host_tissue_sampled', 'Urethral')),
#  ('30006050', ('tissue', 'ovarian')),
#  ('30032016', ('tissue', 'Blood')),
#  ('30057311', ('tissue', 'lung')),
#  ('30073911', ('tissue', 'not applicable')),
#  ('30110796', ('tissue', 'peripheral blood')),
#  ('30168630', ('tissue', 'tibialis anterior muscle')),
#  ('30185284', ('cell line', 'HT-1197')),
#  ('30202054', ('host_anatomical_material', 'Mucus')),
#  ('30215703', ('tissue', 'muscle (leg)')),
#  ('30221420', ('tissue', 'tissue')),
#  ('30224737', ('tissue', 'seed')),
#  ('30269003', ('body site', 'Blood')),
#  ('30271362', ('body site', 'Blood')),
#  ('30271435', ('body site', 'Blood')),
#  ('30273914', ('cell type', 'CD34+ AML cells')),
#  ('30289136', ('body site', 'Peripheral Blood')),
#  ('30306755', ('tissue', 'gut')),
#  ('30327731', ('tissue', 'blood')),
#  ('30347381', ('tissue', 'Lymphoycyte')),
#  ('30379748', ('cell line', 'hBM-MSCs')),
#  ('30400435', ('cell_line', 'HEK293T')),
#  ('30440066', ('brain region', 'PSC')),
#  ('30448000', ('tissue', 'tail')),
#  ('30470330', ('tissue', 'buds')),
#  ('30484421', ('body site', 'Blood')),
#  ('30487743', ('tissue', 'Mantle')),
#  ('30502793', ('tissue', 'Leaves')),
#  ('30506902', ('tissue', 'Pollen')),
#  ('30526214', ('cell line', 'MEF')),
#  ('30560497', ('tissue', 'brain')),
#  ('30567821', ('body site', 'Blood')),
#  ('30569172', ('body site', 'Blood')),
#  ('30583338', ('tissue', 'whole plant')),
#  ('30599824', ('tissue', 'tumour')),
#  ('30609400', ('tissue', 'leaf')),
#  ('30618369', ('tissue', 'Liver')),
#  ('30634653', ('tissue', 'Leaf')),
#  ('30648313', ('tissue', 'lung')),
#  ('30689900', ('cell line', 'BT869')),
#  ('30789573', ('tissue', 'Kidney')),
#  ('30797514', ('tissue', 'striatum')),
#  ('30804697', ('tissue', 'liver')),
#  ('30808806', ('cell line', 'bTS11')),
#  ('30829390', ('body site', 'blood')),
#  ('30834126', ('body site', 'BLOOD')),
#  ('30856973', ('tissue', 'mobilised peripheral blood')),
#  ('30867423', ('cell_type', 'mononuclear cell')),
#  ('30912353', ('tissue', 'colon')),
#  ('30930305', ('anatomical_part', 'Anterior Nares')),
#  ('30946064', ('tissue', 'Longissimus dorsi')),
#  ('30960200', ('tissue', 'Rosette leaves')),
#  ('31088887', ('env_material', 'not aplicable')),
#  ('31089011', ('env_material', 'not aplicable')),
#  ('31106864', ('tissue', 'Pancreatic islets')),
#  ('31119823', ('tissue', 'whole')),
#  ('31143507', ('tissue', 'ovary')),
#  ('31149766', ('condition', 'progression')),
#  ('31151204', ('tissue', 'Tumor')),
#  ('31205245', ('host_tissue_sampled', 'cecum content')),
#  ('31210495', ('env_material', 'thermophilic sediment')),
#  ('31248291', ('anatomical_part', 'Anterior Nares')),
#  ('31273680', ('tissue', 'Placenta - chorionic villi')),
#  ('31298225', ('cell_type', 'bulk')),
#  ('31298319', ('cell_type', 'bulk')),
#  ('31318337', ('brain region', 'TH-7')),
#  ('31349006', ('tissue', 'fin')),
#  ('31365415', ('env_material', 'sediment')),
#  ('31382350', ('tissue', 'blood')),
#  ('31384595', ('tissue', 'bone marrow')),
#  ('31397484', ('tissue_type', 'Small intestine mucosa')),
#  ('31400502', ('body site', 'kidney')),
#  ('31401141', ('brain region', 'VIS-2')),
#  ('31402014', ('brain region', 'VIS-2')),
#  ('31405757', ('brain region', 'VIS-2')),
#  ('31405978', ('brain region', 'VIS-2')),
#  ('31446271', ('body site', 'SALIVA')),
#  ('31449420', ('body site', 'SALIVA')),
#  ('31449442', ('body site', 'SALIVA')),
#  ('31450590', ('body site', 'SALIVA')),
#  ('31452990', ('tissue', 'cecum')),
#  ('31474560', ('tissue', 'pulp')),
#  ('31496190', ('tissue', 'leaf')),
#  ('31503190', ('tissue', 'not applicable')),
#  ('31504901', ('tissue', 'not applicable')),
#  ('31505296', ('tissue', 'not applicable')),
#  ('31517328', ('tissue', 'not applicable')),
#  ('31521114', ('tissue', 'Urine')),
#  ('31539060', ('tissue', 'Young leaf')),
#  ('31543342', ('tissue', 'mycelium')),
#  ('31619179', ('cell type', 'Enriched neutrophils from whole blood')),
#  ('31665017', ('cell line', 'C4-2')),
#  ('31669943', ('cell type', 'mouse embryonic stem cells')),
#  ('31695377', ('tissue', 'fin clip')),
#  ('31714567', ('tissue', 'Whole blood')),
#  ('31745118', ('tissue', 'Loin muscle')),
#  ('31745731', ('body site', 'whole blood')),
#  ('31775194', ('tissue', '8 whole mosquitoes')),
#  ('31775263', ('tissue', '1 whole mosquitoes')),
#  ('31835435', ('cell line', 'in vitro')),
#  ('31843862', ('tissue', 'not applicable')),
#  ('31854088', ('tissue', 'Whole blood')),
#  ('31885068', ('tissue', 'CD4+ and CD8+ T cells')),
#  ('31904932', ('body site', 'BLOOD')),
#  ('31909254', ('body site', 'BLOOD')),
#  ('31913570', ('body site', 'BLOOD')),
#  ('31950287', ('cell type', 'Young-HSC')),
#  ('31965199',
#   ('cell_line', 'renal proximal tubule epithelial cells hTert1 immortalized')),
#  ('31967747', ('tissue', 'leaf')),
#  ('31968468', ('tissue', 'leaf')),
#  ('31983349', ('body site', 'Blood')),
#  ('31985273', ('body site', 'Blood')),
#  ('31994996', ('tissue', 'spores')),
#  ('32000575', ('body site', 'Blood')),
#  ('32007958', ('cell line', 'MG1655')),
#  ('32022618', ('tissue', 'dorsal fin')),
#  ('32023350', ('tissue', 'Embryo')),
#  ('32023990', ('tissue', 'Heart')),
#  ('32047467', ('tissue', 'blood')),
#  ('32049116', ('tissue', 'blood')),
#  ('32051872', ('tissue', 'blood')),
#  ('32052230', ('tissue', 'blood')),
#  ('32053586', ('tissue', 'blood')),
#  ('32056705', ('tissue', 'blood')),
#  ('32059355', ('body site', 'Saliva')),
#  ('32071162', ('tissue', 'fibroblasts')),
#  ('32081007', ('host_anatomical_material', 'Tissue')),
#  ('32082542', ('tissue', 'leaf')),
#  ('32083644', ('tissue', 'needle-31')),
#  ('32106144', ('tissue', 'Tail adipose tissue')),
#  ('32119953', ('collection_site_id', 'WK94-3528')),
#  ('32131583', ('cell line', 'primary Islet cell')),
#  ('32132688', ('tissue', 'whole body')),
#  ('32132881', ('tissue', 'whole body')),
#  ('32137906', ('tissue', 'Embryo')),
#  ('32162349', ('cell_type', 'plasma cell')),
#  ('32183374', ('body site', 'blood')),
#  ('32196192', ('body site', 'blood')),
#  ('32197776', ('body site', 'blood')),
#  ('32200160', ('body site', 'blood')),
#  ('32201591', ('body site', 'blood')),
#  ('32202446', ('body site', 'blood')),
#  ('32235973', ('tissue', 'Skin')),
#  ('32287612', ('tissue', 'Lymphoid')),
#  ('32310608', ('histological type', 'CLL')),
#  ('32324689', ('body site', 'Blood')),
#  ('32327110', ('body site', 'Blood')),
#  ('32334041', ('anatomical_part', 'Anterior Nares')),
#  ('32365798', ('tissue', 'Leaf')),
#  ('32365808', ('tissue', 'Leaf')),
#  ('32378366', ('collection_site_id', 'SQ')),
#  ('32398285', ('tissue', 'Coxtex, Hippocampus')),
#  ('32485579', ('tissue', 'whole pupae')),
#  ('32485589', ('tissue', 'whole pupae')),
#  ('32503689', ('body site', 'Blood')),
#  ('32506320', ('body site', 'Blood')),
#  ('32523112', ('cell_type', 'ependymal cell')),
#  ('32526673', ('tissue', 'leaf')),
#  ('32542020', ('tissue', 'Cerebellum (simulated)')),
#  ('32582395', ('body site', 'Buffy Coat')),
#  ('32585312', ('body site', 'Saliva')),
#  ('32588483', ('body site', 'Saliva')),
#  ('32588567', ('body site', 'Blood')),
#  ('32603760', ('tissue', 'gills')),
#  ('32607397', ('tissue', 'Whole blood')),
#  ('32645028', ('tissue', 'fin clip')),
#  ('32645235', ('tissue', 'fin clip')),
#  ('32677171', ('tissue', 'Bone')),
#  ('32741800', ('tissue', 'missing')),
#  ('32743650', ('tissue', 'leaf')),
#  ('32784972', ('tissue', 'Blood')),
#  ('32854032', ('tissue', 'leaf')),
#  ('32962733', ('host_tissue_sampled', 'leaf')),
#  ('32962813', ('host_tissue_sampled', 'leaf')),
#  ('32989541', ('tissue', 'not applicable')),
#  ('33033061', ('body site', 'Blood')),
#  ('33033241', ('body site', 'Blood')),
#  ('33034745', ('body site', 'Blood')),
#  ('33034978', ('body site', 'Blood')),
#  ('33036336', ('body site', 'Blood')),
#  ('33043858', ('body site', 'Unknown')),
#  ('33043897', ('body site', 'Unknown')),
#  ('33100972', ('tissue', 'retina')),
#  ('33145526', ('body site', 'Blood')),
#  ('33148550', ('body site', 'Blood')),
#  ('33153096', ('body site', 'Blood')),
#  ('33155528', ('body site', 'Blood')),
#  ('33167758', ('body site', 'Blood')),
#  ('33193905', ('tissue', 'leaf')),
#  ('33229914', ('tissue', 'pancreatic cancer')),
#  ('33246442', ('tissue', 'Leaf')),
#  ('33261468', ('tissue', 'Peripheral blood')),
#  ('33262129', ('tissue', 'adductor muscle')),
#  ('33272249', ('body site', 'Blood')),
#  ('33279204', ('tissue', 'trifoliate leaves')),
#  ('33338559', ('collection_site_id', 'CM')),
#  ('33348061', ('cell type', 'Neuron, Glia')),
#  ('33349451', ('tissue', 'cerebellum')),
#  ('33350583', ('tissue', 'cerebral cortex')),
#  ('33354539', ('tissue', 'Pool 75 adults')),
#  ('33356464', ('tissue', 'leaf')),
#  ('33398100', ('tissue', 'cerebellum')),
#  ('33399185', ('tissue', 'cerebellum')),
#  ('33403490', ('tissue', 'cerebellum')),
#  ('33403916', ('tissue', 'cerebellum')),
#  ('33405935', ('tissue', 'kidney')),
#  ('33414701', ('tissue', 'kidney')),
#  ('33449588', ('tissue', 'CK-aoi-001')),
#  ('33471064', ('body site', 'Blood')),
#  ('33473878', ('body site', 'Blood')),
#  ('33474689', ('body site', 'Blood')),
#  ('33474748', ('body site', 'Blood')),
#  ('33491931', ('body site', 'blood')),
#  ('33494400', ('body site', 'Buffy Coat')),
#  ('33504971', ('body site', 'blood')),
#  ('33514135', ('body site', 'peripheral blood plasma')),
#  ('33517707', ('body site', 'Blood')),
#  ('33519165', ('body site', 'blood - buffy coat')),
#  ('33520202', ('body site', 'blood')),
#  ('33525211', ('body site', 'Buffy Coat')),
#  ('33538482', ('body site', 'peripheral blood plasma')),
#  ('33539189', ('body site', 'blood')),
#  ('33539595', ('body site', 'Buffy Coat')),
#  ('33540928', ('body site', 'peripheral blood')),
#  ('33543813', ('body site', 'blood')),
#  ('33544736', ('body site', 'blood')),
#  ('33561291', ('tissue', 'Rat feces')),
#  ('33573479', ('body site', 'Blood')),
#  ('33593053', ('tissue', 'kidney; Embryo')),
#  ('33623850', ('body site', 'Buffy Coat')),
#  ('33634032', ('body site', 'Buffy Coat')),
#  ('33637435', ('body site', 'Buffy Coat')),
#  ('33637958', ('body site', 'Buffy Coat')),
#  ('33643712', ('body site', 'Buffy Coat')),
#  ('33646398', ('body site', 'Buffy Coat')),
#  ('33647729', ('body site', 'Buffy Coat')),
#  ('33647956', ('body site', 'Buffy Coat')),
#  ('33648769', ('body site', 'Buffy Coat')),
#  ('33651406', ('body site', 'Buffy Coat')),
#  ('33657420', ('body site', 'Buffy Coat')),
#  ('33689706', ('host_tissue_sampled', 'FAECES')),
#  ('33700797', ('body site', 'Blood')),
#  ('33730732', ('tissue', 'Leaf')),
#  ('33819677', ('tissue', 'Lung')),
#  ('33850098', ('tissue', 'Soft Tissue_Sarcoma3')),
#  ('33873364', ('tissue', 'Leaf')),
#  ('33907316', ('tissue', 'Leaf')),
#  ('33913885', ('tissue', 'leaf')),
#  ('33917794', ('tissue', 'leaf')),
#  ('33948941', ('collection_site_id', 'OH0025291')),
#  ('33956633', ('tissue', 'mESCs')),
#  ('33964377',
#   ('tissue', 'DDR-focused pooled shRNA screen using a modified sci-RNA-seq3')),
#  ('33971327', ('tissue', 'Striatum, brain')),
#  ('33985667', ('body site', 'Saliva')),
#  ('34022495', ('collection_site_id', 'OH0052922')),
#  ('34031767', ('tissue', 'fin')),
#  ('34043133', ('tissue', 'seed')),
#  ('34061062', ('collection_site_id', 'OH0025003')),
#  ('34061167', ('collection_site_id', 'OH0026069')),
#  ('34061252', ('collection_site_id', 'OH0020532')),
#  ('34148567', ('body site', 'Blood')),
#  ('34150553', ('body site', 'Blood')),
#  ('34153865', ('tissue', 'root')),
#  ('34245843', ('body site', 'Bone Marrow')),
#  ('34281352', ('brain region', 'RHP-2')),
#  ('34285222', ('brain region', 'TEa,ECT,PERI-1')),
#  ('34287511', ('brain region', 'TEa,ECT,PERI-1')),
#  ('34292257', ('brain region', 'VIS-3')),
#  ('34292380', ('brain region', 'VIS-3')),
#  ('34292422', ('brain region', 'VIS-3')),
#  ('34293408', ('brain region', 'VIS-3')),
#  ('34297685', ('brain region', 'RSP-6')),
#  ('34371091', ('collection_site_id', 'ER')),
#  ('34375261', ('tissue', 'chorionic villi')),
#  ('34377012', ('tissue', 'Leaf')),
#  ('34423297', ('env_material', 'anaerobic digestion sludge')),
#  ('34484218', ('tissue', 'brain')),
#  ('34497830', ('tissue', 'brain')),
#  ('34506036', ('tissue', 'brain')),
#  ('34538547', ('tissue', 'brain')),
#  ('34541231', ('tissue', 'brain')),
#  ('34544497', ('tissue', 'brain')),
#  ('34549018', ('tissue', 'brain')),
#  ('34558841', ('body site', 'Peripheral blood')),
#  ('34560236', ('body site', 'Peripheral blood')),
#  ('34560772', ('body site', 'Peripheral blood')),
#  ('34562011', ('body site', 'Peripheral blood')),
#  ('34565189', ('body site', 'Peripheral blood')),
#  ('34565354', ('body site', 'Peripheral blood')),
#  ('34581059', ('tissue', 'Leaf'))]
# Time taken:  5.989192247390747

# %% [markdown]
# ---

# %%
# Code to get the list of package names and their required attributes

templates_path = "data/biosamples/templates_xml/"
biosamples_packages_xml_path = "data/biosamples/biosample_packages.xml"
packages_list = []

class TemplateNamesHander(xml.sax.ContentHandler):
    def __init__(self, templates_list) -> None:
        super().__init__()
        # self.templates = []
        self.is_name = False

    def startElement(self, name, attrs):
        if name == "Name":
            self.is_name = True

    def characters(self, content):
        if self.is_name:
            packages_list.append(content)
            self.is_name = False    
    
parser = xml.sax.make_parser()
parser.setContentHandler(TemplateNamesHander(templates_list=packages_list))
parser.parse(biosamples_packages_xml_path)


'''
- Reads the xml file for each package and extracts the mandatory attributes
- Mandatory attributes for a single package will be stored in a set
    - attributes where at least one in a group is required will be stored in a list

- All data will be stored in a dictionary where the key is the package name and the value is a list of mandatory attributes
'''
class MandatoryAttributeHandler(xml.sax.ContentHandler):
    def __init__(self, attributes_list) -> None:
        super().__init__()
        self.attributes_list = attributes_list
        self.is_mandatory_attribute = False
        self.group_name = None
        self.is_harmonized_name = False
        self.mandatory_groups = {}

    def startElement(self, name, attrs):
        if name == "Attribute":
            use = attrs["use"]
            if use == "optional":
                pass
            elif use == "mandatory":
                self.is_mandatory_attribute = True
            elif use == "either_one_mandatory":
                self.group_name = attrs["group_name"]
                self.is_mandatory_attribute = True
        elif name == "HarmonizedName":
            self.is_harmonized_name = True

    def characters(self, content):
        if self.is_mandatory_attribute and self.is_harmonized_name:
            if self.group_name is None:
                self.attributes_list.append(content)
            else:
                # group name is not None therefore the attribute is part of a group 
                # attribute name added to dictionary with group name as key
                if self.group_name in self.mandatory_groups:
                    self.mandatory_groups[self.group_name].append(content)
                else:
                    self.mandatory_groups[self.group_name] = [content]
                self.group_name = None
            
            self.is_mandatory_attribute = False
            self.is_harmonized_name = False

    def endDocument(self):
        for group in self.mandatory_groups.items():
            self.attributes_list.append(group)
        attribute_list = self.attributes_list


attributes_set = {}
for package in packages_list:
    with open("data/biosamples/templates_xml/" + package + ".xml") as f:
        attribute_list = []
        parser = xml.sax.make_parser()
        parser.setContentHandler(MandatoryAttributeHandler(attribute_list))
        parser.parse(f)
        attributes_set[package] = attribute_list

# %%
biosamples_path = "data/biosamples/biosample_random_samples.xml"
possible_tissue = {"cell_line", "cell_subtype", "cell_type", "host_tissue_sampled", "sample_type", "tissue", "host_anatomical_part", "isolation_source", "source_name", "source_type", "strain", "subclone", "subgroup"}
# possible_tissue = {"tissue"}

class BioSamplesPackageHandler(xml.sax.ContentHandler):
    def __init__(self, useful_packages, attributes_dict):
        super().__init__()
        self.useful_packages = useful_packages
        self.attributes_dict = attributes_dict
        self.is_package = False
        self.package_name = ""
        self.target_attributes = set()
        self.num_samples = 0
        self.biosample_id = ""
        self.attribute_name = ""
        self.sample_dict = {}

    def startElement(self, name, attrs):
        if name == "BioSample":
            self.biosample_id = attrs["id"]
            self.num_samples += 1
        elif name == "Package":
            self.is_package = True
        elif name == "Attribute" and "harmonized_name" in attrs:
                self.attribute_name = attrs["harmonized_name"]

    def characters(self, content):
        if self.is_package:
            self.package_name = content
            if self.package_name in self.useful_packages:
                self.target_attributes = possible_tissue.intersection(set(a for a in self.attributes_dict[self.package_name] if type(a) == str))
                if len(self.target_attributes) > 1:
                    print("more than one matching package: ", self.biosample_id)
            self.is_package = False

        if self.attribute_name != "":
            if self.attribute_name in self.target_attributes:
                self.sample_dict[self.biosample_id] = (self.attribute_name, content)
            self.attribute_name = ""

    def endDocument(self):
        pprint.pprint(self.sample_dict)
        print("Number of possible tissue locations found: ", len(self.sample_dict))

# %%
useful_packages = set()
with open("data/biosamples/useful_packages.txt", "r") as f:
    for package in f.readlines():
        useful_packages.add(package.strip())


t1 = time.time()
parser = xml.sax.make_parser()
handler = BioSamplesPackageHandler(useful_packages, attributes_set)
parser.setContentHandler(handler)
parser.parse(biosamples_path)
t2 = time.time()
print("Time taken: ", t2 - t1)
# Out:
# more than one matching package:  30414169
# {'10037706': ('tissue', 'Whole blood'),
#  '10039586': ('isolation_source', 'missing'),
#  '10058440': ('isolation_source', 'food'),
#  '10070699': ('tissue', 'cormel'),
#  '10072908': ('tissue', 'Proximal jejunum'),
#  '10080731': ('isolation_source', 'Hospital patients'),
#  '10088371': ('tissue', 'Sputum'),
#  '10092280': ('isolation_source', 'missing'),
#  '10097534': ('isolation_source', 'human'),
#  '10104985': ('isolation_source', 'Water column'),
#  '10119081': ('tissue', 'tumor'),
#  '10128932': ('tissue', 'blood'),
#  '10142456': ('tissue', 'lung cancer'),
#  '10148089': ('tissue', 'SKIN FIBROBLASTS'),
#  '10148996': ('tissue', 'leaf'),
#  '10162994': ('tissue', 'cortex'),
#  '10163223': ('isolation_source', 'Drainage from GT site'),
#  '10178733': ('isolation_source', 'upper respiratory tract'),
#  '10179895': ('isolation_source', 'upper respiratory tract'),
#  '10182641': ('isolation_source', 'missing'),
#  '10218328': ('isolation_source', 'not applicable'),
#  '10221719': ('isolation_source', 'stool'),
#  '10222917': ('sample_type', 'metagenomic assembly'),
#  '10223709': ('sample_type', 'metagenomic assembly'),
#  '10239220': ('tissue', 'whole body'),
#  '10250336': ('tissue', 'fin clip'),
#  '10251068': ('tissue', '7 day-old whole mount seedling'),
#  '10251091': ('tissue', '7 day-old whole mount seedling'),
#  '10253602': ('isolation_source', 'clinical'),
#  '10257240': ('tissue', 'Liver'),
#  '10261766': ('isolation_source', 'animal-cattle-dairy cow'),
#  '10268665': ('tissue', 'Liver'),
#  '10273713': ('tissue', 'liver'),
#  '10280703': ('tissue', 'Liver'),
#  '10288577': ('tissue', 'Liver'),
#  '10288578': ('tissue', 'Liver'),
#  '10294455': ('tissue', 'spleen'),
#  '10294851': ('tissue', 'spleen'),
#  '10295030': ('tissue', 'spleen'),
#  '10305610': ('tissue', 'Liver'),
#  '10305865': ('tissue', 'Brain'),
#  '10306396': ('tissue', 'heart'),
#  '10306753': ('tissue', 'heart'),
#  '10306770': ('tissue', 'heart'),
#  '10320007': ('tissue', 'upper leaf'),
#  '10321799': ('tissue', 'Saliva'),
#  '10322698': ('tissue', 'Saliva'),
#  '10326188': ('tissue', 'Blood'),
#  '10369272': ('tissue', 'Peripheral Blood'),
#  '10369720': ('tissue', 'Peripheral Blood'),
#  '10372718': ('tissue', 'Peripheral Blood'),
#  '10373080': ('tissue', 'Bone marrow'),
#  '10382627': ('tissue', 'Peripheral blood'),
#  '10394479': ('tissue', 'nectar'),
#  '10400161': ('tissue', 'inner cell mass'),
#  '10405537': ('tissue', 'Lung'),
#  '10417374': ('sample_type', 'metagenomic assembly'),
#  '10425650': ('tissue', 'leaf'),
#  '10432154': ('isolation_source', 'missing'),
#  '10432940': ('isolation_source', 'human'),
#  '10436663': ('tissue', 'skin'),
#  '10438262': ('tissue', 'lung'),
#  '10444757': ('tissue', 'Blood'),
#  '10444952': ('tissue', 'Blood'),
#  '10445243': ('tissue', 'Buffy coat'),
#  '10457598': ('isolation_source', 'clinical isolate'),
#  '10457703': ('isolation_source', 'clinical isolate'),
#  '10458708': ('isolation_source', 'urine'),
#  '10464209': ('isolation_source', 'hindgut'),
#  '10484209': ('tissue', 'Leaf'),
#  '10488290': ('tissue', 'mammary tumor'),
#  '10501305': ('tissue', 'Placenta'),
#  '10505554': ('isolation_source', 'missing'),
#  '10506826': ('tissue', 'leaf'),
#  '10507055': ('tissue', 'leaf'),
#  '10507251': ('tissue', 'leaf'),
#  '10507440': ('tissue', 'leaf'),
#  '10508228': ('tissue', 'leaf'),
#  '10512103': ('tissue', 'vascular leaf'),
#  '10521872': ('isolation_source', 'human'),
#  '10523477': ('isolation_source', 'lake'),
#  '10525541': ('isolation_source', "['Marine sediment metagenome', '']"),
#  '10527736': ('isolation_source', 'child nostril 86'),
#  '10536141': ('tissue', 'pancreas'),
#  '10579885': ('isolation_source', 'missing'),
#  '10588243': ('isolation_source', 'wood branche'),
#  '10588517': ('isolation_source', 'wood branche'),
#  '10592240': ('tissue', 'leaf'),
#  '10610574': ('sample_type', 'metagenomic assembly'),
#  '10613022': ('tissue', 'Cell line'),
#  '10633369': ('tissue', 'blood'),
#  '10637578': ('tissue', 'Fat4 organoid 2'),
#  '10641765': ('tissue', 'seedlings'),
#  '10644384': ('tissue', 'liver (tumor tissue)'),
#  '10661715': ('isolation_source', 'missing'),
#  '10662759': ('tissue', 'Blood'),
#  '10670995': ('tissue', 'gallbladder'),
#  '10682815': ('tissue', 'lymph node'),
#  '10683969': ('tissue', 'leaf'),
#  '10685947': ('isolation_source', 'missing'),
#  '10689717': ('isolation_source', 'missing'),
#  '10697921': ('isolation_source', 'ocean plankton'),
#  '10713055': ('tissue', 'leaf'),
#  '10757690': ('tissue', 'Whole Blood'),
#  '10758991': ('tissue', 'Whole Blood'),
#  '10759776': ('tissue', 'Whole Blood'),
#  '10774428': ('tissue', 'whole insects'),
#  '10779052': ('tissue', 'Kidney'),
#  '10795181': ('tissue', 'bone marrow'),
#  '10828741': ('sample_type', 'Cell culture'),
#  '10844035': ('tissue', 'Cecal contents'),
#  '10853018': ('tissue', 'prostate cancer'),
#  '10862478': ('tissue', 'whole malpighian tubules'),
#  '10870425': ('tissue', 'Single acute myeloid leukemia intitiating cell'),
#  '10882751': ('tissue', 'Root'),
#  '10887371': ('strain', 'Ec-173'),
#  '10908559': ('tissue', 'Leaf'),
#  '10919884': ('isolation_source', 'missing'),
#  '10921654': ('isolation_source', 'missing'),
#  '10926408': ('isolation_source', 'missing'),
#  '10948556': ('tissue', 'blood'),
#  '10949696': ('tissue', 'Brain'),
#  '10951240': ('tissue', 'Brain'),
#  '10955039': ('tissue', 'adrenal cortex'),
#  '10961432': ('sample_type', 'whole organism'),
#  '10965976': ('sample_type', 'Culture'),
#  '10974888': ('tissue', 'Kidney'),
#  '10990790': ('tissue', 'Blood'),
#  '10997814': ('isolation_source', 'missing'),
#  '11019705': ('tissue', 'ear'),
#  '11026848': ('isolation_source', 'not collected'),
#  '11029462': ('isolation_source',
#               'Biofilm cultures acclimated in artificial seawater with 300 mg '
#               'nitrate-N/L at 23 C, methanol 0.3%'),
#  '11039701': ('isolation_source',
#               'DCD application vegetable soil (Day 21,replicate1)'),
#  '11040044': ('isolation_source', 'Breast milk'),
#  '11041277': ('isolation_source', 'Antarctic soil'),
#  '11048273': ('isolation_source', 'Zea mays'),
#  '11053121': ('isolation_source', 'Bacteria_NPK4'),
#  '11094841': ('tissue', 'whole tadpole'),
#  '11110163': ('tissue', 'body'),
#  '11116540': ('isolation_source', 'sterile site'),
#  '11125023': ('sample_type', 'cell culture'),
#  '11126947': ('strain', '105-L71-A'),
#  '11129563': ('tissue', 'tumor-1'),
#  '11132612': ('tissue', 'whole embryo'),
#  '11150893': ('tissue', 'Brain (middle temporal gyrus)'),
#  '11167516': ('tissue', 'leaf'),
#  '11169373': ('tissue', 'Peripheral Blood'),
#  '11169777': ('tissue', 'Peripheral Blood'),
#  '11170356': ('tissue', 'Peripheral Blood'),
#  '11172493': ('tissue', 'Peripheral Blood'),
#  '11175411': ('tissue', 'cells'),
#  '11179265': ('sample_type', 'cell culture'),
#  '11183865': ('sample_type', 'skin'),
#  '11184252': ('sample_type', 'wall'),
#  '11229513': ('tissue', 'frozen leaf tissue'),
#  '11239006': ('tissue', 'Saliva'),
#  '11242336': ('tissue', 'leaf'),
#  '11244396': ('tissue', 'Kidney'),
#  '11245190': ('tissue', 'Liver'),
#  '11247823': ('tissue', 'leaf'),
#  '11252572': ('tissue', 'other'),
#  '11258622': ('isolation_source', 'pig'),
#  '11263222': ('tissue', 'floral bud'),
#  '11263894': ('tissue', 'Young leaves'),
#  '11264388': ('tissue', 'Young leaves'),
#  '11266299': ('tissue', 'Dorsal root ganglion'),
#  '11285932': ('tissue', 'Primary Blood Derived Cancer - Bone Marrow'),
#  '11292258': ('tissue', 'chest muscle'),
#  '11316702': ('tissue', 'gametophyte'),
#  '11338954': ('isolation_source',
#               'pulmonary sample from from cystic fibrosis patient'),
#  '11343118': ('tissue', 'Kidney'),
#  '11362216': ('tissue', 'Blood'),
#  '11371873': ('tissue', 'Blood'),
#  '11374781': ('tissue', 'Sinoatrial'),
#  '11387980': ('tissue', 'Cochlear implant_control mucosa'),
#  '11401644': ('tissue', 'breast muscle'),
#  '11417993': ('tissue', 'hESCs'),
#  '11462128': ('tissue', 'Ewing sarcoma'),
#  '11475845': ('tissue', 'Whole body'),
#  '11476167': ('sample_type', 'Conidia'),
#  '11477096': ('isolation_source', 'chicken carcass'),
#  '11483577': ('sample_type', 'Frozen Cells'),
#  '11488869': ('tissue', 'leaf'),
#  '11494564': ('tissue', 'not applicable'),
#  '11510403': ('strain', 'WCS417 pqqC::Tn'),
#  '11512334': ('strain', '110'),
#  '11523853': ('isolation_source', 'stool'),
#  '11524200': ('isolation_source', 'sort3AwellK9'),
#  '11527368': ('sample_type', 'Tissue sample'),
#  '11534623': ('tissue', 'ear biopsy'),
#  '11541243': ('tissue', 'Peripheral blood'),
#  '11565131': ('tissue', 'Subcutaneous tumor tissue'),
#  '11566634': ('tissue', 'Spleen'),
#  '11584724': ('tissue', 'blood'),
#  '11590929': ('tissue', 'WholeBlood'),
#  '11612205': ('tissue', 'muscle'),
#  '11613477': ('tissue', 'the whole root system'),
#  '11615590': ('tissue', 'not applicable'),
#  '11620121': ('tissue', 'Bone marrow'),
#  '11642703': ('tissue', 'skin'),
#  '11646060': ('tissue', 'skin'),
#  '11649648': ('tissue', 'skin'),
#  '11658413': ('sample_type', 'cell culture'),
#  '11811966': ('tissue', 'muscle'),
#  '11828034': ('tissue', 'Heart - Left Ventricle'),
#  '11829926': ('tissue', 'Pituitary'),
#  '11830009': ('tissue', 'Skin - Not Sun Exposed (Suprapubic)'),
#  '11846001': ('tissue', 'Liver'),
#  '11849559': ('strain', 'BIOML-A131'),
#  '11849964': ('strain', 'C57BL/6J'),
#  '11854326': ('sample_type', 'pure culture'),
#  '11854585': ('tissue', 'Lung_7'),
#  '11877735': ('tissue', 'Pallial tentacle'),
#  '11890841': ('tissue', 'tea leaves'),
#  '11920491': ('tissue', 'MOUTH'),
#  '11922630': ('tissue', 'MOUTH'),
#  '11923710': ('tissue', 'MOUTH'),
#  '11924653': ('tissue', 'MOUTH'),
#  '11925777': ('tissue', 'MOUTH'),
#  '11946579': ('strain', 'BIOML-A169'),
#  '11952044': ('sample_type', 'Culture'),
#  '11954521': ('sample_type', 'Stool Swab'),
#  '11962847': ('tissue', 'stem'),
#  '11972290': ('tissue', 'Blood'),
#  '12006381': ('isolation_source', 'missing'),
#  '12013299': ('isolation_source', 'human gut'),
#  '12030368': ('isolation_source', 'human gut'),
#  '12057863': ('sample_type', 'not applicable'),
#  '12071539': ('sample_type', 'mixed cultures'),
#  '12078180': ('sample_type', 'Nasal'),
#  '12080461': ('tissue', 'whole body'),
#  '12082351': ('tissue', 'whole body'),
#  '12085308': ('tissue', 'heart'),
#  '12095047': ('tissue', 'gynoecium'),
#  '12101784': ('sample_type', 'whole organism'),
#  '12107914': ('isolation_source', 'missing'),
#  '12138196': ('isolation_source', 'CR9A'),
#  '12142523': ('isolation_source', 'missing'),
#  '12164036': ('isolation_source', 'faecal'),
#  '12164524': ('isolation_source', 'faecal'),
#  '12211534': ('isolation_source', 'subgingival plaque'),
#  '12212205': ('isolation_source', 'sputum'),
#  '12221062': ('isolation_source', 'missing'),
#  '12234444': ('strain', 'MyJU297'),
#  '12236624': ('isolation_source', 'CB-WINGS'),
#  '12237776': ('isolation_source', 'missing'),
#  '12248454': ('tissue', 'liver'),
#  '12250740': ('isolation_source', 'lung'),
#  '12251043': ('isolation_source', 'lung'),
#  '12259529': ('isolation_source', 'feces'),
#  '12276807': ('isolation_source', 'Clinic'),
#  '12283759': ('tissue', 'liver samples'),
#  '12305912': ('tissue', 'full body'),
#  '12319583': ('tissue', 'buccal mucosa'),
#  '12322213': ('tissue', 'leaf'),
#  '12322511': ('tissue', 'leaf'),
#  '12340610': ('tissue', 'leaf'),
#  '12361031': ('tissue', 'one thorax'),
#  '12361176': ('tissue', 'Bone marrow'),
#  '12389796': ('tissue', 'Leaf'),
#  '12394093': ('tissue', 'dentine'),
#  '12398496': ('tissue', 'lymph node'),
#  '12399592': ('tissue', 'leaf'),
#  '12400142': ('tissue', 'Pancreas'),
#  '12401827': ('isolation_source', 'comminuted beef'),
#  '12411271': ('tissue', 'Blood'),
#  '12415794': ('isolation_source', 'missing'),
#  '12475958': ('isolation_source', 'animal-cattle-heifer'),
#  '12484288': ('isolation_source', 'cattle rumen'),
#  '12484440': ('isolation_source', 'cattle rumen'),
#  '12486924': ('isolation_source', 'cattle rumen'),
#  '12487705': ('isolation_source', 'cattle rumen'),
#  '12488792': ('isolation_source', 'cattle rumen'),
#  '12496142': ('tissue', 'root'),
#  '12502969': ('tissue', 'breast'),
#  '12507855': ('strain', 'SESURV_p0_395'),
#  '12508019': ('strain', 'SESURV_p1_0581'),
#  '12509170': ('isolation_source', 'missing'),
#  '12511169': ('isolation_source', 'Microcosm_sample377'),
#  '12519395': ('isolation_source', 'human gut'),
#  '12541047': ('isolation_source', 'feces'),
#  '12546739': ('isolation_source', 'human'),
#  '12551182': ('isolation_source', 'sputum'),
#  '12551394': ('isolation_source', 'sputum'),
#  '12565850': ('isolation_source', 'sputum'),
#  '12573836': ('isolation_source', 'human'),
#  '12578678': ('isolation_source', 'rotten substrate'),
#  '12581495': ('tissue', 'leaf'),
#  '12583493': ('tissue', 'Blood'),
#  '12585648': ('isolation_source', 'feces'),
#  '12589366': ('isolation_source', 'missing'),
#  '12594614': ('isolation_source', 'soil'),
#  '12595544': ('tissue', 'gastric cancer'),
#  '12598709': ('sample_type', 'metagenomic assembly'),
#  '12619494': ('tissue', 'not applicable'),
#  '12624308': ('sample_type', 'cell culture'),
#  '12641608': ('tissue', 'skin'),
#  '12648571': ('isolation_source', 'human'),
#  '12650778': ('isolation_source', 'Arch_A120d_incubation_15_16'),
#  '12658015': ('tissue', 'Leaf'),
#  '12664677': ('tissue', 'Blood'),
#  '12684612': ('isolation_source', 'missing'),
#  '12696886': ('tissue', 'Legs'),
#  '12696954': ('tissue', 'blood'),
#  '12700458': ('tissue', 'basal (= proximal) halves of fully expanded leaves'),
#  '12700555': ('tissue', 'WBC'),
#  '12710038': ('sample_type', 'gut microbiome'),
#  '12711117': ('sample_type', 'saliva'),
#  '12745570': ('isolation_source', 'resp'),
#  '12745606': ('isolation_source', 'blood'),
#  '12746623': ('isolation_source', 'environment'),
#  '12751698': ('isolation_source', 'HF Mouse feces 6'),
#  '12751701': ('isolation_source', 'HS Mouse feces 6'),
#  '12755934': ('isolation_source', 'Rimov reservoir'),
#  '12769348': ('isolation_source', 'gut'),
#  '12769366': ('isolation_source', 'gut'),
#  '12771554': ('isolation_source', 'missing'),
#  '12773534': ('isolation_source', 'surface waters_0.2um'),
#  '12774251': ('sample_type', 'Whole organism'),
#  '12799286': ('isolation_source', 'environmental swab'),
#  '12812247': ('isolation_source', 'missing'),
#  '12815297': ('isolation_source', 'missing'),
#  '12817674': ('isolation_source', 'Semi-arid orchards in the loess plateau'),
#  '12829597': ('tissue', 'not collected'),
#  '12840178': ('tissue', 'Intestine'),
#  '12843670': ('tissue', 'embryonic kidney'),
#  '12847829': ('tissue', 'not collected'),
#  '12867246': ('tissue', 'Blood'),
#  '12875514': ('tissue', 'Leaves'),
#  '12875930': ('tissue', 'Whole organism'),
#  '12877909': ('tissue', 'Liver'),
#  '12878413': ('sample_type', 'not collected'),
#  '12881385': ('isolation_source', 'missing'),
#  '12897947': ('tissue', 'Leaf'),
#  '12904251': ('tissue', 'blood'),
#  '12911150': ('isolation_source', 'missing'),
#  '12911850': ('isolation_source', 'xylem shavings'),
#  '12912828': ('tissue', 'Primary dermal lymphatic endothelial cells'),
#  '12914874': ('tissue', 'Blood'),
#  '12987302': ('tissue', 'Adjacent normal'),
#  '12988544': ('tissue', 'Adjacent normal'),
#  '12988684': ('tissue', 'Tumor'),
#  '13003190': ('isolation_source', 'missing'),
#  '13004499': ('isolation_source', 'food'),
#  '13008173': ('isolation_source', 'Grassland_soil'),
#  '13008405': ('strain', 'FAM19160'),
#  '13021508': ('tissue', 'leaf'),
#  '13028119': ('isolation_source', 'Not applicable'),
#  '13028847': ('tissue', 'whole organism'),
#  '13033211': ('tissue', 'blood'),
#  '13033903': ('tissue', 'not applicable'),
#  '13035003': ('tissue', 'not applicable'),
#  '13041115': ('tissue', 'Whole organism'),
#  '13041581': ('tissue', 'neural cells'),
#  '13048230': ('tissue',
#               'DNA from 2-5 true leaf stage. Phenotypes from fully mature '
#               'plants.'),
#  '13048414': ('tissue', 'nasal ChAT-eGFP+ FSChi/SSChi epithelial cells'),
#  '13049952': ('tissue', 'peripheral blood'),
#  '13058558': ('tissue', 'not applicable'),
#  '13067630': ('tissue', 'MCF-7 cell line'),
#  '13070759': ('tissue', 'placenta/decidua'),
#  '13078383': ('tissue', 'liver'),
#  '13084914': ('tissue', 'mixed embryo and skin'),
#  '13087565': ('isolation_source', 'missing'),
#  '13088838': ('tissue', 'whole body'),
#  '13100934': ('tissue', 'unknown'),
#  '13101942': ('tissue', 'unknown'),
#  '13144567': ('tissue', 'BLOOD'),
#  '13144977': ('tissue', 'BLOOD'),
#  '13147465': ('tissue', 'BLOOD'),
#  '13147508': ('tissue', 'BLOOD'),
#  '13148357': ('tissue', 'BLOOD'),
#  '13165964': ('tissue', 'Root'),
#  '13169709': ('isolation_source', 'sputum'),
#  '13173830': ('isolation_source', 'human'),
#  '13175880': ('isolation_source', 'human oral'),
#  '13182864': ('isolation_source', 'soil78'),
#  '13195468': ('isolation_source', 'Pulmonary'),
#  '13196570': ('isolation_source', 'Fermented pineapple'),
#  '13240872': ('sample_type', 'stool'),
#  '13290057': ('sample_type', 'Soil53'),
#  '13323077': ('strain', 'missing'),
#  '13334965': ('isolation_source', 'patient'),
#  '13340304': ('isolation_source', 'animal-swine-market swine'),
#  '13344095': ('tissue', 'gills'),
#  '13354599': ('isolation_source', 'Auditory canal'),
#  '13356454': ('tissue', 'Pleura'),
#  '13356540': ('tissue', 'Lung'),
#  '13358410': ('tissue', 'Liver'),
#  '13359440': ('tissue', 'Pleura'),
#  '13364556': ('tissue', 'Lung'),
#  '13375836': ('tissue', 'Lung'),
#  '13379099': ('tissue', 'brain'),
#  '13388076': ('tissue', 'Pooled'),
#  '13396520': ('tissue', 'Inner Oral Cavity'),
#  '13400910': ('tissue', 'Brain'),
#  '13405012': ('tissue', 'leaf'),
#  '13452612': ('tissue', 'Stool'),
#  '13463155': ('tissue', 'Blood'),
#  '13467792': ('tissue', 'Plasma'),
#  '13471821': ('isolation_source', 'eye swab'),
#  '13472170': ('isolation_source', 'throat swab'),
#  '13500127': ('isolation_source', 'Fecal matter'),
#  '13500550': ('tissue', 'adult thoracic muscle tissue'),
#  '13503754': ('tissue', 'metastasis lesion'),
#  '13503919': ('sample_type', 'strain culture'),
#  '13518912': ('tissue', 'Leaf'),
#  '13530596': ('tissue', 'spleen'),
#  '13530992': ('tissue', 'spleen'),
#  '13532721': ('tissue', 'Stool'),
#  '13551901': ('tissue', 'whole legs'),
#  '13552797': ('sample_type', 'Single Pathogen Reads from Metagenomic Sample'),
#  '13577992': ('isolation_source', 'human'),
#  '13608391': ('tissue', 'anterior end of body'),
#  '13615526': ('tissue', 'whole brain'),
#  '13625047': ('tissue', 'Primary human adult islet'),
#  '13626487': ('tissue', 'Blood'),
#  '13627938': ('tissue', 'Blood'),
#  '13629956': ('tissue', 'Blood'),
#  '13630003': ('tissue', 'Blood'),
#  '13632608': ('sample_type', 'metagenomic assembly'),
#  '13633042': ('sample_type', 'metagenomic DNA3'),
#  '13633053': ('sample_type', 'metagenomic DNA14'),
#  '13638970': ('isolation_source', 'stool'),
#  '13649740': ('isolation_source', 'feces'),
#  '13662535': ('isolation_source', 'missing'),
#  '13663658': ('isolation_source', 'missing'),
#  '13675508': ('isolation_source', 'oil production water84'),
#  '13676719': ('isolation_source', 'Cecum'),
#  '13684428': ('isolation_source', 'Pelagic sediment'),
#  '13684673': ('isolation_source', 'missing'),
#  '13699479': ('tissue', 'DNA from 2-5 true leaf stage.'),
#  '13707912': ('tissue', 'Foot'),
#  '13717329': ('tissue', 'Brain'),
#  '13722596': ('tissue', 'Peripheral Blood'),
#  '13723605': ('tissue', 'Peripheral Blood'),
#  '13723840': ('tissue', 'Peripheral Blood'),
#  '13725944': ('tissue', 'Peripheral Blood'),
#  '13727602': ('tissue', 'Peripheral Blood'),
#  '13731137': ('tissue', 'Peripheral Blood'),
#  '13765183': ('tissue', 'Blood'),
#  '13765418': ('tissue', 'Blood'),
#  '13765426': ('tissue', 'Blood'),
#  '13768881': ('tissue', 'Blood'),
#  '13772778': ('tissue', 'Blood'),
#  '13776749': ('tissue', 'Blood'),
#  '13779185': ('tissue', 'Blood'),
#  '13779346': ('tissue', 'Blood'),
#  '13781264': ('tissue', 'cochlea'),
#  '13816732': ('tissue', 'caudal fin'),
#  '13819665': ('tissue', 'Peripheral blood'),
#  '13820171': ('tissue', 'Peripheral blood'),
#  '13831794': ('tissue', 'missing'),
#  '13836411': ('tissue', 'dorsal hippocampus'),
#  '13841686': ('tissue', 'germinated conidia'),
#  '13843306': ('tissue', 'not available'),
#  '13844439': ('tissue', 'not available'),
#  '13855440': ('tissue', 'colon'),
#  '13859149': ('tissue', 'colon'),
#  '13890806': ('tissue', 'whole organism'),
#  '13900623': ('tissue', 'colorectal'),
#  '13904921': ('tissue', 'brain'),
#  '13906135': ('isolation_source', 'environmental'),
#  '13906421': ('isolation_source', 'environmental'),
#  '13908744': ('isolation_source', 'male C57BL/6J feces'),
#  '13909747': ('tissue', 'tube foot stem'),
#  '13911986': ('tissue', 'faecal sample'),
#  '13916059': ('tissue', 'leaf'),
#  '13926044': ('tissue', 'Leaf'),
#  '13926400': ('tissue', 'hypothalamus'),
#  '13928035': ('tissue', 'liver'),
#  '13942377': ('tissue', 'Embryonic brain'),
#  '13959796': ('tissue', 'Blood'),
#  '13976155': ('isolation_source', 'missing'),
#  '13977288': ('isolation_source',
#               'A mix of two samples: one from near bottom of the lake, and one '
#               'from the surface, both collected at the deepest part of the '
#               'lake.'),
#  '13978667': ('sample_type', 'Whole organism'),
#  '13996995': ('isolation_source', 'pork chop'),
#  '14009944': ('tissue', 'whole tissue'),
#  '14012183': ('tissue', 'Peripheral Blood'),
#  '14014685': ('tissue', 'Peripheral Blood'),
#  '14019819': ('tissue', 'Peripheral Blood'),
#  '14023830': ('tissue', 'Peripheral Blood'),
#  '14025741': ('tissue', 'Peripheral Blood'),
#  '14029691': ('tissue', 'Peripheral Blood'),
#  '14031847': ('tissue', 'Peripheral Blood'),
#  '14035018': ('tissue', 'Peripheral Blood'),
#  '14041536': ('tissue', 'Peripheral Blood'),
#  '14042319': ('tissue', 'Peripheral Blood'),
#  '14044710': ('tissue', 'Peripheral Blood'),
#  '14047593': ('tissue', 'Peripheral Blood'),
#  '14071607': ('tissue', 'Leaf'),
#  '14080582': ('isolation_source', 'chlorinated drinking water, site 4'),
#  '14092771': ('isolation_source', 'anus'),
#  '14095299': ('isolation_source', 'stool'),
#  '14102550': ('isolation_source', 'stool'),
#  '14113671': ('isolation_source', 'Missing'),
#  '14115465': ('tissue', 'leaf'),
#  '14116460': ('tissue', 'Subcutaneous adipose tissue 9'),
#  '14120208': ('tissue', 'carcass'),
#  '14121374': ('isolation_source', 'human'),
#  '14124545': ('tissue', 'whole body'),
#  '14143356': ('tissue', 'hippocampus'),
#  '14150066': ('tissue', 'leaf'),
#  '14150763': ('isolation_source', 'sterile site'),
#  '14151385': ('isolation_source',
#               'Soil core from HaP96 plot (Hainich forest), 80-100 cm'),
#  '14154558': ('isolation_source', 'groin'),
#  '14209868': ('isolation_source', 'sputum'),
#  '14213979': ('tissue', 'Thorax/Abdomen'),
#  '14235018': ('isolation_source', 'blood'),
#  '14239450': ('isolation_source', 'Endotracheal aspirate'),
#  '14256660': ('tissue', 'Leaf'),
#  '14287647': ('tissue', 'Not available'),
#  '14289919': ('tissue', 'Not available'),
#  '14308705': ('tissue', 'five whole worms'),
#  '14309629': ('tissue', 'flower'),
#  '14319469': ('tissue', 'Brain'),
#  '14320558': ('tissue', 'Brain'),
#  '14321610': ('tissue', 'Brain'),
#  '14321672': ('tissue', 'Brain'),
#  '14324483': ('tissue', 'Whole fly'),
#  '14325416': ('tissue', 'brain'),
#  '14325680': ('tissue', 'brain'),
#  '14325708': ('tissue', 'brain'),
#  '14326858': ('tissue', 'brain'),
#  '14328561': ('tissue', 'Blood'),
#  '14334279': ('tissue', 'brain'),
#  '14336393': ('tissue', 'brain'),
#  '14340877': ('tissue', 'brain'),
#  '14364888': ('sample_type', 'pure culture'),
#  '14369509': ('tissue', 'not applicable'),
#  '14370324': ('tissue', 'not applicable'),
#  '14387373': ('tissue', 'liver'),
#  '14389711': ('tissue', 'Abo'),
#  '14392067': ('tissue', 'Implanted MC38 tumor'),
#  '14392661': ('tissue', 'saliva'),
#  '14396023': ('tissue', 'blood'),
#  '14405790': ('tissue', 'Blood'),
#  '14420455': ('tissue', 'Whole body'),
#  '14423715': ('tissue', 'thymus'),
#  '14431079': ('isolation_source', 'Penguin feces'),
#  '14432031': ('isolation_source', 'stool'),
#  '14436502': ('isolation_source', 'patient clinical specimen'),
#  '14444423': ('tissue', 'coral holobiont (skeleton, tissue, symbiont)'),
#  '14465110': ('tissue', 'kidney'),
#  '14470573': ('tissue', 'Young leaves'),
#  '14471369': ('tissue', 'Lung'),
#  '14472484': ('tissue', 'Blood'),
#  '14475509': ('tissue', 'distal lung'),
#  '14475747': ('tissue', 'distal lung'),
#  '14479874': ('tissue', 'brain'),
#  '14488656': ('tissue', 'liver'),
#  '14496811': ('tissue', 'paraventricular nucleus of hypothalamus'),
#  '14503594': ('isolation_source', 'missing'),
#  '14510621': ('isolation_source', 'Mushroom Spring'),
#  '14511125': ('isolation_source', 'untreated salt marsh sediment'),
#  '14512414': ('isolation_source', 'missing'),
#  '14513317': ('isolation_source', 'missing'),
#  '14519818': ('isolation_source', 'soil'),
#  '14521720': ('tissue', 'tail'),
#  '14528593': ('tissue', 'muscle'),
#  '14540480': ('tissue', 'Intestinal organoid'),
#  '14541177': ('sample_type', 'metagenomic assembly'),
#  '14543971': ('sample_type', 'Monoculture'),
#  '14559910': ('isolation_source', 'missing'),
#  '14564101': ('sample_type', 'metagenomic assembly'),
#  '14565024': ('sample_type', 'soil'),
#  '14582101': ('sample_type', 'cell culture'),
#  '14593156': ('isolation_source',
#               '10 sea water samples from phytoplankton spring bloom collected '
#               'during Heincke cruise HE327'),
#  '14596656': ('sample_type', 'pure culture'),
#  '14598083': ('isolation_source', 'missing'),
#  '14607874': ('tissue', 'Gill'),
#  '14611864': ('tissue', 'Tumor developed in mammary gland 2/3'),
#  '14615848': ('tissue', 'hemolymph'),
#  '14647068': ('tissue', 'leaves'),
#  '14652538': ('tissue', 'CC'),
#  '14652899': ('tissue', 'placneta'),
#  '14653776': ('tissue', 'feces'),
#  '14654453': ('tissue', 'blood'),
#  '14660574': ('tissue', 'NULL'),
#  '14667481': ('tissue', 'Basal part'),
#  '14669278': ('sample_type', 'not applicable'),
#  '14672888': ('tissue', 'Leaf'),
#  '14682432': ('tissue', 'Blood'),
#  '14686624': ('tissue', 'blood'),
#  '14686659': ('tissue', 'blood'),
#  '14690659': ('tissue', 'heart'),
#  '14749566': ('tissue', 'OB'),
#  '14749968': ('tissue', 'blood'),
#  '14753415': ('tissue', 'Blood'),
#  '14760235': ('tissue', 'not applicable'),
#  '14760512': ('tissue', 'not applicable'),
#  '14761166': ('tissue', 'not applicable'),
#  '14761557': ('tissue', 'not applicable'),
#  '14762253': ('tissue', 'not applicable'),
#  '14779728': ('tissue', 'Peripheral Blood'),
#  '14782997': ('tissue', 'skeletal muscle'),
#  '14785623': ('tissue', 'leaf'),
#  '14795801': ('tissue', 'NULL'),
#  '14797096': ('tissue', 'NULL'),
#  '14805604': ('tissue', 'NULL'),
#  '14807558': ('tissue', 'NULL'),
#  '14809896': ('tissue', 'NULL'),
#  '14813242': ('tissue', 'NULL'),
#  '14816247': ('tissue', 'leaves'),
#  '14831115': ('tissue', 'colon'),
#  '14837519': ('tissue', 'Corpus Striatum'),
#  '14838129': ('tissue', 'Seed'),
#  '14840423': ('tissue', 'Two centimetres of germinating seedling roots'),
#  '14850793': ('tissue', 'Whole tick digest (up to 150mg)'),
#  '14851393': ('tissue', 'gill'),
#  '14853732': ('tissue', 'gonad'),
#  '14856834': ('sample_type', 'Dried Blood Spot'),
#  '14885855': ('tissue', 'blood'),
#  '14887894': ('tissue', 'blood'),
#  '14921716': ('tissue', 'Blood'),
#  '14931657': ('tissue', 'Kidney'),
#  '14933166': ('sample_type', 'Pure cell culture'),
#  '14967301': ('isolation_source', 'missing'),
#  '14973448': ('sample_type', 'Culture'),
#  '14980702': ('tissue', 'Ear Biopsy'),
#  '14991135': ('tissue', 'Ear Biopsy'),
#  '14995723': ('tissue', 'muscle'),
#  '14996947': ('isolation_source', 'food'),
#  '14998741': ('isolation_source', 'Ocean water'),
#  '14998810': ('isolation_source', 'Ocean water'),
#  '15007006': ('tissue', 'Dried tissue106283'),
#  '15009967': ('tissue', 'Leaves'),
#  '15011357': ('tissue', 'fin'),
#  '15016641': ('isolation_source', 'unknown'),
#  '15032721': ('tissue', 'tadpole'),
#  '15035839': ('tissue', 'bone marrow'),
#  '15054343': ('tissue', 'Skin fruit tissue'),
#  '15066219': ('tissue', 'liver'),
#  '15073964': ('tissue', 'Resected tumors'),
#  '15083487': ('tissue', 'White muscle'),
#  '15084299': ('tissue', 'Blood'),
#  '15092397': ('tissue', 'Olfactory bulb'),
#  '15097800': ('tissue', 'leaves and young fruits'),
#  '15098055': ('tissue', 'Blood'),
#  '15106692': ('tissue', 'NULL'),
#  '15117335': ('tissue', 'NULL'),
#  '15119963': ('tissue', 'NULL'),
#  '15125927': ('tissue', 'NULL'),
#  '15127351': ('tissue', 'NULL'),
#  '15127550': ('tissue', 'NULL'),
#  '15127834': ('tissue', 'NULL'),
#  '15129646': ('tissue', 'NULL'),
#  '15131699': ('tissue', 'NULL'),
#  '15132104': ('tissue', 'NULL'),
#  '15132940': ('tissue', 'NULL'),
#  '15153080': ('tissue', 'leaf'),
#  '15153303': ('tissue', 'leaf'),
#  '15153702': ('tissue', 'leaf'),
#  '15158342': ('tissue', 'FECAL'),
#  '15165437': ('tissue', 'Blood'),
#  '15190852': ('tissue', 'whole organism'),
#  '15206442': ('tissue', 'testa'),
#  '15218101': ('tissue', 'not applicable'),
#  '15219086': ('isolation_source', 'swab'),
#  '15223231': ('sample_type', 'whole organism'),
#  '15225515': ('isolation_source', 'human'),
#  '15228673': ('isolation_source', 'not applicable'),
#  '15231022': ('isolation_source', 'Sputum sample'),
#  '15248397': ('tissue', 'lung metastasis'),
#  '15250051': ('isolation_source', 'missing'),
#  '15252559': ('isolation_source', 'lake water'),
#  '15257801': ('isolation_source', 'lake water'),
#  '15259258': ('isolation_source', 'lake water'),
#  '15259308': ('isolation_source', 'lake water'),
#  '15264765': ('isolation_source', 'lake water'),
#  '15295889': ('isolation_source', 'Cooper 12'),
#  '15297107': ('tissue', 'blood'),
#  '15307324': ('tissue', 'blood'),
#  '15310709': ('sample_type', 'cell culture'),
#  '15315139': ('strain', 'Hildenborough'),
#  '15315675': ('isolation_source', 'patient isolate'),
#  '15318405': ('tissue', 'feces'),
#  '15320189': ('tissue', 'WBC'),
#  '15325308': ('isolation_source', 'oropharyngeal swab'),
#  '15327976': ('tissue', 'leaf'),
#  '15339181': ('tissue', 'oral buccal mucosa cells'),
#  '15345168': ('tissue', 'Whole root'),
#  '15362171': ('isolation_source', 'buccal swab'),
#  '15391158': ('isolation_source', 'not collected'),
#  '15393694': ('isolation_source', 'missing'),
#  '15393925': ('isolation_source', 'water'),
#  '15399957': ('isolation_source', 'human'),
#  '15402431': ('sample_type', 'missing'),
#  '15403007': ('tissue', 'blood'),
#  '15413369': ('tissue', 'leaf'),
#  '15414592': ('tissue', 'Blood'),
#  '15420235': ('tissue', 'Ileal Crypts'),
#  '15464968': ('tissue', 'white blood cells'),
#  '15465816': ('tissue', 'Spinal Cord Lumbar'),
#  '15472001': ('tissue', 'stool'),
#  '15474713': ('tissue', 'Blood'),
#  '15475895': ('tissue', 'Blood'),
#  '15478435': ('tissue', 'Blood'),
#  '15481053': ('tissue', 'Liver'),
#  '15484816': ('tissue', 'whole larvae'),
#  '15488236': ('tissue', 'Leaf'),
#  '15493233': ('sample_type', 'Pure culture'),
#  '15500907': ('tissue', 'tumor biopsy'),
#  '15507816': ('tissue', 'Leaf'),
#  '15516894': ('tissue', 'whole body'),
#  '15526900': ('tissue', 'CHEEK SWAB'),
#  '15533164': ('sample_type', 'whole organism'),
#  '15533564': ('sample_type', 'Vehicle_Control'),
#  '15562811': ('isolation_source', 'blood'),
#  '15565567': ('isolation_source', 'missing'),
#  '15568299': ('isolation_source', 'sputum'),
#  '15573230': ('tissue', 'Axillary'),
#  '15580409': ('tissue', 'not collected'),
#  '15581490': ('isolation_source', 'comminuted chicken'),
#  '15594498': ('tissue', 'Blood'),
#  '15594768': ('sample_type', 'whole organism'),
#  '15596452': ('tissue', 'fruits'),
#  '15597879': ('tissue', 'Lung tissue, AT2 cells'),
#  '15600363': ('tissue', 'liver'),
#  '15603316': ('tissue', 'Lung tissue, AT2 cells'),
#  '15638740': ('isolation_source', 'missing'),
#  '15639116': ('isolation_source', 'Outdoor air'),
#  '15640964': ('isolation_source', 'Pus'),
#  '15642886': ('tissue', 'fece'),
#  '15663733': ('sample_type', 'fungi'),
#  '15669859': ('isolation_source', 'nasopharyngeal swab'),
#  '15670089': ('isolation_source', 'nasopharyngeal swab'),
#  '15676263': ('strain', 'NBRC 110633'),
#  '15681412': ('strain', 'not applicable'),
#  '15681416': ('strain', 'not applicable'),
#  '15685160': ('tissue', 'seed'),
#  '15687984': ('isolation_source',
#               'activated sludge from Hong Kong Shatin wastewater treatment '
#               'plant'),
#  '15708661': ('isolation_source', 'Human, Faeces'),
#  '15722379': ('sample_type', 'cell culture'),
#  '15730133': ('tissue', 'pelvic fin'),
#  '15732525': ('isolation_source', 'plaque assay'),
#  '15736419': ('isolation_source', 'human listeriosis'),
#  '15737827': ('tissue', 'Whole Blood'),
#  '15747470': ('tissue', 'Flesh'),
#  '15749053': ('sample_type', 'Dried Blood Spot'),
#  '15774195': ('tissue', 'gastrocnemius'),
#  '15776150': ('isolation_source', 'raw intact chicken'),
#  '15797717': ('isolation_source', 'missing'),
#  '15810621': ('tissue', 'blood'),
#  '15817834': ('tissue', 'Bone Marrow'),
#  '15817948': ('tissue', 'Bone Marrow'),
#  '15832203': ('tissue', 'liver'),
#  '15832209': ('tissue', 'liver'),
#  '15858788': ('isolation_source', 'missing'),
#  '15863422': ('tissue', 'muscle/heart/liver'),
#  '15869217': ('tissue', 'ear'),
#  '15871841': ('sample_type', 'metagenomic assembly'),
#  '15890431': ('tissue', 'Leaf'),
#  '15894065': ('isolation_source', 'missing'),
#  '15897522': ('tissue', 'blood'),
#  '15906285': ('tissue', 'Tail end'),
#  '15916719': ('isolation_source', 'missing'),
#  '15934826': ('isolation_source', 'human'),
#  '15938884': ('tissue', 'needles'),
#  '15947028': ('isolation_source', 'chicken carcass'),
#  '15950849': ('isolation_source', 'seawater'),
#  '15970300': ('isolation_source', 'Myrmecodia beccarii'),
#  '16048130': ('isolation_source', 'missing'),
#  '16062699': ('tissue', 'dental plaque'),
#  '16063930': ('tissue', 'blood'),
#  '16066410': ('strain', 'KCTC 32513'),
#  '16074131': ('strain', 'C57BL/6'),
#  '16074446': ('isolation_source', 'freshwater surface (50 cm depth)'),
#  '16088468': ('sample_type', 'culture'),
#  '16094683': ('tissue', 'not applicable'),
#  '16100852': ('tissue', 'Arm vein'),
#  '16102686': ('tissue', 'Arm vein'),
#  '16114399': ('tissue', 'blood'),
#  '16124146': ('tissue', 'leaf'),
#  '16137342': ('tissue', 'thymus'),
#  '16139391': ('tissue', 'thymus'),
#  '16141829': ('tissue', 'NULL'),
#  '16152338': ('tissue', 'NULL'),
#  '16155106': ('tissue', 'NULL'),
#  '16158783': ('tissue', 'NULL'),
#  '16164736': ('tissue', 'thymus'),
#  '16165027': ('tissue', 'thymus'),
#  '16165759': ('tissue', 'thymus'),
#  '16168185': ('tissue', 'thymus'),
#  '16171406': ('tissue', 'thymus'),
#  '16171677': ('tissue', 'thymus'),
#  '16172154': ('tissue', 'thymus'),
#  '16187603': ('tissue', 'leaves'),
#  '16216560': ('tissue', 'Whole Blood'),
#  '16236517': ('isolation_source', 'missing'),
#  '16246062': ('sample_type', 'isolated colony culture'),
#  '16277324': ('sample_type', 'Plasma_ext_blank'),
#  '16279830': ('sample_type', 'isolated colony culture'),
#  '16319905': ('isolation_source', 'missing'),
#  '16323337': ('isolation_source', 'missing'),
#  '16325008': ('isolation_source', 'missing'),
#  '16344046': ('sample_type', 'metagenomic assembly'),
#  '16346838': ('sample_type', 'metagenomic assembly'),
#  '16353157': ('sample_type', 'stool'),
#  '16367541': ('tissue', 'Liver'),
#  '16374871': ('tissue',
#               'Section of primary root containing a lateral root at Stage 1 - '
#               'when two cells express DR5'),
#  '16378269': ('tissue', 'HEK293T cell line'),
#  '16380352': ('tissue', 'Whole blood'),
#  '16395295': ('tissue', 'leaf'),
#  '16400976': ('tissue', 'fecal'),
#  '16408458': ('tissue', 'Pasta'),
#  '16422150': ('isolation_source', 'bovine barrier'),
#  '16425573': ('isolation_source', 'activated sludge from AalW_18-Q3-R10-53'),
#  '16432154': ('isolation_source', 'human'),
#  '16433516': ('sample_type', 'soil'),
#  '16439599': ('isolation_source', 'Partial nitritation anammox bioreactor'),
#  '16443209': ('isolation_source', 'A367'),
#  '16451854': ('isolation_source', 'pig'),
#  '16453731': ('isolation_source', 'Nasopharyngeal/oropharyngeal swab'),
#  '16480344': ('isolation_source', 'stool'),
#  '16522885': ('tissue', 'medulla (brain)'),
#  '16544143': ('tissue', 'Kidney glomerulus'),
#  '16548300': ('isolation_source', 'missing'),
#  '16557526': ('isolation_source', 'decomposing wood'),
#  '16557996': ('sample_type', 'whole organism'),
#  '16563717': ('isolation_source', 'missing'),
#  '16566819': ('tissue', 'blood'),
#  '16569426': ('tissue', 'blood'),
#  '16579954': ('tissue', 'Whole olfactory mucosa'),
#  '16583267': ('tissue', 'leaves'),
#  '16588063': ('tissue', 'Nasopharyngeal'),
#  '16599057': ('tissue', 'Blood'),
#  '16600276': ('tissue', 'Blood'),
#  '16600914': ('tissue', 'Blood'),
#  '16601082': ('tissue', 'Blood'),
#  '16615262': ('isolation_source', 'missing'),
#  '16622896': ('isolation_source', 'feces'),
#  '16628439': ('tissue', 'Young needle'),
#  '16661077': ('tissue', 'Brain'),
#  '16682751': ('tissue', 'Buccal'),
#  '16688975': ('tissue', 'bone_marrow'),
#  '16690972': ('tissue', 'fin clip'),
#  '16696884': ('tissue', 'WHOLE ORGANISM'),
#  '16727252': ('tissue', 'Bone marrow'),
#  '16749455': ('tissue', 'bone marrow'),
#  '16750004': ('tissue', 'whole egg'),
#  '16750600': ('tissue', 'Colon'),
#  '16751733': ('tissue', 'medial frontal gyrus'),
#  '16752374': ('tissue', 'bone marrow'),
#  '16752953': ('tissue', 'not applicable'),
#  '16777781': ('tissue', 'saliva'),
#  '16778729': ('tissue', 'saliva'),
#  '16781666': ('tissue', 'Kidney'),
#  '16787425': ('tissue', 'leaf'),
#  '16790624': ('isolation_source', 'missing'),
#  '16790835': ('tissue', 'Kidney'),
#  '16792275': ('tissue', 'Kidney'),
#  '16802083': ('tissue', 'leaves'),
#  '16822479': ('isolation_source', 'Wound/Abscess'),
#  '16823870': ('tissue', 'muscle, liver, or shed skin'),
#  '16827604': ('tissue', 'whole organism'),
#  '16831485': ('isolation_source', 'missing'),
#  '16846108': ('isolation_source', 'Wood Untreated-control-replicate=1'),
#  '16847209': ('isolation_source', 'human'),
#  '16857576': ('isolation_source', 'missing'),
#  '16860769': ('tissue', 'esophagus'),
#  '16863317': ('tissue', 'fecal'),
#  '16872898': ('tissue', 'Trachea'),
#  '16886515': ('tissue', 'blood'),
#  '16918832': ('tissue', 'Serum'),
#  '16921197': ('tissue', 'Serum'),
#  '16922339': ('tissue', 'Serum'),
#  '16922585': ('tissue', 'Serum'),
#  '16927969': ('tissue', 'fin clips'),
#  '16940496': ('tissue', 'leaf'),
#  '16948673': ('tissue', 'Blood'),
#  '16957135': ('tissue', 'tumour'),
#  '16957934': ('tissue', 'tumour'),
#  '16958284': ('tissue', 'tumour'),
#  '16958865': ('tissue', 'tumour'),
#  '16965054': ('tissue', 'Leaf'),
#  '16968774': ('tissue', 'mature leaf'),
#  '16973051': ('isolation_source', 'missing'),
#  '16975329': ('isolation_source', 'missing'),
#  '16976097': ('tissue', 'Pooled coral larvae'),
#  '16989774': ('isolation_source', 'Nasopharyngeal/oropharyngeal swab'),
#  '17001819': ('isolation_source', 'surgery'),
#  '17013732': ('sample_type', 'missing'),
#  '17015168': ('tissue', 'colon'),
#  '17018844': ('isolation_source', 'missing'),
#  '17020084': ('isolation_source', 'sputum'),
#  '17050155': ('isolation_source', 'soil sample 1'),
#  '17050291': ('sample_type', 'whole organism'),
#  '17057260': ('tissue', 'Leaf blade'),
#  '17067538': ('tissue', 'WHOLE ORGANISM'),
#  '17076110': ('tissue', 'Plasmodium falciparum: asexual blood stage'),
#  '17076167': ('tissue', 'leaf'),
#  '17083998': ('isolation_source', 'missing'),
#  '17086746': ('tissue', 'inflorescence tissue consisting of stage 3 flowers'),
#  '17103685': ('tissue', 'young leaf'),
#  '17110377': ('tissue', 'Whole Blood'),
#  '17118160': ('tissue', 'liver'),
#  '17136507': ('tissue', 'cervical tissues'),
#  '17147442': ('tissue', 'primary mouse motor cortex'),
#  '17147488': ('tissue', 'primary mouse motor cortex'),
#  '17153013': ('tissue', 'brain'),
#  '17158053': ('tissue', 'WHOLE ORGANISM'),
#  '17160023': ('tissue', 'leaves'),
#  '17170907': ('isolation_source', 'not applicable'),
#  '17180621': ('sample_type', 'chyme'),
#  '17209146': ('tissue', 'Leaf'),
#  '17216730': ('sample_type', 'cell culture'),
#  '17223440': ('tissue', 'body'),
#  '17226176': ('tissue', 'Leaf'),
#  '17229085': ('tissue', 'brain'),
#  '17243345': ('isolation_source', 'freshwater sediment'),
#  '17249044': ('tissue', 'body'),
#  '17254054': ('isolation_source', 'none'),
#  '17283331': ('isolation_source', 'T1.D5.3.A/B (Sorting gate 2)'),
#  '17285211': ('isolation_source', 'missing'),
#  '17285393': ('isolation_source', 'patient isolate'),
#  '17300442': ('isolation_source', 'human'),
#  '17313041': ('tissue', 'caudal fin'),
#  '17368733': ('tissue', 'culured immature embryos'),
#  '17382970': ('tissue', 'BLOOD'),
#  '17386458': ('tissue', 'lung'),
#  '17386643': ('sample_type', 'cell culture from single octad cell'),
#  '17506954': ('sample_type', 'DNA-Seq'),
#  '17574413': ('tissue', 'Ovary'),
#  '17574489': ('tissue', 'Pleural fluid'),
#  '17598619': ('tissue', 'Bone marrow'),
#  '17598841': ('tissue', 'Bone marrow'),
#  '17601364': ('isolation_source', 'single-cell amplified by MDA; feces'),
#  '17604646': ('isolation_source', 'seawater'),
#  '17610940': ('tissue', 'Leaf'),
#  '17611165': ('isolation_source', 'pathogen.cl'),
#  '17613801': ('tissue', 'fin clip'),
#  '17613856': ('tissue', 'fin clip'),
#  '17614601': ('tissue', 'leaf'),
#  '17614699': ('tissue', 'leaf'),
#  '17614935': ('tissue', 'leaf'),
#  '17618440': ('isolation_source', 'blood'),
#  '17705445': ('isolation_source', 'seawater'),
#  '17728449': ('tissue', 'blood'),
#  '17791394': ('tissue', 'Tumor'),
#  '17840774': ('isolation_source', 'skin'),
#  '17843809': ('isolation_source', 'missing'),
#  '17846691': ('isolation_source', 'laboratory'),
#  '17852627': ('isolation_source', 'not applicable'),
#  '17854688': ('isolation_source', 'Nasopharynx: Swab'),
#  '17862546': ('isolation_source', 'missing'),
#  '17864483': ('isolation_source', 'Moss crust soil'),
#  '17886165': ('isolation_source', 'soil'),
#  '17887236': ('tissue', 'feces'),
#  '17901280': ('tissue', 'Thymus'),
#  '17902238': ('tissue', 'Thymus'),
#  '17902798': ('tissue', 'Thymus'),
#  '17902914': ('tissue', 'Thymus'),
#  '17920660': ('tissue', 'kidney'),
#  '17930278': ('tissue', '1'),
#  '17931853': ('tissue', '1'),
#  '17936622': ('tissue', 'Stem'),
#  '17939836': ('tissue', 'peripheral blood'),
#  '17942098': ('tissue', 'peripheral blood'),
#  '17980872': ('tissue', 'spleen'),
#  '18026275': ('tissue', 'seedling'),
#  '18031171': ('tissue', 'peripheral blood'),
#  '18031952': ('tissue', 'peripheral blood'),
#  '18032664': ('tissue', 'peripheral blood'),
#  '18033450': ('tissue', 'peripheral blood'),
#  '18035019': ('tissue', 'the whole plantlets'),
#  '18036311': ('tissue', 'blood'),
#  '18037012': ('tissue', 'bone marrow'),
#  '18053183': ('isolation_source', 'chicken carcass'),
#  '18055391': ('isolation_source', 'reactor sample from MC replicate 1'),
#  '18058762': ('isolation_source', 'Superficial water'),
#  '18059520': ('tissue', 'leaf'),
#  '18061166': ('isolation_source', 'Escherichia coli K-12 DH5a'),
#  '18076178': ('tissue', 'CD4+ T cells'),
#  '18077435': ('tissue', 'glioma'),
#  '18082875': ('isolation_source', 'Great toe Swab'),
#  '18092138': ('tissue', 'meiotic terminal tassel'),
#  '18121572': ('isolation_source', 'human'),
#  '18138945': ('tissue', 'shoot'),
#  '18146225': ('sample_type', 'simulated sputum'),
#  '1816110': ('isolation_source', 'pistachio'),
#  '18192351': ('tissue', 'Fecal'),
#  '18196735': ('tissue', 'blood'),
#  '18208245': ('sample_type', 'Pure mutant culture 12'),
#  '18208365': ('isolation_source', 'missing'),
#  '18246113': ('tissue', 'leaf'),
#  '18247786': ('strain', 'DSM 15595'),
#  '18254923': ('isolation_source', 'Dairy farm'),
#  '18268095': ('tissue', 'leg'),
#  '18269778': ('tissue', 'heart'),
#  '18292611': ('sample_type', 'not collected'),
#  '18310152': ('tissue', 'blood'),
#  '18312161': ('isolation_source', 'nasal'),
#  '18312570': ('isolation_source', 'nasal'),
#  '18317841': ('tissue', 'liver'),
#  '18321772': ('isolation_source', 'food'),
#  '18324634': ('isolation_source', 'rectal swab'),
#  '18332902': ('tissue', 'Fresh Pine Needle'),
#  '18336117': ('tissue', 'Young adult whole animals'),
#  '18345918': ('tissue', 'Whole Blood'),
#  '18353741': ('isolation_source', 'marine hydrothermal sediment'),
#  '18381031': ('tissue', 'Flower bud'),
#  '18420217': ('tissue', 'blood'),
#  '18436501': ('sample_type', 'pure culture'),
#  '18471873': ('tissue', 'Whole-blood'),
#  '18473505': ('tissue', 'secondary follicle stage oocyte'),
#  '18473584': ('isolation_source', 'cyanobacterial mat on coral surface'),
#  '18476514': ('isolation_source', 'nectar sample19'),
#  '18515661': ('isolation_source', 'Kingdergarten'),
#  '18522511': ('tissue', 'Peripheral blood'),
#  '18529593': ('isolation_source', 'nasal swab'),
#  '18530844': ('isolation_source', 'wheat straw residue'),
#  '18532414': ('isolation_source', 'soil'),
#  '18533059': ('isolation_source', 'mouse gut'),
#  '18533189': ('isolation_source', 'leaf endosphere'),
#  '18534328': ('isolation_source', 'Spoiled Fermented Olive Fruit'),
#  '18572608': ('isolation_source', 'blood culture'),
#  '18580773': ('isolation_source', 'aqueous humor'),
#  '18581042': ('isolation_source', 'urine'),
#  '18587583': ('tissue', 'thorax'),
#  '18587942': ('tissue', 'thorax'),
#  '18616554': ('isolation_source', 'environmental swab sponge'),
#  '18617133': ('isolation_source', 'nasophyrangeal swab'),
#  '18618978': ('isolation_source', 'missing'),
#  '18640922': ('isolation_source', 'saline spring sediment'),
#  '18645394': ('isolation_source', 'Oropharyngeal swab'),
#  '18649125': ('isolation_source', 'Catheter'),
#  '18678088': ('isolation_source', 'ITS_AHTR'),
#  '18711996': ('tissue', 'fecal swab'),
#  '18713059': ('tissue', 'not applicable'),
#  '18716431': ('isolation_source', 'missing'),
#  '18763332': ('isolation_source', 'Unknown'),
#  '18794754': ('isolation_source', 'urine'),
#  '18797445': ('sample_type', 'Whole organism'),
#  '18819825': ('tissue', 'Not applicable'),
#  '18820424': ('isolation_source', 'stool'),
#  '18824495': ('isolation_source', 'agricultural soil'),
#  '18825684': ('isolation_source', 'wheat'),
#  '18825736': ('isolation_source', 'caecum_chymus'),
#  '18854710': ('tissue', 'Leaf'),
#  '18854763': ('tissue', 'Leaf'),
#  '18869034': ('tissue', 'Rectum'),
#  '18877129': ('tissue', 'Hematopoietic'),
#  '18883604': ('tissue', 'intestine'),
#  '18887055': ('tissue', 'whole fly'),
#  '18893612': ('tissue', 'whole fly'),
#  '18895217': ('tissue', 'Blood'),
#  '18928553': ('tissue', 'brain'),
#  '18938157': ('tissue', 'Multiple entire females'),
#  '18943119': ('isolation_source', 'nasal'),
#  '18945360': ('isolation_source', 'cropland'),
#  '18956925': ('isolation_source', 'nasal'),
#  '18958146': ('isolation_source', 'nasal'),
#  '18968431': ('isolation_source', 'nasal'),
#  '18968940': ('isolation_source', 'nasal'),
#  '18972740': ('isolation_source', 'nasal'),
#  '18977683': ('isolation_source', 'nasal'),
#  '18979591': ('isolation_source', 'nasal'),
#  '18985197': ('isolation_source', 'nasal'),
#  '18985512': ('isolation_source', 'nasal'),
#  '18991966': ('isolation_source', 'nasal'),
#  '18993223': ('isolation_source', 'nasal'),
#  '18993922': ('isolation_source', 'nasal'),
#  '19012134': ('isolation_source', 'clinical'),
#  '19018543': ('tissue', 'retroperitoneal adipose'),
#  '19021999': ('tissue', 'whole organism'),
#  '19023430': ('sample_type', 'pure culture'),
#  '19029529': ('isolation_source', 'nasal'),
#  '19033090': ('isolation_source', 'feces'),
#  '19037683': ('isolation_source', 'clinical'),
#  '19037816': ('isolation_source', 'clinical'),
#  '19066792': ('tissue', 'cryopreserved ejaculate'),
#  '19070493': ('tissue', 'CRH-expressing neuron'),
#  '19076790': ('isolation_source', 'clinical'),
#  '19076933': ('isolation_source', 'clinical'),
#  '19092134': ('tissue', 'Leaf'),
#  '19113424': ('isolation_source', 'missing'),
#  '19115587': ('tissue', 'fin'),
#  '19121156': ('tissue', 'liver'),
#  '19126083': ('tissue', 'liver'),
#  '19131400': ('sample_type', 'bacterial isolate'),
#  '19157558': ('isolation_source', 'clinical'),
#  '19188283': ('tissue', 'whole body'),
#  '19220394': ('isolation_source', 'clinical'),
#  '19222629': ('tissue', 'Gizzard'),
#  '19223871': ('tissue', 'Colorectal cancer'),
#  '19273802': ('tissue', 'embryo'),
#  '19274871': ('tissue', 'embryo'),
#  '19276466': ('tissue', 'muscle'),
#  '19279946': ('tissue', 'whole berries'),
#  '19298620': ('isolation_source', 'Aspo HRL'),
#  '19301138': ('tissue', 'needle/buds'),
#  '19302520': ('sample_type', 'missing'),
#  '19303025': ('tissue', 'not collected'),
#  '19308360': ('tissue', 'needle/buds'),
#  '19312523': ('tissue', 'gill'),
#  '19332219': ('tissue', 'cerebrospinal fluid'),
#  '19332469': ('tissue', 'cerebrospinal fluid'),
#  '19348607': ('sample_type', 'metagenomic assembly'),
#  '19352194': ('isolation_source', 'patient isolate'),
#  '19353683': ('isolation_source', 'ice cream sherbet'),
#  '19366931': ('isolation_source', 'clinical'),
#  '19373960': ('isolation_source', 'nostil'),
#  '19411866': ('isolation_source', 'patient isolate'),
#  '19413865': ('sample_type', 'bacterial isolate'),
#  '19413931': ('sample_type',
#               'Human primary astrocytes (Lonza, #CC-2565) and 2-week '
#               'differentiated human neural progenitors'),
# ...
#  '6652790': ('tissue', 'frontal cortex'),
#  '6659742': ('strain', 'missing'),
#  '6669487': ('sample_type', 'Mixed population from laboratory evolution'),
#  '6679207': ('tissue', 'Leaf'),
#  '6700180': ('isolation_source', 'CSF'),
#  '6822081': ('tissue', 'embryonic kidney'),
#  '6824782': ('tissue', 'embryonic kidney'),
#  '6827577': ('tissue', 'whole bone marrow'),
#  '6828778': ('tissue', 'whole seedling'),
#  '6834045': ('tissue', 'blood'),
#  '6837293': ('tissue', 'Blood'),
#  '6854581': ('tissue', 'whole insect body'),
#  '6890227': ('isolation_source', 'case'),
#  '6890331': ('isolation_source', 'case'),
#  '6894100': ('isolation_source', 'missing'),
#  '6897400': ('isolation_source', 'blood'),
#  '6906118': ('isolation_source', 'Throat'),
#  '6919932': ('isolation_source', 'biofilm on Plastic carrier'),
#  '6921584': ('sample_type', 'cell culture'),
#  '6925497': ('sample_type', 'saliva'),
#  '6946632': ('sample_type', '33'),
#  '6947168': ('sample_type', 'whole organism'),
#  '7037939': ('sample_type', 'fresh_sample'),
#  '7163909': ('isolation_source', 'Product-Swab-Non meat'),
#  '7178512': ('sample_type', 'Pure culture'),
#  '7223240': ('tissue', 'harderian'),
#  '7231280': ('tissue', 'peripheral blood plasma'),
#  '7234278': ('tissue', 'peripheral blood'),
#  '7238825': ('tissue', 'saliva'),
#  '7241881': ('tissue', 'blood'),
#  '7260283': ('tissue', 'right_retina'),
#  '7261121': ('tissue', 'whole organism'),
#  '7292100': ('tissue', 'Leaf'),
#  '7292253': ('tissue', 'Leaf'),
#  '7292286': ('tissue', 'Leaf'),
#  '7298248': ('tissue', 'Liver'),
#  '7313064': ('tissue', 'leaf'),
#  '7323021': ('tissue', 'Blood'),
#  '7323061': ('tissue', 'Blood'),
#  '7327185': ('tissue', 'Leaf sheath'),
#  '7337952': ('isolation_source', 'fish'),
#  '7344744': ('isolation_source',
#              'Fermentation day 1, Gena variety, erosa 4, replication 2'),
#  '7376141': ('isolation_source', 'mangrove sediment'),
#  '7416038': ('tissue', 'Liver'),
#  '7416310': ('tissue', 'Ear'),
#  '7417329': ('tissue', 'fore-limb'),
#  '7430067': ('isolation_source', 'urine'),
#  '7444391': ('sample_type', 'whole organism'),
#  '7449420': ('tissue', 'pCRC'),
#  '7455099': ('tissue', 'Lung'),
#  '7457235': ('tissue', 'Nucleus of the solitary tract'),
#  '7458198': ('tissue', 'whole blood'),
#  '7463944': ('tissue', 'Peripheral Blood'),
#  '7464220': ('tissue', 'Peripheral Blood'),
#  '7469409': ('tissue', 'Peripheral Blood'),
#  '7471647': ('tissue', 'BUCCAL'),
#  '7475831': ('tissue', 'BUCCAL'),
#  '7481434': ('tissue', 'BUCCAL'),
#  '7491685': ('tissue', 'Brain'),
#  '7497554': ('tissue', 'UBERON:feces'),
#  '7512257': ('tissue', 'blood'),
#  '7512904': ('tissue', 'new born cordblood'),
#  '7517229': ('tissue', 'Haemolymphatic fluid'),
#  '7521361': ('tissue', 'leaf'),
#  '7536898': ('tissue', 'whole-animal'),
#  '7552458': ('tissue', 'tumor'),
#  '7559929': ('tissue', 'young leaves'),
#  '7563737': ('tissue', 'Middle part of third leaf'),
#  '7603447': ('tissue', 'blood'),
#  '7605197': ('tissue', 'Fin Clip'),
#  '7619540': ('sample_type', 'metagenomic assembly'),
#  '7644150': ('tissue', 'blood'),
#  '7658857': ('isolation_source', 'clinical sample'),
#  '7659636': ('isolation_source', 'clinical sample'),
#  '7666441': ('isolation_source', 'blood'),
#  '7676677': ('sample_type', 'whole organism'),
#  '7761298': ('sample_type', 'cDNA'),
#  '7762901': ('sample_type', 'mixed culture'),
#  '7771402': ('sample_type', 'skin'),
#  '7772068': ('sample_type', 'skin'),
#  '7774790': ('tissue', 'not applicable'),
#  '7776359': ('tissue', 'Liver'),
#  '7786527': ('tissue', 'whole maggot'),
#  '7795052': ('tissue', 'digestive plus excretory system'),
#  '7795243': ('tissue', 'gonad'),
#  '7796846': ('tissue', 'Knee'),
#  '7798828': ('tissue', 'Hip'),
#  '7799358': ('tissue', 'Wrist'),
#  '7800188': ('tissue', 'Knee'),
#  '7801921': ('tissue', 'Knee'),
#  '7802120': ('tissue', 'Knee'),
#  '7821204': ('strain', 'CEC03095'),
#  '7836351': ('tissue', 'leaf'),
#  '7850672': ('tissue', 'Blood'),
#  '7852246': ('tissue', 'Unknown'),
#  '7852628': ('tissue', 'Blood'),
#  '7852742': ('tissue', 'Unknown'),
#  '7855560': ('tissue', 'Buffy Coat'),
#  '7857493': ('tissue', 'Mouthwash/Saliva'),
#  '7860247': ('tissue', 'Unknown'),
#  '7863704': ('tissue', 'Buffy Coat'),
#  '7865166': ('tissue', 'Blood'),
#  '7867198': ('tissue', 'Unknown'),
#  '7884816': ('tissue', 'Unknown'),
#  '7892467': ('tissue', 'Unknown'),
#  '7894217': ('tissue', 'Unknown'),
#  '7894269': ('tissue', 'Unknown'),
#  '7899609': ('tissue', 'Buffy Coat'),
#  '7900060': ('tissue', 'Buffy Coat'),
#  '7905608': ('tissue', 'Unknown'),
#  '7906440': ('tissue', 'Mouthwash/Saliva'),
#  '7907502': ('tissue', 'Mouthwash/Saliva'),
#  '7908524': ('tissue', 'Unknown'),
#  '7909406': ('tissue', 'Blood'),
#  '7915223': ('tissue', 'Blood'),
#  '7924098': ('tissue', 'Unknown'),
#  '7925463': ('tissue', 'Unknown'),
#  '7928990': ('tissue', 'Mouthwash/Saliva'),
#  '7933881': ('tissue', 'Unknown'),
#  '7941637': ('tissue', 'Unknown'),
#  '7942510': ('tissue', 'Blood'),
#  '7943995': ('tissue', 'tail tip'),
#  '7950407': ('tissue', 'Blood'),
#  '7951984': ('tissue', 'Blood'),
#  '7953322': ('tissue', 'Blood'),
#  '7953613': ('tissue', 'Blood'),
#  '7959639': ('tissue', 'Primary Blood Derived Cancer - Peripheral Blood'),
#  '7969867': ('tissue', 'fin clip'),
#  '7982403': ('tissue', 'Vehicle treated frontal cortex'),
#  '7990427': ('tissue', 'Blood'),
#  '7994944': ('tissue', 'Blood'),
#  '7999960': ('tissue', 'Gastrointestinal tract'),
#  '8009027': ('tissue', 'Blood'),
#  '8026101': ('tissue', 'Heart'),
#  '8045391': ('tissue', 'MEPs'),
#  '8061188': ('tissue', 'Saliva'),
#  '8061846': ('tissue', 'Saliva'),
#  '8064067': ('tissue', 'Saliva'),
#  '8070147': ('tissue', 'Saliva'),
#  '8078060': ('tissue', 'Saliva'),
#  '8083553': ('tissue', 'Saliva'),
#  '8084981': ('tissue', 'Saliva'),
#  '8092534': ('tissue', 'Saliva'),
#  '8116103': ('isolation_source', 'blood'),
#  '8130445': ('tissue', 'muscle'),
#  '8136427': ('tissue', 'benign nodule'),
#  '8139222': ('sample_type', 'Skin Swab'),
#  '8161771': ('isolation_source', 'NA'),
#  '8162863': ('tissue', 'appendix'),
#  '8173949': ('tissue', 'fruit'),
#  '8178051': ('strain', 'USDA-ARS-USMARC-76337'),
#  '8193367': ('strain', 'RUC.THI1'),
#  '8213167': ('tissue', 'albumen gland'),
#  '8214634': ('isolation_source', 'Missing'),
#  '8217169': ('isolation_source', 'soil'),
#  '8220029': ('isolation_source', 'missing'),
#  '8222782': ('isolation_source', 'gut digesta'),
#  '8224923': ('isolation_source', 'nasopharynx'),
#  '8225489': ('isolation_source', 'plastic waste recycling plant'),
#  '8234626': ('isolation_source', 'sputum'),
#  '8241793': ('tissue', 'blood'),
#  '8253813': ('tissue', 'Skin'),
#  '8254674': ('tissue', 'Skin'),
#  '8258957': ('tissue', 'Skin'),
#  '8261030': ('tissue', 'Kidney'),
#  '8261093': ('tissue', 'Kidney'),
#  '8262626': ('tissue', 'Kidney'),
#  '8263338': ('tissue', 'Skin'),
#  '8263971': ('tissue', 'Urine'),
#  '8264337': ('tissue', 'Kidney'),
#  '8264912': ('tissue', 'Kidney'),
#  '8267505': ('tissue', 'Skin'),
#  '8268097': ('tissue', 'Kidney'),
#  '8270948': ('tissue', 'Skin'),
#  '8279777': ('tissue', 'liver'),
#  '8289337': ('isolation_source', 'animal-swine-market swine'),
#  '8298857': ('isolation_source', 'wild boar sausage'),
#  '8331617': ('isolation_source', 'insect body'),
#  '8335178': ('isolation_source', 'intestines'),
#  '8346884': ('isolation_source',
#              'WT mouse chow diet before antibiotic treatment - cage 1 sample '
#              '3'),
#  '8361555': ('tissue', 'Leaves'),
#  '8382095': ('tissue', 'not applicable'),
#  '8388446': ('tissue', 'leaf'),
#  '8390660': ('tissue', 'Brain'),
#  '8390785': ('isolation_source', 'urine'),
#  '8391395': ('tissue', 'fin'),
#  '8397302': ('tissue', 'leaf'),
#  '8398983': ('tissue', 'ovary'),
#  '8433810': ('tissue', 'blood'),
#  '8436863': ('tissue', 'whole blood'),
#  '8444723': ('tissue', 'UBERON:feces'),
#  '8450143': ('tissue', 'leaf'),
#  '8459109': ('tissue', 'blood'),
#  '8459327': ('tissue', 'blood'),
#  '8461404': ('tissue', 'head/thorax'),
#  '8469228': ('tissue', 'Fetal pancreas'),
#  '8472236': ('tissue', 'Pancreas'),
#  '8482209': ('tissue', 'Leg'),
#  '8483264': ('tissue', 'Rectum'),
#  '8484435': ('tissue', 'Rectum'),
#  '8486225': ('tissue', 'Buccal mucosa'),
#  '8486726': ('tissue', 'Buccal mucosa'),
#  '8491951': ('tissue', 'Rectum'),
#  '8498986': ('tissue', 'leg'),
#  '8517352': ('sample_type', 'single cell'),
#  '8517446': ('isolation_source', 'blood'),
#  '8535115': ('tissue', 'Cortex'),
#  '8538369': ('tissue', 'Blood'),
#  '8538521': ('tissue', 'Blood'),
#  '8538582': ('tissue', 'Blood'),
#  '8543678': ('tissue', 'spleen'),
#  '8548835': ('tissue', 'spleen'),
#  '8556750': ('tissue', 'feces'),
#  '8557409': ('tissue', 'feces'),
#  '8562459': ('isolation_source', 'normally sterile site'),
#  '8563959': ('isolation_source', 'milk'),
#  '8575644': ('sample_type', 'bacterial culture'),
#  '8583560': ('isolation_source', 'urethra'),
#  '8583562': ('isolation_source', 'urethra'),
#  '8619395': ('sample_type', 'Montipora digitata1'),
#  '8629154': ('isolation_source', 'Not applicable'),
#  '8635886': ('tissue', 'Liver'),
#  '8638554': ('isolation_source', 'cattle fecal samples'),
#  '8647683': ('isolation_source', 'nasopharyngeal'),
#  '8648282': ('isolation_source', 'bulk soil'),
#  '8660769': ('isolation_source', 'missing'),
#  '8662582': ('isolation_source', 'milk'),
#  '8715335': ('tissue', 'Leaf'),
#  '8717009': ('tissue', 'liver tissue'),
#  '8726462': ('tissue', 'endometrium biopsy'),
#  '8732148': ('isolation_source', 'Not applicable'),
#  '8768147': ('tissue', 'blood'),
#  '8769618': ('strain', 'Q2-87'),
#  '8770341': ('tissue', 'leaves'),
#  '8770961': ('tissue', 'leaves'),
#  '8776722': ('strain', 'PP-F2F-G38'),
#  '8796728': ('strain', 'C57BL/6N'),
#  '8796862': ('isolation_source', 'human'),
#  '8803616': ('tissue', 'pool of 300 leafs from individual plants'),
#  '8803755': ('tissue', 'pool of 300 leafs from individual plants'),
#  '8806492': ('tissue', 'leaf'),
#  '8808083': ('tissue', 'Blood'),
#  '8812064': ('tissue', 'leaf'),
#  '8819511': ('isolation_source', 'plasma'),
#  '8819761': ('tissue', 'leaf'),
#  '8822160': ('isolation_source', 'human'),
#  '8822496': ('isolation_source', 'human'),
#  '8862895': ('isolation_source', 'Not applicable'),
#  '8892479': ('isolation_source', 'Not applicable'),
#  '8904521': ('tissue', 'young leaves'),
#  '8909279': ('tissue', 'Blood'),
#  '8911082': ('isolation_source', 'blood'),
#  '8919160': ('tissue', 'leaf'),
#  '8932936': ('tissue', 'Planulae'),
#  '8936564': ('isolation_source', 'feces blood'),
#  '8940535': ('tissue', 'rectum'),
#  '8951290': ('tissue', 'coral (host + endosymbionts)'),
#  '8988253': ('tissue', 'tree phloem'),
#  '9006701': ('tissue', 'Whole blood'),
#  '9017479': ('tissue', 'embryonic kidney'),
#  '9019784': ('tissue', 'Saliva'),
#  '9021426': ('tissue', 'Saliva'),
#  '9021770': ('tissue', 'Saliva'),
#  '9022277': ('tissue', 'Saliva'),
#  '9025718': ('tissue', 'Saliva'),
#  '9026280': ('tissue', 'Saliva'),
#  '9026982': ('tissue', 'Saliva'),
#  '9027146': ('tissue', 'Saliva'),
#  '9031246': ('tissue', 'Saliva'),
#  '9033950': ('tissue', 'Saliva'),
#  '9038390': ('tissue', 'Saliva'),
#  '9038526': ('tissue', 'Saliva'),
#  '9039582': ('tissue', 'Leaf'),
#  '9042258': ('tissue', 'not applicable'),
#  '9047506': ('tissue', 'Inner Oral Cavity'),
#  '9056003': ('tissue', 'Peripheral Blood'),
#  '9056942': ('tissue', 'Inner Oral Cavity'),
#  '9081307': ('strain', '1766'),
#  '9081877': ('sample_type', 'environment'),
#  '9090470': ('isolation_source', 'Not applicable'),
#  '9094002': ('isolation_source', 'Decomposing leaf litter'),
#  '9199099': ('isolation_source', 'paddy soil'),
#  '9201503': ('isolation_source', 'saline lake water'),
#  '9203647': ('isolation_source', 'human'),
#  '9217426': ('tissue', 'cells'),
#  '9233209': ('sample_type', 'bacterial culture'),
#  '9245058': ('tissue', 'stem'),
#  '9247051': ('tissue', 'Blood'),
#  '9248850': ('tissue', 'Blood'),
#  '9250591': ('tissue', 'Blood'),
#  '9251472': ('tissue', 'Lymphoblastoid Cell Line'),
#  '9268629': ('tissue', 'Thorax muscle'),
#  '9271758': ('tissue', 'bone marrow'),
#  '9283062': ('isolation_source', 'Cattle faeces'),
#  '9290616': ('tissue', 'Leaf'),
#  '9299461': ('tissue', 'renal cortex'),
#  '9317452': ('tissue', 'kidney'),
#  '9322629': ('tissue', 'liver'),
#  '9322859': ('tissue', 'blood'),
#  '9332032': ('tissue', 'leaf'),
#  '9333407': ('tissue', 'leaf'),
#  '9336073': ('tissue', 'leaf'),
#  '9356314': ('tissue', 'Blood'),
#  '9356613': ('tissue', 'Pancreas'),
#  '9370895': ('tissue', 'Leaf'),
#  '9372520': ('isolation_source', 'Comminuted Turkey'),
#  '9372596': ('isolation_source', 'raw intact chicken'),
#  '9375494': ('tissue', 'Tail'),
#  '9376060': ('tissue', 'Liver'),
#  '9380095': ('tissue', 'Bladder urothelium'),
#  '9380554': ('isolation_source', 'human'),
#  '9387072': ('tissue', 'Leaf'),
#  '9387370': ('isolation_source', 'human'),
#  '9396722': ('isolation_source', 'Dust'),
#  '9403907': ('isolation_source', 'human'),
#  '9425122': ('tissue', 'stem'),
#  '9429020': ('tissue', 'aerial part'),
#  '9435089': ('isolation_source', 'human'),
#  '9437361': ('isolation_source', 'arable land soil'),
#  '9440204': ('tissue', 'liver'),
#  '9440293': ('tissue', 'liver'),
#  '9442529': ('tissue', 'Arm/Hand Venipuncture'),
#  '9453437': ('tissue', 'seedling'),
#  '9453713': ('tissue', 'pancreatic cyst fluid'),
#  '9455903': ('tissue', 'primary Th17 lymphocytes'),
#  '9462858': ('isolation_source', 'human'),
#  '9469089': ('isolation_source', 'human'),
#  '9476385': ('isolation_source', 'human'),
#  '9484431': ('isolation_source', 'human'),
#  '9487403': ('tissue', 'midgut'),
#  '9489678': ('isolation_source', 'water'),
#  '9501973': ('tissue', 'blood'),
#  '9503550': ('isolation_source', 'human'),
#  '9508652': ('isolation_source', 'Auckland Westhaven Marine, NZ'),
#  '9517886': ('isolation_source', 'not applicable'),
#  '9520498': ('isolation_source', 'microcosm soil'),
#  '9565597': ('isolation_source', 'host'),
#  '9568786': ('isolation_source', 'feces'),
#  '9602333': ('isolation_source', 'fecal sample'),
#  '9605376': ('isolation_source', 'coral reef'),
#  '9621776': ('tissue', 'leaf'),
#  '9664860': ('tissue', 'ES-derived progenitors'),
#  '9664995': ('isolation_source', 'pathogen.cl'),
#  '9696158': ('isolation_source', 'feces'),
#  '9722743': ('tissue', 'feces'),
#  '9735075': ('tissue', 'liver'),
#  '9738666': ('tissue', 'Whole flies'),
#  '9738760': ('tissue', 'Whole flies'),
#  '9743687': ('tissue', 'adipose fin'),
#  '9746675': ('tissue', 'bone marrow'),
#  '9748158': ('tissue', 'fruit peel'),
#  '9756065': ('isolation_source', 'Mycobacterial Culture'),
#  '9760175': ('tissue', 'FRUIT12'),
#  '9760206': ('isolation_source', 'stool'),
#  '9762615': ('tissue', 'muscle'),
#  '9763015': ('tissue', 'UBERON:mouth'),
#  '9767135': ('sample_type', 'cell culture'),
#  '9770347': ('tissue', 'Liver'),
#  '9787662': ('isolation_source', 'missing'),
#  '9788843': ('isolation_source', 'cecum'),
#  '9793954': ('tissue', 'embryonic kidney'),
#  '9794988': ('tissue', 'embryonic kidney'),
#  '9795936': ('tissue', 'embryonic kidney'),
#  '9796185': ('tissue', 'embryonic kidney'),
#  '9796886': ('tissue', 'embryonic kidney'),
#  '9806717': ('tissue', 'embryonic kidney'),
#  '9816013': ('tissue', 'Blood'),
#  '9826181': ('tissue', 'Blood'),
#  '9827805': ('tissue', 'Blood'),
#  '9828157': ('tissue', 'Blood'),
#  '9838056': ('tissue', 'Primary breast tumor tissue'),
#  '9843408': ('tissue', 'cortical brain tissue'),
#  '9848206': ('isolation_source', 'missing'),
#  '9849647': ('isolation_source', 'sterile site'),
#  '9866405': ('isolation_source', 'comminuted beef'),
#  '9905518': ('isolation_source', 'Total RNA isolated from mouse carcasses'),
#  '9907152': ('isolation_source', 'stool'),
#  '9908163': ('tissue', 'connective tissue'),
#  '9911763': ('tissue', 'not applicable'),
#  '9912693': ('tissue', 'UBERON:lung'),
#  '9915174': ('tissue', 'blood'),
#  '9915398': ('tissue', 'ear tissue'),
#  '9920608': ('tissue', 'Leaf'),
#  '9923493': ('tissue', 'Leaf'),
#  '9928369': ('tissue', 'full body'),
#  '9936823': ('isolation_source', 'raw intact chicken'),
#  '9939344': ('isolation_source', 'not collected'),
#  '9947185': ('tissue', 'Semen'),
#  '9949659': ('tissue', 'tumor'),
#  '9953324': ('tissue', 'blood'),
#  '9983854': ('tissue', 'Normal stomach muscle'),
#  '9989470': ('strain', 'LPA8'),
#  '9994973': ('tissue', 'leaf')}
# Number of possible tissue locations found:  3777
# Time taken:  1.0051853656768799

# %% [markdown]
# ---

# %%
class BioSamplesAttributeHandler(xml.sax.ContentHandler):
    def __init__(self, attributes_set, sample_dict) -> None:
        super().__init__()
        sample_dict = sample_dict
        self.attributes_set = attributes_set
        self.biosample_id = ""
        self.attribute_name = ""

    def startElement(self, name, attrs):
        if name == "BioSample":
            self.biosample_id = attrs["accession"]
        elif name == "Attribute" and "harmonized_name" in attrs:
            attribute_name = attrs["harmonized_name"]
            if attribute_name in self.attributes_set:
                self.attribute_name = attribute_name

    def characters(self, content):
        if self.attribute_name != "":
            sample_dict[self.biosample_id] = (self.attribute_name, content)
            self.attribute_name = ""

    def endDocument(self):
        print("Number of possible tissue locations found: ", len(sample_dict))

# %%
biosamples_path = "data/biosamples/biosample_random_samples.xml"
possible_tissue = {"cell_line", "cell_subtype", "cell_type", "host_tissue_sampled", "sample_type", "tissue", "host_anatomical_part", "isolation_source", "source_name", "source_type", "strain", "subclone", "subgroup"}
sample_dict = {}

t1 = time.time()
parser = xml.sax.make_parser()
handler = BioSamplesAttributeHandler(possible_tissue, sample_dict)
parser.setContentHandler(handler)
parser.parse(biosamples_path)
t2 = time.time()
print("Time taken: ", t2 - t1)

pprint.pprint(sample_dict)

sample_dict_small = sample_dict
# Out:
# Number of possible tissue locations found:  6603
# Time taken:  0.8822062015533447
# {'SAMD00000683': ('strain', 'T000240'),
#  'SAMD00021033': ('strain', 'WK12'),
#  'SAMD00036614': ('strain', 'T-34'),
#  'SAMD00049287': ('strain', 'CEC11100'),
#  'SAMD00060847': ('strain', 'missing'),
#  'SAMD00061605': ('strain', 'missing'),
#  'SAMD00078983': ('cell_line', 'N2A'),
#  'SAMD00091260': ('cell_line', 'cellline.ZNF646.1'),
#  'SAMD00107974': ('isolation_source', 'freshwater'),
#  'SAMD00118585': ('tissue', 'mature leaves'),
#  'SAMD00119977': ('cell_line', 'H1299'),
#  'SAMD00121723': ('cell_line', 'H1975'),
#  'SAMD00122745': ('cell_line', 'RERF-LC-MS'),
#  'SAMD00133768': ('tissue', 'pancreatic islet'),
#  'SAMD00142065': ('cell_type', 'B cell'),
#  'SAMD00154869': ('tissue', 'blastocyst'),
#  'SAMD00195195': ('tissue', 'gut'),
#  'SAMD00199674': ('sample_type', 'single amplified genome'),
#  'SAMD00219821': ('tissue', 'LN'),
#  'SAMD00235438': ('strain', '08-054'),
#  'SAMD00239440': ('cell_type', 'control'),
#  'SAMD00243312': ('strain', 'missing'),
#  'SAMD00247029': ('strain', 'JPN_161'),
#  'SAMD00268369': ('strain', 'missing'),
#  'SAMD00269220': ('strain', 'missing'),
#  'SAMD00275592': ('strain', 'missing'),
#  'SAMD00290206': ('strain', 'missing'),
#  'SAMD00290484': ('strain', 'missing'),
#  'SAMD00321647': ('strain', 'B6D2F1 (C57BL/6N-DBA/2)'),
#  'SAMD00326789': ('strain', 'missing'),
#  'SAMD00333936': ('strain', '155_60092_Kp'),
#  'SAMD00335229': ('sample_type', 'metagenomic assembly'),
#  'SAMD00347441': ('sample_type', 'metagenomic assembly'),
#  'SAMD00348350': ('sample_type', 'metagenomic assembly'),
#  'SAMD00349721': ('sample_type', 'metagenomic assembly'),
#  'SAMD00353948': ('sample_type', 'metagenomic assembly'),
#  'SAMD00355846': ('sample_type', 'metagenomic assembly'),
#  'SAMD00358349': ('sample_type', 'metagenomic assembly'),
#  'SAMD00358973': ('sample_type', 'metagenomic assembly'),
#  'SAMD00361343': ('sample_type', 'metagenomic assembly'),
#  'SAMD00361752': ('sample_type', 'metagenomic assembly'),
#  'SAMD00362489': ('sample_type', 'metagenomic assembly'),
#  'SAMD00363370': ('sample_type', 'metagenomic assembly'),
#  'SAMD00379836': ('sample_type', 'metagenomic assembly'),
#  'SAMD00386246': ('sample_type', 'metagenomic assembly'),
#  'SAMD00392533': ('tissue', 'whole body'),
#  'SAMD00439565': ('tissue', 'Root'),
#  'SAMD00449314': ('strain', 'not applicable'),
#  'SAMD00470677': ('isolation_source', 'fecal samples'),
#  'SAMD00474532': ('isolation_source', 'fecal samples'),
#  'SAMD00480906': ('isolation_source', 'fecal samples'),
#  'SAMD00481281': ('isolation_source', 'fecal samples'),
#  'SAMD00482197': ('isolation_source', 'fecal samples'),
#  'SAMD00485407': ('isolation_source', 'fecal samples'),
#  'SAMD00487933': ('isolation_source', 'fecal samples'),
#  'SAMD00491831': ('isolation_source', 'water-12'),
#  'SAMD00495969': ('strain', '97_161789'),
#  'SAMD00498219': ('strain', 'JBBBACD-19-0148'),
#  'SAMD00500253': ('strain', 'JBCGACB-19-0205'),
#  'SAMD00505775': ('tissue', 'Leaf'),
#  'SAMD00506627': ('tissue', 'Adducter muscle'),
#  'SAMD00520696': ('tissue', 'muscle'),
#  'SAMD00529505': ('tissue', 'Kidney'),
#  'SAMD00536809': ('strain', 'NBRC 3782'),
#  'SAMD00537191': ('strain', 'NBRC 12763'),
#  'SAMD00537705': ('strain', 'NBRC 13545'),
#  'SAMD00537819': ('strain', 'NBRC 13767'),
#  'SAMD00539715': ('strain', 'NBRC 101046'),
#  'SAMD00540977': ('strain', 'NBRC 104807'),
#  'SAMD00542553': ('strain', 'NBRC 109954'),
#  'SAMD00549931': ('tissue', 'calli'),
#  'SAMD00563702': ('isolation_source', 'bioreactor'),
#  'SAMD00564173': ('isolation_source', 'bioreactor'),
#  'SAMD00593873': ('isolation_source', 'bioreactor'),
#  'SAMEA10201648': ('tissue', '**OTHER SOMATIC ANIMAL TISSUE**'),
#  'SAMEA10313618': ('sample_type', 'stool'),
#  'SAMEA1032131': ('strain', 'TW20'),
#  'SAMEA103886841': ('tissue', 'pons'),
#  'SAMEA103921040': ('sample_type', 'skin'),
#  'SAMEA103923374': ('strain', 'Tubingen Long Fin'),
#  'SAMEA103927633': ('cell_type', 'CD4+ T cell'),
#  'SAMEA103988719': ('tissue', 'tracheal epithelium'),
#  'SAMEA103989404': ('tissue', 'adrenal cortex'),
#  'SAMEA103989850': ('tissue', 'thymus'),
#  'SAMEA103991365': ('tissue', 'jejunum'),
#  'SAMEA103993929': ('strain', 'BY4742'),
#  'SAMEA103995837': ('strain', 's288c'),
#  'SAMEA103997583': ('tissue', 'blood'),
#  'SAMEA104009137': ('tissue', 'blood'),
#  'SAMEA104010179': ('tissue', 'Bronchial Epithelium'),
#  'SAMEA104026421': ('strain', 'Nadia (NA)'),
#  'SAMEA104027358': ('isolation_source', 'Gastric lavage'),
#  'SAMEA104035637': ('strain', 'GPSC8'),
#  'SAMEA104092061': ('strain', 'mixed'),
#  'SAMEA104124504': ('tissue', 'shoot phloem companion cells'),
#  'SAMEA104140940': ('isolation_source', 'fecal material'),
#  'SAMEA104181591': ('sample_type', 'soil'),
#  'SAMEA104189786': ('tissue', 'dermis'),
#  'SAMEA104203658': ('tissue', 'dermis'),
#  'SAMEA104204959': ('tissue', 'dermis'),
#  'SAMEA104205968': ('strain', '16009361_S19_L001_R1_001'),
#  'SAMEA104206525': ('sample_type', 'Stool'),
#  'SAMEA104225526': ('strain', 'Nichols'),
#  'SAMEA104244444': ('strain', 'R6'),
#  'SAMEA104245643': ('tissue', 'whole seedling'),
#  'SAMEA104246459': ('strain', 'BY4742'),
#  'SAMEA104252190': ('strain', '61010701'),
#  'SAMEA104255718': ('tissue', 'whole blood'),
#  'SAMEA104257705': ('tissue', 'animal ovary'),
#  'SAMEA104263357': ('tissue', 'mammary gland'),
#  'SAMEA104264163': ('strain', 'BY4742'),
#  'SAMEA104266464': ('cell_type', 'peripheral blood mononuclear cell'),
#  'SAMEA104270077': ('tissue', 'lung'),
#  'SAMEA104270468': ('tissue', 'bronchus'),
#  'SAMEA104270499': ('tissue', 'bronchus'),
#  'SAMEA104270891': ('tissue', 'muscle'),
#  'SAMEA104306271': ('sample_type', 'stool'),
#  'SAMEA104322278': ('strain', 'C57BL/6'),
#  'SAMEA104323318': ('tissue', 'skin'),
#  'SAMEA104382892': ('strain', 'C57BLKS/J'),
#  'SAMEA104385104': ('cell_line', '293T'),
#  'SAMEA104459099': ('strain', 'NIES-3945'),
#  'SAMEA104493871': ('cell_type', 'induced pluripotent stem cell'),
#  'SAMEA104495988': ('cell_type', 'embryonic stem cell'),
#  'SAMEA104618068': ('tissue', 'human small airway epithelial cells'),
#  'SAMEA104626313': ('tissue', 'epidermis'),
#  'SAMEA104726821': ('tissue', 'decidua'),
#  'SAMEA10792403': ('tissue', 'vasculature of brain'),
#  'SAMEA10793065': ('sample_type', 'saliva'),
#  'SAMEA10801058': ('tissue', 'kidney'),
#  'SAMEA10983206': ('tissue', 'SHOOT'),
#  'SAMEA110013350': ('tissue', 'WHOLE ORGANISM'),
#  'SAMEA110043299': ('sample_type', 'surface'),
#  'SAMEA110052605': ('isolation_source', 'Freshwater lake'),
#  'SAMEA110133226': ('sample_type', 'cecum content'),
#  'SAMEA110178717': ('strain', 'C57BL/6J'),
#  'SAMEA110353658': ('isolation_source', 'coastal sediment'),
#  'SAMEA110371077': ('strain', 'C57BL/6'),
#  'SAMEA110378502': ('isolation_source', 'salmon'),
#  'SAMEA110378793': ('isolation_source', 'salmon'),
#  'SAMEA110380232': ('isolation_source', 'Freshwater lake'),
#  'SAMEA110402955': ('isolation_source', 'pig gut metagenome'),
#  'SAMEA110411416': ('isolation_source', 'pond'),
#  'SAMEA110424602': ('isolation_source', 'human'),
#  'SAMEA110448411': ('isolation_source', 'Guyana'),
#  'SAMEA110451741': ('tissue', 'WHOLE ORGANISM'),
#  'SAMEA11052209': ('isolation_source', 'K:DNA_bank'),
#  'SAMEA110640646': ('tissue', 'Whole body'),
#  'SAMEA110643290': ('isolation_source', 'sheep gut metagenome'),
#  'SAMEA110643585': ('isolation_source', 'sheep gut metagenome'),
#  'SAMEA110670416': ('tissue', 'epiblast'),
#  'SAMEA110759883': ('tissue', 'Feces'),
#  'SAMEA111331855': ('isolation_source', 'urine sample'),
#  'SAMEA111342851': ('isolation_source', 'rhizosphere metagenome'),
#  'SAMEA111350717': ('strain', 'SC5314'),
#  'SAMEA111465104': ('isolation_source', 'beef/minced meat'),
#  'SAMEA111500879': ('isolation_source', 'mouse gut metagenome'),
#  'SAMEA111507863': ('tissue', 'Duodenum'),
#  'SAMEA111532951': ('tissue', 'WHOLE ORGANISM'),
#  'SAMEA111537330': ('sample_type', 'BM1'),
#  'SAMEA112139643': ('tissue', 'WHOLE ORGANISM'),
#  'SAMEA112147328': ('isolation_source', 'lake water'),
#  'SAMEA112153044': ('isolation_source', 'mouse gut metagenome'),
#  'SAMEA112168728': ('tissue', 'UNICELLULAR ORGANISMS IN CULTURE'),
#  'SAMEA112174666': ('isolation_source', 'lake water'),
#  'SAMEA112185436': ('tissue', 'Plant shoot tissue'),
#  'SAMEA112206125': ('host_tissue_sampled', 'human-gut'),
#  'SAMEA112222039': ('tissue', 'WHOLE ORGANISM'),
#  'SAMEA112223153': ('isolation_source', 'mouse gut metagenome'),
#  'SAMEA112230730': ('isolation_source', 'rabbit gut'),
#  'SAMEA112280108': ('tissue', 'microbiome'),
#  'SAMEA112286718': ('sample_type', 'real samples'),
#  'SAMEA112293935': ('tissue', 'blood'),
#  'SAMEA112302663': ('strain', 'Sall1ncre:Cx3cr1ccre'),
#  'SAMEA112320608': ('tissue', 'FIN'),
#  'SAMEA112330470': ('isolation_source', 'hospital'),
#  'SAMEA112342013': ('isolation_source', 'chicken gut metagenome'),
#  'SAMEA112344489': ('isolation_source', 'chicken gut metagenome'),
#  'SAMEA112372041': ('tissue', 'WHOLE ORGANISM'),
#  'SAMEA112372163': ('tissue', 'WHOLE ORGANISM'),
#  'SAMEA112376406': ('isolation_source', 'feces'),
#  'SAMEA112377551': ('isolation_source', 'feces'),
#  'SAMEA112380008': ('isolation_source', 'feces'),
#  'SAMEA112380196': ('isolation_source', 'feces'),
#  'SAMEA112382195': ('isolation_source', 'feces'),
#  'SAMEA112382560': ('isolation_source', 'feces'),
#  'SAMEA112382635': ('isolation_source', 'feces'),
#  'SAMEA112385245': ('isolation_source', 'Ileo-caecum'),
#  'SAMEA112392997': ('isolation_source', 'feces'),
#  'SAMEA112399647': ('isolation_source', 'feces'),
#  'SAMEA112400388': ('isolation_source', 'feces'),
#  'SAMEA112401477': ('isolation_source', 'feces'),
#  'SAMEA112409451': ('isolation_source', 'feces'),
#  'SAMEA112410881': ('isolation_source', 'Caecum'),
#  'SAMEA112415354': ('isolation_source', 'feces'),
#  'SAMEA112416054': ('isolation_source', 'feces'),
#  'SAMEA112416902': ('isolation_source', 'feces'),
#  'SAMEA112425015': ('isolation_source', 'feces'),
#  'SAMEA112425756': ('isolation_source', 'feces'),
#  'SAMEA112426686': ('isolation_source', 'feces'),
#  'SAMEA112430221': ('isolation_source', 'feces'),
#  'SAMEA112432370': ('isolation_source', 'Caecum'),
#  'SAMEA112436121': ('isolation_source', 'feces'),
#  'SAMEA112468035': ('tissue', 'WHOLE ORGANISM'),
#  'SAMEA112694256': ('cell_line', 'HeLa'),
#  'SAMEA112698909': ('strain', 'EH3156'),
#  'SAMEA112711565': ('isolation_source', 'mouse gut metagenome'),
#  'SAMEA112712977': ('isolation_source', 'mouse gut metagenome'),
#  'SAMEA112728312': ('isolation_source', 'mouse gut metagenome'),
#  'SAMEA112751613': ('tissue', 'FIN'),
#  'SAMEA112819260': ('tissue', 'WHOLE ORGANISM'),
#  'SAMEA112911861': ('isolation_source', 'mouse gut metagenome'),
#  'SAMEA112912239': ('isolation_source', 'mouse gut metagenome'),
#  'SAMEA112915673': ('isolation_source', 'mouse gut metagenome'),
#  'SAMEA112918591': ('isolation_source', 'mouse gut metagenome'),
#  'SAMEA112919398': ('isolation_source', 'mouse gut metagenome'),
#  'SAMEA112919732': ('isolation_source', 'mouse gut metagenome'),
#  'SAMEA112931065': ('isolation_source', 'mouse gut metagenome'),
#  'SAMEA112934557': ('isolation_source', 'mouse gut metagenome'),
#  'SAMEA112957310': ('strain', 'Tiso-Argenton'),
#  'SAMEA115003': ('tissue', 'brain'),
#  'SAMEA11503940': ('cell_type', 'Blood Cell'),
#  'SAMEA115126': ('strain', 'C57BL/6'),
#  'SAMEA11658466': ('isolation_source', 'Lower respiratory tract'),
#  'SAMEA12110672': ('tissue', 'WHOLE ORGANISM'),
#  'SAMEA12110735': ('tissue', 'WHOLE ORGANISM'),
#  'SAMEA124205': ('strain', 'A048281893'),
#  'SAMEA125637': ('strain', 'C.g. ATCC13032'),
#  'SAMEA12595312': ('tissue', 'GILL ANIMAL'),
#  'SAMEA12626317': ('strain', 'C57BL/6'),
#  'SAMEA1279661': ('tissue', 'leaf'),
#  'SAMEA1279767': ('strain', 'HMS174(DE3)(pET30a6his-sNpro-sGFPmut3.1)'),
#  'SAMEA1280207': ('strain', 'C606'),
#  'SAMEA1283937': ('cell_line', 'MCF7'),
#  'SAMEA12853744': ('isolation_source', 'sputum'),
#  'SAMEA1289491': ('strain', 'Crj:CD(SD)IGS'),
#  'SAMEA1289853': ('strain', 'Crj:CD(SD)IGS'),
#  'SAMEA1291539': ('strain', 'Crj:CD(SD)IGS'),
#  'SAMEA129332': ('tissue', 'blood'),
#  'SAMEA1294631': ('strain', 'Crj:CD(SD)IGS'),
#  'SAMEA129665': ('tissue', 'brain'),
#  'SAMEA1297747': ('strain', 'DBA/2J'),
#  'SAMEA12985992': ('strain', 'C57BL/6J'),
#  'SAMEA1299376': ('tissue', 'blood'),
#  'SAMEA12998021': ('tissue', 'vascular leaf'),
#  'SAMEA13003410': ('tissue', 'small intestine smooth muscle'),
#  'SAMEA1300834': ('tissue', 'skin'),
#  'SAMEA13008868': ('isolation_source', 'chicken gut metagenome'),
#  'SAMEA1306372': ('tissue', 'skin'),
#  'SAMEA1307632': ('strain', 'C57BL/6'),
#  'SAMEA13159022': ('strain', 'clinical isolate of L. monocytogenes'),
#  'SAMEA13323238': ('isolation_source',
#                    'oyster digestive glands spiked with nucleic acids '
#                    '(extracted from human feces) from different NoV strains'),
#  'SAMEA13323688': ('isolation_source', 'oyster'),
#  'SAMEA13471573': ('isolation_source', 'human feces'),
#  'SAMEA13473406': ('isolation_source', 'human feces'),
#  'SAMEA13477937': ('isolation_source', 'human feces'),
#  'SAMEA13485300': ('isolation_source', 'human feces'),
#  'SAMEA13488606': ('isolation_source', 'human feces'),
#  'SAMEA13488967': ('isolation_source', 'human feces'),
#  'SAMEA13491586': ('isolation_source', 'human feces'),
#  'SAMEA13495058': ('isolation_source', 'human feces'),
#  'SAMEA13500939': ('isolation_source', 'human feces'),
#  'SAMEA13515314': ('isolation_source', 'human feces'),
#  'SAMEA13516373': ('isolation_source', 'human feces'),
#  'SAMEA13517020': ('isolation_source', 'human feces'),
#  'SAMEA13517307': ('isolation_source', 'human feces'),
#  'SAMEA13520447': ('isolation_source', 'human feces'),
#  'SAMEA13524252': ('isolation_source', 'human feces'),
#  'SAMEA13528757': ('isolation_source', 'human feces'),
#  'SAMEA13531337': ('isolation_source', 'human feces'),
#  'SAMEA13538903': ('isolation_source', 'human feces'),
#  'SAMEA13539318': ('isolation_source', 'human feces'),
#  'SAMEA13541204': ('isolation_source', 'human feces'),
#  'SAMEA13541398': ('isolation_source', 'human feces'),
#  'SAMEA13544070': ('isolation_source', 'human feces'),
#  'SAMEA13553567': ('isolation_source', 'human feces'),
#  'SAMEA13556334': ('isolation_source', 'human feces'),
#  'SAMEA13560280': ('isolation_source', 'human feces'),
#  'SAMEA13561095': ('isolation_source', 'human feces'),
#  'SAMEA13562576': ('isolation_source', 'human feces'),
#  'SAMEA13567595': ('isolation_source', 'human gut'),
#  'SAMEA13657864': ('sample_type', 'cervical lavage'),
#  'SAMEA137194': ('tissue', 'skin'),
#  'SAMEA13791717': ('tissue', 'temporal_cortex'),
#  'SAMEA1390208': ('strain', 'UTEX 89'),
#  'SAMEA1391849': ('cell_type', 'hepatocyte'),
#  'SAMEA1392747': ('cell_type', 'hepatocyte'),
#  'SAMEA1393679': ('cell_type', 'hepatocyte'),
#  'SAMEA1402353': ('strain', 'lsh30'),
#  'SAMEA14080498': ('isolation_source', 'gut metagenome'),
#  'SAMEA14085026': ('isolation_source', 'human gut metagenome'),
#  'SAMEA14089926': ('strain', 'BA.1.1'),
#  'SAMEA14093836': ('strain', '08CEB5805SAL'),
#  'SAMEA1419821': ('tissue', 'mammary gland'),
#  'SAMEA1419863': ('strain', 'C57BL/6'),
#  'SAMEA14263459': ('tissue', 'HEAD | THORAX'),
#  'SAMEA14268928': ('tissue', 'WHOLE ORGANISM'),
#  'SAMEA14371027': ('tissue', 'skin'),
#  'SAMEA14383708': ('strain', 'C57BL/6J'),
#  'SAMEA14392061': ('tissue', 'SHOOT'),
#  'SAMEA14392399': ('tissue', 'THALLUS PLANT'),
#  'SAMEA14410789': ('cell_line', 'HAP1'),
#  'SAMEA14416526': ('sample_type', 'root'),
#  'SAMEA14416649': ('sample_type', 'root'),
#  'SAMEA14473349': ('strain', 'B.1.177.44'),
#  'SAMEA14510734': ('isolation_source', 'Blood_cell_pellets'),
#  'SAMEA1463610': ('strain', '81.4'),
#  'SAMEA1530152': ('strain', 'HS209'),
#  'SAMEA1530711': ('strain', 'ERS141632'),
#  'SAMEA1557340': ('tissue', 'UBERON:skin of limb'),
#  'SAMEA1568512': ('strain', 'CH5'),
#  'SAMEA1583958': ('tissue', 'leaf'),
#  'SAMEA1591077': ('tissue', 'blood'),
#  'SAMEA1610165': ('tissue', 'liver'),
#  'SAMEA164008': ('cell_type', 'embryonic stem cell'),
#  'SAMEA1644482': ('cell_type', 'lymphoblastoid cell line'),
#  'SAMEA1645063': ('cell_type', 'lymphoblastoid cell'),
#  'SAMEA164594': ('strain', 'FE0101AJO'),
#  'SAMEA1710236': ('strain', 'ERS180139'),
#  'SAMEA1711175': ('strain', 'mixed'),
#  'SAMEA1876220': ('strain', 'BPK 087/0 clone 11_SCMIL30 subclone 9'),
#  'SAMEA1877515': ('strain', 'Escherichia coliVM/16/08'),
#  'SAMEA1888655': ('strain', 'TL/AB'),
#  'SAMEA201646': ('tissue', 'stomach'),
#  'SAMEA2054486': ('strain', 'ILBSalm5484219'),
#  'SAMEA2058113': ('strain', 'mixed'),
#  'SAMEA2060694': ('strain', 'Promega'),
#  'SAMEA2065455': ('strain', 'A-055-05-1-08'),
#  'SAMEA2076733': ('strain', 'BEL_09_8'),
#  'SAMEA2160276': ('strain', '2590STDY5562154'),
#  'SAMEA2168797': ('tissue', 'UBERON:mucosa of stomach'),
#  'SAMEA2175189': ('strain', '3D7'),
#  'SAMEA2191451': ('tissue', 'cell line'),
#  'SAMEA2214029': ('tissue', 'adipose tissue'),
#  'SAMEA2228527': ('tissue', 'kidney'),
#  'SAMEA2228747': ('tissue', 'kidney'),
#  'SAMEA2236584': ('tissue', 'apical shoot meristem'),
#  'SAMEA2250565': ('strain', 'YEF473A'),
#  'SAMEA2277723': ('strain', 'AB2.2. Rex1-GFP'),
#  'SAMEA2291469': ('strain', 'NOD'),
#  'SAMEA2299796': ('tissue', 'bone marrow'),
#  'SAMEA2342400': ('strain', 'M08013626'),
#  'SAMEA2344493': ('cell_line', 'U20S'),
#  'SAMEA2345353': ('strain', 'R20291'),
#  'SAMEA2352044': ('tissue', 'kidney'),
#  'SAMEA2353126': ('tissue', 'whole blood'),
#  'SAMEA2353689': ('tissue', 'whole blood'),
#  'SAMEA2354449': ('tissue', 'leaf'),
#  'SAMEA238021': ('cell_line', 'PC12'),
#  'SAMEA2384334': ('strain', 'MSSA'),
#  'SAMEA2393232': ('tissue', 'UBERON:skin of leg'),
#  'SAMEA2439499': ('tissue', 'skin'),
#  'SAMEA2455463': ('strain',
#                   'Mixed Heterozygous Essential and Homozygous Non-Essential '
#                   'Deletion Strains'),
#  'SAMEA2472656': ('tissue', 'UBERON:feces'),
#  'SAMEA262989': ('tissue', 'Lung'),
#  'SAMEA2676216': ('strain', 'ST772'),
#  'SAMEA274661': ('tissue', 'skin'),
#  'SAMEA2757672': ('strain', 'mixed'),
#  'SAMEA2779953': ('strain', 'BY4741'),
#  'SAMEA2782814': ('tissue', 'detached leaves'),
#  'SAMEA2813754': ('cell_type', 'Peripheral blood mononuclear cells (PBMCs)'),
#  'SAMEA299728': ('cell_type', 'lymphoblastoid'),
#  'SAMEA301715': ('cell_type', 'lymphoblastoid'),
#  'SAMEA3098868': ('strain', 'Dd2'),
#  'SAMEA3108744': ('strain', 'NHEC0069'),
#  'SAMEA312009': ('tissue', 'testis'),
#  'SAMEA3175287': ('strain', 'LdBOB'),
#  'SAMEA3198247': ('tissue', 'colon/rectum'),
#  'SAMEA3215178': ('cell_type', 'fibroblast'),
#  'SAMEA3234571': ('cell_type', 'iPSC derived cell line'),
#  'SAMEA3255616': ('host_tissue_sampled', 'adductor muscle'),
#  'SAMEA3256785': ('tissue', 'lymph node'),
#  'SAMEA3283396': ('strain', 'MSSA'),
#  'SAMEA328474': ('tissue', 'skin'),
#  'SAMEA331287': ('tissue', 'breast tumour'),
#  'SAMEA3313902': ('strain', 'C57BL/6'),
#  'SAMEA3316719': ('cell_type', 'Blastomere, 4-cell embryo'),
#  'SAMEA3323892': ('cell_type', 'induced pluripotent stem cell'),
#  'SAMEA3356423': ('strain', 'C57BL/6'),
#  'SAMEA3389738': ('strain', 'GPSC227'),
#  'SAMEA3390268': ('strain', 'IT2980'),
#  'SAMEA3443582': ('tissue', 'Embryo'),
#  'SAMEA3460814': ('strain', 'from clinical sample'),
#  'SAMEA3473168': ('cell_line', 'HOP-62'),
#  'SAMEA3473425': ('cell_line', 'DMS-79'),
#  'SAMEA3485738': ('strain', 'ES057'),
#  'SAMEA3498333': ('strain', 'Tg(nkx6.1:GPF)'),
#  'SAMEA3570415': ('sample_type', 'Stool'),
#  'SAMEA3573929': ('isolation_source', 'MRSA [Broth]'),
#  'SAMEA3581536': ('tissue', 'embryo'),
#  'SAMEA3598354': ('tissue', 'Basal 0.5 cm Leaf 4'),
#  'SAMEA3609261': ('strain', 'C57BL/6N'),
#  'SAMEA3632557': ('sample_type', 'Stool'),
#  'SAMEA3683831': ('strain',
#                   'MATa, his3?1, leu2?0, met15?0, ura3?0 rtt109?0::KanMX4, '
#                   'tos4?0::hph'),
#  'SAMEA3706758': ('sample_type', 'control'),
#  'SAMEA3725253': ('cell_type', 'mESC'),
#  'SAMEA3755153': ('cell_type', 'fibroblast'),
#  'SAMEA3758592': ('tissue', 'hippocampus'),
#  'SAMEA3762968': ('tissue', 'mammary gland'),
#  'SAMEA3763271': ('cell_type', 'monocyte-derived dendritic cell'),
#  'SAMEA3764445': ('tissue', 'prostate'),
#  'SAMEA3769289': ('tissue', 'liver'),
#  'SAMEA3775577': ('tissue', 'aorta'),
#  'SAMEA3776561': ('cell_type', 'lymphocyte'),
#  'SAMEA378493': ('tissue', 'brain'),
#  'SAMEA379314': ('cell_line', 'SK-N-RA'),
#  'SAMEA3852718': ('cell_type', 'induced pluripotent stem cell'),
#  'SAMEA3864087': ('cell_type', 'neuronal stem cell'),
#  'SAMEA3866834': ('sample_type', 'Stool'),
#  'SAMEA3872901': ('cell_type', 'Hepatocytes'),
#  'SAMEA3889986': ('sample_type', 'dissected ant abdomen'),
#  'SAMEA3914762': ('strain', 'Ay-127 from Pedersen et al, 2012'),
#  'SAMEA3924032': ('strain', '20121343'),
#  'SAMEA3928512': ('strain', 'CT18'),
#  'SAMEA3958131': ('sample_type', 'stool'),
#  'SAMEA3959198': ('sample_type', 'saliva'),
#  'SAMEA3962401': ('cell_type', 'induced pluripotent stem cell'),
#  'SAMEA3962760': ('tissue', 'head'),
#  'SAMEA39642418': ('sample_type', 'sponge tissue'),
#  'SAMEA3965531': ('strain', 'Sprague-Dawley'),
#  'SAMEA3969059': ('tissue', 'bone marrow'),
#  'SAMEA3995401': ('tissue', 'inflorescence (EFO_0001029)'),
#  'SAMEA3996920': ('tissue', 'whole organism (EFO_0002906)'),
#  'SAMEA4011455': ('isolation_source', 'clinical'),
#  'SAMEA4037014': ('sample_type', 'control blank'),
#  'SAMEA4038450': ('sample_type', 'Countertop'),
#  'SAMEA4039506': ('sample_type', 'Hand'),
#  'SAMEA4041125': ('strain', 'CEN.PK102-5B - MeLS0138'),
#  'SAMEA4044628': ('sample_type', 'Stool_Stabilizer'),
#  'SAMEA4050392': ('tissue', 'cerebellum'),
#  'SAMEA4050707': ('tissue', 'midbrain'),
#  'SAMEA4060829': ('sample_type', 'stool'),
#  'SAMEA4066413': ('host_tissue_sampled', 'fecal'),
#  'SAMEA4069683': ('sample_type', 'stool'),
#  'SAMEA4073573': ('strain', 'C57BL/6'),
#  'SAMEA4077827': ('sample_type', 'skin'),
#  'SAMEA4077833': ('sample_type', 'skin'),
#  'SAMEA4087421': ('cell_type', 'primary mouse embryonic fibroblast'),
#  'SAMEA4094250': ('cell_type', 'induced pluripotent stem cell'),
#  'SAMEA4102061': ('strain', 'Mycobacterium bovis Pasteur'),
#  'SAMEA4107701': ('tissue', 'brown adipose tissue'),
#  'SAMEA4113329': ('tissue', 'pollen grain'),
#  'SAMEA4117876': ('tissue', 'prostate'),
#  'SAMEA4119076': ('tissue', 'colon'),
#  'SAMEA4125409': ('strain', 'yFS189'),
#  'SAMEA4127669': ('strain', 'Dahomey'),
#  'SAMEA4128204': ('strain', 'CCS1'),
#  'SAMEA4130643': ('tissue', 'root'),
#  'SAMEA4137353': ('strain', '129 strain'),
#  'SAMEA4140364': ('strain', 'M600'),
#  'SAMEA4141692': ('strain', 'SW900'),
#  'SAMEA4143291': ('strain', 'C57BL/6'),
#  'SAMEA4150131': ('strain', 'HCT116'),
#  'SAMEA4151760': ('strain', 'mixed'),
#  'SAMEA4152436': ('tissue', 'peripheral blood mononuclear cells'),
#  'SAMEA4156772': ('tissue', 'mammary gland'),
#  'SAMEA4160603': ('tissue', 'blood'),
#  'SAMEA4163204': ('tissue', 'blood'),
#  'SAMEA4164549': ('tissue', 'lung'),
#  'SAMEA4165493': ('tissue', 'leaf'),
#  'SAMEA4168480': ('tissue', 'leaf'),
#  'SAMEA4177286': ('strain', 'HaCat'),
#  'SAMEA4180077': ('strain', 'C57BL/6'),
#  'SAMEA4198803': ('tissue', 'brain cerebellum'),
#  'SAMEA4200871': ('tissue', 'blood'),
#  'SAMEA4201897': ('tissue', 'liver'),
#  'SAMEA4206541': ('cell_type', 'hepatocyte'),
#  'SAMEA4207784': ('cell_type', 'hepatocyte'),
#  'SAMEA4213512': ('strain', 'Crj:CD(SD)IGS'),
#  'SAMEA4217144': ('strain', 'Crj:CD(SD)IGS'),
#  'SAMEA4217447': ('strain', 'Crj:CD(SD)IGS'),
#  'SAMEA4219130': ('strain', 'Crj:CD(SD)IGS'),
#  'SAMEA4221883': ('strain', 'Crj:CD(SD)IGS'),
#  'SAMEA4225497': ('strain', 'Crj:CD(SD)IGS'),
#  'SAMEA4233783': ('strain', 'A048044830'),
#  'SAMEA4235100': ('cell_type', 'oestrogen receptor positive breast cancer'),
#  'SAMEA4240232': ('tissue', 'oral cavity'),
#  'SAMEA424247': ('strain', 'HepG2 (ATCC:HB 8065)'),
#  'SAMEA4242834': ('cell_type', 'melanocyte'),
#  'SAMEA4269596': ('strain', 'N402'),
#  'SAMEA4271345': ('tissue', 'mammary gland'),
#  'SAMEA4287760': ('tissue', 'liver'),
#  'SAMEA4289940': ('strain', 'CGR8'),
#  'SAMEA4295142': ('cell_type', 'MPP'),
#  'SAMEA4296298': ('tissue', 'whole aerial tissue'),
#  'SAMEA4296493': ('strain', 'NG H15'),
#  'SAMEA4296799': ('strain', 'SAG12ipt'),
#  'SAMEA4299535': ('strain', 'HepG2 (ATCC:HB 8065)'),
#  'SAMEA4299804': ('strain', 'SH-SY5Y (ATCC:CRL-2266)'),
#  'SAMEA4315093': ('strain',
#                   'Mixed Heterozygous Essential and Homozygous Non-Essential '
#                   'Deletion Strains'),
#  'SAMEA4315181': ('strain',
#                   'Mixed Heterozygous Essential and Homozygous Non-Essential '
#                   'Deletion Strains'),
#  'SAMEA4318988': ('tissue', 'plasma'),
#  'SAMEA4319628': ('tissue', 'endometrium'),
#  'SAMEA4320298': ('tissue', 'adipose tissue'),
#  'SAMEA4325995': ('tissue', 'brain'),
#  'SAMEA4335061': ('cell_type', 'macrophage'),
#  'SAMEA4335334': ('tissue', 'bone marrow'),
#  'SAMEA4335778': ('tissue', 'bone marrow'),
#  'SAMEA4337462': ('tissue', 'Blood/Brain'),
#  'SAMEA4337723': ('tissue', 'Blood/Brain'),
#  'SAMEA4349447': ('isolation_source', 'human'),
#  'SAMEA4353734': ('sample_type', 'Mouth'),
#  'SAMEA4354343': ('sample_type', 'wetland soil'),
#  'SAMEA4354771': ('sample_type', 'soil'),
#  'SAMEA4368958': ('host_tissue_sampled', 'rumen'),
#  'SAMEA4373240': ('strain', 'PA83'),
#  'SAMEA4374788': ('tissue', 'blood'),
#  'SAMEA4389208': ('sample_type', 'soil'),
#  'SAMEA4437321': ('tissue', 'pancreas'),
#  'SAMEA4446807': ('cell_type', 'hepatic stellate cell'),
#  'SAMEA4448541': ('cell_type', 'induced pluripotent stem cell'),
#  'SAMEA4450066': ('tissue', 'liver'),
#  'SAMEA4450098': ('cell_type', 'induced pluripotent stem cell'),
#  'SAMEA4456318': ('cell_type', 'CD8+ T-cells'),
#  'SAMEA4461017': ('sample_type', 'marine sediment'),
#  'SAMEA4479127': ('sample_type', 'fresh water'),
#  'SAMEA44853418': ('sample_type', 'sponge tissue'),
#  'SAMEA4523075': ('tissue', 'cerebellum'),
#  'SAMEA4534965': ('sample_type', 'gut'),
#  'SAMEA4608422': ('strain', '4928STDY7071675'),
#  'SAMEA4631765': ('strain', 'C57BL/6J'),
#  'SAMEA463554': ('tissue', 'stem, 2nd internode'),
#  'SAMEA4669987': ('tissue', 'head'),
#  'SAMEA4671684': ('strain', 'CD-1'),
#  'SAMEA4697496': ('isolation_source', 'feces'),
#  'SAMEA4728320': ('strain', 'C57BL/6'),
#  'SAMEA4728469': ('strain', 'C57BL/6'),
#  'SAMEA4729665': ('sample_type', 'stool'),
#  'SAMEA4758483': ('strain', 'C57BL/6J'),
#  'SAMEA4759482': ('isolation_source', 'human'),
#  'SAMEA4772968': ('sample_type', 'biofilm'),
#  'SAMEA4776616': ('tissue', 'lung'),
#  'SAMEA4781408': ('strain', 'SPARK_1145_C1'),
#  'SAMEA4788361': ('sample_type', 'Stool'),
#  'SAMEA4788414': ('sample_type', 'Stool'),
#  'SAMEA4808952': ('strain', 'C57BL/6 x CAST/EiJ'),
#  'SAMEA4837611': ('strain', 'M129'),
#  'SAMEA4857848': ('strain', 'C57BL/6J'),
#  'SAMEA4862375': ('tissue', 'leaf'),
#  'SAMEA4892685': ('strain', 'MA.BD-OM-2008-02-001666'),
#  'SAMEA4897618': ('tissue', 'Stomach'),
#  'SAMEA4898418': ('tissue', 'Terminal ileum lumen'),
#  'SAMEA4899405': ('tissue', 'Cecum lumen'),
#  'SAMEA4933652': ('tissue', 'skin'),
#  'SAMEA4947838': ('tissue', 'blood'),
#  'SAMEA4960060': ('host_tissue_sampled', 'caecum'),
#  'SAMEA5042422': ('sample_type', 'dust'),
#  'SAMEA5042629': ('sample_type', 'surface'),
#  'SAMEA5046953': ('tissue', 'tonsil'),
#  'SAMEA5050058': ('strain', 'SPARK_2797_C3'),
#  'SAMEA5129308': ('strain', 'C57BL/6'),
#  'SAMEA5179337': ('strain', 'C57BL/6'),
#  'SAMEA5179872': ('strain', 'C57BL/6'),
#  'SAMEA5184328': ('strain', 'C57BL/6'),
#  'SAMEA5225233': ('tissue', 'Fetal liver'),
#  'SAMEA5312670': ('strain', 'SL1344'),
#  'SAMEA5317363': ('sample_type', 'dental plaque'),
#  'SAMEA5368591': ('isolation_source', 'Hospitalized patient'),
#  'SAMEA537073': ('tissue', 'thyroid gland'),
#  'SAMEA53788918': ('strain', 'BKQMCE'),
#  'SAMEA5417310': ('strain', 'C57/Bl6 background'),
#  'SAMEA5435119': ('isolation_source', 'human gut'),
#  'SAMEA5435268': ('isolation_source', 'human gut'),
#  'SAMEA5437398': ('isolation_source', 'human gut'),
#  'SAMEA5440441': ('isolation_source', 'human gut'),
#  'SAMEA5442198': ('isolation_source', 'human gut'),
#  'SAMEA5447329': ('isolation_source', 'human gut'),
#  'SAMEA5452016': ('isolation_source', 'human gut'),
#  'SAMEA5457021': ('isolation_source', 'human gut'),
#  'SAMEA5460836': ('isolation_source', 'human gut'),
#  'SAMEA5461454': ('isolation_source', 'human gut'),
#  'SAMEA5462971': ('isolation_source', 'human gut'),
#  'SAMEA5466444': ('isolation_source', 'human gut'),
#  'SAMEA5472421': ('isolation_source', 'human gut'),
#  'SAMEA5474084': ('isolation_source', 'human gut'),
#  'SAMEA5474624': ('isolation_source', 'human gut'),
#  'SAMEA5476167': ('isolation_source', 'human gut'),
#  'SAMEA5476638': ('isolation_source', 'human gut'),
#  'SAMEA5476828': ('isolation_source', 'human gut'),
#  'SAMEA5476944': ('isolation_source', 'human gut'),
#  'SAMEA5481661': ('isolation_source', 'human gut'),
#  'SAMEA5482102': ('isolation_source', 'human gut'),
#  'SAMEA5482824': ('isolation_source', 'human gut'),
#  'SAMEA5483266': ('isolation_source', 'human gut'),
#  'SAMEA5483671': ('isolation_source', 'human gut'),
#  'SAMEA5484294': ('isolation_source', 'human gut'),
#  'SAMEA5488903': ('isolation_source', 'human gut'),
#  'SAMEA5490115': ('isolation_source', 'human gut'),
#  'SAMEA5493784': ('isolation_source', 'human gut'),
#  'SAMEA5495012': ('isolation_source', 'human gut'),
#  'SAMEA549823': ('tissue', 'adipose tissue'),
#  'SAMEA5500971': ('isolation_source', 'human gut'),
#  'SAMEA5508761': ('isolation_source', 'human gut'),
#  'SAMEA5509013': ('isolation_source', 'human gut'),
#  'SAMEA5509686': ('isolation_source', 'human gut'),
#  'SAMEA5510845': ('isolation_source', 'human gut'),
#  'SAMEA5512157': ('isolation_source', 'human gut'),
#  'SAMEA5513704': ('isolation_source', 'human gut'),
#  'SAMEA5514263': ('isolation_source', 'human gut'),
#  'SAMEA5514451': ('isolation_source', 'human gut'),
#  'SAMEA5518289': ('isolation_source', 'human gut'),
#  'SAMEA5522404': ('cell_type', 'Human iPS-derived macrophage'),
#  'SAMEA5531521': ('isolation_source',
#                   'Wheat residues inoculated with Z. tritici'),
#  'SAMEA5581342': ('tissue', 'colon'),
#  'SAMEA5594540': ('tissue', 'whole organism'),
#  'SAMEA5596975': ('isolation_source', 'feces'),
#  'SAMEA5597714': ('strain', 'BALB/c'),
#  'SAMEA5602174': ('sample_type', 'FecalFTA'),
#  'SAMEA5608832': ('isolation_source', 'anus'),
#  'SAMEA5609661': ('sample_type', 'wine'),
#  'SAMEA5613928': ('strain', 'R-17268'),
#  'SAMEA5626905': ('strain', 'A873'),
#  'SAMEA564021': ('tissue', 'peritoneal fat'),
#  'SAMEA5669894': ('host_tissue_sampled', 'fecal_pellet.1'),
#  'SAMEA5701204': ('strain', '129/Ola'),
#  'SAMEA5703816': ('cell_type', 'neuroectoderm'),
#  'SAMEA5719336': ('strain', 'K-12'),
#  'SAMEA5723360': ('strain', 'DIO'),
#  'SAMEA5724622': ('sample_type', 'child fecal sample'),
#  'SAMEA5765528': ('sample_type', 'marine sediment'),
#  'SAMEA5771874': ('sample_type', 'feces'),
#  'SAMEA5771965': ('sample_type', 'control mock community'),
#  'SAMEA5797108': ('tissue', 'lung'),
#  'SAMEA5817297': ('tissue', 'Muscle (claw)'),
#  'SAMEA5825076': ('isolation_source', 'cattle rumen'),
#  'SAMEA5828145': ('isolation_source', 'cattle rumen'),
#  'SAMEA5828862': ('isolation_source', 'cattle rumen'),
#  'SAMEA5835973': ('isolation_source', 'cattle rumen'),
#  'SAMEA5837250': ('isolation_source', 'cattle rumen'),
#  'SAMEA5838397': ('isolation_source', 'cattle rumen'),
#  'SAMEA584357': ('strain', 'Bora-Bora'),
#  'SAMEA584778': ('cell_line', 'A-172'),
#  'SAMEA5850248': ('isolation_source', 'human gut'),
#  'SAMEA5850494': ('isolation_source', 'human gut'),
#  'SAMEA5850876': ('isolation_source', 'human gut'),
#  'SAMEA5850968': ('isolation_source', 'human gut'),
#  'SAMEA5851393': ('isolation_source', 'human gut'),
#  'SAMEA5852232': ('isolation_source', 'human gut'),
#  'SAMEA5852342': ('isolation_source', 'human gut'),
#  'SAMEA5860616': ('tissue', 'SI'),
#  'SAMEA586174': ('tissue', 'Cardiac Ventricle'),
#  'SAMEA5868770': ('tissue', 'leaf'),
#  'SAMEA589795': ('tissue', 'adipose tissue'),
#  'SAMEA5946136': ('sample_type', 'dust'),
#  'SAMEA5948720': ('tissue', 'Hypothalamus'),
#  'SAMEA602236': ('tissue', 'colon'),
#  'SAMEA6056374': ('isolation_source', 'soil'),
#  'SAMEA6058248': ('isolation_source', 'food'),
#  'SAMEA6059820': ('strain', 'C57BL/6N'),
#  'SAMEA6072391': ('isolation_source', 'marine water'),
#  'SAMEA6072703': ('isolation_source', 'marine water'),
#  'SAMEA6073421': ('isolation_source', 'marine water'),
#  'SAMEA6078006': ('isolation_source', 'marine water'),
#  'SAMEA6083084': ('strain', 'A1_14'),
#  'SAMEA6099458': ('strain', 'ZKP13'),
#  'SAMEA6141855': ('source_name', 'DNA'),
#  'SAMEA6147487': ('source_name', 'DNA'),
#  'SAMEA6151321': ('isolation_source', 'cattle rumen'),
#  'SAMEA6168464': ('isolation_source', 'human primary care urine'),
#  'SAMEA623585': ('tissue', 'heart'),
#  'SAMEA6344078': ('tissue', 'whole body'),
#  'SAMEA642154': ('strain', 'C57BL/6 c/c'),
#  'SAMEA6477305': ('strain', 'C57BL/6'),
#  'SAMEA6479540': ('strain', 'C57BL/6'),
#  'SAMEA6480591': ('strain', 'C57BL/6'),
#  'SAMEA6481438': ('strain', 'C57BL/6'),
#  'SAMEA6482649': ('isolation_source', 'water'),
#  'SAMEA6483668': ('isolation_source', 'water'),
#  'SAMEA6557211': ('sample_type', 'feces'),
#  'SAMEA6559930': ('sample_type', 'feces'),
#  'SAMEA6561077': ('sample_type', 'feces'),
#  'SAMEA6561445': ('sample_type', 'feces'),
#  'SAMEA6563168': ('strain', 'K-12'),
#  'SAMEA6570490': ('sample_type', 'skin'),
#  'SAMEA6571195': ('sample_type', 'feces'),
#  'SAMEA6575686': ('sample_type', 'nasal mucus'),
#  'SAMEA6581624': ('sample_type', 'skin'),
#  'SAMEA6583100': ('sample_type', 'feces'),
#  'SAMEA6674994': ('isolation_source', 'sputum'),
#  'SAMEA6679916': ('isolation_source', 'human gut'),
#  'SAMEA6680415': ('isolation_source', 'human gut'),
#  'SAMEA6681091': ('isolation_source', 'human gut'),
#  'SAMEA6703970': ('isolation_source', 'human gut'),
#  'SAMEA6710071': ('isolation_source', 'human gut'),
#  'SAMEA6712672': ('isolation_source', 'human gut'),
#  'SAMEA671667': ('cell_type', 'EMBRYONIC STEM CELLS'),
#  'SAMEA6722996': ('isolation_source', 'human gut'),
#  'SAMEA6730400': ('isolation_source', 'human gut'),
#  'SAMEA6732449': ('isolation_source', 'human gut'),
#  'SAMEA6734431': ('isolation_source', 'human gut'),
#  'SAMEA6737076': ('isolation_source', 'human gut'),
#  'SAMEA6739467': ('isolation_source', 'human gut'),
#  'SAMEA6739766': ('isolation_source', 'human gut'),
#  'SAMEA6740485': ('isolation_source', 'human gut'),
#  'SAMEA6742023': ('isolation_source', 'human gut'),
#  'SAMEA6742593': ('isolation_source', 'human gut'),
#  'SAMEA6747138': ('isolation_source', 'human gut'),
#  'SAMEA6750560': ('isolation_source', 'human gut'),
#  'SAMEA6750922': ('isolation_source', 'human gut'),
#  'SAMEA6754115': ('isolation_source', 'human gut'),
#  'SAMEA6765384': ('isolation_source', 'human gut'),
#  'SAMEA6773112': ('isolation_source', 'human gut'),
#  'SAMEA6776595': ('isolation_source', 'human gut'),
#  'SAMEA6776767': ('isolation_source', 'human gut'),
#  'SAMEA6777091': ('isolation_source', 'human gut'),
#  'SAMEA6781533': ('isolation_source', 'human gut'),
#  'SAMEA6790119': ('isolation_source', 'freshwater'),
#  'SAMEA6793807': ('isolation_source', 'human gut'),
#  'SAMEA6800806': ('strain', 'clinical isolate of L. monocytogenes'),
#  'SAMEA6825067': ('tissue', 'bone marrow'),
#  'SAMEA6837435': ('tissue', 'liver'),
#  'SAMEA6843119': ('tissue', 'bone marrow'),
#  'SAMEA692914': ('strain', 'variety Terra Regina'),
#  'SAMEA6939324': ('isolation_source', 'coastal sea water'),
#  'SAMEA6942706': ('strain', 'C57BL/6J'),
#  'SAMEA6954328': ('isolation_source', 'lake water'),
#  'SAMEA6954412': ('isolation_source', 'lake water'),
#  'SAMEA6967906': ('strain', 'BALB/c'),
#  'SAMEA7025247': ('host_tissue_sampled', 'Caecum content'),
#  'SAMEA7037524': ('tissue', 'leaves'),
#  'SAMEA7064247': ('tissue', 'mammary gland'),
#  'SAMEA7095522': ('strain', 'C57BL/6J'),
#  'SAMEA7113474': ('strain', 'M115'),
#  'SAMEA7115869': ('sample_type', 'feces'),
#  'SAMEA7176079': ('tissue', 'bone'),
#  'SAMEA7182212': ('isolation_source', 'metagenome'),
#  'SAMEA7191790': ('isolation_source', 'F1 offspring'),
#  'SAMEA7199448': ('strain', 'C57BL/6J'),
#  'SAMEA7199734': ('strain', 'C57BL/6J'),
#  'SAMEA7202256': ('isolation_source', 'metagenome'),
#  'SAMEA7226435': ('strain', 'C57BL/6J'),
#  'SAMEA7226731': ('strain', 'C57BL/6J'),
#  'SAMEA7279897': ('isolation_source', 'Nyons fermented Olive fruit'),
#  'SAMEA7280926': ('isolation_source', 'Nyons fermented Olive fruit'),
#  'SAMEA7292692': ('tissue', 'Anterior intestine'),
#  'SAMEA7295813': ('sample_type', 'skin'),
#  'SAMEA7297203': ('isolation_source', 'chigger - from rodent'),
#  'SAMEA7298680': ('strain', 'F344/DuCrl'),
#  'SAMEA7313411': ('strain', 'C57BL/6NTac'),
#  'SAMEA7332180': ('tissue', 'mixed spleen and lymph node'),
#  'SAMEA7332482': ('tissue', 'leaf'),
#  'SAMEA7336483': ('host_tissue_sampled', 'human-gut'),
#  'SAMEA741979': ('cell_type', 'lymphoblastoid'),
#  'SAMEA7429090': ('isolation_source', 'human gut'),
#  'SAMEA7433186': ('isolation_source', 'human gut'),
#  'SAMEA7446011': ('isolation_source', 'human gut'),
#  'SAMEA7450356': ('isolation_source', 'human gut'),
#  'SAMEA7483601': ('isolation_source', 'Broiler meat'),
#  'SAMEA7505952': ('isolation_source', 'metagenome'),
#  'SAMEA7507200': ('isolation_source', 'metagenome'),
#  'SAMEA7522236': ('tissue', 'LEAF'),
#  'SAMEA7536294': ('tissue', '**OTHER PLANT TISSUE**'),
#  'SAMEA755729': ('cell_type', 'insulinoma'),
#  'SAMEA7602021': ('isolation_source', 'soil'),
#  'SAMEA7632618': ('isolation_source', 'not provided'),
#  'SAMEA7715206': ('tissue', 'not applicable'),
#  'SAMEA7715344': ('tissue', 'lymph node'),
#  'SAMEA7731178': ('sample_type', 'feces'),
#  'SAMEA7740932': ('tissue', 'inner cell mass'),
#  'SAMEA7754315': ('isolation_source', 'K:Living_collection:2010-1947'),
#  'SAMEA7761219': ('tissue', 'blood'),
#  'SAMEA7768924': ('isolation_source', 'trachea'),
#  'SAMEA7777059': ('isolation_source', 'cultured isolate'),
#  'SAMEA7832275': ('tissue', 'venom gland'),
#  'SAMEA7847614': ('isolation_source', 'human gut'),
#  'SAMEA7848760': ('strain', 'PS312'),
#  'SAMEA7871809': ('isolation_source', 'wild bird'),
#  'SAMEA7889667': ('isolation_source', 'Near ground (NG) air'),
#  'SAMEA8161122': ('host_tissue_sampled', 'Dorsal'),
#  'SAMEA8224230': ('tissue', 'THALLUS FUNGI'),
#  'SAMEA8387667': ('isolation_source', 'pure culture, shake flask'),
#  'SAMEA8506764': ('sample_type', 'Stool'),
#  'SAMEA8550501': ('strain', 'PBIO475'),
#  'SAMEA8557369': ('tissue', 'tonsil'),
#  'SAMEA8567802': ('cell_type', 'Blood'),
#  'SAMEA8603295': ('tissue', 'ABDOMEN'),
#  'SAMEA8603336': ('tissue', 'WHOLE ORGANISM'),
#  'SAMEA8695319': ('strain', 'C57BL/6'),
#  'SAMEA8719967': ('isolation_source', 'Human Sample'),
#  'SAMEA8735086': ('tissue', 'Foliage'),
#  'SAMEA87796918': ('sample_type', 'mosquito tissue'),
#  'SAMEA8798941': ('isolation_source', 'Seed'),
#  'SAMEA8900315': ('isolation_source', 'stool'),
#  'SAMEA8912172': ('isolation_source', 'blood'),
#  'SAMEA8923732': ('isolation_source', 'stool'),
#  'SAMEA9068807': ('host_tissue_sampled', 'Distal gut content'),
#  'SAMEA9144209': ('tissue', 'SHOOT'),
#  'SAMEA92377168': ('sample_type', 'Stool'),
#  'SAMEA9296394': ('strain', 'w1118'),
#  'SAMEA9296573': ('strain', 'w1118'),
#  'SAMEA9296843': ('strain', 'w1118'),
#  'SAMEA9297447': ('strain', 'w1118'),
#  'SAMEA9300575': ('strain', 'w1118'),
#  'SAMEA9302003': ('strain', 'w1118'),
#  'SAMEA9304751': ('strain', 'w1118'),
#  'SAMEA9305834': ('strain', 'w1118'),
#  'SAMEA9311149': ('strain', 'w1118'),
#  'SAMEA9312575': ('tissue', 'WHOLE ORGANISM'),
#  'SAMEA9360711': ('sample_type', 'surface'),
#  'SAMEA9372233': ('tissue', 'kidney'),
#  'SAMEA9541694': ('tissue', 'adipose'),
#  'SAMEA9653073': ('tissue', 'Leaf'),
#  'SAMEA976951': ('tissue', 'sigmoid colon'),
#  'SAMEA9958680': ('tissue', 'trophectoderm'),
#  'SAMN00014824': ('cell_type', 'C2C12 cells'),
#  'SAMN00024345': ('isolation_source', 'ileum'),
#  'SAMN00031572': ('isolation_source', 'G_DNA_Supragingival plaque'),
#  'SAMN00033172': ('isolation_source', 'G_DNA_L_Retroauricular crease'),
#  'SAMN00033422': ('isolation_source', 'G_DNA_Stool'),
#  'SAMN00033710': ('isolation_source', 'G_DNA_Hard palate'),
#  'SAMN00043887': ('isolation_source', 'G_DNA_Stool'),
#  'SAMN00044397': ('isolation_source', 'G_DNA_Stool'),
#  'SAMN00048526': ('tissue', 'Primary Tumor'),
#  'SAMN00063659': ('isolation_source', 'G_DNA_Hard palate'),
#  'SAMN00073199': ('isolation_source', 'Blood whole'),
#  'SAMN00081058': ('tissue', 'Blood Derived Normal'),
#  'SAMN00084312': ('isolation_source', 'G_DNA_Mid vagina'),
#  'SAMN00086177': ('isolation_source', 'primary_g_Stool'),
#  'SAMN00087679': ('isolation_source', 'G_DNA_Buccal mucosa'),
#  'SAMN00092642': ('tissue', 'Primary Tumor'),
#  'SAMN00097718': ('isolation_source', 'G_DNA_Palatine Tonsils'),
#  'SAMN00101044': ('tissue', 'Primary Tumor'),
#  'SAMN00101996': ('tissue', 'Primary Tumor'),
#  'SAMN00138427': ('sample_type', 'rRNA depleted total RNA'),
#  'SAMN00145857': ('isolation_source', 'G_DNA_Stool'),
#  'SAMN00147445': ('isolation_source', 'G_DNA_Attached/Keratinized gingiva'),
#  'SAMN00149946': ('tissue', 'blood serum'),
#  'SAMN00153759': ('tissue', 'root'),
#  'SAMN00159839': ('tissue', 'head_neck'),
#  'SAMN00162559': ('tissue', 'marrow'),
#  'SAMN00170098': ('tissue', 'Liver'),
#  'SAMN00174384': ('tissue', 'Cervix Uteri'),
#  'SAMN00181193': ('strain', 'NP5295'),
#  'SAMN00208112': ('tissue', 'Blood'),
#  'SAMN00223984': ('strain', 'NE7220'),
#  'SAMN00224660': ('strain', 'NE2480'),
#  'SAMN00225593': ('strain', 'NC3836'),
#  'SAMN00225936': ('strain', 'NC4691'),
#  'SAMN00233701': ('strain', 'NF4924'),
#  'SAMN00234475': ('strain', 'ND1809'),
#  'SAMN00234655': ('strain', 'ND7316'),
#  'SAMN00236044': ('strain', 'NF6313'),
#  'SAMN00236131': ('strain', 'NC6445'),
#  'SAMN00237012': ('strain', 'ND7928'),
#  'SAMN00237394': ('strain', 'NG6235'),
#  'SAMN00239916': ('strain', 'NF2783'),
#  'SAMN00242239': ('strain', 'NF9234'),
#  'SAMN00242263': ('strain', 'NF9334'),
#  'SAMN00242861': ('strain', 'NG9551'),
#  'SAMN00244953': ('strain', 'NF4608'),
#  'SAMN00248087': ('strain', 'NG0886'),
#  'SAMN00249325': ('strain', 'NE6174'),
#  'SAMN00250096': ('isolation_source', 'mid-vagina'),
#  'SAMN00254506': ('tissue', 'Blood'),
#  'SAMN00255812': ('isolation_source', 'oral'),
#  'SAMN00255931': ('isolation_source', 'oral'),
#  'SAMN00256179': ('isolation_source', 'oral'),
#  'SAMN00273734': ('tissue', 'blood'),
#  'SAMN00275360': ('tissue', 'BLOOD'),
#  'SAMN00276287': ('tissue', 'BLOOD'),
#  'SAMN00277769': ('tissue', 'blood'),
#  'SAMN00284851': ('tissue', 'BLOOD'),
#  'SAMN00297725': ('tissue', 'blood'),
#  'SAMN00303708': ('tissue', 'Blood'),
#  'SAMN00311975': ('tissue', 'Blood'),
#  'SAMN00313091': ('tissue', 'Blood'),
#  'SAMN00313203': ('tissue', 'Blood'),
#  'SAMN00315879': ('tissue', 'Blood'),
#  'SAMN00329931': ('tissue', 'Blood'),
#  'SAMN00358871': ('tissue', 'Blood'),
#  'SAMN00369679': ('tissue', 'Blood'),
#  'SAMN00377791': ('tissue', 'Blood'),
#  'SAMN00398565': ('tissue', 'Blood'),
#  'SAMN00426052': ('tissue', 'Blood'),
#  'SAMN00426075': ('tissue', 'Blood'),
#  'SAMN00426626': ('tissue', 'Blood'),
#  'SAMN00427118': ('tissue', 'Blood'),
#  'SAMN00449392': ('tissue', 'Blood'),
#  'SAMN00451903': ('tissue', 'Blood'),
#  'SAMN00452304': ('tissue', 'Blood'),
#  'SAMN00452503': ('tissue', 'Blood'),
#  'SAMN00455781': ('tissue', 'Blood'),
#  'SAMN00456214': ('tissue', 'Blood'),
#  'SAMN00458237': ('tissue', 'Blood'),
#  'SAMN00462941': ('tissue', 'Blood'),
#  'SAMN00470247': ('tissue', 'Peripheral Blood'),
#  'SAMN00473037': ('tissue', 'Peripheral Blood'),
#  'SAMN00474716': ('tissue', 'Peripheral Blood'),
#  'SAMN00480436': ('tissue', 'Blood'),
#  'SAMN00482353': ('tissue', 'Blood'),
#  'SAMN00518786': ('tissue', 'Blood'),
#  'SAMN00525077': ('tissue', 'Blood'),
#  'SAMN00527144': ('tissue', 'Blood'),
#  'SAMN00535354': ('tissue', 'Blood'),
#  'SAMN00560742': ('tissue', 'Peripheral Blood'),
#  'SAMN00575564': ('tissue', 'Blood'),
#  'SAMN00579332': ('tissue', 'Blood'),
#  'SAMN00595405': ('tissue', 'whole blood'),
#  'SAMN00601018': ('tissue', 'BLOOD'),
#  'SAMN00601832': ('tissue', 'BLOOD'),
#  'SAMN00605887': ('tissue', 'BLOOD'),
#  'SAMN00609013': ('tissue', 'blood'),
#  'SAMN00611745': ('tissue', 'blood'),
#  'SAMN00676543': ('tissue', 'Cell Line'),
#  'SAMN00693398': ('tissue', 'Blood'),
#  'SAMN00704517': ('tissue', 'Peripheral Whole Blood'),
#  'SAMN00750288': ('strain', 'SJL'),
#  'SAMN00752734': ('tissue', 'Primary Blood Derived Cancer - Peripheral Blood'),
#  'SAMN00762146': ('tissue', 'blood'),
#  'SAMN00774500': ('tissue', 'Blood'),
#  'SAMN00785369': ('tissue', 'Blood'),
#  'SAMN00786208': ('tissue', 'Blood'),
#  'SAMN00786622': ('tissue', 'Blood'),
#  'SAMN00787356': ('tissue', 'Blood'),
#  'SAMN00793331': ('tissue', 'Blood'),
#  'SAMN00794006': ('tissue', 'Blood'),
#  'SAMN00802733': ('cell_type', 'B-Lymphocyte'),
#  'SAMN00804576': ('cell_type', 'Fibroblast'),
#  'SAMN00809033': ('strain', 'M0692'),
#  'SAMN00809890': ('tissue', 'Prostate'),
#  'SAMN00811715': ('tissue', 'Primary Blood Derived Cancer - Bone Marrow'),
#  'SAMN00815415': ('tissue', 'Blood'),
#  'SAMN00831778': ('tissue', 'blood'),
#  'SAMN00838347': ('tissue', 'BLOOD'),
#  'SAMN00839219': ('tissue', 'BLOOD'),
#  'SAMN00845202': ('tissue', 'Blood'),
#  'SAMN00851683': ('tissue', 'Blood'),
#  'SAMN00852286': ('tissue', 'Blood'),
#  'SAMN00855029': ('tissue', 'BLOOD'),
#  'SAMN00863193': ('tissue', 'blood'),
#  'SAMN00868320': ('tissue', 'blood'),
#  'SAMN00868598': ('tissue', 'serum'),
#  'SAMN00870268': ('tissue', 'cell line'),
#  'SAMN00907447': ('tissue', 'Blood'),
#  'SAMN00910779': ('tissue', 'Blood'),
#  'SAMN00912094': ('tissue', 'Blood'),
#  'SAMN00914755': ('tissue', 'Blood'),
#  'SAMN00915439': ('tissue', 'Blood'),
#  'SAMN00917231': ('tissue', 'Blood'),
#  'SAMN00917360': ('tissue', 'Blood'),
#  'SAMN00919430': ('tissue', 'Blood'),
#  'SAMN00922170': ('tissue', 'Blood'),
#  'SAMN00922414': ('tissue', 'Blood'),
#  'SAMN00948129': ('tissue', 'blood'),
#  'SAMN00950372': ('tissue', 'blood'),
#  'SAMN00951388': ('tissue', 'cell line'),
#  'SAMN00980605': ('tissue', 'blood'),
#  'SAMN00982254': ('tissue', 'blood'),
#  'SAMN00983138': ('tissue', 'blood'),
#  'SAMN00983724': ('tissue', 'blood'),
#  'SAMN00992855': ('tissue', 'Brain - Cerebellum'),
#  'SAMN00998326': ('cell_type', 'ES-derived dopamine neuron cells'),
#  'SAMN01027380': ('tissue', 'Primary Tumor'),
#  'SAMN01029665': ('tissue', 'Blood Derived Normal'),
#  'SAMN01034792': ('tissue', 'Blood Derived Normal'),
#  'SAMN01047614': ('strain', 'missing'),
#  'SAMN01058904': ('tissue', 'Peripheral blood'),
#  'SAMN01094896': ('isolation_source', 'Fecal swab'),
#  'SAMN01099995': ('tissue', 'Brain tissue'),
#  'SAMN01100630': ('tissue', 'Blood'),
#  'SAMN01120326': ('cell_type', 'Tcf3(E2A) deficient pre-pro-B'),
#  'SAMN01129089': ('tissue', 'BLOOD'),
#  'SAMN01160188': ('tissue', 'blood'),
#  'SAMN01178245': ('cell_type', 'Th17'),
#  'SAMN01221544': ('tissue', 'cell line'),
#  'SAMN01661130': ('tissue', 'Blood'),
#  'SAMN01661573': ('tissue', 'Blood'),
#  'SAMN01668328': ('tissue', 'Blood'),
#  'SAMN01668796': ('tissue', 'Blood'),
#  'SAMN01669834': ('tissue', 'Blood'),
#  'SAMN01676169': ('tissue', 'Blood'),
#  'SAMN01677395': ('tissue', 'Blood'),
#  'SAMN01758807': ('strain', 'JK574 fog-2(q71)'),
#  'SAMN01770010': ('tissue', 'Blood'),
#  'SAMN01770813': ('tissue', 'Blood'),
#  'SAMN01776504': ('tissue', 'Blood'),
#  'SAMN01788651': ('tissue', 'whole blood'),
#  'SAMN01791698': ('tissue', 'N/A'),
#  'SAMN01792941': ('tissue', 'N/A'),
#  'SAMN01804489': ('tissue', 'BLOOD'),
#  'SAMN01820529': ('tissue', 'Primary Solid Tumor'),
#  'SAMN01850470': ('tissue', 'Blood'),
#  'SAMN01861092': ('tissue', 'Blood'),
#  'SAMN01863162': ('tissue', 'Blood'),
#  'SAMN01864216': ('tissue', 'BLOOD'),
#  'SAMN01865784': ('tissue', 'BLOOD'),
#  'SAMN01873896': ('tissue', 'blood'),
#  'SAMN01887340': ('tissue', 'Artery - Tibial'),
#  'SAMN01894209': ('cell_type', 'Human Peripheral Blood Mononuclear Cells'),
#  'SAMN01901733': ('tissue', 'fat body'),
#  'SAMN01903828': ('tissue', 'Blood'),
#  'SAMN01909543': ('tissue', 'BLOOD'),
#  'SAMN01916958': ('isolation_source', 'Feces, human'),
#  'SAMN01931558': ('tissue', 'Blood'),
#  'SAMN01933440': ('tissue', 'Blood'),
#  'SAMN01933491': ('tissue', 'Blood'),
#  'SAMN01938579': ('tissue', 'Blood'),
#  'SAMN01982793': ('tissue', 'Blood'),
#  'SAMN01983651': ('tissue', 'Blood'),
#  'SAMN01993238': ('tissue', 'leaves/stem'),
#  'SAMN01993542': ('source_name', 'wildtype'),
#  'SAMN02016657': ('tissue', 'Blood'),
#  'SAMN02017622': ('tissue', 'Blood'),
#  'SAMN02022274': ('tissue', 'Blood'),
#  'SAMN02023370': ('tissue', 'Blood'),
#  'SAMN02026957': ('tissue', 'Blood'),
#  'SAMN02031781': ('tissue', 'Blood'),
#  'SAMN02035652': ('tissue', 'Blood'),
#  'SAMN02038326': ('tissue', 'Blood'),
#  'SAMN02040347': ('tissue', 'Blood'),
#  'SAMN02045659': ('cell_line', 'ME-1'),
#  'SAMN02053771': ('strain', 'TKK-01-0038'),
#  'SAMN02092511': ('isolation_source', 'field isolate'),
#  'SAMN02117576': ('tissue', 'heart'),
# ...
#  'SAMN32135205': ('isolation_source', 'marine sediment'),
#  'SAMN32141045': ('isolation_source', 'nasal swab'),
#  'SAMN32141519': ('isolation_source', 'Nasal Swabs'),
#  'SAMN32143987': ('isolation_source', 'Nasal Swabs'),
#  'SAMN32157279': ('isolation_source', 'clinical'),
#  'SAMN32157477': ('sample_type', 'single cell'),
#  'SAMN32161443': ('isolation_source', 'Nasal Swabs'),
#  'SAMN32164716': ('sample_type', 'crc'),
#  'SAMN32180686': ('tissue', 'Blood'),
#  'SAMN32185571': ('sample_type', 'metagenomic assembly'),
#  'SAMN32188454': ('isolation_source', 'Not Collected'),
#  'SAMN32195577': ('tissue', 'blood'),
#  'SAMN32196007': ('tissue', 'blood'),
#  'SAMN32202680': ('tissue', 'blood'),
#  'SAMN32203974': ('tissue', 'blood'),
#  'SAMN32240847': ('isolation_source', 'Nasal Swabs'),
#  'SAMN32245496': ('isolation_source', 'nasopharyngeal swab'),
#  'SAMN32252112': ('tissue', 'Peripheral blood leukocytes'),
#  'SAMN32252655': ('isolation_source', 'missing'),
#  'SAMN32254321': ('sample_type', 'whole-population culture'),
#  'SAMN32262270': ('isolation_source', 'missing'),
#  'SAMN32287670': ('cell_line', 'K562'),
#  'SAMN32290062': ('isolation_source', 'Nasal Swabs'),
#  'SAMN32305595': ('isolation_source', 'Nasal Swabs'),
#  'SAMN32312764': ('tissue', 'Splenocytes'),
#  'SAMN32315030': ('sample_type', 'not applicable'),
#  'SAMN32319124': ('isolation_source', 'Nasal Swabs'),
#  'SAMN32327120': ('tissue', 'Blood'),
#  'SAMN32344070': ('sample_type', 'tissue'),
#  'SAMN32356196': ('tissue', 'tissues distal to cancer'),
#  'SAMN32395033': ('isolation_source', 'lung'),
#  'SAMN32405700': ('isolation_source', 'silage for phyllosphere'),
#  'SAMN32415411': ('isolation_source', 'clinical'),
#  'SAMN32422000': ('isolation_source', 'missing'),
#  'SAMN32423260': ('isolation_source', 'nasal'),
#  'SAMN32470490': ('isolation_source', 'patient isolate'),
#  'SAMN32477442': ('isolation_source', 'clinical'),
#  'SAMN32477509': ('isolation_source', 'clinical'),
#  'SAMN32479081': ('isolation_source', 'anaerobic bioreactor at pulpmill'),
#  'SAMN32489834': ('tissue', 'liver'),
#  'SAMN32492028': ('isolation_source', 'clinical'),
#  'SAMN32498093': ('tissue', 'Blood'),
#  'SAMN32498773': ('tissue', 'Blood'),
#  'SAMN32499907': ('tissue', 'Blood'),
#  'SAMN32502723': ('tissue', 'Blood'),
#  'SAMN32504486': ('tissue', 'Blood'),
#  'SAMN32513076': ('isolation_source', 'nasopharynx'),
#  'SAMN32535549': ('isolation_source', 'clinical'),
#  'SAMN32545362': ('isolation_source', 'wastewater'),
#  'SAMN32552307': ('isolation_source', 'Nasal Swabs'),
#  'SAMN32575591': ('isolation_source', 'wastewater'),
#  'SAMN32581820': ('isolation_source', 'jejunal content'),
#  'SAMN32582783': ('tissue', 'Buffy Coat'),
#  'SAMN32583214': ('tissue', 'Blood'),
#  'SAMN32587186': ('tissue', 'Blood'),
#  'SAMN32590682': ('tissue', 'Saliva'),
#  'SAMN32592570': ('tissue', 'Saliva'),
#  'SAMN32593777': ('tissue', 'Saliva'),
#  'SAMN32595491': ('tissue', 'thorax'),
#  'SAMN32601025': ('tissue', 'Whole Blood'),
#  'SAMN32607698': ('tissue', 'Whole blood'),
#  'SAMN32616953': ('isolation_source', 'human'),
#  'SAMN32620325': ('isolation_source', 'patient isolate'),
#  'SAMN32620473': ('isolation_source', 'wastewater'),
#  'SAMN32640005': ('isolation_source', 'Nasal Swabs'),
#  'SAMN32646316': ('isolation_source', 'patient isolate'),
#  'SAMN32651727': ('isolation_source', 'Nasal Swabs'),
#  'SAMN32663666': ('isolation_source', 'wastewater'),
#  'SAMN32673488': ('isolation_source', 'clinical'),
#  'SAMN32674602': ('sample_type', 'Cell culture'),
#  'SAMN32680964': ('host_anatomical_part', 'Nasopharynx'),
#  'SAMN32688262': ('isolation_source', 'nasal swab'),
#  'SAMN32689913': ('isolation_source', 'Apple tree soil'),
#  'SAMN32723106': ('isolation_source', 'dustbin surface'),
#  'SAMN32723478': ('isolation_source', 'nasal swab'),
#  'SAMN32735559': ('isolation_source', 'missing'),
#  'SAMN32735620': ('isolation_source', 'Tailing soil'),
#  'SAMN32746600': ('isolation_source', 'Nasal Swabs'),
#  'SAMN32768422': ('isolation_source', 'patient isolate'),
#  'SAMN32771360': ('isolation_source', 'wastewater'),
#  'SAMN32798792': ('sample_type', 'metagenomic assembly'),
#  'SAMN32799041': ('sample_type', 'metagenomic assembly'),
#  'SAMN32799910': ('isolation_source', 'comminuted chicken'),
#  'SAMN32807291': ('isolation_source', 'nasopharyngeal swab'),
#  'SAMN32819166': ('sample_type', 'culture'),
#  'SAMN32824429': ('isolation_source', 'fecal sample'),
#  'SAMN32854331': ('sample_type', 'metagenomic assembly'),
#  'SAMN32875654': ('isolation_source', 'human orophayrnx microbiome'),
#  'SAMN32877550': ('isolation_source', 'feces'),
#  'SAMN32880313': ('isolation_source', 'missing'),
#  'SAMN32909501': ('cell_type', 'Tumor'),
#  'SAMN32915387': ('isolation_source', 'Nasal Swabs'),
#  'SAMN32917367': ('tissue', 'yeast cells'),
#  'SAMN32931745': ('isolation_source', 'nasal'),
#  'SAMN32934370': ('isolation_source', 'skin'),
#  'SAMN32939237': ('isolation_source', 'missing'),
#  'SAMN32944598': ('tissue', 'blood'),
#  'SAMN32945054': ('isolation_source', 'Nasal Swabs'),
#  'SAMN32950610': ('strain', 'CD-1 IGS'),
#  'SAMN32951337': ('strain', 'not applicable'),
#  'SAMN32952690': ('isolation_source', 'Nasal Swabs'),
#  'SAMN32963814': ('isolation_source', 'vagina'),
#  'SAMN32969778': ('isolation_source', 'Nasal Swabs'),
#  'SAMN33008024': ('sample_type', 'tissue sample'),
#  'SAMN33017968': ('tissue', 'Blood'),
#  'SAMN33026147': ('tissue', 'Blood'),
#  'SAMN33026405': ('tissue', 'Blood'),
#  'SAMN33027229': ('tissue', 'Blood'),
#  'SAMN33032921': ('tissue', 'Blood'),
#  'SAMN33037558': ('tissue', 'Blood'),
#  'SAMN33052310': ('isolation_source', 'stool'),
#  'SAMN33060552': ('isolation_source', 'PrimeStore MTM - Nasal Swab'),
#  'SAMN33138843': ('cell_type', 'ipRGC'),
#  'SAMN33139830': ('isolation_source', 'human'),
#  'SAMN33154362': ('strain', 'not applicable'),
#  'SAMN33155093': ('tissue', 'Blood'),
#  'SAMN33161706': ('tissue', 'Blood'),
#  'SAMN33162978': ('tissue', 'Blood'),
#  'SAMN33167949': ('tissue', 'Blood'),
#  'SAMN33168688': ('isolation_source',
#                   'Greenhouse tomato plants (var. Mountain Fresh)'),
#  'SAMN33181334': ('isolation_source', 'Nasal Swabs'),
#  'SAMN33184625': ('isolation_source', 'nasal swab'),
#  'SAMN33184724': ('isolation_source', 'nasal swab'),
#  'SAMN33194219': ('isolation_source', 'wastewater'),
#  'SAMN33194313': ('isolation_source', 'wastewater'),
#  'SAMN33195411': ('isolation_source', 'composting'),
#  'SAMN33196622': ('isolation_source', 'soil'),
#  'SAMN33196780': ('isolation_source', 'air'),
#  'SAMN33213787': ('isolation_source', 'Nasopharyngeal'),
#  'SAMN33227756': ('isolation_source', 'Nasopharyngeal'),
#  'SAMN33228999': ('cell_type', 'Melanoma cells'),
#  'SAMN33236274': ('isolation_source', 'Nasal Swabs'),
#  'SAMN33247243': ('tissue', 'whole testis'),
#  'SAMN33269434': ('isolation_source', 'clinical'),
#  'SAMN33270603': ('strain', 'C57BL/6'),
#  'SAMN33274811': ('sample_type', 'Single cell BCR'),
#  'SAMN33275214': ('isolation_source', 'nasopharynx'),
#  'SAMN33292885': ('isolation_source', 'anterior nares'),
#  'SAMN33293132': ('isolation_source', 'anterior nares'),
#  'SAMN33293318': ('isolation_source', 'anterior nares'),
#  'SAMN33304557': ('cell_type', 'cancer cell'),
#  'SAMN33307907': ('isolation_source', 'clinical'),
#  'SAMN33309345': ('isolation_source', 'clinical'),
#  'SAMN33309976': ('isolation_source', 'clinical'),
#  'SAMN33315098': ('isolation_source', 'patient isolate'),
#  'SAMN33315530': ('isolation_source', 'patient isolate'),
#  'SAMN33320684': ('isolation_source', 'Nasal Swabs'),
#  'SAMN33338406': ('isolation_source', 'wastewater'),
#  'SAMN33340764': ('isolation_source', 'stool'),
#  'SAMN33352555': ('tissue', 'cerebellum'),
#  'SAMN33384832': ('isolation_source', 'clinical'),
#  'SAMN33385444': ('isolation_source', 'clinical'),
#  'SAMN33386374': ('strain', 'C57BL/6'),
#  'SAMN33388971': ('isolation_source', 'Nasal Swabs'),
#  'SAMN33390879': ('tissue', 'leaf'),
#  'SAMN33393762': ('tissue', 'Bone marrow lineage minus cells'),
#  'SAMN33397195': ('tissue', 'cerebellum'),
#  'SAMN33402275': ('tissue', 'cerebellum'),
#  'SAMN33402823': ('isolation_source', 'Cigar tobacco leaves'),
#  'SAMN33404725': ('tissue', 'kidney'),
#  'SAMN33405162': ('tissue', 'kidney'),
#  'SAMN33407744': ('isolation_source', 'A110'),
#  'SAMN33413956': ('isolation_source', 'ileum'),
#  'SAMN33415532': ('isolation_source', 'Sea urchin D2 body wall 2 (replicate)'),
#  'SAMN33417528': ('tissue', 'leaves'),
#  'SAMN33426275': ('sample_type', 'control pUC19, lambda phage, and T4-phage'),
#  'SAMN33428069': ('isolation_source', 'fecal sample16'),
#  'SAMN33432601': ('isolation_source', 'Nasal Swabs'),
#  'SAMN33438537': ('cell_type', 'Ba/F3'),
#  'SAMN33451466': ('isolation_source', 'wastewater'),
#  'SAMN33468713': ('tissue', 'Blood'),
#  'SAMN33470448': ('tissue', 'Blood'),
#  'SAMN33471429': ('tissue', 'Blood'),
#  'SAMN33471932': ('tissue', 'Blood'),
#  'SAMN33491039': ('tissue', 'blood'),
#  'SAMN33497946': ('tissue', 'blood'),
#  'SAMN33500150': ('tissue', 'blood'),
#  'SAMN33508252': ('tissue', 'Buffy Coat'),
#  'SAMN33508419': ('tissue', 'Buffy Coat'),
#  'SAMN33508615': ('tissue', 'Buffy Coat'),
#  'SAMN33511320': ('tissue', 'Buffy Coat'),
#  'SAMN33511707': ('tissue', 'blood'),
#  'SAMN33520989': ('tissue', 'Blood'),
#  'SAMN33523410': ('tissue', 'peripheral blood plasma'),
#  'SAMN33528059': ('tissue', 'blood'),
#  'SAMN33530957': ('tissue', 'Blood'),
#  'SAMN33538928': ('tissue', 'blood'),
#  'SAMN33540636': ('tissue', 'Buffy Coat'),
#  'SAMN33541525': ('tissue', 'blood'),
#  'SAMN33545463': ('tissue', 'Buffy Coat'),
#  'SAMN33546073': ('tissue', 'blood'),
#  'SAMN33548502': ('isolation_source', 'Panax notoginseng rhizosphere soil'),
#  'SAMN33551999': ('isolation_source', 'agricultural soil'),
#  'SAMN33562027': ('isolation_source', 'soil sample'),
#  'SAMN33576137': ('sample_type', 'abscess'),
#  'SAMN33576678': ('isolation_source', 'implant (sonication fluid)'),
#  'SAMN33578227': ('isolation_source', 'patient isolate'),
#  'SAMN33593800': ('tissue', 'leaves (developmental stage: 14-leaf-rosette)'),
#  'SAMN33597381': ('isolation_source', 'Nasal Swabs'),
#  'SAMN33599314': ('isolation_source', 'Nasal Swabs'),
#  'SAMN33602573': ('isolation_source', 'Clinical/Nasal Swab'),
#  'SAMN33608577': ('isolation_source', 'missing'),
#  'SAMN33609838': ('isolation_source', 'Nasal Swabs'),
#  'SAMN33613535': ('isolation_source', 'patient isolate'),
#  'SAMN33616506': ('isolation_source', 'clinical'),
#  'SAMN33625383': ('tissue', 'Buffy Coat'),
#  'SAMN33626401': ('tissue', 'Buffy Coat'),
#  'SAMN33627530': ('tissue', 'Buffy Coat'),
#  'SAMN33628431': ('tissue', 'Buffy Coat'),
#  'SAMN33629206': ('tissue', 'Mouthwash'),
#  'SAMN33631410': ('tissue', 'Buffy Coat'),
#  'SAMN33635313': ('tissue', 'Buffy Coat'),
#  'SAMN33636653': ('tissue', 'Buffy Coat'),
#  'SAMN33639448': ('tissue', 'Buffy Coat'),
#  'SAMN33641051': ('tissue', 'Buffy Coat'),
#  'SAMN33642500': ('tissue', 'Buffy Coat'),
#  'SAMN33646765': ('tissue', 'Buffy Coat'),
#  'SAMN33650937': ('tissue', 'Buffy Coat'),
#  'SAMN33651397': ('tissue', 'Buffy Coat'),
#  'SAMN33655055': ('tissue', 'Buffy Coat'),
#  'SAMN33655831': ('isolation_source', 'Oropharyngeal swab'),
#  'SAMN33656810': ('tissue', 'Buffy Coat'),
#  'SAMN33657298': ('tissue', 'Buffy Coat'),
#  'SAMN33693645': ('isolation_source', 'Nasal Swabs'),
#  'SAMN33702743': ('tissue', 'Blood'),
#  'SAMN33703152': ('tissue', 'Blood'),
#  'SAMN33703428': ('tissue', 'Blood'),
#  'SAMN33707108': ('isolation_source', 'liver_chicken_1'),
#  'SAMN33712753': ('isolation_source', 'missing'),
#  'SAMN33727507': ('tissue', 'whole embryo'),
#  'SAMN33733290': ('isolation_source', 'Nasal Swabs'),
#  'SAMN33735866': ('tissue', 'breast_tumor_right_FFPE'),
#  'SAMN33739387': ('sample_type', 'tissue sapmle'),
#  'SAMN33744529': ('tissue', 'Breast'),
#  'SAMN33745855': ('isolation_source', 'bovine'),
#  'SAMN33746241': ('isolation_source', 'Clinical/Nasal Swab'),
#  'SAMN33752062': ('tissue', 'Blood'),
#  'SAMN33754975': ('cell_type', 'FACS sorted'),
#  'SAMN33770571': ('host_tissue_sampled', 'oropharynx'),
#  'SAMN33780239': ('strain', 'not applicable'),
#  'SAMN33783537': ('isolation_source', 'human'),
#  'SAMN33816580': ('isolation_source', 'Sorghum bicolor - leaf'),
#  'SAMN33817039': ('isolation_source', 'wastewater'),
#  'SAMN33831406': ('isolation_source', 'swine feces'),
#  'SAMN33833941': ('tissue', 'leaves'),
#  'SAMN33837561': ('cell_type', 'Differentiating erythroid'),
#  'SAMN33863207': ('tissue', 'mediastinal lymph node'),
#  'SAMN33870192': ('tissue', 'Left Ventricle'),
#  'SAMN33874244': ('isolation_source', 'missing'),
#  'SAMN33875330': ('sample_type', 'Metagenomic assembly'),
#  'SAMN33905008': ('tissue', 'peripheral blood'),
#  'SAMN33906495': ('sample_type', 'Cell culture'),
#  'SAMN33913845': ('tissue', 'leaf'),
#  'SAMN33921889': ('isolation_source', 'root'),
#  'SAMN33937725': ('source_type', 'environmental'),
#  'SAMN33943000': ('strain', 'not applicable'),
#  'SAMN33950800': ('cell_type', 'hiPSC-neurons'),
#  'SAMN33954936': ('tissue', 'tail tip'),
#  'SAMN33958413': ('sample_type', 'larva/pupa'),
#  'SAMN33963212': ('isolation_source', 'guano'),
#  'SAMN33976930': ('isolation_source', 'Soil_689'),
#  'SAMN33977072': ('isolation_source', 'Soil_831'),
#  'SAMN33979900': ('isolation_source', 'River/stream'),
#  'SAMN33992001': ('strain', 'C57BL/6'),
#  'SAMN33992296': ('strain', 'C57BL/6'),
#  'SAMN33994007': ('strain', 'C57BL/6'),
#  'SAMN33994905': ('strain', 'C57BL/6'),
#  'SAMN33999888': ('strain', 'C57BL/6'),
#  'SAMN34000554': ('strain', 'C57BL/6'),
#  'SAMN34047596': ('isolation_source', 'Cloacal swabs'),
#  'SAMN34057844': ('isolation_source', 'wastewater'),
#  'SAMN34058260': ('isolation_source', 'wastewater'),
#  'SAMN34060886': ('isolation_source', 'wastewater'),
#  'SAMN34091537': ('isolation_source', 'Reactor2'),
#  'SAMN34127867': ('tissue', 'gill'),
#  'SAMN34137290': ('strain', 'SD'),
#  'SAMN34139744': ('isolation_source', 'missing'),
#  'SAMN34148048': ('strain', 'NA'),
#  'SAMN34150467': ('tissue', 'Blood'),
#  'SAMN34151320': ('tissue', 'Blood'),
#  'SAMN34155192': ('tissue', 'protoplast'),
#  'SAMN34167261': ('isolation_source', 'clinical'),
#  'SAMN34196739': ('sample_type', 'whole organism'),
#  'SAMN34218830': ('host_anatomical_part', 'nasopharynx'),
#  'SAMN34219469': ('isolation_source', 'clinical'),
#  'SAMN34226897': ('tissue', 'fecal45'),
#  'SAMN34237328': ('isolation_source', 'not collected'),
#  'SAMN34240077': ('isolation_source', 'not collected'),
#  'SAMN34274175': ('isolation_source', 'Nasal Swabs'),
#  'SAMN34282102': ('isolation_source', 'clinical'),
#  'SAMN34283003': ('strain', 'C57BL/6J'),
#  'SAMN34284471': ('strain', 'C57BL/6J'),
#  'SAMN34286777': ('tissue', 'Whole Blood'),
#  'SAMN34291660': ('tissue', 'Saliva'),
#  'SAMN34294841': ('strain', 'C57BL/6J'),
#  'SAMN34298446': ('strain', 'C57BL/6J'),
#  'SAMN34333167': ('strain', 'C57BL/6J'),
#  'SAMN34339750': ('tissue', 'not applicable'),
#  'SAMN34353220': ('isolation_source', 'Anal Gland'),
#  'SAMN34360975': ('strain', 'AVS0343'),
#  'SAMN34371493': ('isolation_source', 'wastewater'),
#  'SAMN34389001': ('tissue', 'peripheral blood'),
#  'SAMN34410301': ('isolation_source', 'clinical'),
#  'SAMN34422951': ('tissue', 'brain'),
#  'SAMN34425190': ('tissue', 'brain'),
#  'SAMN34432633': ('tissue', 'brain'),
#  'SAMN34432986': ('tissue', 'brain'),
#  'SAMN34439888': ('tissue', 'Leaf'),
#  'SAMN34442989': ('isolation_source', 'Nasal Swabs'),
#  'SAMN34473407': ('isolation_source', 'dung'),
#  'SAMN34485599': ('tissue', 'brain'),
#  'SAMN34489613': ('tissue', 'brain'),
#  'SAMN34494266': ('tissue', 'brain'),
#  'SAMN34501844': ('tissue', 'brain'),
#  'SAMN34505467': ('tissue', 'brain'),
#  'SAMN34536893': ('isolation_source', 'Clinical/Nasal Swab'),
#  'SAMN34538029': ('tissue', 'brain'),
#  'SAMN34560116': ('tissue', 'Peripheral blood'),
#  'SAMN34560610': ('tissue', 'Peripheral blood'),
#  'SAMN34564137': ('tissue', 'Peripheral blood'),
#  'SAMN34567493': ('isolation_source', '0-10 cm soil depth'),
#  'SAMN34573124': ('isolation_source', 'not collected'),
#  'SAMN34577227': ('isolation_source', 'Surface water of the estuary'),
#  'SAMN34584030': ('isolation_source', 'not collected'),
#  'SAMN34721029': ('tissue', 'iPSC'),
#  'SAMN34721207': ('tissue', 'iPSC'),
#  'SAMN34896041': ('isolation_source', 'Nasal Swabs'),
#  'SAMN34993370': ('host_tissue_sampled', 'Right Femoral Head')}

# %%
biosamples_path = "data/biosamples/biosample_random_samples.xml"
possible_tissue = {"cell_line", "cell_subtype", "cell_type", "host_tissue_sampled", "sample_type", "tissue", "host_anatomical_part", "isolation_source", "source_name", "source_type", "strain", "subclone", "subgroup"}
possible_tissue = possible_tissue.union(body_site_terms)
sample_dict = {}

t1 = time.time()
parser = xml.sax.make_parser()
handler = BioSamplesAttributeHandler(possible_tissue, sample_dict)
parser.setContentHandler(handler)
parser.parse(biosamples_path)
t2 = time.time()
print("Time taken: ", t2 - t1)

# pprint.pprint(sample_dict)
diff = set.difference(set(sample_dict.keys()), set(sample_dict_small.keys()))
print(diff)
print(len(diff))
# Out:
# Number of possible tissue locations found:  6663
# Time taken:  0.8906302452087402
# {'SAMN12468512', 'SAMN08976291', 'SAMN06748331', 'SAMN02810828', 'SAMEA7028739', 'SAMN02823722', 'SAMN00192860', 'SAMEA6498181', 'SAMN04078534', 'SAMN09290105', 'SAMN01019417', 'SAMN05313297', 'SAMN00123946', 'SAMN15970555', 'SAMN00413202', 'SAMN02815279', 'SAMN03916352', 'SAMEA8959259', 'SAMN03919531', 'SAMN02824176', 'SAMN23824008', 'SAMN12455222', 'SAMEA5330489', 'SAMN02825807', 'SAMEA8778292', 'SAMN23822002', 'SAMN06746468', 'SAMN02411087', 'SAMN05319155', 'SAMN12466080', 'SAMN04079065', 'SAMN00060356', 'SAMN06747610', 'SAMEA4625186', 'SAMEA2803962', 'SAMN03918163', 'SAMN04080345', 'SAMN06734663', 'SAMN02829172', 'SAMN12455379', 'SAMN01022952', 'SAMN28047659', 'SAMN02813236', 'SAMN12449816', 'SAMN20403362', 'SAMN12457475', 'SAMN07711961', 'SAMEA3357570', 'SAMN11840495', 'SAMN02831854', 'SAMN02815029', 'SAMN01142474', 'SAMN02810260', 'SAMN05316694', 'SAMN07712546', 'SAMN12471631', 'SAMEA6498519', 'SAMN20403509', 'SAMN02829103', 'SAMN13692440'}
# 60

# %% [markdown]
# - From basic code, directly looking at the attributes of each biosamples gives the most coverage in terms of possible tissue terms
# - As expected, checking the package of the biosample provides a faster method of extracting the possible tissue terms
#     - issues arise from the Generic.1.0 package from biosamples that have not been updated
# - DictHandler that uses a fuzzy search is more than 5 times slower than other methods and does not give better coverage with current settings

# %% [markdown]
# ----

# %%
class BioSamplesAttributeListHandler(xml.sax.ContentHandler):
    def __init__(self, attributes_set, sample_dict) -> None:
        super().__init__()
        sample_dict = sample_dict
        self.attributes_set = attributes_set
        self.biosample_id = ""
        self.attribute_name = ""
        self.attribute_list = []

    def startElement(self, name, attrs):
        if name == "BioSample":
            self.biosample_id = attrs["accession"]
        elif name == "Attribute" and "harmonized_name" in attrs:
            attribute_name = attrs["harmonized_name"]
            if attribute_name in self.attributes_set:
                self.attribute_name = attribute_name

    def characters(self, content):
        if self.attribute_name != "":
            self.attribute_list.append((self.attribute_name, content))
            self.attribute_name = ""

    def endElement(self, name):
        if name == "BioSample":
            sample_dict[self.biosample_id] = self.attribute_list
            self.biosample_id = ""
            self.attribute_list = []

    def endDocument(self):
        print("Number of possible tissue locations found: ", len(sample_dict))

# %%
sample_dict = {}
biosamples_path = "data/biosamples/biosample_random_samples.xml"
possible_tissue = {"cell_line", "cell_subtype", "cell_type", "host_tissue_sampled", "sample_type", "tissue", "host_anatomical_part", "isolation_source", "source_name", "source_type", "strain", "subclone", "subgroup"}


parser = xml.sax.make_parser()
handler = BioSamplesAttributeListHandler(possible_tissue, sample_dict)
parser.setContentHandler(handler)
parser.parse(biosamples_path)

positive_samples = {key for key, value in sample_dict.items() if len(value) > 0}
print(len(positive_samples))

print(sample_dict)
# Out:
# Number of possible tissue locations found:  10000
# 6603
# {'SAMN00000478': [], 'SAMN00000982': [], 'SAMN00003190': [], 'SAMN00006038': [], 'SAMN00014824': [('source_name', 'myotubes'), ('strain', 'C3H'), ('cell_type', 'C2C12 cells')], 'SAMD00000683': [('strain', 'T000240')], 'SAMN00017717': [], 'SAMN00023185': [], 'SAMN00024345': [('isolation_source', 'ileum')], 'SAMEA741979': [('cell_type', 'lymphoblastoid')], 'SAMN00031572': [('isolation_source', 'G_DNA_Supragingival plaque')], 'SAMN00033172': [('isolation_source', 'G_DNA_L_Retroauricular crease')], 'SAMN00033422': [('isolation_source', 'G_DNA_Stool')], 'SAMN00033710': [('isolation_source', 'G_DNA_Hard palate')], 'SAMN00043887': [('isolation_source', 'G_DNA_Stool')], 'SAMN00044397': [('isolation_source', 'G_DNA_Stool')], 'SAMN00048526': [('tissue', 'Primary Tumor')], 'SAMN00060356': [], 'SAMN00063659': [('isolation_source', 'G_DNA_Hard palate')], 'SAMN00073199': [('isolation_source', 'Blood whole')], 'SAMN00080674': [], 'SAMN00081058': [('tissue', 'Blood Derived Normal')], 'SAMN00084312': [('isolation_source', 'G_DNA_Mid vagina')], 'SAMN00086177': [('isolation_source', 'primary_g_Stool')], 'SAMN00087679': [('isolation_source', 'G_DNA_Buccal mucosa')], 'SAMN00092642': [('tissue', 'Primary Tumor')], 'SAMN00097718': [('isolation_source', 'G_DNA_Palatine Tonsils')], 'SAMN00101044': [('tissue', 'Primary Tumor')], 'SAMN00101996': [('tissue', 'Primary Tumor')], 'SAMN00105115': [], 'SAMN00109398': [], 'SAMEA893050': [], 'SAMN00123946': [], 'SAMN00125136': [], 'SAMN00127364': [], 'SAMN00127639': [], 'SAMN00138427': [('source_name', 'in vitro culture'), ('strain', 'METSMITS96A'), ('sample_type', 'rRNA depleted total RNA')], 'SAMN00145857': [('isolation_source', 'G_DNA_Stool')], 'SAMN00147445': [('isolation_source', 'G_DNA_Attached/Keratinized gingiva')], 'SAMN00149946': [('tissue', 'blood serum')], 'SAMN00153632': [], 'SAMN00153759': [('tissue', 'root hair'), ('tissue', 'root')], 'SAMN00154697': [], 'SAMN00159839': [('tissue', 'head_neck')], 'SAMN00162559': [('tissue', 'marrow')], 'SAMN00170098': [('strain', 'Zucker (fa/fa)'), ('tissue', 'Liver')], 'SAMN00174384': [('strain', 'Sprague-Dawley'), ('tissue', 'Cervix Uteri')], 'SAMN00181193': [('strain', 'NP5295')], 'SAMN00187896': [], 'SAMN00192860': [], 'SAMN00204112': [], 'SAMN00204890': [], 'SAMN00208112': [('tissue', 'Blood')], 'SAMN00216021': [], 'SAMN00223984': [('strain', 'NE7220')], 'SAMN00224660': [('strain', 'NE2480')], 'SAMN00225593': [('strain', 'NC3836')], 'SAMN00225936': [('strain', 'NC4691')], 'SAMN00233701': [('strain', 'NF4924')], 'SAMN00234475': [('strain', 'ND1809')], 'SAMN00234655': [('strain', 'ND7316')], 'SAMN00236044': [('strain', 'NF6313')], 'SAMN00236131': [('strain', 'NC6445')], 'SAMN00237012': [('strain', 'ND7928')], 'SAMN00237394': [('strain', 'NG6235')], 'SAMN00239916': [('strain', 'NF2783')], 'SAMN00242239': [('strain', 'NF9234')], 'SAMN00242263': [('strain', 'NF9334')], 'SAMN00242861': [('strain', 'NG9551')], 'SAMN00244953': [('strain', 'NF4608')], 'SAMN00248087': [('strain', 'NG0886')], 'SAMN00249325': [('strain', 'NE6174')], 'SAMN00250096': [('isolation_source', 'mid-vagina')], 'SAMN00254506': [('tissue', 'Blood')], 'SAMN00255812': [('isolation_source', 'oral')], 'SAMN00255931': [('isolation_source', 'oral')], 'SAMN00256179': [('isolation_source', 'oral')], 'SAMN00273734': [('tissue', 'blood')], 'SAMN00275360': [('tissue', 'BLOOD')], 'SAMN00276287': [('tissue', 'BLOOD')], 'SAMN00277769': [('tissue', 'blood')], 'SAMN00284851': [('tissue', 'BLOOD')], 'SAMN00297725': [('tissue', 'blood')], 'SAMN00303708': [('tissue', 'Blood')], 'SAMN00311975': [('tissue', 'Blood')], 'SAMN00313091': [('tissue', 'Blood')], 'SAMN00313203': [('tissue', 'Blood')], 'SAMN00315879': [('tissue', 'Blood')], 'SAMN00323181': [], 'SAMN00324413': [], 'SAMN00326231': [], 'SAMN00328947': [], 'SAMN00329931': [('tissue', 'Blood')], 'SAMN00332716': [], 'SAMN00334002': [], 'SAMN00340219': [], 'SAMN00340414': [], 'SAMN00342379': [], 'SAMN00344937': [], 'SAMN00346449': [], 'SAMN00346654': [], 'SAMN00350 ...

# %% [markdown]
# ----
# # Matching results to the BTO
# - using the dictionary of possible tissue terms, a search can be carried out on the BTO to find the matching term

# %%
result_dict = {}
result_front_wildcard = {}
result_back_wildcard = {}
result_both_wildcard = {}

for sample_id, attribute in sample_dict.items():
    result = onto.search_one(label = "{}".format(attribute[1]), _case_sensitive = False)
    result_front = onto.search_one(label = "{}*".format(attribute[1]), _case_sensitive = False)
    result_back = onto.search_one(label = "*{}".format(attribute[1]), _case_sensitive = False)
    result_both = onto.search_one(label = "*{}*".format(attribute[1]), _case_sensitive = False)
    if result is not None:
        result_dict[sample_id] = (result.name, result.label[0])
    else:
        result_dict[sample_id] = (None, None)

    if result_front is not None:
        result_front_wildcard[sample_id] = (result_front.name, result_front.label[0])
    else:
        result_front_wildcard[sample_id] = (None, None)
    
    if result_back is not None:
        result_back_wildcard[sample_id] = (result_back.name, result_back.label[0])
    else:
        result_back_wildcard[sample_id] = (None, None)

    if result_both is not None:
        result_both_wildcard[sample_id] = (result_both.name, result_both.label[0])
    else:
        result_both_wildcard[sample_id] = (None, None)

# pprint.pprint(result_dict)

# %%
# # print the number of sammples that have a match
# positive_results = [(sample_id, result[1]) for sample_id, result in result_dict.items() if result != (None, None)]
positive_results = {sample_id: result[1] for sample_id, result in result_dict.items() if result != (None, None)}
print("Number of exact matches in the BTO: ", len(positive_results))




filtered_results = dict(filter(lambda x: x[1] == "blood", positive_results.items()))
print("Number of matches with 'Blood' in the BTO: ", len(filtered_results))
print(filtered_results)
# print({a for a in result_dict.values() if a is not None})
# Out:
# Number of exact matches in the BTO:  2133
# Number of matches with 'Blood' in the BTO:  779
# {'116303': 'blood', '182671': 'blood', '207804': 'blood', '209188': 'blood', '218984': 'blood', '259774': 'blood', '272252': 'blood', '282424': 'blood', '285590': 'blood', '299261': 'blood', '299409': 'blood', '300388': 'blood', '302005': 'blood', '302869': 'blood', '314075': 'blood', '320480': 'blood', '330926': 'blood', '358984': 'blood', '376017': 'blood', '378418': 'blood', '383282': 'blood', '398656': 'blood', '425799': 'blood', '426758': 'blood', '426891': 'blood', '428706': 'blood', '452333': 'blood', '461095': 'blood', '463605': 'blood', '479608': 'blood', '517051': 'blood', '518279': 'blood', '519059': 'blood', '519521': 'blood', '519689': 'blood', '520440': 'blood', '524175': 'blood', '528239': 'blood', '528273': 'blood', '529484': 'blood', '530324': 'blood', '531605': 'blood', '531794': 'blood', '533664': 'blood', '578669': 'blood', '604885': 'blood', '605938': 'blood', '608849': 'blood', '612064': 'blood', '677582': 'blood', '694064': 'blood', '695796': 'blood', '698011': 'blood', '707939': 'blood', '760136': 'blood', '772423': 'blood', '775093': 'blood', '775310': 'blood', '775524': 'blood', '784669': 'blood', '813449': 'blood', '831042': 'blood', '832160': 'blood', '835988': 'blood', '848966': 'blood', '854240': 'blood', '865526': 'blood', '865590': 'blood', '884550': 'blood', '887077': 'blood', '887218': 'blood', '887768': 'blood', '909081': 'blood', '910382': 'blood', '911242': 'blood', '916604': 'blood', '922416': 'blood', '934081': 'blood', '945679': 'blood', '949659': 'blood', '968654': 'blood', '969447': 'blood', '969699': 'blood', '979049': 'blood', '984728': 'blood', '1092921': 'blood', '1123101': 'blood', '1123138': 'blood', '1127487': 'blood', '1133932': 'blood', '1134344': 'blood', '1135797': 'blood', '1157998': 'blood', '1183519': 'blood', '1223953': 'blood', '1666231': 'blood', '1667516': 'blood', '1677325': 'blood', '1678158': 'blood', '1728246': 'blood', '1733436': 'blood', '1734234': 'blood', '1735228': 'blood', '1833685': 'blood', '1834737': 'blood', '1842422': 'blood', '1845154': 'blood', '1847662': 'blood', '1848612': 'blood', '1864579': 'blood', '1873727': 'blood', '1903343': 'blood', '1903639': 'blood', '1925881': 'blood', '1934953': 'blood', '1979567': 'blood', '1988869': 'blood', '2010857': 'blood', '2014880': 'blood', '2016366': 'blood', '2017151': 'blood', '2018405': 'blood', '2021401': 'blood', '2023613': 'blood', '2036960': 'blood', '2037866': 'blood', '2148164': 'blood', '2149514': 'blood', '2154036': 'blood', '2159929': 'blood', '2164326': 'blood', '2171996': 'blood', '2173920': 'blood', '2221472': 'blood', '2223803': 'blood', '2256048': 'blood', '2266438': 'blood', '2268649': 'blood', '2271410': 'blood', '2271963': 'blood', '2276390': 'blood', '2276754': 'blood', '2278320': 'blood', '2282069': 'blood', '2282655': 'blood', '2286190': 'blood', '2292257': 'blood', '2307207': 'blood', '2308360': 'blood', '2312142': 'blood', '2312369': 'blood', '2354806': 'blood', '2355212': 'blood', '2446356': 'blood', '2447029': 'blood', '2450509': 'blood', '2452554': 'blood', '2460115': 'blood', '2468131': 'blood', '2474110': 'blood', '2476709': 'blood', '2480689': 'blood', '2606593': 'blood', '2620022': 'blood', '2621333': 'blood', '2631714': 'blood', '2632405': 'blood', '2634631': 'blood', '2634767': 'blood', '2635389': 'blood', '2636636': 'blood', '2637066': 'blood', '2638950': 'blood', '2647342': 'blood', '2647908': 'blood', '2648756': 'blood', '2648800': 'blood', '2652663': 'blood', '2676855': 'blood', '2683459': 'blood', '2683759': 'blood', '2715067': 'blood', '2754949': 'blood', '2855565': 'blood', '2856544': 'blood', '2859835': 'blood', '2860277': 'blood', '2875134': 'blood', '2877239': 'blood', '2877737': 'blood', '2882633': 'blood', '2883774': 'blood', '2887874': 'blood', '2889757': 'blood', '2896843': 'blood', '2917574': 'blood', '2956244': 'blood', '2959647': 'blood', '2961030': 'blood', '2978307': 'blood', '3033648': 'blood', '3033682': 'blood', '3040714': 'blood', '3043252': 'blood', '305 ...

# %% [markdown]
# ----
# # Gettting search results from NCBI
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi?db=biosample&term=blood&retmax=100&usehistory=y
# - Search results can be fetched from the NCBI website
#     - all biosample ids that match a given search term can be fetched
#     - result returned as an XML file
# - Comparison can be made results from the BioSamplesAttributeHandler and NCBI results to check for false positives

# %%
import requests
import keys
from time import sleep

# %%
base_url = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/"
query = "esearch.fcgi?db=biosample&term=blood&retmax=100&usehistory=y"

url = base_url + query + "&api_key=" + keys.ncbi_key
response = requests.get(url)

assert response.status_code == 200, "Error: " + str(response.status_code)

# Gets the required values from the initial search response
root = ET.fromstring(response.content)
webenv = root.find("WebEnv").text
query_key = root.find("QueryKey").text
count = root.find("Count").text


ids = set()
for i in root.findall("IdList/Id"):
    ids.add(i.text)

retmax = 10000
for retstart in range(0, int(count), retmax):
    fetch_url = base_url + "efetch.fcgi?db=biosample&WebEnv=" + webenv 
    fetch_url += "&query_key=" + query_key + "&retstart=" + str(retstart) + "&retmax=" + str(retmax) 
    fetch_url += "&rettype=uilist&retmode=xml&api_key=" + keys.ncbi_key

    fetch_response = requests.get(fetch_url)
    assert fetch_response.status_code == 200, "Error: " + str(fetch_response.status_code)
    sleep(0.2) # sleep to avoid overloading the server
    fetch_root = ET.fromstring(fetch_response.content)
    for i in fetch_root.findall("Id"):
        ids.add(i.text)

print("Number of ids: ", len(ids))
print("Expected number of ids: ", count)

# pprint.pprint(ids)
# Out:
# Number of ids:  3326542
# Expected number of ids:  3326542

# %%
returned_ids = set(filtered_results.keys())
print("Number of ids with 'blood' in the BTO: ", len(returned_ids))

# ids that have returned results but not in the NCBI search - False Positives
set_difference = returned_ids.difference(ids)

print(len(set_difference), "False Positives")
print(set_difference)

print('33544736' in ids)
# Out:
# Number of ids with 'blood' in the BTO:  779
# 94 False Positives
# {'832160', '16016553', '33544736', '33504971', '517051', '1157998', '12191993', '528273', '2023613', '34148567', '2271963', '865526', '2282655', '3675248', '519689', '6943924', '13691856', '911242', '934081', '13693299', '29117118', '13626487', '33520202', '1864579', '2278320', '865590', '12197483', '2276754', '784669', '2014880', '16017558', '2016366', '2683459', '3671428', '302869', '2266438', '2460115', '519059', '519521', '218984', '949659', '33543813', '2286190', '979049', '33539189', '909081', '2683759', '524175', '984728', '910382', '520440', '16033835', '2452554', '12193874', '831042', '2021401', '33517707', '3679727', '9827805', '2171996', '2017151', '2159929', '2447029', '22579999', '6944214', '529484', '916604', '2446356', '1925881', '945679', '922416', '8855655', '2271410', '1183519', '2282069', '2010857', '2292257', '6133933', '1223953', '6945860', '528239', '2018405', '9826181', '2276390', '2268649', '12800143', '3660222', '2450509', '530324', '34150553', '2173920', '518279', '33491931', '6941889'}
# 3326542
# False

# %% [markdown]
# ----
# # Running code on biosample_set.xml
# - same attribute handler code as above but run on the whole set
#     - code writes the found information to a csv file in order to not overload memory

# %%
class BioSamplesAttributeHandler(xml.sax.ContentHandler):
    def __init__(self, attributes_set) -> None:
        super().__init__()
        self.attributes_set = attributes_set
        self.biosample_id = ""
        self.attribute_name = ""
        self.biosample_count = 0
        
        with open("data/biosamples/results/biosamples_tissue.csv", "w") as f:
            writer = csv.writer(f)
            writer.writerow(["biosample_id", "tissue"])

    def startElement(self, name, attrs):
        if name == "BioSample":
            self.biosample_id = attrs["id"]
            self.biosample_count += 1
            if self.biosample_count % 1000000 == 0:
                print("Number of biosamples processed: ", self.biosample_count)
                
        elif name == "Attribute" and "harmonized_name" in attrs:
            attribute_name = attrs["harmonized_name"]
            if attribute_name in self.attributes_set:
                self.attribute_name = attribute_name

    def characters(self, content):
        if self.attribute_name != "":
            with open("data/biosamples/results/biosamples_tissue.csv", "a") as f:
                writer = csv.writer(f)
                writer.writerow([self.biosample_id, content])
            self.attribute_name = ""

    def endDocument(self):
        print("Finished writing to file")

# %%
biosamples_path = "data/biosamples/biosample_set.xml"
possible_tissue = {"cell_line", "cell_subtype", "cell_type", "host_tissue_sampled", "sample_type", "tissue", "host_anatomical_part", "isolation_source", "source_name", "source_type", "strain", "subclone", "subgroup"}

parser = xml.sax.make_parser()
handler = BioSamplesAttributeHandler(possible_tissue)
parser.setContentHandler(handler)
parser.parse(biosamples_path)
# Out:
# Number of biosamples processed:  1000000
# Number of biosamples processed:  2000000
# Number of biosamples processed:  3000000
# Number of biosamples processed:  4000000
# Number of biosamples processed:  5000000
# Number of biosamples processed:  6000000
# Number of biosamples processed:  7000000
# Number of biosamples processed:  8000000
# Number of biosamples processed:  9000000
# Number of biosamples processed:  10000000
# Number of biosamples processed:  11000000
# Number of biosamples processed:  12000000
# Number of biosamples processed:  13000000
# Number of biosamples processed:  14000000
# Number of biosamples processed:  15000000
# Number of biosamples processed:  16000000
# Number of biosamples processed:  17000000
# Number of biosamples processed:  18000000
# Number of biosamples processed:  19000000
# Number of biosamples processed:  20000000
# Number of biosamples processed:  21000000
# Number of biosamples processed:  22000000
# Number of biosamples processed:  23000000
# Number of biosamples processed:  24000000
# Number of biosamples processed:  25000000
# Number of biosamples processed:  26000000
# Number of biosamples processed:  27000000
# Number of biosamples processed:  28000000
# Number of biosamples processed:  29000000
# Number of biosamples processed:  30000000
# Number of biosamples processed:  31000000
# Number of biosamples processed:  32000000
# Finished writing to file

# %% [markdown]
# ----
# # Generating statistics

# %%
import plotly.express as px

# %%
# plots graph of numbe of attributes found per biosample 
# sample_dict should have the format {sample_id: [attribute1, attribute2, ...]}
attribute_count = {}

for key, value in sample_dict.items():
    num_attrs = len(value)
    if num_attrs in attribute_count:
        attribute_count[num_attrs] += 1
    else:
        attribute_count[num_attrs] = 1


bar_data = {"num_attributes": list(attribute_count.keys()), "num_samples": list(attribute_count.values()), "label": list(attribute_count.values())}
fig = px.bar(bar_data, x="num_attributes", y="num_samples", text="label")
fig.update_layout(title="Number of attributes found per biosample", xaxis=dict(title="# of attributes assigned to biosample"), yaxis=dict(title="Count"))
fig.show()
# Out:
# <div>                            <div id="2293f95e-5047-4b4f-b4d2-73c89105f90b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2293f95e-5047-4b4f-b4d2-73c89105f90b")) {                    Plotly.newPlot(                        "2293f95e-5047-4b4f-b4d2-73c89105f90b",                        [{"alignmentgroup":"True","hovertemplate":"num_attributes=%{x}<br>num_samples=%{y}<br>label=%{text}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[3397.0,576.0,4471.0,1473.0,72.0,3.0,1.0,7.0],"textposition":"auto","x":[0,3,1,2,4,7,6,5],"xaxis":"x","y":[3397,576,4471,1473,72,3,1,7],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth": ...

# %%
# plots a bar graph of number of samples with no matches
# sample_dict should have the format {sample_id: [attribute1, attribute2, ...]}

no_match_count = attribute_count[0]
match_count = 10000 - no_match_count

bar_data = {"num_attributes": ["No Matches", "Matches"], "num_samples": [no_match_count, match_count], "label": [no_match_count, match_count]}
fig = px.bar(bar_data, x="num_attributes", y="num_samples", text="label")
fig.update_layout(title="Number of samples with no matches", xaxis=dict(title=""), yaxis=dict(title="Count"))
fig.show()
# Out:
# <div>                            <div id="8c86ebe7-d06a-47a3-b2a5-82cdb9ae0bf3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8c86ebe7-d06a-47a3-b2a5-82cdb9ae0bf3")) {                    Plotly.newPlot(                        "8c86ebe7-d06a-47a3-b2a5-82cdb9ae0bf3",                        [{"alignmentgroup":"True","hovertemplate":"num_attributes=%{x}<br>num_samples=%{y}<br>label=%{text}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[3397.0,6603.0],"textposition":"auto","x":["No Matches","Matches"],"xaxis":"x","y":[3397,6603],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type": ...
