# %%
# %pip install --upgrade pandas
# %pip install --upgrade numpy
# %pip install --upgrade psycopg2-binary
# %pip install --upgrade owlready2
# Out:
# Requirement already satisfied: pandas in /home/ec2-user/workspace/.azure/lib/python3.9/site-packages (2.1.3)
# Requirement already satisfied: numpy<2,>=1.22.4 in /home/ec2-user/workspace/.azure/lib/python3.9/site-packages (from pandas) (1.26.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/ec2-user/workspace/.azure/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/ec2-user/workspace/.azure/lib/python3.9/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/ec2-user/workspace/.azure/lib/python3.9/site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in /home/ec2-user/workspace/.azure/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy in /home/ec2-user/workspace/.azure/lib/python3.9/site-packages (1.26.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: psycopg2-binary in /home/ec2-user/workspace/.azure/lib/python3.9/site-packages (2.9.9)
# Note: you may need to restart the kernel to use updated packages.
# Collecting owlready2
#   Downloading owlready2-0.45.tar.gz (27.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.3/27.3 MB 62.2 MB/s eta 0:00:0000:0100:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: owlready2
#   Building wheel for owlready2 (pyproject.toml) ... done
#   Created wheel for owlready2: filename=owlready2-0.45-cp39-cp39-linux_aarch64.whl size=24039811 sha256=8062c5081f3e0bae98e45d688d6b0858a88fdb960f9cfb468f3e70d2b7427eec
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/fd/3d/21/a3354f6877530e6efe0f645ca518f7fb07e9af5be7655b2355
# Successfully built owlready2
# Installing collected packages: owlready2
# Successfully installed owlready2-0.45
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ----
# # Loading BTO

# %%
from owlready2 import *

# Load the BTO ontology
onto_path.append('../data/ontologies/')
onto = get_ontology('http://purl.obolibrary.org/obo/bto.owl').load()

# classes dictionary: {class_name: class_label} 
#   - class_label is None if no label is found
classes = {c.name: c.label.first() for c in onto.classes()}
bto_objects = {c.name: c for c in onto.classes()}
bto_objects_rev = {c: c.name for c in onto.classes()}

# fetch children of all classes
bto_immediate_children = {c.name: set() for c in onto.classes()}

# generate the immediate children of each class
for bto_class in bto_objects_rev:
    for bto_parent_class in bto_class.is_a:
        if bto_parent_class == owl.Thing:
            # ignore the root class
            continue
        else:
            bto_class_type = type(bto_parent_class)
            if bto_class_type == ThingClass:
                bto_immediate_children[bto_parent_class.name].add(bto_class.name)
            elif bto_class_type == Restriction:
                # Restriction 2202 defines a derives_from/develops_from relationship
                bto_immediate_children[bto_parent_class.value.name].add(bto_class.name)

def get_all_children(bto_immediate_children, bto_class):
    '''
    helper function to get all children of a given class by recursing down the tree
    - base case for recursion when value for the class in bto_children is empty
    - recursive case for recursion when value for the class in bto_children is not empty
    - returns a set of all children of the given class
    '''
    if not bto_immediate_children[bto_class]:
        return set()
    else:
        children = set()
        for child in bto_immediate_children[bto_class]:
            children.add(child)
            children = children.union(get_all_children(bto_immediate_children, child))
        return children


bto_children = {c.name: set() for c in onto.classes()}

for bto_class, _ in bto_immediate_children.items():
    bto_children[bto_class] = get_all_children(bto_immediate_children, bto_class)
# Out:
# Warning: SQLite3 version 3.40.0 and 3.41.2 have huge performance regressions; please install version 3.41.1 or 3.42!

# %% [markdown]
# ----
# # Retrieve table from PostgreSQL
# - Want to store the `biosample_tissue` table in a pandas df
#     - Could also retrieve data from `tissue_map_rerun.csv` but use `biosample_tissue` to be consistent

# %%
import psycopg2
import pandas as pd

# database connection details
host = "serratus-aurora-20210406.cluster-ro-ccz9y6yshbls.us-east-1.rds.amazonaws.com"
database = "summary"
user = "public_reader"
password = "serratus"

try:
    conn = psycopg2.connect(host=host, database=database, user=user, password=password)
    print("Successfully connected to Serratus 🗻")

    # select all records from the biosample_tissue table
    query = """
        SELECT * FROM biosample_tissue;
    """
    print("Running query...")
    # load the data into a Pandas DataFrame
    tissue_df = pd.read_sql(query, conn)

    conn.close()
except Exception as e:
    print("Unable to connect to Serratus 🗻")
    print(e)
# Out:
# Successfully connected to Serratus 🗻
# Running query...
# /tmp/ipykernel_4199/246954172.py:20: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   tissue_df = pd.read_sql(query, conn)

# %%
tissue_df
# Out:
#             biosample_id      srs_id                             source  \
# 0         SAMEA104642966  ERS2244349                        description
# 1         SAMEA104642967  ERS2244350  biological material preprocessing
# 2         SAMEA104642967  ERS2244350  biological material preprocessing
# 3         SAMEA104642967  ERS2244350            plant anatomical entity
# 4         SAMEA104642967  ERS2244350  plant structure development stage
# ...                  ...         ...                                ...
# 21628226  SAMEA104642965  ERS2244348  biological material preprocessing
# 21628227  SAMEA104642965  ERS2244348            plant anatomical entity
# 21628228  SAMEA104642965  ERS2244348  plant structure development stage
# 21628229  SAMEA104642965  ERS2244348                        description
# 21628230  SAMEA104642966  ERS2244349  biological material preprocessing
#
#                                                        text    tissue  \
# 0         individual plants were grown in a greenhouse f...     plant
# 1         ssd derived material from a single seed of a s...       cap
# 2         ssd derived material from a single seed of a s...      seed
# 3                                                      leaf  seedling
# 4                                                  seedling      leaf
# ...                                                     ...       ...
# 21628226  ssd derived material from a single seed of a s...      seed
# 21628227                                               leaf  seedling
# 21628228                                           seedling      leaf
# 21628229  individual plants were grown in a greenhouse f...     plant
# 21628230  ssd derived material from a single seed of a s...       cap
#
#                bto_id
# 0         BTO_0001226
# 1         BTO_0000172
# 2         BTO_0001228
# 3         BTO_0000713
# 4         BTO_0001481
# ...               ...
# 21628226  BTO_0001228
# 21628227  BTO_0000713
# 21628228  BTO_0001481
# 21628229  BTO_0001226
# 21628230  BTO_0000172
#
# [21628231 rows x 6 columns]

# %% [markdown]
# ----
# # Retrieve random samples from dataframe
# - want 30000 random biosample ids from the `biosample_tissue` table
#     - dataframe will have more than 30000 rows since biosamples can have multiple tissues
#     - use `sample` function from pandas to get random samples
# - random samples may have false positives...

# %%
# get unique biosample ids
biosample_ids = list(tissue_df['biosample_id'].unique())
n = len(biosample_ids)
print(f"Found {n} unique biosample ids")
# Out:
# Found 17675425 unique biosample ids

# %%
# generate 30000 random biosample ids
import random
random.seed(42)
random_biosample_ids = random.sample(biosample_ids, 30000)

# %%
tissue_df_subset = tissue_df[tissue_df['biosample_id'].isin(random_biosample_ids)]
tissue_df_subset
# Out:
#             biosample_id      srs_id                             source  \
# 1513      SAMEA104643266  ERS2244649  biological material preprocessing
# 1514      SAMEA104643266  ERS2244649  biological material preprocessing
# 1515      SAMEA104643266  ERS2244649            plant anatomical entity
# 1516      SAMEA104643266  ERS2244649  plant structure development stage
# 1517      SAMEA104643266  ERS2244649                        description
# ...                  ...         ...                                ...
# 21625866  SAMEA104642498  ERS2243881  biological material preprocessing
# 21625867  SAMEA104642498  ERS2243881  biological material preprocessing
# 21625868  SAMEA104642498  ERS2243881            plant anatomical entity
# 21625869  SAMEA104642498  ERS2243881  plant structure development stage
# 21625870  SAMEA104642498  ERS2243881                        description
#
#                                                        text    tissue  \
# 1513      ssd derived material from a single seed of a s...       cap
# 1514      ssd derived material from a single seed of a s...      seed
# 1515                                                   leaf  seedling
# 1516                                               seedling      leaf
# 1517      individual plants were grown in a greenhouse f...     plant
# ...                                                     ...       ...
# 21625866  ssd derived material from a single seed of a s...       cap
# 21625867  ssd derived material from a single seed of a s...      seed
# 21625868                                               leaf  seedling
# 21625869                                           seedling      leaf
# 21625870  individual plants were grown in a greenhouse f...     plant
#
#                bto_id
# 1513      BTO_0000172
# 1514      BTO_0001228
# 1515      BTO_0000713
# 1516      BTO_0001481
# 1517      BTO_0001226
# ...               ...
# 21625866  BTO_0000172
# 21625867  BTO_0001228
# 21625868  BTO_0000713
# 21625869  BTO_0001481
# 21625870  BTO_0001226
#
# [36513 rows x 6 columns]

# %%
# export the subset of the tissue table to a csv file
tissue_df_subset.to_csv('tissue_subset.csv', index=False)
